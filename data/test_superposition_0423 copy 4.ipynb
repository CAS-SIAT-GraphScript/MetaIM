# %%
import torch
import sys
sys.path.append('/home/zjy/project/MetaIM')
pwd = '/home/zjy/project/MetaIM/data'
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %%
from torch_geometric.datasets import Planetoid

cora_dataset = Planetoid(root=pwd+'/cora', name='cora')
data = cora_dataset[0]
edge_index = data.edge_index

# %%
import numpy as np
individual_infection_path = pwd+'/for_meta/cora_individual_infection_sir_200_sample_500.npy'
seeds_infection_path = pwd+'/for_meta/cora_seed_infection_sir_200_sample_500.npy'

individual_infection = np.load(individual_infection_path)
seeds_infection = np.load(seeds_infection_path)
individual_infection.shape,seeds_infection.shape
# Out:
# ((2708, 2708), (1000, 2, 2708))

# %%
import torch
from torch_geometric.utils import to_scipy_sparse_matrix
import scipy.sparse as sp

# 转换为 scipy 稀疏矩阵
adj = to_scipy_sparse_matrix(edge_index)

adj = torch.Tensor(adj.toarray()).to_sparse()
adj = adj.to(device)

# %%
def edge_index_to_adj(edge_index, num_nodes):
    adj = torch.zeros((num_nodes, num_nodes))
    for i in range(edge_index.size(1)):
        start_node = edge_index[0, i]
        end_node = edge_index[1, i]
        adj[start_node, end_node] = 1
        adj[end_node, start_node] = 1  # 如果是有向图，可以不需要这行
    return adj

adj_n = edge_index_to_adj(edge_index, individual_infection.shape[0])

# %%
def graph_laplacian_embedding(adjacency_matrix, num_dimensions):
    # 将邻接矩阵转换为PyTorch张量
    adjacency_matrix = torch.tensor(adjacency_matrix, dtype=torch.float32)
    
    # Step 1: 计算度矩阵
    degree_matrix = torch.diag(adjacency_matrix.sum(dim=1))
    
    # Step 2: 计算拉普拉斯矩阵
    laplacian_matrix = degree_matrix - adjacency_matrix
    
    # Step 3: 计算拉普拉斯矩阵的特征向量和特征值
    eigenvalues, eigenvectors = torch.linalg.eigh(laplacian_matrix)
    
    # Step 4: 选择低维表示
    # 取特征值非零的前 num_dimensions 个特征向量作为嵌入结果
    embedding = eigenvectors[:, :num_dimensions]
    
    return embedding

# %%
laplace_emb = graph_laplacian_embedding(adj_n, 64)
laplace_emb = laplace_emb.to(device)
# Out:
# /tmp/ipykernel_2522300/1279567966.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   adjacency_matrix = torch.tensor(adjacency_matrix, dtype=torch.float32)

# %%
seed_num = int(seeds_infection[0][0].sum())

# %%
from torch.utils.data import Dataset, DataLoader, random_split


class CustomDataset(Dataset):
    def __init__(self, individual_infection,seeds_infection, seed_num):
        self.individual_infection = individual_infection
        self.seeds_infection = seeds_infection
        self.feat_shape = (len(individual_infection), seed_num)

    def __len__(self):
        return len(self.seeds_infection)

    def __getitem__(self, idx):
        seeds= np.nonzero(self.seeds_infection[idx][0])[0]
        
        feature = torch.zeros(self.feat_shape[0],self.feat_shape[1])
        for i in range(len(seeds)):
            seed_i_infection = torch.tensor(self.individual_infection[seeds[i]])
            feature[:, i] = seed_i_infection
            
        label = self.seeds_infection[idx][1]
        
        return self.seeds_infection[idx][0], feature, label

dataset = CustomDataset(individual_infection, seeds_infection, seed_num)

# %%
# 定义划分比例
train_ratio = 0.8
test_ratio = 0.2

# 划分数据集
train_dataset, test_dataset = random_split(dataset, [int(len(dataset)*train_ratio), int(len(dataset)*test_ratio)])

train_batch_size = 32
test_batch_size = 2

# 创建数据加载器
train_loader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True, drop_last=False)
test_loader = DataLoader(test_dataset, batch_size=test_batch_size, shuffle=False)

# %%
import torch
import torch.nn as nn

from torch_geometric.nn import GATConv
from torch.optim import Adam, SGD
import torch.nn.functional as F

class GAT(nn.Module):
    def __init__(self, feat_dim, latent_dim, hidden_channels, out_channels, num_heads):
        super(GAT, self).__init__()
        self.linear1 = nn.Linear(latent_dim, 128)
        self.conv1 = GATConv(feat_dim, hidden_channels, heads=num_heads)
        self.conv2 = GATConv(hidden_channels * num_heads, hidden_channels * num_heads, heads=1)
        self.linear2 = nn.Linear(hidden_channels * num_heads+128, 1)

    def forward(self, feat_i, x_i, edge_index):
        x = self.conv1(feat_i, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv2(x, edge_index)
        
        latten = F.relu(self.linear1(x_i))
        x =  torch.cat((x, latten), dim=-1)
        x = self.linear2(x)
        return F.relu(x)

# %%
feat_num = seed_num
latent_dim = 64

forward_model = GAT(feat_num,latent_dim, 512, 1, 4)

optimizer = Adam([{'params': forward_model.parameters()}], 
                 lr=0.001)

adj = adj.to(device)
forward_model = forward_model.to(device)
forward_model.train()
# Out:
# GAT(
#   (linear1): Linear(in_features=64, out_features=128, bias=True)
#   (conv1): GATConv(135, 512, heads=4)
#   (conv2): GATConv(2048, 2048, heads=1)
#   (linear2): Linear(in_features=2176, out_features=1, bias=True)
# )

# %%
import torch

# 假设 A 和 emb 是随机生成的示例张量
A = torch.randint(0, 2, (2700,)).double()
emb = torch.randn(2700, 64).double()

# 将emb进行转置
emb_transpose = emb

# 计算A与emb的转置的乘积
result = torch.matmul(A, emb_transpose)

# 打印结果
print("Result:")
print(result)
# Out:
# Result:
# tensor([-41.1103,  13.6770,  57.3309,  13.6348,   0.7261, -34.0031, -65.9632,
#         -16.3272,  20.3972, -38.0744, -39.8438, -55.5805, -19.1470,  43.8956,
#          47.9416,  -7.9666, -36.6753, -36.7269,  27.8084,   5.2519, -29.6941,
#         -40.0241, -12.2777,  45.2819,  14.2243, -23.7032,  30.9957, -19.4507,
#         -35.1556,  39.8545,   1.3376, -21.7191,  13.2834, -19.3445, -47.2657,
#         -18.1323,  13.0394, -10.4747, -29.0267, -16.0358, -11.0079,  39.8639,
#          26.4519, -22.0124,  29.3506, 115.8004,  52.6481, -15.6346,  -6.8232,
#         -13.7503,   2.6397, -24.4359, -28.6654,   6.1546, -19.2340,  54.5242,
#           2.2569, -10.7268, -31.3181,  31.2496, -35.7503,  -3.7822, -65.6443,
#          37.7439], dtype=torch.float64)

# %%
edge_index = edge_index.to(device)
top_num = 500
# encoder = vae_model.Encoder

for epoch in range(2000):

    total_overall = 0
    forward_loss = 0

    mean_train_accuracy = 0
    for batch_idx, x_feature_label in enumerate(train_loader):  
        x =  x_feature_label[0].to(device)     
        features = x_feature_label[1].to(device)
        labels = x_feature_label[2].to(device)
        optimizer.zero_grad()
        
        loss = 0
        train_accuracy = 0
        for i, feat_i in enumerate(features):
            
            # log_sum = torch.sum(torch.log(1 - x_i), dim=1, keepdim=True)
            # feat = 1 - torch.exp(log_sum)
            x_i = x[i]
            x_i = torch.matmul(x_i, laplace_emb)
            
            
            # x_i = encoder(x_i).detach()
            # x_i = torch.rand(latent_dim).to(device)
            # x_i = normalize_features(x_i)
            x_i = x_i.expand(features.shape[1], -1)
            # final_feat_i =  torch.cat((feat_i, x_i), dim=1)
            
            
            y_i = labels[i]
            y_hat = forward_model(feat_i, x_i, edge_index)
            _, top_indices_true = torch.topk(y_i.clone(), top_num)
            label_2 = torch.zeros(y_i.shape).to(device)
            label_2[top_indices_true] = 1
            
            _, top_indices_predict = torch.topk(y_hat.clone().squeeze(-1), top_num)
            
            # 将张量数组转换为Python列表
            list1 = top_indices_true.tolist()
            list_pre = top_indices_predict.tolist()

            # 使用集合操作找到交集
            intersection = list(set(list1) & set(list_pre))
            accuracy_i = len(intersection) / top_num       
            train_accuracy += accuracy_i 

            forward_loss = 0.5*F.mse_loss(y_hat.squeeze(-1), y_i, reduction='sum') + F.mse_loss(y_hat.squeeze(-1), label_2, reduction='sum')    
            loss += forward_loss    
        
        total_overall += loss.item()    
        train_accuracy /= len(features)
        mean_train_accuracy = train_accuracy
        loss = loss/features.size(0)
        loss.backward()
        optimizer.step()
        # for p in forward_model.parameters():
        #     p.data.clamp_(min=0)
        
        
    print("Epoch: {}".format(epoch+1), 
        "\tTotal: {:.4f}".format(total_overall / train_batch_size),
        "\tMean_train_accuracy: {:.4f}".format(mean_train_accuracy),
        )  
    
    mean_accuracy = 0
    mean_accuracy_sum = 0

    
    for batch_idx, x_feature_label in enumerate(test_loader):  
        x =  x_feature_label[0].to(device)
        features = x_feature_label[1].to(device)
        labels = x_feature_label[2].to(device)
        
        accuracy = 0
        accuracy_sum = 0
        
        for i, feat_i in enumerate(features):
            # x_i = x[i]
            # x_i = encoder(x_i).detach()
            # x_i = normalize_features(x_i)
            x_i = x[i]
            x_i = torch.matmul(x_i, laplace_emb)
            x_i = x_i.expand(features.shape[1], -1)
            # final_feat_i =  torch.cat((feat_i, x_i), dim=1)
            y_i = labels[i]
            _, top_indices_true = torch.topk(y_i, top_num)
            
            y_hat = forward_model(feat_i, x_i, edge_index)
            
            _, top_indices_predict = torch.topk(y_hat.squeeze(-1), top_num)
            
            sum_pre = torch.sum(feat_i, dim=1, keepdim=True)
            _, top_indices_sum = torch.topk(sum_pre.squeeze(-1), top_num)
            
            # 将张量数组转换为Python列表
            list1 = top_indices_true.tolist()
            list_pre = top_indices_predict.tolist()
            
            list_sum = top_indices_sum.tolist()

            # 使用集合操作找到交集
            intersection = list(set(list1) & set(list_pre))
            
            intersection_sum = list(set(list1) & set(list_sum))
            
            accuracy_i = len(intersection) / top_num       
            accuracy += accuracy_i 
            accuracy_sum += len(intersection_sum) / top_num  
        accuracy /= test_batch_size
        accuracy_sum/= test_batch_size
        mean_accuracy = accuracy
        mean_accuracy_sum = accuracy_sum
        break
    
    print(
        "\tMean_test_accuracy: {:.4f}".format(mean_accuracy),
        "\tMean_test_accuracy_sum: {:.4f}".format(mean_accuracy_sum)
        )
# Out:
# Epoch: 1 	Total: 10888.2294 	Mean_train_accuracy: 0.5281
# 	Mean_test_accuracy: 0.5780 	Mean_test_accuracy_sum: 0.5560
# Epoch: 2 	Total: 8698.3886 	Mean_train_accuracy: 0.5928
# 	Mean_test_accuracy: 0.6320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 3 	Total: 8324.8123 	Mean_train_accuracy: 0.6232
# 	Mean_test_accuracy: 0.6440 	Mean_test_accuracy_sum: 0.5560
# Epoch: 4 	Total: 8071.5876 	Mean_train_accuracy: 0.6322
# 	Mean_test_accuracy: 0.6420 	Mean_test_accuracy_sum: 0.5560
# Epoch: 5 	Total: 8044.2961 	Mean_train_accuracy: 0.6346
# 	Mean_test_accuracy: 0.6580 	Mean_test_accuracy_sum: 0.5560
# Epoch: 6 	Total: 7766.9346 	Mean_train_accuracy: 0.6466
# 	Mean_test_accuracy: 0.6760 	Mean_test_accuracy_sum: 0.5560
# Epoch: 7 	Total: 7569.1193 	Mean_train_accuracy: 0.6496
# 	Mean_test_accuracy: 0.6740 	Mean_test_accuracy_sum: 0.5560
# Epoch: 8 	Total: 7457.2259 	Mean_train_accuracy: 0.6609
# 	Mean_test_accuracy: 0.6800 	Mean_test_accuracy_sum: 0.5560
# Epoch: 9 	Total: 7299.6323 	Mean_train_accuracy: 0.6573
# 	Mean_test_accuracy: 0.6900 	Mean_test_accuracy_sum: 0.5560
# Epoch: 10 	Total: 7161.3314 	Mean_train_accuracy: 0.6596
# 	Mean_test_accuracy: 0.6890 	Mean_test_accuracy_sum: 0.5560
# Epoch: 11 	Total: 7069.6323 	Mean_train_accuracy: 0.6625
# 	Mean_test_accuracy: 0.7060 	Mean_test_accuracy_sum: 0.5560
# Epoch: 12 	Total: 7032.2397 	Mean_train_accuracy: 0.6699
# 	Mean_test_accuracy: 0.6990 	Mean_test_accuracy_sum: 0.5560
# Epoch: 13 	Total: 6890.0433 	Mean_train_accuracy: 0.6681
# 	Mean_test_accuracy: 0.7000 	Mean_test_accuracy_sum: 0.5560
# Epoch: 14 	Total: 6832.6990 	Mean_train_accuracy: 0.6721
# 	Mean_test_accuracy: 0.7000 	Mean_test_accuracy_sum: 0.5560
# Epoch: 15 	Total: 6775.4887 	Mean_train_accuracy: 0.6746
# 	Mean_test_accuracy: 0.7070 	Mean_test_accuracy_sum: 0.5560
# Epoch: 16 	Total: 6736.2306 	Mean_train_accuracy: 0.6784
# 	Mean_test_accuracy: 0.7120 	Mean_test_accuracy_sum: 0.5560
# Epoch: 17 	Total: 6710.8259 	Mean_train_accuracy: 0.6734
# 	Mean_test_accuracy: 0.7090 	Mean_test_accuracy_sum: 0.5560
# Epoch: 18 	Total: 6644.8763 	Mean_train_accuracy: 0.6917
# 	Mean_test_accuracy: 0.7100 	Mean_test_accuracy_sum: 0.5560
# Epoch: 19 	Total: 6648.1737 	Mean_train_accuracy: 0.6812
# 	Mean_test_accuracy: 0.7100 	Mean_test_accuracy_sum: 0.5560
# Epoch: 20 	Total: 6584.7527 	Mean_train_accuracy: 0.6893
# 	Mean_test_accuracy: 0.7210 	Mean_test_accuracy_sum: 0.5560
# Epoch: 21 	Total: 6573.9384 	Mean_train_accuracy: 0.6906
# 	Mean_test_accuracy: 0.7120 	Mean_test_accuracy_sum: 0.5560
# Epoch: 22 	Total: 6580.6839 	Mean_train_accuracy: 0.6909
# 	Mean_test_accuracy: 0.7150 	Mean_test_accuracy_sum: 0.5560
# Epoch: 23 	Total: 6524.7861 	Mean_train_accuracy: 0.6883
# 	Mean_test_accuracy: 0.7240 	Mean_test_accuracy_sum: 0.5560
# Epoch: 24 	Total: 6491.1531 	Mean_train_accuracy: 0.6921
# 	Mean_test_accuracy: 0.7120 	Mean_test_accuracy_sum: 0.5560
# Epoch: 25 	Total: 6444.7284 	Mean_train_accuracy: 0.6938
# 	Mean_test_accuracy: 0.7230 	Mean_test_accuracy_sum: 0.5560
# Epoch: 26 	Total: 6475.6373 	Mean_train_accuracy: 0.6966
# 	Mean_test_accuracy: 0.7220 	Mean_test_accuracy_sum: 0.5560
# Epoch: 27 	Total: 6426.3573 	Mean_train_accuracy: 0.6986
# 	Mean_test_accuracy: 0.7280 	Mean_test_accuracy_sum: 0.5560
# Epoch: 28 	Total: 6452.8377 	Mean_train_accuracy: 0.6901
# 	Mean_test_accuracy: 0.7210 	Mean_test_accuracy_sum: 0.5560
# Epoch: 29 	Total: 6400.1452 	Mean_train_accuracy: 0.7069
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.5560
# Epoch: 30 	Total: 6301.7100 	Mean_train_accuracy: 0.7161
# 	Mean_test_accuracy: 0.7330 	Mean_test_accuracy_sum: 0.5560
# Epoch: 31 	Total: 6322.8212 	Mean_train_accuracy: 0.7081
# 	Mean_test_accuracy: 0.7410 	Mean_test_accuracy_sum: 0.5560
# Epoch: 32 	Total: 6329.6165 	Mean_train_accuracy: 0.7171
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.5560
# Epoch: 33 	Total: 6269.1275 	Mean_train_accuracy: 0.7222
# 	Mean_test_accuracy: 0.7390 	Mean_test_accuracy_sum: 0.5560
# Epoch: 34 	Total: 6273.3549 	Mean_train_accuracy: 0.7334
# 	Mean_test_accuracy: 0.7460 	Mean_test_accuracy_sum: 0.5560
# Epoch: 35 	Total: 6251.7246 	Mean_train_accuracy: 0.7248
# 	Mean_test_accuracy: 0.7390 	Mean_test_accuracy_sum: 0.5560
# Epoch: 36 	Total: 6229.6362 	Mean_train_accuracy: 0.7231
# 	Mean_test_accuracy: 0.7560 	Mean_test_accuracy_sum: 0.5560
# Epoch: 37 	Total: 6199.0472 	Mean_train_accuracy: 0.7297
# 	Mean_test_accuracy: 0.7370 	Mean_test_accuracy_sum: 0.5560
# Epoch: 38 	Total: 6201.9074 	Mean_train_accuracy: 0.7161
# 	Mean_test_accuracy: 0.7460 	Mean_test_accuracy_sum: 0.5560
# Epoch: 39 	Total: 6211.3783 	Mean_train_accuracy: 0.7231
# 	Mean_test_accuracy: 0.7460 	Mean_test_accuracy_sum: 0.5560
# Epoch: 40 	Total: 6260.4213 	Mean_train_accuracy: 0.7221
# 	Mean_test_accuracy: 0.7450 	Mean_test_accuracy_sum: 0.5560
# Epoch: 41 	Total: 6203.3170 	Mean_train_accuracy: 0.7224
# 	Mean_test_accuracy: 0.7420 	Mean_test_accuracy_sum: 0.5560
# Epoch: 42 	Total: 6138.7953 	Mean_train_accuracy: 0.7302
# 	Mean_test_accuracy: 0.7430 	Mean_test_accuracy_sum: 0.5560
# Epoch: 43 	Total: 6096.8686 	Mean_train_accuracy: 0.7291
# 	Mean_test_accuracy: 0.7460 	Mean_test_accuracy_sum: 0.5560
# Epoch: 44 	Total: 6247.5010 	Mean_train_accuracy: 0.7105
# 	Mean_test_accuracy: 0.7290 	Mean_test_accuracy_sum: 0.5560
# Epoch: 45 	Total: 6211.8379 	Mean_train_accuracy: 0.7343
# 	Mean_test_accuracy: 0.7390 	Mean_test_accuracy_sum: 0.5560
# Epoch: 46 	Total: 6094.7134 	Mean_train_accuracy: 0.7369
# 	Mean_test_accuracy: 0.7580 	Mean_test_accuracy_sum: 0.5560
# Epoch: 47 	Total: 6061.5457 	Mean_train_accuracy: 0.7369
# 	Mean_test_accuracy: 0.7520 	Mean_test_accuracy_sum: 0.5560
# Epoch: 48 	Total: 6072.9036 	Mean_train_accuracy: 0.7321
# 	Mean_test_accuracy: 0.7490 	Mean_test_accuracy_sum: 0.5560
# Epoch: 49 	Total: 6138.9874 	Mean_train_accuracy: 0.7205
# 	Mean_test_accuracy: 0.7410 	Mean_test_accuracy_sum: 0.5560
# Epoch: 50 	Total: 6342.5310 	Mean_train_accuracy: 0.7372
# 	Mean_test_accuracy: 0.7480 	Mean_test_accuracy_sum: 0.5560
# Epoch: 51 	Total: 6071.9592 	Mean_train_accuracy: 0.7458
# 	Mean_test_accuracy: 0.7580 	Mean_test_accuracy_sum: 0.5560
# Epoch: 52 	Total: 6044.5664 	Mean_train_accuracy: 0.7417
# 	Mean_test_accuracy: 0.7530 	Mean_test_accuracy_sum: 0.5560
# Epoch: 53 	Total: 6061.1136 	Mean_train_accuracy: 0.7472
# 	Mean_test_accuracy: 0.7280 	Mean_test_accuracy_sum: 0.5560
# Epoch: 54 	Total: 6834.4406 	Mean_train_accuracy: 0.7285
# 	Mean_test_accuracy: 0.7540 	Mean_test_accuracy_sum: 0.5560
# Epoch: 55 	Total: 6179.6889 	Mean_train_accuracy: 0.7461
# 	Mean_test_accuracy: 0.7460 	Mean_test_accuracy_sum: 0.5560
# Epoch: 56 	Total: 6017.9252 	Mean_train_accuracy: 0.7521
# 	Mean_test_accuracy: 0.7670 	Mean_test_accuracy_sum: 0.5560
# Epoch: 57 	Total: 5959.0674 	Mean_train_accuracy: 0.7489
# 	Mean_test_accuracy: 0.7730 	Mean_test_accuracy_sum: 0.5560
# Epoch: 58 	Total: 5938.7416 	Mean_train_accuracy: 0.7553
# 	Mean_test_accuracy: 0.7650 	Mean_test_accuracy_sum: 0.5560
# Epoch: 59 	Total: 5945.8812 	Mean_train_accuracy: 0.7574
# 	Mean_test_accuracy: 0.7710 	Mean_test_accuracy_sum: 0.5560
# Epoch: 60 	Total: 5944.6808 	Mean_train_accuracy: 0.7613
# 	Mean_test_accuracy: 0.7630 	Mean_test_accuracy_sum: 0.5560
# Epoch: 61 	Total: 5915.2515 	Mean_train_accuracy: 0.7696
# 	Mean_test_accuracy: 0.7720 	Mean_test_accuracy_sum: 0.5560
# Epoch: 62 	Total: 5889.4583 	Mean_train_accuracy: 0.7661
# 	Mean_test_accuracy: 0.7760 	Mean_test_accuracy_sum: 0.5560
# Epoch: 63 	Total: 5914.2985 	Mean_train_accuracy: 0.7721
# 	Mean_test_accuracy: 0.7610 	Mean_test_accuracy_sum: 0.5560
# Epoch: 64 	Total: 5921.7710 	Mean_train_accuracy: 0.7708
# 	Mean_test_accuracy: 0.7770 	Mean_test_accuracy_sum: 0.5560
# Epoch: 65 	Total: 5784.4148 	Mean_train_accuracy: 0.7679
# 	Mean_test_accuracy: 0.7690 	Mean_test_accuracy_sum: 0.5560
# Epoch: 66 	Total: 5966.0136 	Mean_train_accuracy: 0.7743
# 	Mean_test_accuracy: 0.7770 	Mean_test_accuracy_sum: 0.5560
# Epoch: 67 	Total: 5778.6133 	Mean_train_accuracy: 0.7778
# 	Mean_test_accuracy: 0.7790 	Mean_test_accuracy_sum: 0.5560
# Epoch: 68 	Total: 5933.0304 	Mean_train_accuracy: 0.7501
# 	Mean_test_accuracy: 0.7640 	Mean_test_accuracy_sum: 0.5560
# Epoch: 69 	Total: 6047.6931 	Mean_train_accuracy: 0.7704
# 	Mean_test_accuracy: 0.7660 	Mean_test_accuracy_sum: 0.5560
# Epoch: 70 	Total: 5763.7500 	Mean_train_accuracy: 0.7801
# 	Mean_test_accuracy: 0.7800 	Mean_test_accuracy_sum: 0.5560
# Epoch: 71 	Total: 5786.3857 	Mean_train_accuracy: 0.7719
# 	Mean_test_accuracy: 0.7790 	Mean_test_accuracy_sum: 0.5560
# Epoch: 72 	Total: 5898.3342 	Mean_train_accuracy: 0.7734
# 	Mean_test_accuracy: 0.7710 	Mean_test_accuracy_sum: 0.5560
# Epoch: 73 	Total: 5684.2015 	Mean_train_accuracy: 0.7813
# 	Mean_test_accuracy: 0.7870 	Mean_test_accuracy_sum: 0.5560
# Epoch: 74 	Total: 5687.8431 	Mean_train_accuracy: 0.7785
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.5560
# Epoch: 75 	Total: 5697.8552 	Mean_train_accuracy: 0.7764
# 	Mean_test_accuracy: 0.7810 	Mean_test_accuracy_sum: 0.5560
# Epoch: 76 	Total: 5674.7739 	Mean_train_accuracy: 0.7856
# 	Mean_test_accuracy: 0.7710 	Mean_test_accuracy_sum: 0.5560
# Epoch: 77 	Total: 5630.0760 	Mean_train_accuracy: 0.7859
# 	Mean_test_accuracy: 0.7790 	Mean_test_accuracy_sum: 0.5560
# Epoch: 78 	Total: 5830.2536 	Mean_train_accuracy: 0.7775
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.5560
# Epoch: 79 	Total: 5748.7696 	Mean_train_accuracy: 0.7860
# 	Mean_test_accuracy: 0.7790 	Mean_test_accuracy_sum: 0.5560
# Epoch: 80 	Total: 5666.9572 	Mean_train_accuracy: 0.7781
# 	Mean_test_accuracy: 0.7880 	Mean_test_accuracy_sum: 0.5560
# Epoch: 81 	Total: 5729.2167 	Mean_train_accuracy: 0.7767
# 	Mean_test_accuracy: 0.7790 	Mean_test_accuracy_sum: 0.5560
# Epoch: 82 	Total: 5584.4939 	Mean_train_accuracy: 0.7840
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.5560
# Epoch: 83 	Total: 5614.6545 	Mean_train_accuracy: 0.7863
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.5560
# Epoch: 84 	Total: 5590.9293 	Mean_train_accuracy: 0.7843
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.5560
# Epoch: 85 	Total: 5597.8430 	Mean_train_accuracy: 0.7891
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.5560
# Epoch: 86 	Total: 5573.8031 	Mean_train_accuracy: 0.7885
# 	Mean_test_accuracy: 0.7690 	Mean_test_accuracy_sum: 0.5560
# Epoch: 87 	Total: 5600.4294 	Mean_train_accuracy: 0.7845
# 	Mean_test_accuracy: 0.7880 	Mean_test_accuracy_sum: 0.5560
# Epoch: 88 	Total: 5549.3791 	Mean_train_accuracy: 0.7895
# 	Mean_test_accuracy: 0.7780 	Mean_test_accuracy_sum: 0.5560
# Epoch: 89 	Total: 5525.9235 	Mean_train_accuracy: 0.7873
# 	Mean_test_accuracy: 0.7930 	Mean_test_accuracy_sum: 0.5560
# Epoch: 90 	Total: 5733.7225 	Mean_train_accuracy: 0.7833
# 	Mean_test_accuracy: 0.7810 	Mean_test_accuracy_sum: 0.5560
# Epoch: 91 	Total: 5594.9270 	Mean_train_accuracy: 0.7918
# 	Mean_test_accuracy: 0.7760 	Mean_test_accuracy_sum: 0.5560
# Epoch: 92 	Total: 5514.2793 	Mean_train_accuracy: 0.7949
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.5560
# Epoch: 93 	Total: 5653.1108 	Mean_train_accuracy: 0.7854
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.5560
# Epoch: 94 	Total: 5614.6898 	Mean_train_accuracy: 0.7820
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.5560
# Epoch: 95 	Total: 5609.6804 	Mean_train_accuracy: 0.7914
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.5560
# Epoch: 96 	Total: 5475.8624 	Mean_train_accuracy: 0.7893
# 	Mean_test_accuracy: 0.7990 	Mean_test_accuracy_sum: 0.5560
# Epoch: 97 	Total: 5448.1697 	Mean_train_accuracy: 0.7911
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.5560
# Epoch: 98 	Total: 5473.7049 	Mean_train_accuracy: 0.7885
# 	Mean_test_accuracy: 0.7810 	Mean_test_accuracy_sum: 0.5560
# Epoch: 99 	Total: 5636.6379 	Mean_train_accuracy: 0.7899
# 	Mean_test_accuracy: 0.7920 	Mean_test_accuracy_sum: 0.5560
# Epoch: 100 	Total: 5441.9329 	Mean_train_accuracy: 0.7963
# 	Mean_test_accuracy: 0.7990 	Mean_test_accuracy_sum: 0.5560
# Epoch: 101 	Total: 5414.0460 	Mean_train_accuracy: 0.7963
# 	Mean_test_accuracy: 0.7990 	Mean_test_accuracy_sum: 0.5560
# Epoch: 102 	Total: 5405.1188 	Mean_train_accuracy: 0.8027
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.5560
# Epoch: 103 	Total: 5674.0402 	Mean_train_accuracy: 0.7877
# 	Mean_test_accuracy: 0.7810 	Mean_test_accuracy_sum: 0.5560
# Epoch: 104 	Total: 5523.1623 	Mean_train_accuracy: 0.7996
# 	Mean_test_accuracy: 0.7880 	Mean_test_accuracy_sum: 0.5560
# Epoch: 105 	Total: 5385.6383 	Mean_train_accuracy: 0.8005
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.5560
# Epoch: 106 	Total: 5380.6844 	Mean_train_accuracy: 0.8005
# 	Mean_test_accuracy: 0.7930 	Mean_test_accuracy_sum: 0.5560
# Epoch: 107 	Total: 5371.5873 	Mean_train_accuracy: 0.8007
# 	Mean_test_accuracy: 0.7930 	Mean_test_accuracy_sum: 0.5560
# Epoch: 108 	Total: 5365.5014 	Mean_train_accuracy: 0.8023
# 	Mean_test_accuracy: 0.7960 	Mean_test_accuracy_sum: 0.5560
# Epoch: 109 	Total: 5332.0786 	Mean_train_accuracy: 0.8029
# 	Mean_test_accuracy: 0.7920 	Mean_test_accuracy_sum: 0.5560
# Epoch: 110 	Total: 5373.7795 	Mean_train_accuracy: 0.8058
# 	Mean_test_accuracy: 0.7960 	Mean_test_accuracy_sum: 0.5560
# Epoch: 111 	Total: 5376.6030 	Mean_train_accuracy: 0.7981
# 	Mean_test_accuracy: 0.7990 	Mean_test_accuracy_sum: 0.5560
# Epoch: 112 	Total: 5355.7099 	Mean_train_accuracy: 0.7959
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.5560
# Epoch: 113 	Total: 5321.6545 	Mean_train_accuracy: 0.8012
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.5560
# Epoch: 114 	Total: 5302.2872 	Mean_train_accuracy: 0.8068
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.5560
# Epoch: 115 	Total: 5364.3323 	Mean_train_accuracy: 0.8006
# 	Mean_test_accuracy: 0.7970 	Mean_test_accuracy_sum: 0.5560
# Epoch: 116 	Total: 5344.9407 	Mean_train_accuracy: 0.8051
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.5560
# Epoch: 117 	Total: 5397.1725 	Mean_train_accuracy: 0.8017
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.5560
# Epoch: 118 	Total: 5605.2593 	Mean_train_accuracy: 0.7887
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.5560
# Epoch: 119 	Total: 5323.7335 	Mean_train_accuracy: 0.8041
# 	Mean_test_accuracy: 0.8000 	Mean_test_accuracy_sum: 0.5560
# Epoch: 120 	Total: 5296.5220 	Mean_train_accuracy: 0.8030
# 	Mean_test_accuracy: 0.7960 	Mean_test_accuracy_sum: 0.5560
# Epoch: 121 	Total: 5296.3758 	Mean_train_accuracy: 0.8012
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.5560
# Epoch: 122 	Total: 5295.2753 	Mean_train_accuracy: 0.8080
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.5560
# Epoch: 123 	Total: 5290.5260 	Mean_train_accuracy: 0.7925
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.5560
# Epoch: 124 	Total: 5273.3692 	Mean_train_accuracy: 0.8065
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.5560
# Epoch: 125 	Total: 5342.0827 	Mean_train_accuracy: 0.7968
# 	Mean_test_accuracy: 0.7950 	Mean_test_accuracy_sum: 0.5560
# Epoch: 126 	Total: 5287.7135 	Mean_train_accuracy: 0.8035
# 	Mean_test_accuracy: 0.8180 	Mean_test_accuracy_sum: 0.5560
# Epoch: 127 	Total: 5616.1657 	Mean_train_accuracy: 0.7918
# 	Mean_test_accuracy: 0.7920 	Mean_test_accuracy_sum: 0.5560
# Epoch: 128 	Total: 5446.5441 	Mean_train_accuracy: 0.8026
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.5560
# Epoch: 129 	Total: 5237.6592 	Mean_train_accuracy: 0.8025
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.5560
# Epoch: 130 	Total: 5241.6464 	Mean_train_accuracy: 0.8056
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.5560
# Epoch: 131 	Total: 5211.4005 	Mean_train_accuracy: 0.8059
# 	Mean_test_accuracy: 0.8010 	Mean_test_accuracy_sum: 0.5560
# Epoch: 132 	Total: 5333.9415 	Mean_train_accuracy: 0.7971
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.5560
# Epoch: 133 	Total: 5412.0861 	Mean_train_accuracy: 0.8075
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.5560
# Epoch: 134 	Total: 5210.4196 	Mean_train_accuracy: 0.8046
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.5560
# Epoch: 135 	Total: 5189.5039 	Mean_train_accuracy: 0.8111
# 	Mean_test_accuracy: 0.7990 	Mean_test_accuracy_sum: 0.5560
# Epoch: 136 	Total: 5255.1082 	Mean_train_accuracy: 0.8076
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.5560
# Epoch: 137 	Total: 5442.9447 	Mean_train_accuracy: 0.7921
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.5560
# Epoch: 138 	Total: 5226.5660 	Mean_train_accuracy: 0.8070
# 	Mean_test_accuracy: 0.8020 	Mean_test_accuracy_sum: 0.5560
# Epoch: 139 	Total: 5359.7237 	Mean_train_accuracy: 0.7905
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.5560
# Epoch: 140 	Total: 5370.5492 	Mean_train_accuracy: 0.8089
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.5560
# Epoch: 141 	Total: 5172.8681 	Mean_train_accuracy: 0.8124
# 	Mean_test_accuracy: 0.7990 	Mean_test_accuracy_sum: 0.5560
# Epoch: 142 	Total: 5226.4880 	Mean_train_accuracy: 0.8015
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.5560
# Epoch: 143 	Total: 5318.2689 	Mean_train_accuracy: 0.7921
# 	Mean_test_accuracy: 0.7970 	Mean_test_accuracy_sum: 0.5560
# Epoch: 144 	Total: 5291.9733 	Mean_train_accuracy: 0.8064
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.5560
# Epoch: 145 	Total: 5259.7310 	Mean_train_accuracy: 0.7983
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.5560
# Epoch: 146 	Total: 5254.0900 	Mean_train_accuracy: 0.8126
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.5560
# Epoch: 147 	Total: 5166.4099 	Mean_train_accuracy: 0.8051
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.5560
# Epoch: 148 	Total: 5177.5172 	Mean_train_accuracy: 0.7969
# 	Mean_test_accuracy: 0.8160 	Mean_test_accuracy_sum: 0.5560
# Epoch: 149 	Total: 5186.4075 	Mean_train_accuracy: 0.8088
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.5560
# Epoch: 150 	Total: 5165.9055 	Mean_train_accuracy: 0.8107
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.5560
# Epoch: 151 	Total: 5132.5856 	Mean_train_accuracy: 0.8112
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.5560
# Epoch: 152 	Total: 5127.3015 	Mean_train_accuracy: 0.8167
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.5560
# Epoch: 153 	Total: 5350.8315 	Mean_train_accuracy: 0.7964
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.5560
# Epoch: 154 	Total: 5276.2656 	Mean_train_accuracy: 0.8058
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.5560
# Epoch: 155 	Total: 5186.4700 	Mean_train_accuracy: 0.8059
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.5560
# Epoch: 156 	Total: 5309.3701 	Mean_train_accuracy: 0.8041
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.5560
# Epoch: 157 	Total: 5202.5949 	Mean_train_accuracy: 0.8010
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.5560
# Epoch: 158 	Total: 5136.5352 	Mean_train_accuracy: 0.8094
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.5560
# Epoch: 159 	Total: 5108.5921 	Mean_train_accuracy: 0.8170
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.5560
# Epoch: 160 	Total: 5099.6010 	Mean_train_accuracy: 0.8169
# 	Mean_test_accuracy: 0.8160 	Mean_test_accuracy_sum: 0.5560
# Epoch: 161 	Total: 5103.0311 	Mean_train_accuracy: 0.8091
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.5560
# Epoch: 162 	Total: 5104.4745 	Mean_train_accuracy: 0.8056
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.5560
# Epoch: 163 	Total: 5116.4772 	Mean_train_accuracy: 0.8094
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.5560
# Epoch: 164 	Total: 5116.8372 	Mean_train_accuracy: 0.8177
# 	Mean_test_accuracy: 0.8140 	Mean_test_accuracy_sum: 0.5560
# Epoch: 165 	Total: 5114.2636 	Mean_train_accuracy: 0.8072
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.5560
# Epoch: 166 	Total: 5135.4809 	Mean_train_accuracy: 0.8074
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.5560
# Epoch: 167 	Total: 5074.7654 	Mean_train_accuracy: 0.8127
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.5560
# Epoch: 168 	Total: 5243.4462 	Mean_train_accuracy: 0.8071
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.5560
# Epoch: 169 	Total: 5328.8187 	Mean_train_accuracy: 0.8076
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.5560
# Epoch: 170 	Total: 5249.1858 	Mean_train_accuracy: 0.8079
# 	Mean_test_accuracy: 0.8170 	Mean_test_accuracy_sum: 0.5560
# Epoch: 171 	Total: 5184.5812 	Mean_train_accuracy: 0.8121
# 	Mean_test_accuracy: 0.7990 	Mean_test_accuracy_sum: 0.5560
# Epoch: 172 	Total: 5137.6380 	Mean_train_accuracy: 0.8141
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.5560
# Epoch: 173 	Total: 5079.1613 	Mean_train_accuracy: 0.8113
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.5560
# Epoch: 174 	Total: 5214.8313 	Mean_train_accuracy: 0.8174
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.5560
# Epoch: 175 	Total: 5218.1914 	Mean_train_accuracy: 0.8131
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.5560
# Epoch: 176 	Total: 5102.8171 	Mean_train_accuracy: 0.8131
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.5560
# Epoch: 177 	Total: 5074.5501 	Mean_train_accuracy: 0.8083
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.5560
# Epoch: 178 	Total: 5224.5688 	Mean_train_accuracy: 0.8186
# 	Mean_test_accuracy: 0.8170 	Mean_test_accuracy_sum: 0.5560
# Epoch: 179 	Total: 5083.0101 	Mean_train_accuracy: 0.8211
# 	Mean_test_accuracy: 0.8160 	Mean_test_accuracy_sum: 0.5560
# Epoch: 180 	Total: 5041.8893 	Mean_train_accuracy: 0.8147
# 	Mean_test_accuracy: 0.8160 	Mean_test_accuracy_sum: 0.5560
# Epoch: 181 	Total: 5039.3940 	Mean_train_accuracy: 0.8164
# 	Mean_test_accuracy: 0.8240 	Mean_test_accuracy_sum: 0.5560
# Epoch: 182 	Total: 5035.9819 	Mean_train_accuracy: 0.8167
# 	Mean_test_accuracy: 0.8200 	Mean_test_accuracy_sum: 0.5560
# Epoch: 183 	Total: 5056.1974 	Mean_train_accuracy: 0.8169
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.5560
# Epoch: 184 	Total: 5050.2107 	Mean_train_accuracy: 0.8179
# 	Mean_test_accuracy: 0.8250 	Mean_test_accuracy_sum: 0.5560
# Epoch: 185 	Total: 5466.6674 	Mean_train_accuracy: 0.8056
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.5560
# Epoch: 186 	Total: 5130.0858 	Mean_train_accuracy: 0.8159
# 	Mean_test_accuracy: 0.8180 	Mean_test_accuracy_sum: 0.5560
# Epoch: 187 	Total: 5037.4230 	Mean_train_accuracy: 0.8196
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.5560
# Epoch: 188 	Total: 5040.4675 	Mean_train_accuracy: 0.8073
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.5560
# Epoch: 189 	Total: 5042.0337 	Mean_train_accuracy: 0.8192
# 	Mean_test_accuracy: 0.8170 	Mean_test_accuracy_sum: 0.5560
# Epoch: 190 	Total: 5065.4706 	Mean_train_accuracy: 0.8157
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.5560
# Epoch: 191 	Total: 5203.6571 	Mean_train_accuracy: 0.8191
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.5560
# Epoch: 192 	Total: 5130.7726 	Mean_train_accuracy: 0.8182
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.5560
# Epoch: 193 	Total: 5038.6772 	Mean_train_accuracy: 0.8212
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.5560
# Epoch: 194 	Total: 5219.5766 	Mean_train_accuracy: 0.8101
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.5560
# Epoch: 195 	Total: 5029.4849 	Mean_train_accuracy: 0.8159
# 	Mean_test_accuracy: 0.8140 	Mean_test_accuracy_sum: 0.5560
# Epoch: 196 	Total: 4999.8806 	Mean_train_accuracy: 0.8224
# 	Mean_test_accuracy: 0.8190 	Mean_test_accuracy_sum: 0.5560
# Epoch: 197 	Total: 4993.3962 	Mean_train_accuracy: 0.8220
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.5560
# Epoch: 198 	Total: 4997.6750 	Mean_train_accuracy: 0.8214
# 	Mean_test_accuracy: 0.8160 	Mean_test_accuracy_sum: 0.5560
# Epoch: 199 	Total: 5023.2204 	Mean_train_accuracy: 0.8209
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.5560
# Epoch: 200 	Total: 5004.5359 	Mean_train_accuracy: 0.8183
# 	Mean_test_accuracy: 0.8180 	Mean_test_accuracy_sum: 0.5560
# Epoch: 201 	Total: 5006.5992 	Mean_train_accuracy: 0.8212
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.5560
# Epoch: 202 	Total: 5209.4675 	Mean_train_accuracy: 0.8063
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.5560
# Epoch: 203 	Total: 5103.4135 	Mean_train_accuracy: 0.8162
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.5560
# Epoch: 204 	Total: 5054.4061 	Mean_train_accuracy: 0.8150
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.5560
# Epoch: 205 	Total: 5139.6131 	Mean_train_accuracy: 0.8229
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.5560
# Epoch: 206 	Total: 4999.1926 	Mean_train_accuracy: 0.8255
# 	Mean_test_accuracy: 0.8220 	Mean_test_accuracy_sum: 0.5560
# Epoch: 207 	Total: 4970.7702 	Mean_train_accuracy: 0.8160
# 	Mean_test_accuracy: 0.8200 	Mean_test_accuracy_sum: 0.5560
# Epoch: 208 	Total: 5009.4821 	Mean_train_accuracy: 0.8210
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.5560
# Epoch: 209 	Total: 4972.6580 	Mean_train_accuracy: 0.8191
# 	Mean_test_accuracy: 0.8160 	Mean_test_accuracy_sum: 0.5560
# Epoch: 210 	Total: 4998.2083 	Mean_train_accuracy: 0.8203
# 	Mean_test_accuracy: 0.8190 	Mean_test_accuracy_sum: 0.5560
# Epoch: 211 	Total: 5124.4720 	Mean_train_accuracy: 0.8108
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.5560
# Epoch: 212 	Total: 5123.8813 	Mean_train_accuracy: 0.8229
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.5560
# Epoch: 213 	Total: 4980.8823 	Mean_train_accuracy: 0.8239
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.5560
# Epoch: 214 	Total: 5389.1080 	Mean_train_accuracy: 0.8104
# 	Mean_test_accuracy: 0.8160 	Mean_test_accuracy_sum: 0.5560
# Epoch: 215 	Total: 5091.8466 	Mean_train_accuracy: 0.8153
# 	Mean_test_accuracy: 0.8180 	Mean_test_accuracy_sum: 0.5560
# Epoch: 216 	Total: 4975.4159 	Mean_train_accuracy: 0.8187
# 	Mean_test_accuracy: 0.8210 	Mean_test_accuracy_sum: 0.5560
# Epoch: 217 	Total: 4992.3842 	Mean_train_accuracy: 0.8235
# 	Mean_test_accuracy: 0.8210 	Mean_test_accuracy_sum: 0.5560
# Epoch: 218 	Total: 4976.1105 	Mean_train_accuracy: 0.8219
# 	Mean_test_accuracy: 0.8210 	Mean_test_accuracy_sum: 0.5560
# Epoch: 219 	Total: 4961.3926 	Mean_train_accuracy: 0.8230
# 	Mean_test_accuracy: 0.8270 	Mean_test_accuracy_sum: 0.5560
# Epoch: 220 	Total: 5102.0651 	Mean_train_accuracy: 0.8146
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.5560
# Epoch: 221 	Total: 5062.2290 	Mean_train_accuracy: 0.8224
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.5560
# Epoch: 222 	Total: 4986.4753 	Mean_train_accuracy: 0.8184
# 	Mean_test_accuracy: 0.8220 	Mean_test_accuracy_sum: 0.5560
# Epoch: 223 	Total: 4947.2531 	Mean_train_accuracy: 0.8197
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.5560
# Epoch: 224 	Total: 5176.5148 	Mean_train_accuracy: 0.8156
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.5560
# Epoch: 225 	Total: 5064.9925 	Mean_train_accuracy: 0.8239
# 	Mean_test_accuracy: 0.8140 	Mean_test_accuracy_sum: 0.5560
# Epoch: 226 	Total: 4939.8056 	Mean_train_accuracy: 0.8252
# 	Mean_test_accuracy: 0.8210 	Mean_test_accuracy_sum: 0.5560
# Epoch: 227 	Total: 4935.1852 	Mean_train_accuracy: 0.8209
# 	Mean_test_accuracy: 0.8180 	Mean_test_accuracy_sum: 0.5560
# Epoch: 228 	Total: 4934.5526 	Mean_train_accuracy: 0.8232
# 	Mean_test_accuracy: 0.8170 	Mean_test_accuracy_sum: 0.5560
# Epoch: 229 	Total: 4918.3692 	Mean_train_accuracy: 0.8221
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.5560
# Epoch: 230 	Total: 4945.9474 	Mean_train_accuracy: 0.8179
# 	Mean_test_accuracy: 0.8140 	Mean_test_accuracy_sum: 0.5560
# Epoch: 231 	Total: 4951.0023 	Mean_train_accuracy: 0.8267
# 	Mean_test_accuracy: 0.8210 	Mean_test_accuracy_sum: 0.5560
# Epoch: 232 	Total: 4940.4715 	Mean_train_accuracy: 0.8289
# 	Mean_test_accuracy: 0.8270 	Mean_test_accuracy_sum: 0.5560
# Epoch: 233 	Total: 4955.5027 	Mean_train_accuracy: 0.8211
# 	Mean_test_accuracy: 0.8210 	Mean_test_accuracy_sum: 0.5560
# Epoch: 234 	Total: 4964.5595 	Mean_train_accuracy: 0.8199
# 	Mean_test_accuracy: 0.8140 	Mean_test_accuracy_sum: 0.5560
# Epoch: 235 	Total: 4932.2728 	Mean_train_accuracy: 0.8219
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.5560
# Epoch: 236 	Total: 4970.6903 	Mean_train_accuracy: 0.8243
# 	Mean_test_accuracy: 0.8240 	Mean_test_accuracy_sum: 0.5560
# Epoch: 237 	Total: 5151.0698 	Mean_train_accuracy: 0.8131
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.5560
# Epoch: 238 	Total: 5086.4570 	Mean_train_accuracy: 0.8195
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.5560
# Epoch: 239 	Total: 4933.7091 	Mean_train_accuracy: 0.8270
# 	Mean_test_accuracy: 0.8170 	Mean_test_accuracy_sum: 0.5560
# Epoch: 240 	Total: 4938.6584 	Mean_train_accuracy: 0.8230
# 	Mean_test_accuracy: 0.8250 	Mean_test_accuracy_sum: 0.5560
# Epoch: 241 	Total: 4934.7899 	Mean_train_accuracy: 0.8286
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.5560
# Epoch: 242 	Total: 4932.3622 	Mean_train_accuracy: 0.8243
# 	Mean_test_accuracy: 0.8210 	Mean_test_accuracy_sum: 0.5560
# Epoch: 243 	Total: 4923.3380 	Mean_train_accuracy: 0.8208
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.5560
# Epoch: 244 	Total: 4969.4565 	Mean_train_accuracy: 0.8264
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.5560
# Epoch: 245 	Total: 5160.3706 	Mean_train_accuracy: 0.8218
# 	Mean_test_accuracy: 0.8220 	Mean_test_accuracy_sum: 0.5560
# Epoch: 246 	Total: 4980.5000 	Mean_train_accuracy: 0.8229
# 	Mean_test_accuracy: 0.8270 	Mean_test_accuracy_sum: 0.5560
# Epoch: 247 	Total: 5009.6951 	Mean_train_accuracy: 0.8141
# 	Mean_test_accuracy: 0.8010 	Mean_test_accuracy_sum: 0.5560
# Epoch: 248 	Total: 5334.9062 	Mean_train_accuracy: 0.8137
# 	Mean_test_accuracy: 0.8190 	Mean_test_accuracy_sum: 0.5560
# Epoch: 249 	Total: 5003.5552 	Mean_train_accuracy: 0.8212
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.5560
# Epoch: 250 	Total: 4925.5331 	Mean_train_accuracy: 0.8224
# 	Mean_test_accuracy: 0.8290 	Mean_test_accuracy_sum: 0.5560
# Epoch: 251 	Total: 5027.2409 	Mean_train_accuracy: 0.8212
# 	Mean_test_accuracy: 0.8180 	Mean_test_accuracy_sum: 0.5560
# Epoch: 252 	Total: 4970.7019 	Mean_train_accuracy: 0.8199
# 	Mean_test_accuracy: 0.8260 	Mean_test_accuracy_sum: 0.5560
# Epoch: 253 	Total: 4965.2141 	Mean_train_accuracy: 0.8243
# 	Mean_test_accuracy: 0.8210 	Mean_test_accuracy_sum: 0.5560
# Epoch: 254 	Total: 5018.5537 	Mean_train_accuracy: 0.8199
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.5560
# Epoch: 255 	Total: 4957.5506 	Mean_train_accuracy: 0.8180
# 	Mean_test_accuracy: 0.8250 	Mean_test_accuracy_sum: 0.5560
# Epoch: 256 	Total: 4956.4855 	Mean_train_accuracy: 0.8218
# 	Mean_test_accuracy: 0.8250 	Mean_test_accuracy_sum: 0.5560
# Epoch: 257 	Total: 4887.5732 	Mean_train_accuracy: 0.8291
# 	Mean_test_accuracy: 0.8250 	Mean_test_accuracy_sum: 0.5560
# Epoch: 258 	Total: 4928.4847 	Mean_train_accuracy: 0.8222
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.5560
# Epoch: 259 	Total: 4899.2348 	Mean_train_accuracy: 0.8249
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.5560
# Epoch: 260 	Total: 4870.1492 	Mean_train_accuracy: 0.8307
# 	Mean_test_accuracy: 0.8210 	Mean_test_accuracy_sum: 0.5560
# Epoch: 261 	Total: 4918.5414 	Mean_train_accuracy: 0.8299
# 	Mean_test_accuracy: 0.8200 	Mean_test_accuracy_sum: 0.5560
# Epoch: 262 	Total: 5055.7404 	Mean_train_accuracy: 0.8236
# 	Mean_test_accuracy: 0.8230 	Mean_test_accuracy_sum: 0.5560
# Epoch: 263 	Total: 4914.3378 	Mean_train_accuracy: 0.8246
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.5560
# Epoch: 264 	Total: 4880.0741 	Mean_train_accuracy: 0.8247
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.5560
# Epoch: 265 	Total: 5089.3770 	Mean_train_accuracy: 0.8223
# 	Mean_test_accuracy: 0.8170 	Mean_test_accuracy_sum: 0.5560
# Epoch: 266 	Total: 5004.3565 	Mean_train_accuracy: 0.8270
# 	Mean_test_accuracy: 0.8230 	Mean_test_accuracy_sum: 0.5560
# Epoch: 267 	Total: 4898.3027 	Mean_train_accuracy: 0.8317
# 	Mean_test_accuracy: 0.8230 	Mean_test_accuracy_sum: 0.5560
# Epoch: 268 	Total: 4896.9841 	Mean_train_accuracy: 0.8226
# 	Mean_test_accuracy: 0.8180 	Mean_test_accuracy_sum: 0.5560
# Epoch: 269 	Total: 5009.9658 	Mean_train_accuracy: 0.8236
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.5560
# Epoch: 270 	Total: 4875.5422 	Mean_train_accuracy: 0.8272
# 	Mean_test_accuracy: 0.8200 	Mean_test_accuracy_sum: 0.5560
# Epoch: 271 	Total: 4909.5272 	Mean_train_accuracy: 0.8251
# 	Mean_test_accuracy: 0.8260 	Mean_test_accuracy_sum: 0.5560
# Epoch: 272 	Total: 4981.4189 	Mean_train_accuracy: 0.8247
# 	Mean_test_accuracy: 0.8240 	Mean_test_accuracy_sum: 0.5560
# Epoch: 273 	Total: 5008.2056 	Mean_train_accuracy: 0.8214
# 	Mean_test_accuracy: 0.8210 	Mean_test_accuracy_sum: 0.5560
# Epoch: 274 	Total: 4889.9255 	Mean_train_accuracy: 0.8321
# 	Mean_test_accuracy: 0.8260 	Mean_test_accuracy_sum: 0.5560
# Epoch: 275 	Total: 5016.3215 	Mean_train_accuracy: 0.8199
# 	Mean_test_accuracy: 0.8240 	Mean_test_accuracy_sum: 0.5560
# Epoch: 276 	Total: 4903.1819 	Mean_train_accuracy: 0.8284
# 	Mean_test_accuracy: 0.8240 	Mean_test_accuracy_sum: 0.5560
# Epoch: 277 	Total: 4869.4434 	Mean_train_accuracy: 0.8306
# 	Mean_test_accuracy: 0.8350 	Mean_test_accuracy_sum: 0.5560
# Epoch: 278 	Total: 4877.2376 	Mean_train_accuracy: 0.8293
# 	Mean_test_accuracy: 0.8270 	Mean_test_accuracy_sum: 0.5560
# Epoch: 279 	Total: 4873.1536 	Mean_train_accuracy: 0.8294
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.5560
# Epoch: 280 	Total: 4847.9546 	Mean_train_accuracy: 0.8291
# 	Mean_test_accuracy: 0.8210 	Mean_test_accuracy_sum: 0.5560
# Epoch: 281 	Total: 4829.6507 	Mean_train_accuracy: 0.8244
# 	Mean_test_accuracy: 0.8170 	Mean_test_accuracy_sum: 0.5560
# Epoch: 282 	Total: 4830.5779 	Mean_train_accuracy: 0.8317
# 	Mean_test_accuracy: 0.8220 	Mean_test_accuracy_sum: 0.5560
# Epoch: 283 	Total: 5128.7783 	Mean_train_accuracy: 0.8245
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.5560
# Epoch: 284 	Total: 4930.1770 	Mean_train_accuracy: 0.8328
# 	Mean_test_accuracy: 0.8210 	Mean_test_accuracy_sum: 0.5560
# Epoch: 285 	Total: 4846.2476 	Mean_train_accuracy: 0.8275
# 	Mean_test_accuracy: 0.8180 	Mean_test_accuracy_sum: 0.5560
# Epoch: 286 	Total: 4867.7108 	Mean_train_accuracy: 0.8314
# 	Mean_test_accuracy: 0.8260 	Mean_test_accuracy_sum: 0.5560
# Epoch: 287 	Total: 5017.5852 	Mean_train_accuracy: 0.8256
# 	Mean_test_accuracy: 0.8360 	Mean_test_accuracy_sum: 0.5560
# Epoch: 288 	Total: 4929.7403 	Mean_train_accuracy: 0.8317
# 	Mean_test_accuracy: 0.8230 	Mean_test_accuracy_sum: 0.5560
# Epoch: 289 	Total: 4852.2631 	Mean_train_accuracy: 0.8300
# 	Mean_test_accuracy: 0.8140 	Mean_test_accuracy_sum: 0.5560
# Epoch: 290 	Total: 4936.9514 	Mean_train_accuracy: 0.8232
# 	Mean_test_accuracy: 0.8290 	Mean_test_accuracy_sum: 0.5560
# Epoch: 291 	Total: 4848.2361 	Mean_train_accuracy: 0.8261
# 	Mean_test_accuracy: 0.8210 	Mean_test_accuracy_sum: 0.5560
# Epoch: 292 	Total: 4827.0173 	Mean_train_accuracy: 0.8357
# 	Mean_test_accuracy: 0.8220 	Mean_test_accuracy_sum: 0.5560
# Epoch: 293 	Total: 4830.9595 	Mean_train_accuracy: 0.8341
# 	Mean_test_accuracy: 0.8230 	Mean_test_accuracy_sum: 0.5560
# Epoch: 294 	Total: 4843.9236 	Mean_train_accuracy: 0.8333
# 	Mean_test_accuracy: 0.8240 	Mean_test_accuracy_sum: 0.5560
# Epoch: 295 	Total: 4834.8774 	Mean_train_accuracy: 0.8340
# 	Mean_test_accuracy: 0.8220 	Mean_test_accuracy_sum: 0.5560
# Epoch: 296 	Total: 4803.0713 	Mean_train_accuracy: 0.8343
# 	Mean_test_accuracy: 0.8220 	Mean_test_accuracy_sum: 0.5560
# Epoch: 297 	Total: 4803.5462 	Mean_train_accuracy: 0.8318
# 	Mean_test_accuracy: 0.8260 	Mean_test_accuracy_sum: 0.5560
# Epoch: 298 	Total: 4807.4541 	Mean_train_accuracy: 0.8264
# 	Mean_test_accuracy: 0.8220 	Mean_test_accuracy_sum: 0.5560
# Epoch: 299 	Total: 4876.5393 	Mean_train_accuracy: 0.8259
# 	Mean_test_accuracy: 0.8160 	Mean_test_accuracy_sum: 0.5560
# Epoch: 300 	Total: 5165.2903 	Mean_train_accuracy: 0.8219
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.5560
# Epoch: 301 	Total: 4947.4478 	Mean_train_accuracy: 0.8296
# 	Mean_test_accuracy: 0.8220 	Mean_test_accuracy_sum: 0.5560
# Epoch: 302 	Total: 4939.8171 	Mean_train_accuracy: 0.8270
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.5560
# Epoch: 303 	Total: 4876.2649 	Mean_train_accuracy: 0.8325
# 	Mean_test_accuracy: 0.8190 	Mean_test_accuracy_sum: 0.5560
# Epoch: 304 	Total: 4815.6951 	Mean_train_accuracy: 0.8321
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 305 	Total: 4798.5307 	Mean_train_accuracy: 0.8299
# 	Mean_test_accuracy: 0.8190 	Mean_test_accuracy_sum: 0.5560
# Epoch: 306 	Total: 5068.4939 	Mean_train_accuracy: 0.8206
# 	Mean_test_accuracy: 0.8350 	Mean_test_accuracy_sum: 0.5560
# Epoch: 307 	Total: 4904.8087 	Mean_train_accuracy: 0.8284
# 	Mean_test_accuracy: 0.8240 	Mean_test_accuracy_sum: 0.5560
# Epoch: 308 	Total: 4848.6014 	Mean_train_accuracy: 0.8264
# 	Mean_test_accuracy: 0.8290 	Mean_test_accuracy_sum: 0.5560
# Epoch: 309 	Total: 5064.7758 	Mean_train_accuracy: 0.8232
# 	Mean_test_accuracy: 0.8230 	Mean_test_accuracy_sum: 0.5560
# Epoch: 310 	Total: 4917.4213 	Mean_train_accuracy: 0.8289
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 311 	Total: 4837.4288 	Mean_train_accuracy: 0.8369
# 	Mean_test_accuracy: 0.8290 	Mean_test_accuracy_sum: 0.5560
# Epoch: 312 	Total: 4873.2620 	Mean_train_accuracy: 0.8279
# 	Mean_test_accuracy: 0.8300 	Mean_test_accuracy_sum: 0.5560
# Epoch: 313 	Total: 4848.7534 	Mean_train_accuracy: 0.8375
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 314 	Total: 4840.3331 	Mean_train_accuracy: 0.8325
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 315 	Total: 4833.6772 	Mean_train_accuracy: 0.8356
# 	Mean_test_accuracy: 0.8410 	Mean_test_accuracy_sum: 0.5560
# Epoch: 316 	Total: 4812.5557 	Mean_train_accuracy: 0.8349
# 	Mean_test_accuracy: 0.8280 	Mean_test_accuracy_sum: 0.5560
# Epoch: 317 	Total: 4789.3901 	Mean_train_accuracy: 0.8329
# 	Mean_test_accuracy: 0.8230 	Mean_test_accuracy_sum: 0.5560
# Epoch: 318 	Total: 4817.2062 	Mean_train_accuracy: 0.8279
# 	Mean_test_accuracy: 0.8280 	Mean_test_accuracy_sum: 0.5560
# Epoch: 319 	Total: 4980.3468 	Mean_train_accuracy: 0.8294
# 	Mean_test_accuracy: 0.8140 	Mean_test_accuracy_sum: 0.5560
# Epoch: 320 	Total: 4801.6462 	Mean_train_accuracy: 0.8318
# 	Mean_test_accuracy: 0.8350 	Mean_test_accuracy_sum: 0.5560
# Epoch: 321 	Total: 4838.3559 	Mean_train_accuracy: 0.8328
# 	Mean_test_accuracy: 0.8360 	Mean_test_accuracy_sum: 0.5560
# Epoch: 322 	Total: 4812.5500 	Mean_train_accuracy: 0.8336
# 	Mean_test_accuracy: 0.8390 	Mean_test_accuracy_sum: 0.5560
# Epoch: 323 	Total: 4809.7600 	Mean_train_accuracy: 0.8350
# 	Mean_test_accuracy: 0.8210 	Mean_test_accuracy_sum: 0.5560
# Epoch: 324 	Total: 4805.1604 	Mean_train_accuracy: 0.8355
# 	Mean_test_accuracy: 0.8260 	Mean_test_accuracy_sum: 0.5560
# Epoch: 325 	Total: 4771.0985 	Mean_train_accuracy: 0.8317
# 	Mean_test_accuracy: 0.8300 	Mean_test_accuracy_sum: 0.5560
# Epoch: 326 	Total: 5071.4676 	Mean_train_accuracy: 0.8268
# 	Mean_test_accuracy: 0.8350 	Mean_test_accuracy_sum: 0.5560
# Epoch: 327 	Total: 4834.9567 	Mean_train_accuracy: 0.8286
# 	Mean_test_accuracy: 0.8290 	Mean_test_accuracy_sum: 0.5560
# Epoch: 328 	Total: 5124.3170 	Mean_train_accuracy: 0.8279
# 	Mean_test_accuracy: 0.8220 	Mean_test_accuracy_sum: 0.5560
# Epoch: 329 	Total: 4900.6727 	Mean_train_accuracy: 0.8365
# 	Mean_test_accuracy: 0.8310 	Mean_test_accuracy_sum: 0.5560
# Epoch: 330 	Total: 4800.2995 	Mean_train_accuracy: 0.8332
# 	Mean_test_accuracy: 0.8270 	Mean_test_accuracy_sum: 0.5560
# Epoch: 331 	Total: 4767.5019 	Mean_train_accuracy: 0.8341
# 	Mean_test_accuracy: 0.8300 	Mean_test_accuracy_sum: 0.5560
# Epoch: 332 	Total: 4763.4859 	Mean_train_accuracy: 0.8386
# 	Mean_test_accuracy: 0.8240 	Mean_test_accuracy_sum: 0.5560
# Epoch: 333 	Total: 4775.8905 	Mean_train_accuracy: 0.8342
# 	Mean_test_accuracy: 0.8280 	Mean_test_accuracy_sum: 0.5560
# Epoch: 334 	Total: 4884.4123 	Mean_train_accuracy: 0.8349
# 	Mean_test_accuracy: 0.8220 	Mean_test_accuracy_sum: 0.5560
# Epoch: 335 	Total: 4770.4924 	Mean_train_accuracy: 0.8396
# 	Mean_test_accuracy: 0.8300 	Mean_test_accuracy_sum: 0.5560
# Epoch: 336 	Total: 4739.5018 	Mean_train_accuracy: 0.8366
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 337 	Total: 4757.5053 	Mean_train_accuracy: 0.8247
# 	Mean_test_accuracy: 0.8250 	Mean_test_accuracy_sum: 0.5560
# Epoch: 338 	Total: 5046.1898 	Mean_train_accuracy: 0.8278
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.5560
# Epoch: 339 	Total: 4825.0612 	Mean_train_accuracy: 0.8384
# 	Mean_test_accuracy: 0.8230 	Mean_test_accuracy_sum: 0.5560
# Epoch: 340 	Total: 4752.2984 	Mean_train_accuracy: 0.8393
# 	Mean_test_accuracy: 0.8300 	Mean_test_accuracy_sum: 0.5560
# Epoch: 341 	Total: 4771.9046 	Mean_train_accuracy: 0.8356
# 	Mean_test_accuracy: 0.8240 	Mean_test_accuracy_sum: 0.5560
# Epoch: 342 	Total: 4922.8067 	Mean_train_accuracy: 0.8294
# 	Mean_test_accuracy: 0.8210 	Mean_test_accuracy_sum: 0.5560
# Epoch: 343 	Total: 4816.2176 	Mean_train_accuracy: 0.8387
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 344 	Total: 4746.4600 	Mean_train_accuracy: 0.8377
# 	Mean_test_accuracy: 0.8260 	Mean_test_accuracy_sum: 0.5560
# Epoch: 345 	Total: 4881.9985 	Mean_train_accuracy: 0.8271
# 	Mean_test_accuracy: 0.8240 	Mean_test_accuracy_sum: 0.5560
# Epoch: 346 	Total: 4803.6499 	Mean_train_accuracy: 0.8368
# 	Mean_test_accuracy: 0.8340 	Mean_test_accuracy_sum: 0.5560
# Epoch: 347 	Total: 4781.3391 	Mean_train_accuracy: 0.8361
# 	Mean_test_accuracy: 0.8280 	Mean_test_accuracy_sum: 0.5560
# Epoch: 348 	Total: 4750.8791 	Mean_train_accuracy: 0.8411
# 	Mean_test_accuracy: 0.8190 	Mean_test_accuracy_sum: 0.5560
# Epoch: 349 	Total: 4717.0354 	Mean_train_accuracy: 0.8356
# 	Mean_test_accuracy: 0.8350 	Mean_test_accuracy_sum: 0.5560
# Epoch: 350 	Total: 4722.8256 	Mean_train_accuracy: 0.8397
# 	Mean_test_accuracy: 0.8310 	Mean_test_accuracy_sum: 0.5560
# Epoch: 351 	Total: 4720.1181 	Mean_train_accuracy: 0.8380
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 352 	Total: 4719.7913 	Mean_train_accuracy: 0.8356
# 	Mean_test_accuracy: 0.8190 	Mean_test_accuracy_sum: 0.5560
# Epoch: 353 	Total: 4748.9427 	Mean_train_accuracy: 0.8422
# 	Mean_test_accuracy: 0.8280 	Mean_test_accuracy_sum: 0.5560
# Epoch: 354 	Total: 4723.2755 	Mean_train_accuracy: 0.8389
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 355 	Total: 4736.8730 	Mean_train_accuracy: 0.8414
# 	Mean_test_accuracy: 0.8240 	Mean_test_accuracy_sum: 0.5560
# Epoch: 356 	Total: 4745.0187 	Mean_train_accuracy: 0.8376
# 	Mean_test_accuracy: 0.8280 	Mean_test_accuracy_sum: 0.5560
# Epoch: 357 	Total: 4732.7661 	Mean_train_accuracy: 0.8386
# 	Mean_test_accuracy: 0.8190 	Mean_test_accuracy_sum: 0.5560
# Epoch: 358 	Total: 4729.3165 	Mean_train_accuracy: 0.8442
# 	Mean_test_accuracy: 0.8330 	Mean_test_accuracy_sum: 0.5560
# Epoch: 359 	Total: 4742.5460 	Mean_train_accuracy: 0.8381
# 	Mean_test_accuracy: 0.8280 	Mean_test_accuracy_sum: 0.5560
# Epoch: 360 	Total: 4718.5259 	Mean_train_accuracy: 0.8432
# 	Mean_test_accuracy: 0.8310 	Mean_test_accuracy_sum: 0.5560
# Epoch: 361 	Total: 5072.8987 	Mean_train_accuracy: 0.8267
# 	Mean_test_accuracy: 0.8230 	Mean_test_accuracy_sum: 0.5560
# Epoch: 362 	Total: 5031.6151 	Mean_train_accuracy: 0.8358
# 	Mean_test_accuracy: 0.8180 	Mean_test_accuracy_sum: 0.5560
# Epoch: 363 	Total: 4803.5477 	Mean_train_accuracy: 0.8378
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 364 	Total: 4716.8029 	Mean_train_accuracy: 0.8448
# 	Mean_test_accuracy: 0.8370 	Mean_test_accuracy_sum: 0.5560
# Epoch: 365 	Total: 4707.1260 	Mean_train_accuracy: 0.8379
# 	Mean_test_accuracy: 0.8370 	Mean_test_accuracy_sum: 0.5560
# Epoch: 366 	Total: 4693.1052 	Mean_train_accuracy: 0.8393
# 	Mean_test_accuracy: 0.8410 	Mean_test_accuracy_sum: 0.5560
# Epoch: 367 	Total: 5293.7345 	Mean_train_accuracy: 0.8206
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.5560
# Epoch: 368 	Total: 4856.1857 	Mean_train_accuracy: 0.8347
# 	Mean_test_accuracy: 0.8410 	Mean_test_accuracy_sum: 0.5560
# Epoch: 369 	Total: 4809.7888 	Mean_train_accuracy: 0.8374
# 	Mean_test_accuracy: 0.8370 	Mean_test_accuracy_sum: 0.5560
# Epoch: 370 	Total: 4720.0346 	Mean_train_accuracy: 0.8384
# 	Mean_test_accuracy: 0.8290 	Mean_test_accuracy_sum: 0.5560
# Epoch: 371 	Total: 4689.2721 	Mean_train_accuracy: 0.8407
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 372 	Total: 4715.1173 	Mean_train_accuracy: 0.8362
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 373 	Total: 4817.3418 	Mean_train_accuracy: 0.8376
# 	Mean_test_accuracy: 0.8410 	Mean_test_accuracy_sum: 0.5560
# Epoch: 374 	Total: 4707.1965 	Mean_train_accuracy: 0.8453
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 375 	Total: 4843.1059 	Mean_train_accuracy: 0.8144
# 	Mean_test_accuracy: 0.8240 	Mean_test_accuracy_sum: 0.5560
# Epoch: 376 	Total: 4971.6629 	Mean_train_accuracy: 0.8391
# 	Mean_test_accuracy: 0.8330 	Mean_test_accuracy_sum: 0.5560
# Epoch: 377 	Total: 4737.7270 	Mean_train_accuracy: 0.8398
# 	Mean_test_accuracy: 0.8480 	Mean_test_accuracy_sum: 0.5560
# Epoch: 378 	Total: 4683.8053 	Mean_train_accuracy: 0.8376
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 379 	Total: 4722.1758 	Mean_train_accuracy: 0.8361
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 380 	Total: 4921.2287 	Mean_train_accuracy: 0.8395
# 	Mean_test_accuracy: 0.8330 	Mean_test_accuracy_sum: 0.5560
# Epoch: 381 	Total: 4791.8441 	Mean_train_accuracy: 0.8437
# 	Mean_test_accuracy: 0.8360 	Mean_test_accuracy_sum: 0.5560
# Epoch: 382 	Total: 4686.3502 	Mean_train_accuracy: 0.8395
# 	Mean_test_accuracy: 0.8230 	Mean_test_accuracy_sum: 0.5560
# Epoch: 383 	Total: 4689.0757 	Mean_train_accuracy: 0.8489
# 	Mean_test_accuracy: 0.8290 	Mean_test_accuracy_sum: 0.5560
# Epoch: 384 	Total: 4723.2351 	Mean_train_accuracy: 0.8292
# 	Mean_test_accuracy: 0.8350 	Mean_test_accuracy_sum: 0.5560
# Epoch: 385 	Total: 4747.6622 	Mean_train_accuracy: 0.8386
# 	Mean_test_accuracy: 0.8340 	Mean_test_accuracy_sum: 0.5560
# Epoch: 386 	Total: 4680.3248 	Mean_train_accuracy: 0.8413
# 	Mean_test_accuracy: 0.8380 	Mean_test_accuracy_sum: 0.5560
# Epoch: 387 	Total: 4814.0432 	Mean_train_accuracy: 0.8458
# 	Mean_test_accuracy: 0.8370 	Mean_test_accuracy_sum: 0.5560
# Epoch: 388 	Total: 4748.0627 	Mean_train_accuracy: 0.8453
# 	Mean_test_accuracy: 0.8240 	Mean_test_accuracy_sum: 0.5560
# Epoch: 389 	Total: 4668.5461 	Mean_train_accuracy: 0.8431
# 	Mean_test_accuracy: 0.8380 	Mean_test_accuracy_sum: 0.5560
# Epoch: 390 	Total: 4726.5939 	Mean_train_accuracy: 0.8331
# 	Mean_test_accuracy: 0.8480 	Mean_test_accuracy_sum: 0.5560
# Epoch: 391 	Total: 4675.7082 	Mean_train_accuracy: 0.8391
# 	Mean_test_accuracy: 0.8290 	Mean_test_accuracy_sum: 0.5560
# Epoch: 392 	Total: 4801.3938 	Mean_train_accuracy: 0.8276
# 	Mean_test_accuracy: 0.8360 	Mean_test_accuracy_sum: 0.5560
# Epoch: 393 	Total: 4778.2061 	Mean_train_accuracy: 0.8412
# 	Mean_test_accuracy: 0.8250 	Mean_test_accuracy_sum: 0.5560
# Epoch: 394 	Total: 4682.5151 	Mean_train_accuracy: 0.8454
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 395 	Total: 4657.9330 	Mean_train_accuracy: 0.8448
# 	Mean_test_accuracy: 0.8440 	Mean_test_accuracy_sum: 0.5560
# Epoch: 396 	Total: 4661.0540 	Mean_train_accuracy: 0.8407
# 	Mean_test_accuracy: 0.8330 	Mean_test_accuracy_sum: 0.5560
# Epoch: 397 	Total: 4639.1392 	Mean_train_accuracy: 0.8427
# 	Mean_test_accuracy: 0.8310 	Mean_test_accuracy_sum: 0.5560
# Epoch: 398 	Total: 4654.3585 	Mean_train_accuracy: 0.8417
# 	Mean_test_accuracy: 0.8360 	Mean_test_accuracy_sum: 0.5560
# Epoch: 399 	Total: 4742.3322 	Mean_train_accuracy: 0.8354
# 	Mean_test_accuracy: 0.8380 	Mean_test_accuracy_sum: 0.5560
# Epoch: 400 	Total: 4835.8302 	Mean_train_accuracy: 0.8446
# 	Mean_test_accuracy: 0.8310 	Mean_test_accuracy_sum: 0.5560
# Epoch: 401 	Total: 4676.3571 	Mean_train_accuracy: 0.8403
# 	Mean_test_accuracy: 0.8420 	Mean_test_accuracy_sum: 0.5560
# Epoch: 402 	Total: 4745.6865 	Mean_train_accuracy: 0.8428
# 	Mean_test_accuracy: 0.8350 	Mean_test_accuracy_sum: 0.5560
# Epoch: 403 	Total: 4692.3979 	Mean_train_accuracy: 0.8459
# 	Mean_test_accuracy: 0.8390 	Mean_test_accuracy_sum: 0.5560
# Epoch: 404 	Total: 4637.9135 	Mean_train_accuracy: 0.8455
# 	Mean_test_accuracy: 0.8290 	Mean_test_accuracy_sum: 0.5560
# Epoch: 405 	Total: 4616.1025 	Mean_train_accuracy: 0.8483
# 	Mean_test_accuracy: 0.8430 	Mean_test_accuracy_sum: 0.5560
# Epoch: 406 	Total: 4651.3818 	Mean_train_accuracy: 0.8376
# 	Mean_test_accuracy: 0.8300 	Mean_test_accuracy_sum: 0.5560
# Epoch: 407 	Total: 4827.4303 	Mean_train_accuracy: 0.8365
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 408 	Total: 4686.3405 	Mean_train_accuracy: 0.8441
# ...
# Epoch: 1822 	Total: 4110.3069 	Mean_train_accuracy: 0.8866
# 	Mean_test_accuracy: 0.8530 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1823 	Total: 4120.1373 	Mean_train_accuracy: 0.8776
# 	Mean_test_accuracy: 0.8420 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1824 	Total: 4104.3061 	Mean_train_accuracy: 0.8839
# 	Mean_test_accuracy: 0.8360 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1825 	Total: 4081.2329 	Mean_train_accuracy: 0.8847
# 	Mean_test_accuracy: 0.8500 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1826 	Total: 4088.7770 	Mean_train_accuracy: 0.8836
# 	Mean_test_accuracy: 0.8410 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1827 	Total: 4078.4659 	Mean_train_accuracy: 0.8888
# 	Mean_test_accuracy: 0.8400 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1828 	Total: 4053.5112 	Mean_train_accuracy: 0.8856
# 	Mean_test_accuracy: 0.8450 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1829 	Total: 4058.1516 	Mean_train_accuracy: 0.8844
# 	Mean_test_accuracy: 0.8390 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1830 	Total: 4077.5904 	Mean_train_accuracy: 0.8832
# 	Mean_test_accuracy: 0.8340 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1831 	Total: 4071.3486 	Mean_train_accuracy: 0.8839
# 	Mean_test_accuracy: 0.8450 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1832 	Total: 4076.5268 	Mean_train_accuracy: 0.8865
# 	Mean_test_accuracy: 0.8350 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1833 	Total: 4091.5334 	Mean_train_accuracy: 0.8852
# 	Mean_test_accuracy: 0.8440 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1834 	Total: 4099.5690 	Mean_train_accuracy: 0.8877
# 	Mean_test_accuracy: 0.8460 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1835 	Total: 4097.4131 	Mean_train_accuracy: 0.8876
# 	Mean_test_accuracy: 0.8430 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1836 	Total: 4131.7771 	Mean_train_accuracy: 0.8799
# 	Mean_test_accuracy: 0.8300 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1837 	Total: 4089.8964 	Mean_train_accuracy: 0.8841
# 	Mean_test_accuracy: 0.8450 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1838 	Total: 4091.5000 	Mean_train_accuracy: 0.8804
# 	Mean_test_accuracy: 0.8570 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1839 	Total: 4143.4941 	Mean_train_accuracy: 0.8807
# 	Mean_test_accuracy: 0.8350 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1840 	Total: 4143.1631 	Mean_train_accuracy: 0.8806
# 	Mean_test_accuracy: 0.8400 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1841 	Total: 4184.7053 	Mean_train_accuracy: 0.8787
# 	Mean_test_accuracy: 0.8470 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1842 	Total: 4142.7124 	Mean_train_accuracy: 0.8789
# 	Mean_test_accuracy: 0.8530 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1843 	Total: 4121.0637 	Mean_train_accuracy: 0.8817
# 	Mean_test_accuracy: 0.8490 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1844 	Total: 4097.6190 	Mean_train_accuracy: 0.8828
# 	Mean_test_accuracy: 0.8620 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1845 	Total: 4108.1552 	Mean_train_accuracy: 0.8782
# 	Mean_test_accuracy: 0.8490 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1846 	Total: 4085.2684 	Mean_train_accuracy: 0.8830
# 	Mean_test_accuracy: 0.8450 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1847 	Total: 4108.0851 	Mean_train_accuracy: 0.8866
# 	Mean_test_accuracy: 0.8550 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1848 	Total: 4072.6713 	Mean_train_accuracy: 0.8874
# 	Mean_test_accuracy: 0.8330 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1849 	Total: 4067.5044 	Mean_train_accuracy: 0.8830
# 	Mean_test_accuracy: 0.8440 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1850 	Total: 4076.8761 	Mean_train_accuracy: 0.8829
# 	Mean_test_accuracy: 0.8510 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1851 	Total: 4086.1760 	Mean_train_accuracy: 0.8834
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1852 	Total: 4101.9717 	Mean_train_accuracy: 0.8879
# 	Mean_test_accuracy: 0.8520 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1853 	Total: 4081.9426 	Mean_train_accuracy: 0.8888
# 	Mean_test_accuracy: 0.8420 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1854 	Total: 4071.0686 	Mean_train_accuracy: 0.8791
# 	Mean_test_accuracy: 0.8590 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1855 	Total: 4077.3418 	Mean_train_accuracy: 0.8866
# 	Mean_test_accuracy: 0.8510 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1856 	Total: 4067.2829 	Mean_train_accuracy: 0.8886
# 	Mean_test_accuracy: 0.8510 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1857 	Total: 4083.6756 	Mean_train_accuracy: 0.8844
# 	Mean_test_accuracy: 0.8540 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1858 	Total: 4104.4579 	Mean_train_accuracy: 0.8824
# 	Mean_test_accuracy: 0.8430 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1859 	Total: 4075.1426 	Mean_train_accuracy: 0.8879
# 	Mean_test_accuracy: 0.8320 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1860 	Total: 4074.1044 	Mean_train_accuracy: 0.8836
# 	Mean_test_accuracy: 0.8530 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1861 	Total: 4089.5656 	Mean_train_accuracy: 0.8802
# 	Mean_test_accuracy: 0.8520 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1862 	Total: 4070.6514 	Mean_train_accuracy: 0.8843
# 	Mean_test_accuracy: 0.8600 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1863 	Total: 4073.3171 	Mean_train_accuracy: 0.8833
# 	Mean_test_accuracy: 0.8490 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1864 	Total: 4068.8521 	Mean_train_accuracy: 0.8871
# 	Mean_test_accuracy: 0.8590 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1865 	Total: 4052.2473 	Mean_train_accuracy: 0.8844
# 	Mean_test_accuracy: 0.8540 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1866 	Total: 4066.7295 	Mean_train_accuracy: 0.8841
# 	Mean_test_accuracy: 0.8570 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1867 	Total: 4072.1972 	Mean_train_accuracy: 0.8847
# 	Mean_test_accuracy: 0.8280 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1868 	Total: 4063.9727 	Mean_train_accuracy: 0.8848
# 	Mean_test_accuracy: 0.8460 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1869 	Total: 4070.3524 	Mean_train_accuracy: 0.8816
# 	Mean_test_accuracy: 0.8420 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1870 	Total: 4072.3708 	Mean_train_accuracy: 0.8821
# 	Mean_test_accuracy: 0.8470 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1871 	Total: 4067.5833 	Mean_train_accuracy: 0.8856
# 	Mean_test_accuracy: 0.8490 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1872 	Total: 4085.0347 	Mean_train_accuracy: 0.8842
# 	Mean_test_accuracy: 0.8470 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1873 	Total: 4145.5448 	Mean_train_accuracy: 0.8818
# 	Mean_test_accuracy: 0.8390 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1874 	Total: 4104.4986 	Mean_train_accuracy: 0.8844
# 	Mean_test_accuracy: 0.8540 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1875 	Total: 4065.3474 	Mean_train_accuracy: 0.8911
# 	Mean_test_accuracy: 0.8480 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1876 	Total: 4060.8109 	Mean_train_accuracy: 0.8869
# 	Mean_test_accuracy: 0.8580 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1877 	Total: 4064.8534 	Mean_train_accuracy: 0.8863
# 	Mean_test_accuracy: 0.8650 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1878 	Total: 4085.8273 	Mean_train_accuracy: 0.8885
# 	Mean_test_accuracy: 0.8500 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1879 	Total: 4097.7647 	Mean_train_accuracy: 0.8858
# 	Mean_test_accuracy: 0.8560 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1880 	Total: 4060.7144 	Mean_train_accuracy: 0.8835
# 	Mean_test_accuracy: 0.8530 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1881 	Total: 4090.4519 	Mean_train_accuracy: 0.8842
# 	Mean_test_accuracy: 0.8510 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1882 	Total: 4103.4536 	Mean_train_accuracy: 0.8847
# 	Mean_test_accuracy: 0.8580 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1883 	Total: 4088.5715 	Mean_train_accuracy: 0.8818
# 	Mean_test_accuracy: 0.8520 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1884 	Total: 4141.5596 	Mean_train_accuracy: 0.8816
# 	Mean_test_accuracy: 0.8450 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1885 	Total: 4182.2068 	Mean_train_accuracy: 0.8844
# 	Mean_test_accuracy: 0.8510 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1886 	Total: 4163.9889 	Mean_train_accuracy: 0.8851
# 	Mean_test_accuracy: 0.8550 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1887 	Total: 4089.6425 	Mean_train_accuracy: 0.8827
# 	Mean_test_accuracy: 0.8380 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1888 	Total: 4096.9775 	Mean_train_accuracy: 0.8864
# 	Mean_test_accuracy: 0.8510 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1889 	Total: 4152.6492 	Mean_train_accuracy: 0.8808
# 	Mean_test_accuracy: 0.8400 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1890 	Total: 4087.3303 	Mean_train_accuracy: 0.8831
# 	Mean_test_accuracy: 0.8360 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1891 	Total: 4062.6526 	Mean_train_accuracy: 0.8842
# 	Mean_test_accuracy: 0.8550 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1892 	Total: 4089.0401 	Mean_train_accuracy: 0.8826
# 	Mean_test_accuracy: 0.8440 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1893 	Total: 4105.5008 	Mean_train_accuracy: 0.8849
# 	Mean_test_accuracy: 0.8480 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1894 	Total: 4086.6223 	Mean_train_accuracy: 0.8828
# 	Mean_test_accuracy: 0.8520 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1895 	Total: 4071.4393 	Mean_train_accuracy: 0.8848
# 	Mean_test_accuracy: 0.8420 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1896 	Total: 4086.8732 	Mean_train_accuracy: 0.8826
# 	Mean_test_accuracy: 0.8600 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1897 	Total: 4057.9784 	Mean_train_accuracy: 0.8874
# 	Mean_test_accuracy: 0.8400 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1898 	Total: 4099.0391 	Mean_train_accuracy: 0.8831
# 	Mean_test_accuracy: 0.8480 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1899 	Total: 4086.9059 	Mean_train_accuracy: 0.8847
# 	Mean_test_accuracy: 0.8540 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1900 	Total: 4074.5968 	Mean_train_accuracy: 0.8866
# 	Mean_test_accuracy: 0.8450 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1901 	Total: 4093.5516 	Mean_train_accuracy: 0.8883
# 	Mean_test_accuracy: 0.8520 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1902 	Total: 4067.3671 	Mean_train_accuracy: 0.8852
# 	Mean_test_accuracy: 0.8490 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1903 	Total: 4069.7455 	Mean_train_accuracy: 0.8907
# 	Mean_test_accuracy: 0.8350 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1904 	Total: 4115.7349 	Mean_train_accuracy: 0.8827
# 	Mean_test_accuracy: 0.8560 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1905 	Total: 4127.6264 	Mean_train_accuracy: 0.8864
# 	Mean_test_accuracy: 0.8440 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1906 	Total: 4073.7793 	Mean_train_accuracy: 0.8839
# 	Mean_test_accuracy: 0.8380 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1907 	Total: 4071.7316 	Mean_train_accuracy: 0.8866
# 	Mean_test_accuracy: 0.8310 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1908 	Total: 4110.4422 	Mean_train_accuracy: 0.8822
# 	Mean_test_accuracy: 0.8620 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1909 	Total: 4074.4160 	Mean_train_accuracy: 0.8857
# 	Mean_test_accuracy: 0.8590 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1910 	Total: 4077.1387 	Mean_train_accuracy: 0.8866
# 	Mean_test_accuracy: 0.8390 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1911 	Total: 4060.2152 	Mean_train_accuracy: 0.8891
# 	Mean_test_accuracy: 0.8400 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1912 	Total: 4105.3911 	Mean_train_accuracy: 0.8823
# 	Mean_test_accuracy: 0.8460 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1913 	Total: 4087.0464 	Mean_train_accuracy: 0.8843
# 	Mean_test_accuracy: 0.8540 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1914 	Total: 4079.1067 	Mean_train_accuracy: 0.8816
# 	Mean_test_accuracy: 0.8620 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1915 	Total: 4086.2173 	Mean_train_accuracy: 0.8801
# 	Mean_test_accuracy: 0.8460 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1916 	Total: 4080.3067 	Mean_train_accuracy: 0.8836
# 	Mean_test_accuracy: 0.8490 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1917 	Total: 4062.9053 	Mean_train_accuracy: 0.8839
# 	Mean_test_accuracy: 0.8540 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1918 	Total: 4116.4834 	Mean_train_accuracy: 0.8835
# 	Mean_test_accuracy: 0.8460 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1919 	Total: 4104.8275 	Mean_train_accuracy: 0.8858
# 	Mean_test_accuracy: 0.8510 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1920 	Total: 4089.9193 	Mean_train_accuracy: 0.8875
# 	Mean_test_accuracy: 0.8550 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1921 	Total: 4068.9103 	Mean_train_accuracy: 0.8856
# 	Mean_test_accuracy: 0.8450 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1922 	Total: 4066.8335 	Mean_train_accuracy: 0.8869
# 	Mean_test_accuracy: 0.8390 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1923 	Total: 4058.9897 	Mean_train_accuracy: 0.8874
# 	Mean_test_accuracy: 0.8390 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1924 	Total: 4064.1878 	Mean_train_accuracy: 0.8876
# 	Mean_test_accuracy: 0.8500 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1925 	Total: 4051.0592 	Mean_train_accuracy: 0.8852
# 	Mean_test_accuracy: 0.8500 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1926 	Total: 4063.2370 	Mean_train_accuracy: 0.8883
# 	Mean_test_accuracy: 0.8550 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1927 	Total: 4053.5368 	Mean_train_accuracy: 0.8867
# 	Mean_test_accuracy: 0.8500 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1928 	Total: 4043.5137 	Mean_train_accuracy: 0.8888
# 	Mean_test_accuracy: 0.8430 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1929 	Total: 4062.2791 	Mean_train_accuracy: 0.8816
# 	Mean_test_accuracy: 0.8290 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1930 	Total: 4106.6569 	Mean_train_accuracy: 0.8881
# 	Mean_test_accuracy: 0.8350 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1931 	Total: 4090.2488 	Mean_train_accuracy: 0.8806
# 	Mean_test_accuracy: 0.8530 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1932 	Total: 4087.3016 	Mean_train_accuracy: 0.8859
# 	Mean_test_accuracy: 0.8470 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1933 	Total: 4051.1269 	Mean_train_accuracy: 0.8828
# 	Mean_test_accuracy: 0.8560 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1934 	Total: 4066.7041 	Mean_train_accuracy: 0.8901
# 	Mean_test_accuracy: 0.8350 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1935 	Total: 4057.4597 	Mean_train_accuracy: 0.8874
# 	Mean_test_accuracy: 0.8400 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1936 	Total: 4111.0837 	Mean_train_accuracy: 0.8863
# 	Mean_test_accuracy: 0.8510 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1937 	Total: 4197.8416 	Mean_train_accuracy: 0.8780
# 	Mean_test_accuracy: 0.8500 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1938 	Total: 4187.9557 	Mean_train_accuracy: 0.8819
# 	Mean_test_accuracy: 0.8470 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1939 	Total: 4109.7766 	Mean_train_accuracy: 0.8884
# 	Mean_test_accuracy: 0.8380 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1940 	Total: 4093.2115 	Mean_train_accuracy: 0.8852
# 	Mean_test_accuracy: 0.8430 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1941 	Total: 4105.0855 	Mean_train_accuracy: 0.8832
# 	Mean_test_accuracy: 0.8620 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1942 	Total: 4173.3017 	Mean_train_accuracy: 0.8835
# 	Mean_test_accuracy: 0.8530 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1943 	Total: 4108.4155 	Mean_train_accuracy: 0.8846
# 	Mean_test_accuracy: 0.8510 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1944 	Total: 4061.0123 	Mean_train_accuracy: 0.8874
# 	Mean_test_accuracy: 0.8490 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1945 	Total: 4070.7223 	Mean_train_accuracy: 0.8834
# 	Mean_test_accuracy: 0.8430 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1946 	Total: 4073.0889 	Mean_train_accuracy: 0.8878
# 	Mean_test_accuracy: 0.8450 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1947 	Total: 4063.2238 	Mean_train_accuracy: 0.8844
# 	Mean_test_accuracy: 0.8480 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1948 	Total: 4090.1016 	Mean_train_accuracy: 0.8820
# 	Mean_test_accuracy: 0.8410 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1949 	Total: 4126.9635 	Mean_train_accuracy: 0.8807
# 	Mean_test_accuracy: 0.8580 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1950 	Total: 4090.3179 	Mean_train_accuracy: 0.8865
# 	Mean_test_accuracy: 0.8540 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1951 	Total: 4065.7097 	Mean_train_accuracy: 0.8868
# 	Mean_test_accuracy: 0.8570 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1952 	Total: 4070.5876 	Mean_train_accuracy: 0.8807
# 	Mean_test_accuracy: 0.8490 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1953 	Total: 4102.7375 	Mean_train_accuracy: 0.8846
# 	Mean_test_accuracy: 0.8490 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1954 	Total: 4070.6027 	Mean_train_accuracy: 0.8858
# 	Mean_test_accuracy: 0.8560 	Mean_test_accuracy_sum: 0.5560
# Epoch: 1955 	Total: 4090.3918 	Mean_train_accuracy: 0.8819
# 	Mean_test_accuracy: 0.8470 	Mean_test_accuracy_sum: 0.5560
