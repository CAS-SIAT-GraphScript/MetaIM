# %%
import torch
pwd = '/home/zjy/project/MetaIM/data'
device = torch.device('cuda:2' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=2)

# %%
from torch_geometric.datasets import Planetoid

cora_dataset = Planetoid(root=pwd+'/cora', name='cora')
data = cora_dataset[0]
edge_index = data.edge_index

# %%
import numpy as np
individual_infection_path = pwd+'/for_meta/cora_individual_infection_sir_200_sample_500.npy'
seeds_infection_path = pwd+'/for_meta/cora_seed_infection_sir_200_sample_500.npy'

individual_infection = np.load(individual_infection_path)
seeds_infection = np.load(seeds_infection_path)
individual_infection.shape,seeds_infection.shape
# Out:
# ((2708, 2708), (1000, 2, 2708))

# %%
import torch
from torch_geometric.utils import to_scipy_sparse_matrix
import scipy.sparse as sp

# 转换为 scipy 稀疏矩阵
adj = to_scipy_sparse_matrix(edge_index)


# def normalize_adj(mx):
#     """Row-normalize sparse matrix"""
#     rowsum = np.array(mx.sum(1))
#     r_inv_sqrt = np.power(rowsum, -0.5).flatten()
#     r_inv_sqrt[np.isinf(r_inv_sqrt)] = 0.
#     r_mat_inv_sqrt = sp.diags(r_inv_sqrt)
#     return mx.dot(r_mat_inv_sqrt).transpose().dot(r_mat_inv_sqrt)



# adj = adj + adj.T.multiply(adj.T > adj) - adj.multiply(adj.T > adj)
# adj = normalize_adj(adj + sp.eye(adj.shape[0]))
adj = torch.Tensor(adj.toarray()).to_sparse()
adj
# Out:
# tensor(indices=tensor([[   0,    0,    0,  ..., 2707, 2707, 2707],
#                        [ 633, 1862, 2582,  ...,  598, 1473, 2706]]),
#        values=tensor([1., 1., 1.,  ..., 1., 1., 1.]),
#        size=(2708, 2708), nnz=10556, layout=torch.sparse_coo)

# %%
feat_num = int(seeds_infection[0][0].sum())

# %%
from torch.utils.data import Dataset, DataLoader, random_split


class CustomDataset(Dataset):
    def __init__(self, individual_infection,seeds_infection, feat_num):
        self.individual_infection = individual_infection
        self.seeds_infection = seeds_infection
        self.feat_shape = (len(individual_infection), feat_num)

    def __len__(self):
        return len(self.seeds_infection)

    def __getitem__(self, idx):
        seeds= np.nonzero(self.seeds_infection[idx][0])[0]
        
        feature = torch.zeros(self.feat_shape[0],self.feat_shape[1])
        for i in range(len(seeds)):
            seed_i_infection = torch.tensor(self.individual_infection[seeds[i]])
            feature[:, i] = seed_i_infection
            
        label = self.seeds_infection[idx][1]
        
        return feature, label

dataset = CustomDataset(individual_infection,seeds_infection,feat_num)

# %%
# 定义划分比例
train_ratio = 0.8
test_ratio = 0.2

# 划分数据集
train_dataset, test_dataset = random_split(dataset, [int(len(dataset)*train_ratio), int(len(dataset)*test_ratio)])

train_batch_size = 32
test_batch_size = 2

# 创建数据加载器
train_loader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True, drop_last=False)
test_loader = DataLoader(test_dataset, batch_size=test_batch_size, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv

class GAT(nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_heads):
        super(GAT, self).__init__()
        self.conv1 = GATConv(in_channels, hidden_channels, heads=num_heads)
        self.conv2 = GATConv(hidden_channels * num_heads, out_channels, heads=1)

    def forward(self, x, edge_index):
        x = F.elu(self.conv1(x, edge_index))
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv2(x, edge_index)
        return F.elu(x)

# %%
# from data.model.gat import GAT, SpGAT
from torch.optim import Adam, SGD


# forward_model = SpGAT(nfeat=feat_num, 
#                 nhid=64, 
#                 nclass=1, 
#                 dropout=0.2, 
#                 nheads=1, 
#                 alpha=0.2)
forward_model = GAT(feat_num, 256, 1, 8)

optimizer = Adam([{'params': forward_model.parameters()}], 
                 lr=1e-3)

adj = adj.to(device)
forward_model = forward_model.to(device)
forward_model.train()
# Out:
# GAT(
#   (conv1): GATConv(135, 256, heads=8)
#   (conv2): GATConv(2048, 1, heads=1)
# )

# %%
def weighted_dkl(y_true, y_pred, weights=None):
    y_true = torch.clamp(y_true, 1e-15, 1 - 1e-15)
    y_pred = torch.clamp(y_pred, 1e-15, 1 - 1e-15)
    loss = torch.sum(y_true * (torch.log(y_true) - torch.log(y_pred)), -1)
    return torch.sum(loss)


def weighted_jsd(y_true, y_pred, weights=None):
    m = 0.5 * (y_true + y_pred)
    return weighted_dkl(y_true, m, weights=weights) + weighted_dkl(
        y_pred, m, weights=weights
    )

# %%
edge_index = edge_index.to(device)
top_num = 500

for epoch in range(2000):

    total_overall = 0
    forward_loss = 0

    mean_train_accuracy = 0
    for batch_idx, feature_label in enumerate(train_loader):        
        features = feature_label[0].to(device)
        labels = feature_label[1].to(device)
        optimizer.zero_grad()
        
        loss = 0
        train_accuracy = 0
        for i, x_i in enumerate(features):
            y_i = labels[i]
            y_hat = forward_model(x_i, edge_index)
            _, top_indices_true = torch.topk(y_i.clone(), top_num)
            label_2 = torch.zeros(y_i.shape).to(device)
            label_2[top_indices_true] = 1
            
            _, top_indices_predict = torch.topk(y_hat.clone().squeeze(-1), top_num)
            
            # 将张量数组转换为Python列表
            list1 = top_indices_true.tolist()
            list_pre = top_indices_predict.tolist()

            # 使用集合操作找到交集
            intersection = list(set(list1) & set(list_pre))
            accuracy_i = len(intersection) / top_num       
            train_accuracy += accuracy_i 

            forward_loss = 0.5*F.mse_loss(y_hat.squeeze(-1), y_i, reduction='sum') + F.mse_loss(y_hat.squeeze(-1), label_2, reduction='sum')      
            loss += forward_loss    
        
        total_overall += loss.item()    
        train_accuracy /= len(features)
        mean_train_accuracy = train_accuracy
        loss = loss/features.size(0)
        loss.backward()
        optimizer.step()
        # for p in forward_model.parameters():
        #     p.data.clamp_(min=0)
        
        
    print("Epoch: {}".format(epoch+1), 
        "\tTotal: {:.4f}".format(total_overall / train_batch_size),
        "\tMean_train_accuracy: {:.4f}".format(mean_train_accuracy),
        )  
    
    mean_accuracy = 0
    mean_accuracy_sum = 0

    
    for batch_idx, feature_label in enumerate(test_loader):   
        features = feature_label[0].to(device)
        labels = feature_label[1].to(device)
        
        accuracy = 0
        accuracy_sum = 0
        
        for i, x_i in enumerate(features):
            y_i = labels[i]
            _, top_indices_true = torch.topk(y_i, top_num)
            
            y_hat = forward_model(x_i, edge_index)
            
            _, top_indices_predict = torch.topk(y_hat.squeeze(-1), top_num)
            
            sum_pre = torch.sum(x_i, dim=1, keepdim=True)
            _, top_indices_sum = torch.topk(sum_pre.squeeze(-1), top_num)
            
            # 将张量数组转换为Python列表
            list1 = top_indices_true.tolist()
            list_pre = top_indices_predict.tolist()
            
            list_sum = top_indices_sum.tolist()

            # 使用集合操作找到交集
            intersection = list(set(list1) & set(list_pre))
            
            intersection_sum = list(set(list1) & set(list_sum))
            
            accuracy_i = len(intersection) / top_num       
            accuracy += accuracy_i 
            accuracy_sum += len(intersection_sum) / top_num  
        accuracy /= test_batch_size
        accuracy_sum/= test_batch_size
        mean_accuracy = accuracy
        mean_accuracy_sum = accuracy_sum
        break
    
    print(
        "\tMean_test_accuracy: {:.4f}".format(mean_accuracy),
        "\tMean_test_accuracy_sum: {:.4f}".format(mean_accuracy_sum)
        )
# Out:
# Epoch: 1 	Total: 14417.1475 	Mean_train_accuracy: 0.4350
# 	Mean_test_accuracy: 0.4300 	Mean_test_accuracy_sum: 0.5070
# Epoch: 2 	Total: 10956.3455 	Mean_train_accuracy: 0.4408
# 	Mean_test_accuracy: 0.4260 	Mean_test_accuracy_sum: 0.5070
# Epoch: 3 	Total: 10768.3653 	Mean_train_accuracy: 0.4416
# 	Mean_test_accuracy: 0.4360 	Mean_test_accuracy_sum: 0.5070
# Epoch: 4 	Total: 10708.2341 	Mean_train_accuracy: 0.4453
# 	Mean_test_accuracy: 0.4370 	Mean_test_accuracy_sum: 0.5070
# Epoch: 5 	Total: 10660.1141 	Mean_train_accuracy: 0.4459
# 	Mean_test_accuracy: 0.4460 	Mean_test_accuracy_sum: 0.5070
# Epoch: 6 	Total: 10616.7645 	Mean_train_accuracy: 0.4546
# 	Mean_test_accuracy: 0.4450 	Mean_test_accuracy_sum: 0.5070
# Epoch: 7 	Total: 10594.1547 	Mean_train_accuracy: 0.4532
# 	Mean_test_accuracy: 0.4400 	Mean_test_accuracy_sum: 0.5070
# Epoch: 8 	Total: 10568.7242 	Mean_train_accuracy: 0.4659
# 	Mean_test_accuracy: 0.4480 	Mean_test_accuracy_sum: 0.5070
# Epoch: 9 	Total: 10544.3789 	Mean_train_accuracy: 0.4616
# 	Mean_test_accuracy: 0.4490 	Mean_test_accuracy_sum: 0.5070
# Epoch: 10 	Total: 10521.4626 	Mean_train_accuracy: 0.4550
# 	Mean_test_accuracy: 0.4500 	Mean_test_accuracy_sum: 0.5070
# Epoch: 11 	Total: 10495.9589 	Mean_train_accuracy: 0.4563
# 	Mean_test_accuracy: 0.4540 	Mean_test_accuracy_sum: 0.5070
# Epoch: 12 	Total: 10472.9703 	Mean_train_accuracy: 0.4564
# 	Mean_test_accuracy: 0.4540 	Mean_test_accuracy_sum: 0.5070
# Epoch: 13 	Total: 10447.7763 	Mean_train_accuracy: 0.4648
# 	Mean_test_accuracy: 0.4550 	Mean_test_accuracy_sum: 0.5070
# Epoch: 14 	Total: 10426.3709 	Mean_train_accuracy: 0.4656
# 	Mean_test_accuracy: 0.4570 	Mean_test_accuracy_sum: 0.5070
# Epoch: 15 	Total: 10399.3680 	Mean_train_accuracy: 0.4648
# 	Mean_test_accuracy: 0.4610 	Mean_test_accuracy_sum: 0.5070
# Epoch: 16 	Total: 10381.9139 	Mean_train_accuracy: 0.4746
# 	Mean_test_accuracy: 0.4660 	Mean_test_accuracy_sum: 0.5070
# Epoch: 17 	Total: 10363.8762 	Mean_train_accuracy: 0.4615
# 	Mean_test_accuracy: 0.4670 	Mean_test_accuracy_sum: 0.5070
# Epoch: 18 	Total: 10346.4911 	Mean_train_accuracy: 0.4651
# 	Mean_test_accuracy: 0.4720 	Mean_test_accuracy_sum: 0.5070
# Epoch: 19 	Total: 10334.4328 	Mean_train_accuracy: 0.4726
# 	Mean_test_accuracy: 0.4730 	Mean_test_accuracy_sum: 0.5070
# Epoch: 20 	Total: 10315.2719 	Mean_train_accuracy: 0.4732
# 	Mean_test_accuracy: 0.4720 	Mean_test_accuracy_sum: 0.5070
# Epoch: 21 	Total: 10301.7508 	Mean_train_accuracy: 0.4804
# 	Mean_test_accuracy: 0.4700 	Mean_test_accuracy_sum: 0.5070
# Epoch: 22 	Total: 10285.0618 	Mean_train_accuracy: 0.4708
# 	Mean_test_accuracy: 0.4740 	Mean_test_accuracy_sum: 0.5070
# Epoch: 23 	Total: 10271.0248 	Mean_train_accuracy: 0.4785
# 	Mean_test_accuracy: 0.4690 	Mean_test_accuracy_sum: 0.5070
# Epoch: 24 	Total: 10256.1218 	Mean_train_accuracy: 0.4792
# 	Mean_test_accuracy: 0.4810 	Mean_test_accuracy_sum: 0.5070
# Epoch: 25 	Total: 10246.3368 	Mean_train_accuracy: 0.4705
# 	Mean_test_accuracy: 0.4830 	Mean_test_accuracy_sum: 0.5070
# Epoch: 26 	Total: 10224.6803 	Mean_train_accuracy: 0.4776
# 	Mean_test_accuracy: 0.4840 	Mean_test_accuracy_sum: 0.5070
# Epoch: 27 	Total: 10211.9323 	Mean_train_accuracy: 0.4893
# 	Mean_test_accuracy: 0.4740 	Mean_test_accuracy_sum: 0.5070
# Epoch: 28 	Total: 10225.4314 	Mean_train_accuracy: 0.4869
# 	Mean_test_accuracy: 0.4860 	Mean_test_accuracy_sum: 0.5070
# Epoch: 29 	Total: 10184.8023 	Mean_train_accuracy: 0.4840
# 	Mean_test_accuracy: 0.4810 	Mean_test_accuracy_sum: 0.5070
# Epoch: 30 	Total: 10160.4619 	Mean_train_accuracy: 0.4881
# 	Mean_test_accuracy: 0.4820 	Mean_test_accuracy_sum: 0.5070
# Epoch: 31 	Total: 10141.8128 	Mean_train_accuracy: 0.4862
# 	Mean_test_accuracy: 0.4770 	Mean_test_accuracy_sum: 0.5070
# Epoch: 32 	Total: 10129.7156 	Mean_train_accuracy: 0.5058
# 	Mean_test_accuracy: 0.4880 	Mean_test_accuracy_sum: 0.5070
# Epoch: 33 	Total: 10103.9955 	Mean_train_accuracy: 0.4873
# 	Mean_test_accuracy: 0.4900 	Mean_test_accuracy_sum: 0.5070
# Epoch: 34 	Total: 10089.0731 	Mean_train_accuracy: 0.4947
# 	Mean_test_accuracy: 0.4920 	Mean_test_accuracy_sum: 0.5070
# Epoch: 35 	Total: 10074.6036 	Mean_train_accuracy: 0.4924
# 	Mean_test_accuracy: 0.4930 	Mean_test_accuracy_sum: 0.5070
# Epoch: 36 	Total: 10038.4796 	Mean_train_accuracy: 0.4935
# 	Mean_test_accuracy: 0.5060 	Mean_test_accuracy_sum: 0.5070
# Epoch: 37 	Total: 10014.8904 	Mean_train_accuracy: 0.5011
# 	Mean_test_accuracy: 0.5070 	Mean_test_accuracy_sum: 0.5070
# Epoch: 38 	Total: 9972.1612 	Mean_train_accuracy: 0.5166
# 	Mean_test_accuracy: 0.5100 	Mean_test_accuracy_sum: 0.5070
# Epoch: 39 	Total: 9940.3540 	Mean_train_accuracy: 0.5108
# 	Mean_test_accuracy: 0.5180 	Mean_test_accuracy_sum: 0.5070
# Epoch: 40 	Total: 9904.1379 	Mean_train_accuracy: 0.5121
# 	Mean_test_accuracy: 0.5200 	Mean_test_accuracy_sum: 0.5070
# Epoch: 41 	Total: 9860.9207 	Mean_train_accuracy: 0.5283
# 	Mean_test_accuracy: 0.5230 	Mean_test_accuracy_sum: 0.5070
# Epoch: 42 	Total: 9827.2750 	Mean_train_accuracy: 0.5286
# 	Mean_test_accuracy: 0.5360 	Mean_test_accuracy_sum: 0.5070
# Epoch: 43 	Total: 9782.3972 	Mean_train_accuracy: 0.5406
# 	Mean_test_accuracy: 0.5400 	Mean_test_accuracy_sum: 0.5070
# Epoch: 44 	Total: 9719.4474 	Mean_train_accuracy: 0.5396
# 	Mean_test_accuracy: 0.5430 	Mean_test_accuracy_sum: 0.5070
# Epoch: 45 	Total: 9662.5502 	Mean_train_accuracy: 0.5544
# 	Mean_test_accuracy: 0.5390 	Mean_test_accuracy_sum: 0.5070
# Epoch: 46 	Total: 9589.6577 	Mean_train_accuracy: 0.5620
# 	Mean_test_accuracy: 0.5620 	Mean_test_accuracy_sum: 0.5070
# Epoch: 47 	Total: 9523.8010 	Mean_train_accuracy: 0.5529
# 	Mean_test_accuracy: 0.5660 	Mean_test_accuracy_sum: 0.5070
# Epoch: 48 	Total: 9460.9750 	Mean_train_accuracy: 0.5606
# 	Mean_test_accuracy: 0.5560 	Mean_test_accuracy_sum: 0.5070
# Epoch: 49 	Total: 9393.5489 	Mean_train_accuracy: 0.5601
# 	Mean_test_accuracy: 0.5740 	Mean_test_accuracy_sum: 0.5070
# Epoch: 50 	Total: 9318.3878 	Mean_train_accuracy: 0.5739
# 	Mean_test_accuracy: 0.5880 	Mean_test_accuracy_sum: 0.5070
# Epoch: 51 	Total: 9230.9956 	Mean_train_accuracy: 0.5715
# 	Mean_test_accuracy: 0.5850 	Mean_test_accuracy_sum: 0.5070
# Epoch: 52 	Total: 9176.2502 	Mean_train_accuracy: 0.5779
# 	Mean_test_accuracy: 0.5770 	Mean_test_accuracy_sum: 0.5070
# Epoch: 53 	Total: 9102.1517 	Mean_train_accuracy: 0.5917
# 	Mean_test_accuracy: 0.6000 	Mean_test_accuracy_sum: 0.5070
# Epoch: 54 	Total: 9004.7490 	Mean_train_accuracy: 0.5917
# 	Mean_test_accuracy: 0.6150 	Mean_test_accuracy_sum: 0.5070
# Epoch: 55 	Total: 8928.9656 	Mean_train_accuracy: 0.5911
# 	Mean_test_accuracy: 0.6120 	Mean_test_accuracy_sum: 0.5070
# Epoch: 56 	Total: 8879.2661 	Mean_train_accuracy: 0.6104
# 	Mean_test_accuracy: 0.6100 	Mean_test_accuracy_sum: 0.5070
# Epoch: 57 	Total: 8781.8355 	Mean_train_accuracy: 0.6032
# 	Mean_test_accuracy: 0.6110 	Mean_test_accuracy_sum: 0.5070
# Epoch: 58 	Total: 8688.2482 	Mean_train_accuracy: 0.6123
# 	Mean_test_accuracy: 0.6200 	Mean_test_accuracy_sum: 0.5070
# Epoch: 59 	Total: 8559.9033 	Mean_train_accuracy: 0.6164
# 	Mean_test_accuracy: 0.6250 	Mean_test_accuracy_sum: 0.5070
# Epoch: 60 	Total: 8484.7532 	Mean_train_accuracy: 0.6146
# 	Mean_test_accuracy: 0.6250 	Mean_test_accuracy_sum: 0.5070
# Epoch: 61 	Total: 8348.5520 	Mean_train_accuracy: 0.6259
# 	Mean_test_accuracy: 0.6320 	Mean_test_accuracy_sum: 0.5070
# Epoch: 62 	Total: 8240.6201 	Mean_train_accuracy: 0.6336
# 	Mean_test_accuracy: 0.6290 	Mean_test_accuracy_sum: 0.5070
# Epoch: 63 	Total: 8156.9727 	Mean_train_accuracy: 0.6331
# 	Mean_test_accuracy: 0.6380 	Mean_test_accuracy_sum: 0.5070
# Epoch: 64 	Total: 8015.8418 	Mean_train_accuracy: 0.6410
# 	Mean_test_accuracy: 0.6450 	Mean_test_accuracy_sum: 0.5070
# Epoch: 65 	Total: 7987.4941 	Mean_train_accuracy: 0.6481
# 	Mean_test_accuracy: 0.6480 	Mean_test_accuracy_sum: 0.5070
# Epoch: 66 	Total: 7870.4869 	Mean_train_accuracy: 0.6509
# 	Mean_test_accuracy: 0.6630 	Mean_test_accuracy_sum: 0.5070
# Epoch: 67 	Total: 7803.0403 	Mean_train_accuracy: 0.6564
# 	Mean_test_accuracy: 0.6720 	Mean_test_accuracy_sum: 0.5070
# Epoch: 68 	Total: 7704.8330 	Mean_train_accuracy: 0.6546
# 	Mean_test_accuracy: 0.6630 	Mean_test_accuracy_sum: 0.5070
# Epoch: 69 	Total: 7571.2366 	Mean_train_accuracy: 0.6665
# 	Mean_test_accuracy: 0.6790 	Mean_test_accuracy_sum: 0.5070
# Epoch: 70 	Total: 7508.9326 	Mean_train_accuracy: 0.6771
# 	Mean_test_accuracy: 0.6790 	Mean_test_accuracy_sum: 0.5070
# Epoch: 71 	Total: 7454.5870 	Mean_train_accuracy: 0.6704
# 	Mean_test_accuracy: 0.6790 	Mean_test_accuracy_sum: 0.5070
# Epoch: 72 	Total: 7372.8658 	Mean_train_accuracy: 0.6751
# 	Mean_test_accuracy: 0.6780 	Mean_test_accuracy_sum: 0.5070
# Epoch: 73 	Total: 7317.0546 	Mean_train_accuracy: 0.6876
# 	Mean_test_accuracy: 0.6770 	Mean_test_accuracy_sum: 0.5070
# Epoch: 74 	Total: 7277.6442 	Mean_train_accuracy: 0.6789
# 	Mean_test_accuracy: 0.6750 	Mean_test_accuracy_sum: 0.5070
# Epoch: 75 	Total: 7336.8552 	Mean_train_accuracy: 0.6882
# 	Mean_test_accuracy: 0.6840 	Mean_test_accuracy_sum: 0.5070
# Epoch: 76 	Total: 7265.3589 	Mean_train_accuracy: 0.6838
# 	Mean_test_accuracy: 0.6910 	Mean_test_accuracy_sum: 0.5070
# Epoch: 77 	Total: 7239.4852 	Mean_train_accuracy: 0.6906
# 	Mean_test_accuracy: 0.6910 	Mean_test_accuracy_sum: 0.5070
# Epoch: 78 	Total: 7231.7600 	Mean_train_accuracy: 0.6879
# 	Mean_test_accuracy: 0.6900 	Mean_test_accuracy_sum: 0.5070
# Epoch: 79 	Total: 7320.8503 	Mean_train_accuracy: 0.6800
# 	Mean_test_accuracy: 0.6840 	Mean_test_accuracy_sum: 0.5070
# Epoch: 80 	Total: 7203.4509 	Mean_train_accuracy: 0.6874
# 	Mean_test_accuracy: 0.6930 	Mean_test_accuracy_sum: 0.5070
# Epoch: 81 	Total: 7183.2109 	Mean_train_accuracy: 0.6832
# 	Mean_test_accuracy: 0.6880 	Mean_test_accuracy_sum: 0.5070
# Epoch: 82 	Total: 7161.2187 	Mean_train_accuracy: 0.6927
# 	Mean_test_accuracy: 0.6860 	Mean_test_accuracy_sum: 0.5070
# Epoch: 83 	Total: 7171.4831 	Mean_train_accuracy: 0.6832
# 	Mean_test_accuracy: 0.6940 	Mean_test_accuracy_sum: 0.5070
# Epoch: 84 	Total: 7147.7944 	Mean_train_accuracy: 0.6848
# 	Mean_test_accuracy: 0.6980 	Mean_test_accuracy_sum: 0.5070
# Epoch: 85 	Total: 7148.5064 	Mean_train_accuracy: 0.6836
# 	Mean_test_accuracy: 0.6910 	Mean_test_accuracy_sum: 0.5070
# Epoch: 86 	Total: 7142.1493 	Mean_train_accuracy: 0.6873
# 	Mean_test_accuracy: 0.6970 	Mean_test_accuracy_sum: 0.5070
# Epoch: 87 	Total: 7131.6344 	Mean_train_accuracy: 0.6912
# 	Mean_test_accuracy: 0.6960 	Mean_test_accuracy_sum: 0.5070
# Epoch: 88 	Total: 7121.3646 	Mean_train_accuracy: 0.6889
# 	Mean_test_accuracy: 0.6920 	Mean_test_accuracy_sum: 0.5070
# Epoch: 89 	Total: 7113.7114 	Mean_train_accuracy: 0.6952
# 	Mean_test_accuracy: 0.6920 	Mean_test_accuracy_sum: 0.5070
# Epoch: 90 	Total: 7118.0056 	Mean_train_accuracy: 0.6838
# 	Mean_test_accuracy: 0.6830 	Mean_test_accuracy_sum: 0.5070
# Epoch: 91 	Total: 7100.6006 	Mean_train_accuracy: 0.6888
# 	Mean_test_accuracy: 0.6910 	Mean_test_accuracy_sum: 0.5070
# Epoch: 92 	Total: 7102.6914 	Mean_train_accuracy: 0.6959
# 	Mean_test_accuracy: 0.6920 	Mean_test_accuracy_sum: 0.5070
# Epoch: 93 	Total: 7099.1937 	Mean_train_accuracy: 0.6917
# 	Mean_test_accuracy: 0.6980 	Mean_test_accuracy_sum: 0.5070
# Epoch: 94 	Total: 7103.8318 	Mean_train_accuracy: 0.6901
# 	Mean_test_accuracy: 0.6930 	Mean_test_accuracy_sum: 0.5070
# Epoch: 95 	Total: 7104.5576 	Mean_train_accuracy: 0.6845
# 	Mean_test_accuracy: 0.6920 	Mean_test_accuracy_sum: 0.5070
# Epoch: 96 	Total: 7092.8226 	Mean_train_accuracy: 0.6954
# 	Mean_test_accuracy: 0.6970 	Mean_test_accuracy_sum: 0.5070
# Epoch: 97 	Total: 7089.8170 	Mean_train_accuracy: 0.6916
# 	Mean_test_accuracy: 0.6960 	Mean_test_accuracy_sum: 0.5070
# Epoch: 98 	Total: 7119.7793 	Mean_train_accuracy: 0.7029
# 	Mean_test_accuracy: 0.6890 	Mean_test_accuracy_sum: 0.5070
# Epoch: 99 	Total: 7108.1279 	Mean_train_accuracy: 0.6898
# 	Mean_test_accuracy: 0.7070 	Mean_test_accuracy_sum: 0.5070
# Epoch: 100 	Total: 7097.3477 	Mean_train_accuracy: 0.6804
# 	Mean_test_accuracy: 0.6880 	Mean_test_accuracy_sum: 0.5070
# Epoch: 101 	Total: 7079.3546 	Mean_train_accuracy: 0.6962
# 	Mean_test_accuracy: 0.6870 	Mean_test_accuracy_sum: 0.5070
# Epoch: 102 	Total: 7072.6322 	Mean_train_accuracy: 0.6919
# 	Mean_test_accuracy: 0.6910 	Mean_test_accuracy_sum: 0.5070
# Epoch: 103 	Total: 7070.6169 	Mean_train_accuracy: 0.6904
# 	Mean_test_accuracy: 0.6920 	Mean_test_accuracy_sum: 0.5070
# Epoch: 104 	Total: 7068.9211 	Mean_train_accuracy: 0.6907
# 	Mean_test_accuracy: 0.6990 	Mean_test_accuracy_sum: 0.5070
# Epoch: 105 	Total: 7070.6970 	Mean_train_accuracy: 0.6929
# 	Mean_test_accuracy: 0.6980 	Mean_test_accuracy_sum: 0.5070
# Epoch: 106 	Total: 7081.0027 	Mean_train_accuracy: 0.6902
# 	Mean_test_accuracy: 0.6930 	Mean_test_accuracy_sum: 0.5070
# Epoch: 107 	Total: 7082.3943 	Mean_train_accuracy: 0.6844
# 	Mean_test_accuracy: 0.7000 	Mean_test_accuracy_sum: 0.5070
# Epoch: 108 	Total: 7078.3716 	Mean_train_accuracy: 0.6954
# 	Mean_test_accuracy: 0.6990 	Mean_test_accuracy_sum: 0
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.5070
# Epoch: 381 	Total: 6798.3662 	Mean_train_accuracy: 0.7159
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.5070
# Epoch: 382 	Total: 6784.6932 	Mean_train_accuracy: 0.7169
# 	Mean_test_accuracy: 0.7080 	Mean_test_accuracy_sum: 0.5070
# Epoch: 383 	Total: 6842.0058 	Mean_train_accuracy: 0.7175
# 	Mean_test_accuracy: 0.7070 	Mean_test_accuracy_sum: 0.5070
# Epoch: 384 	Total: 6844.6140 	Mean_train_accuracy: 0.7149
# 	Mean_test_accuracy: 0.7190 	Mean_test_accuracy_sum: 0.5070
# Epoch: 385 	Total: 6805.7119 	Mean_train_accuracy: 0.7149
# 	Mean_test_accuracy: 0.7290 	Mean_test_accuracy_sum: 0.5070
# Epoch: 386 	Total: 6790.9493 	Mean_train_accuracy: 0.7208
# 	Mean_test_accuracy: 0.7120 	Mean_test_accuracy_sum: 0.5070
# Epoch: 387 	Total: 6788.9204 	Mean_train_accuracy: 0.7230
# 	Mean_test_accuracy: 0.7360 	Mean_test_accuracy_sum: 0.5070
# Epoch: 388 	Total: 6775.5327 	Mean_train_accuracy: 0.7214
# 	Mean_test_accuracy: 0.7190 	Mean_test_accuracy_sum: 0.5070
# Epoch: 389 	Total: 6776.2955 	Mean_train_accuracy: 0.7234
# 	Mean_test_accuracy: 0.7240 	Mean_test_accuracy_sum: 0.5070
# Epoch: 390 	Total: 6802.7303 	Mean_train_accuracy: 0.7194
# 	Mean_test_accuracy: 0.7270 	Mean_test_accuracy_sum: 0.5070
# Epoch: 391 	Total: 6793.6464 	Mean_train_accuracy: 0.7187
# 	Mean_test_accuracy: 0.7150 	Mean_test_accuracy_sum: 0.5070
# Epoch: 392 	Total: 6775.3890 	Mean_train_accuracy: 0.7205
# 	Mean_test_accuracy: 0.7140 	Mean_test_accuracy_sum: 0.5070
# Epoch: 393 	Total: 6789.6093 	Mean_train_accuracy: 0.7123
# 	Mean_test_accuracy: 0.7030 	Mean_test_accuracy_sum: 0.5070
# Epoch: 394 	Total: 6866.2138 	Mean_train_accuracy: 0.7093
# 	Mean_test_accuracy: 0.7190 	Mean_test_accuracy_sum: 0.5070
# Epoch: 395 	Total: 6825.7324 	Mean_train_accuracy: 0.7201
# 	Mean_test_accuracy: 0.7230 	Mean_test_accuracy_sum: 0.5070
# Epoch: 396 	Total: 6794.4418 	Mean_train_accuracy: 0.7126
# 	Mean_test_accuracy: 0.7210 	Mean_test_accuracy_sum: 0.5070
# Epoch: 397 	Total: 6809.4232 	Mean_train_accuracy: 0.7059
# 	Mean_test_accuracy: 0.7100 	Mean_test_accuracy_sum: 0.5070
# Epoch: 398 	Total: 6791.0681 	Mean_train_accuracy: 0.7215
# 	Mean_test_accuracy: 0.7180 	Mean_test_accuracy_sum: 0.5070
# Epoch: 399 	Total: 6774.9177 	Mean_train_accuracy: 0.7177
# 	Mean_test_accuracy: 0.7220 	Mean_test_accuracy_sum: 0.5070
# Epoch: 400 	Total: 6770.0323 	Mean_train_accuracy: 0.7233
# 	Mean_test_accuracy: 0.7180 	Mean_test_accuracy_sum: 0.5070
# Epoch: 401 	Total: 6771.5257 	Mean_train_accuracy: 0.7151
# 	Mean_test_accuracy: 0.7170 	Mean_test_accuracy_sum: 0.5070
# Epoch: 402 	Total: 6773.3188 	Mean_train_accuracy: 0.7212
# 	Mean_test_accuracy: 0.6970 	Mean_test_accuracy_sum: 0.5070
# Epoch: 403 	Total: 6771.3577 	Mean_train_accuracy: 0.7270
# 	Mean_test_accuracy: 0.7330 	Mean_test_accuracy_sum: 0.5070
# Epoch: 404 	Total: 6770.3364 	Mean_train_accuracy: 0.7128
# 	Mean_test_accuracy: 0.7100 	Mean_test_accuracy_sum: 0.