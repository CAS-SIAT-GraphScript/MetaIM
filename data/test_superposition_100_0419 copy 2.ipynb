# %%
import torch
pwd = '/home/zjy/project/MetaIM/data'
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=1)

# %%
from torch_geometric.datasets import Planetoid

cora_dataset = Planetoid(root=pwd+'/cora', name='cora')
data = cora_dataset[0]
edge_index = data.edge_index

# %%
import numpy as np
individual_infection_path = pwd+'/for_meta/cora_individual_infection_sir_200_sample_500.npy'
seeds_infection_path = pwd+'/for_meta/cora_seed_infection_sir_200_sample_500.npy'

individual_infection = np.load(individual_infection_path)
seeds_infection = np.load(seeds_infection_path)
individual_infection.shape,seeds_infection.shape
# Out:
# ((2708, 2708), (1000, 2, 2708))

# %%
import torch
from torch_geometric.utils import to_scipy_sparse_matrix
import scipy.sparse as sp

# 转换为 scipy 稀疏矩阵
adj = to_scipy_sparse_matrix(edge_index)


# def normalize_adj(mx):
#     """Row-normalize sparse matrix"""
#     rowsum = np.array(mx.sum(1))
#     r_inv_sqrt = np.power(rowsum, -0.5).flatten()
#     r_inv_sqrt[np.isinf(r_inv_sqrt)] = 0.
#     r_mat_inv_sqrt = sp.diags(r_inv_sqrt)
#     return mx.dot(r_mat_inv_sqrt).transpose().dot(r_mat_inv_sqrt)



# adj = adj + adj.T.multiply(adj.T > adj) - adj.multiply(adj.T > adj)
# adj = normalize_adj(adj + sp.eye(adj.shape[0]))
adj = torch.Tensor(adj.toarray()).to_sparse()
adj
# Out:
# tensor(indices=tensor([[   0,    0,    0,  ..., 2707, 2707, 2707],
#                        [ 633, 1862, 2582,  ...,  598, 1473, 2706]]),
#        values=tensor([1., 1., 1.,  ..., 1., 1., 1.]),
#        size=(2708, 2708), nnz=10556, layout=torch.sparse_coo)

# %%
feat_num = int(seeds_infection[0][0].sum())

# %%
from torch.utils.data import Dataset, DataLoader, random_split


class CustomDataset(Dataset):
    def __init__(self, individual_infection,seeds_infection, feat_num):
        self.individual_infection = individual_infection
        self.seeds_infection = seeds_infection
        self.feat_shape = (len(individual_infection), feat_num)

    def __len__(self):
        return len(self.seeds_infection)

    def __getitem__(self, idx):
        seeds= np.nonzero(self.seeds_infection[idx][0])[0]
        
        feature = torch.zeros(self.feat_shape[0],self.feat_shape[1])
        for i in range(len(seeds)):
            seed_i_infection = torch.tensor(self.individual_infection[seeds[i]])
            feature[:, i] = seed_i_infection
            
        label = self.seeds_infection[idx][1]
        
        return feature, label

dataset = CustomDataset(individual_infection,seeds_infection,feat_num)

# %%
# 定义划分比例
train_ratio = 0.8
test_ratio = 0.2

# 划分数据集
train_dataset, test_dataset = random_split(dataset, [int(len(dataset)*train_ratio), int(len(dataset)*test_ratio)])

train_batch_size = 32
test_batch_size = 2

# 创建数据加载器
train_loader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True, drop_last=False)
test_loader = DataLoader(test_dataset, batch_size=test_batch_size, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv

class GAT(nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_heads):
        super(GAT, self).__init__()
        self.conv1 = GATConv(in_channels, hidden_channels, heads=num_heads)
        self.conv2 = GATConv(hidden_channels * num_heads, out_channels, heads=1)

    def forward(self, x, edge_index):
        x = F.elu(self.conv1(x, edge_index))
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv2(x, edge_index)
        return F.elu(x)

# %%
# from data.model.gat import GAT, SpGAT
from torch.optim import Adam, SGD


# forward_model = SpGAT(nfeat=feat_num, 
#                 nhid=64, 
#                 nclass=1, 
#                 dropout=0.2, 
#                 nheads=1, 
#                 alpha=0.2)
forward_model = GAT(feat_num, 256, 1, 8)

optimizer = Adam([{'params': forward_model.parameters()}], 
                 lr=1e-3)

adj = adj.to(device)
forward_model = forward_model.to(device)
forward_model.train()
# Out:
# GAT(
#   (conv1): GATConv(135, 256, heads=8)
#   (conv2): GATConv(2048, 1, heads=1)
# )

# %%
# def weighted_dkl(y_true, y_pred):
#     y_true = torch.clamp(y_true, 1e-15, 1 - 1e-15)
#     y_pred = torch.clamp(y_pred, 1e-15, 1 - 1e-15)
#     loss = torch.sum(y_true * (torch.log(y_true) - torch.log(y_pred)), -1)
#     return torch.sum(loss)


# def weighted_jsd(y_true, y_pred):
#     m = 0.5 * (y_true + y_pred)
#     return weighted_dkl(y_true, m) + weighted_dkl(y_pred, m)



def weighted_dkl_and_jsd(y_true, y_pred):
    # 防止概率值为0或1，避免 log(0) 或 log(1) 的情况
    y_true = torch.clamp(y_true, 1e-15, 1 - 1e-15)
    y_pred = torch.clamp(y_pred, 1e-15, 1 - 1e-15)
    
    # 计算 Jensen-Shannon 散度所需的中间值
    m = 0.5 * (y_true + y_pred)
    
    # 计算加权的 Kullback-Leibler 散度
    loss_dkl = torch.sum(y_true * (torch.log(y_true) - torch.log(y_pred)), -1)
    
    # 计算加权的 Jensen-Shannon 散度
    loss_jsd = torch.sum(loss_dkl) + torch.sum(weighted_dkl(y_pred, m))
    
    return loss_dkl, loss_jsd

# %%
import torch

def kl_divergence(p, q):
    # 防止概率值为0或1，避免 log(0) 或 log(1) 的情况
    p = torch.clamp(p, 1e-15, 1 - 1e-15)
    q = torch.clamp(q, 1e-15, 1 - 1e-15)
    
    # 计算 KL 散度
    kl_div = torch.sum(p * (torch.log(p) - torch.log(q)), -1)
    
    return kl_div

# 例子使用
p_distribution = torch.tensor([0.2, 0.8])
q_distribution = torch.tensor([0.3, 0.7])

kl_loss = kl_divergence(p_distribution, q_distribution)
print("KL Divergence:", kl_loss.item())
# Out:
# KL Divergence: 0.025732122361660004

# %%
edge_index = edge_index.to(device)
top_num = 300

for epoch in range(2000):

    total_overall = 0
    forward_loss = 0

    mean_train_accuracy = 0
    for batch_idx, feature_label in enumerate(train_loader):        
        features = feature_label[0].to(device)
        labels = feature_label[1].to(device)
        optimizer.zero_grad()
        
        loss = 0
        train_accuracy = 0
        for i, x_i in enumerate(features):
            y_i = labels[i]
            y_hat = forward_model(x_i, edge_index)
            _, top_indices_true = torch.topk(y_i.clone(), top_num)
            label_2 = torch.zeros(y_i.shape).to(device)
            label_2[top_indices_true] = 1
            
            _, top_indices_predict = torch.topk(y_hat.clone().squeeze(-1), top_num)
            
            # 将张量数组转换为Python列表
            list1 = top_indices_true.tolist()
            list_pre = top_indices_predict.tolist()

            # 使用集合操作找到交集
            intersection = list(set(list1) & set(list_pre))
            accuracy_i = len(intersection) / top_num       
            train_accuracy += accuracy_i 

            forward_loss = 0.5*F.mse_loss(y_hat.squeeze(-1), y_i, reduction='sum') + F.mse_loss(y_hat.squeeze(-1), label_2, reduction='sum') + kl_divergence(y_hat.squeeze(-1), y_i) 
            # forward_loss = weighted_jsd(y_hat, y_i)  
            loss += forward_loss    
        
        total_overall += loss.item()    
        train_accuracy /= len(features)
        mean_train_accuracy = train_accuracy
        loss.backward()
        optimizer.step()
        # for p in forward_model.parameters():
        #     p.data.clamp_(min=0)
        
        
    print("Epoch: {}".format(epoch+1), 
        "\tTotal: {:.4f}".format(total_overall / train_batch_size),
        "\tMean_train_accuracy: {:.4f}".format(mean_train_accuracy),
        )  
    
    mean_accuracy = 0
    mean_accuracy_sum = 0

    
    for batch_idx, feature_label in enumerate(test_loader):   
        features = feature_label[0].to(device)
        labels = feature_label[1].to(device)
        
        accuracy = 0
        accuracy_sum = 0
        
        for i, x_i in enumerate(features):
            y_i = labels[i]
            _, top_indices_true = torch.topk(y_i, top_num)
            
            y_hat = forward_model(x_i, edge_index)
            
            _, top_indices_predict = torch.topk(y_hat.squeeze(-1), top_num)
            
            sum_pre = torch.sum(x_i, dim=1, keepdim=True)
            _, top_indices_sum = torch.topk(sum_pre.squeeze(-1), top_num)
            
            # 将张量数组转换为Python列表
            list1 = top_indices_true.tolist()
            list_pre = top_indices_predict.tolist()
            
            list_sum = top_indices_sum.tolist()

            # 使用集合操作找到交集
            intersection = list(set(list1) & set(list_pre))
            
            intersection_sum = list(set(list1) & set(list_sum))
            
            accuracy_i = len(intersection) / top_num       
            accuracy += accuracy_i 
            accuracy_sum += len(intersection_sum) / top_num  
        accuracy /= test_batch_size
        accuracy_sum/= test_batch_size
        mean_accuracy = accuracy
        mean_accuracy_sum = accuracy_sum
        break
    
    print(
        "\tMean_test_accuracy: {:.4f}".format(mean_accuracy),
        "\tMean_test_accuracy_sum: {:.4f}".format(mean_accuracy_sum)
        )
# Out:
# Epoch: 1 	Total: 3672.9822 	Mean_train_accuracy: 0.7015
# 	Mean_test_accuracy: 0.6900 	Mean_test_accuracy_sum: 0.3883
# Epoch: 2 	Total: 3666.7721 	Mean_train_accuracy: 0.7070
# 	Mean_test_accuracy: 0.6867 	Mean_test_accuracy_sum: 0.3883
# Epoch: 3 	Total: 3621.8003 	Mean_train_accuracy: 0.7137
# 	Mean_test_accuracy: 0.6800 	Mean_test_accuracy_sum: 0.3883
# Epoch: 4 	Total: 3621.9491 	Mean_train_accuracy: 0.7078
# 	Mean_test_accuracy: 0.6867 	Mean_test_accuracy_sum: 0.3883
# Epoch: 5 	Total: 3815.0370 	Mean_train_accuracy: 0.6955
# 	Mean_test_accuracy: 0.6700 	Mean_test_accuracy_sum: 0.3883
# Epoch: 6 	Total: 4012.4893 	Mean_train_accuracy: 0.6995
# 	Mean_test_accuracy: 0.6783 	Mean_test_accuracy_sum: 0.3883
# Epoch: 7 	Total: 3704.4662 	Mean_train_accuracy: 0.7070
# 	Mean_test_accuracy: 0.6850 	Mean_test_accuracy_sum: 0.3883
# Epoch: 8 	Total: 3659.6958 	Mean_train_accuracy: 0.7085
# 	Mean_test_accuracy: 0.6967 	Mean_test_accuracy_sum: 0.3883
# Epoch: 9 	Total: 3620.1743 	Mean_train_accuracy: 0.7125
# 	Mean_test_accuracy: 0.6950 	Mean_test_accuracy_sum: 0.3883
# Epoch: 10 	Total: 3655.6970 	Mean_train_accuracy: 0.7119
# 	Mean_test_accuracy: 0.7017 	Mean_test_accuracy_sum: 0.3883
# Epoch: 11 	Total: 3657.8690 	Mean_train_accuracy: 0.7092
# 	Mean_test_accuracy: 0.6900 	Mean_test_accuracy_sum: 0.3883
# Epoch: 12 	Total: 3691.8852 	Mean_train_accuracy: 0.7123
# 	Mean_test_accuracy: 0.6950 	Mean_test_accuracy_sum: 0.3883
# Epoch: 13 	Total: 3683.1716 	Mean_train_accuracy: 0.7095
# 	Mean_test_accuracy: 0.6933 	Mean_test_accuracy_sum: 0.3883
# Epoch: 14 	Total: 3609.3936 	Mean_train_accuracy: 0.7054
# 	Mean_test_accuracy: 0.6917 	Mean_test_accuracy_sum: 0.3883
# Epoch: 15 	Total: 3648.5296 	Mean_train_accuracy: 0.7097
# 	Mean_test_accuracy: 0.6783 	Mean_test_accuracy_sum: 0.3883
# Epoch: 16 	Total: 3677.6651 	Mean_train_accuracy: 0.7100
# 	Mean_test_accuracy: 0.6950 	Mean_test_accuracy_sum: 0.3883
# Epoch: 17 	Total: 3629.0603 	Mean_train_accuracy: 0.7053
# 	Mean_test_accuracy: 0.6983 	Mean_test_accuracy_sum: 0.3883
# Epoch: 18 	Total: 3606.5557 	Mean_train_accuracy: 0.7083
# 	Mean_test_accuracy: 0.6867 	Mean_test_accuracy_sum: 0.3883
# Epoch: 19 	Total: 3666.7605 	Mean_train_accuracy: 0.7118
# 	Mean_test_accuracy: 0.6817 	Mean_test_accuracy_sum: 0.3883
# Epoch: 20 	Total: 3729.6693 	Mean_train_accuracy: 0.7105
# 	Mean_test_accuracy: 0.6833 	Mean_test_accuracy_sum: 0.3883
# Epoch: 21 	Total: 3702.5568 	Mean_train_accuracy: 0.7106
# 	Mean_test_accuracy: 0.6967 	Mean_test_accuracy_sum: 0.3883
# Epoch: