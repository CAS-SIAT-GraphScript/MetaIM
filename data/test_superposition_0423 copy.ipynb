# %%
import torch
import sys
sys.path.append('/home/zjy/project/MetaIM')
pwd = '/home/zjy/project/MetaIM/data'
device = torch.device('cuda:5' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=5)

# %%
from torch_geometric.datasets import Planetoid

cora_dataset = Planetoid(root=pwd+'/cora', name='cora')
data = cora_dataset[0]
edge_index = data.edge_index

# %%
import numpy as np
individual_infection_path = pwd+'/for_meta/cora_individual_infection_sir_200.npy'
seeds_infection_path = pwd+'/for_meta/cora_seed_infection_sir_200_sample_1000.npy'

individual_infection = np.load(individual_infection_path)
seeds_infection = np.load(seeds_infection_path)
individual_infection.shape,seeds_infection.shape
# Out:
# ((2708, 2708), (1000, 2, 2708))

# %%
import torch
from torch_geometric.utils import to_scipy_sparse_matrix
import scipy.sparse as sp

# 转换为 scipy 稀疏矩阵
adj = to_scipy_sparse_matrix(edge_index)


# def normalize_adj(mx):
#     """Row-normalize sparse matrix"""
#     rowsum = np.array(mx.sum(1))
#     r_inv_sqrt = np.power(rowsum, -0.5).flatten()
#     r_inv_sqrt[np.isinf(r_inv_sqrt)] = 0.
#     r_mat_inv_sqrt = sp.diags(r_inv_sqrt)
#     return mx.dot(r_mat_inv_sqrt).transpose().dot(r_mat_inv_sqrt)



# adj = adj + adj.T.multiply(adj.T > adj) - adj.multiply(adj.T > adj)
# adj = normalize_adj(adj + sp.eye(adj.shape[0]))
adj = torch.Tensor(adj.toarray()).to_sparse()
adj
# Out:
# tensor(indices=tensor([[   0,    0,    0,  ..., 2707, 2707, 2707],
#                        [ 633, 1862, 2582,  ...,  598, 1473, 2706]]),
#        values=tensor([1., 1., 1.,  ..., 1., 1., 1.]),
#        size=(2708, 2708), nnz=10556, layout=torch.sparse_coo)

# %%
seed_num = int(seeds_infection[0][0].sum())

# %%
from torch.utils.data import Dataset, DataLoader, random_split


class CustomDataset(Dataset):
    def __init__(self, individual_infection,seeds_infection, seed_num):
        self.individual_infection = individual_infection
        self.seeds_infection = seeds_infection
        self.feat_shape = (len(individual_infection), seed_num)

    def __len__(self):
        return len(self.seeds_infection)

    def __getitem__(self, idx):
        seeds= np.nonzero(self.seeds_infection[idx][0])[0]
        
        feature = torch.zeros(self.feat_shape[0],self.feat_shape[1])
        for i in range(len(seeds)):
            seed_i_infection = torch.tensor(self.individual_infection[seeds[i]])
            feature[:, i] = seed_i_infection
            
        label = self.seeds_infection[idx][1]
        
        return self.seeds_infection[idx][0], feature, label

dataset = CustomDataset(individual_infection, seeds_infection, seed_num)

# %%
# 定义划分比例
train_ratio = 0.8
test_ratio = 0.2

# 划分数据集
train_dataset, test_dataset = random_split(dataset, [int(len(dataset)*train_ratio), int(len(dataset)*test_ratio)])

train_batch_size = 32
test_batch_size = 2

# 创建数据加载器
train_loader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True, drop_last=False)
test_loader = DataLoader(test_dataset, batch_size=test_batch_size, shuffle=False)

# %% [markdown]
# 训练VAE

# %%
# from data import model 
from data.model.model import VAEModel, Encoder, Decoder
from torch.optim import Adam, SGD
import torch.nn.functional as F

# # hidden_dim = 256
# # latent_dim = 64
hidden_dim = 1024
latent_dim = 64

encoder = Encoder(input_dim= len(seeds_infection[0][0]), 
                  hidden_dim=hidden_dim, 
                  latent_dim=latent_dim)

decoder = Decoder(input_dim=latent_dim, 
                  latent_dim=latent_dim, 
                  hidden_dim=hidden_dim, 
                  output_dim=len(seeds_infection[0][0]))

vae_model = VAEModel(Encoder=encoder, Decoder=decoder).to(device)

optimizer_vae = Adam([{'params': vae_model.parameters()}], 
                 lr=1e-3)
vae_model.train()
# Out:
# VAEModel(
#   (Encoder): Encoder(
#     (FC_input): Linear(in_features=2708, out_features=1024, bias=True)
#     (FC_input2): Linear(in_features=1024, out_features=1024, bias=True)
#     (FC_output): Linear(in_features=1024, out_features=64, bias=True)
#     (bn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Decoder): Decoder(
#     (FC_input): Linear(in_features=64, out_features=64, bias=True)
#     (FC_hidden_1): Linear(in_features=64, out_features=1024, bias=True)
#     (FC_hidden_2): Linear(in_features=1024, out_features=1024, bias=True)
#     (FC_output): Linear(in_features=1024, out_features=2708, bias=True)
#   )
# )

# %%
for epoch in range(200):
    train_vae_loss = 0
    mean_train_accuracy = 0
    for batch_idx, x_feature_label in enumerate(train_loader):        
        x = x_feature_label[0].to(device)
        optimizer_vae.zero_grad()
        loss = 0
        for i, x_i in enumerate(x):
            x_hat = vae_model(x_i)

            reproduction_loss = F.binary_cross_entropy(x_hat, x_i, reduction='sum')   
            loss += reproduction_loss    
        train_vae_loss += loss.item()
        loss = loss/x.size(0)
        loss.backward()
        optimizer_vae.step()
        
    print("Epoch: {}".format(epoch+1), 
        "\tTrain_vae_loss: {:.4f}".format(train_vae_loss / train_batch_size),
        )
    
for param in vae_model.parameters():
    param.requires_grad = False
# Out:
# Epoch: 1 	Train_vae_loss: 20644.5453
# Epoch: 2 	Train_vae_loss: 13972.6542
# Epoch: 3 	Train_vae_loss: 13597.9060
# Epoch: 4 	Train_vae_loss: 13543.9771
# Epoch: 5 	Train_vae_loss: 13526.2445
# Epoch: 6 	Train_vae_loss: 13519.0703
# Epoch: 7 	Train_vae_loss: 13505.4734
# Epoch: 8 	Train_vae_loss: 13504.7794
# Epoch: 9 	Train_vae_loss: 13496.8535
# Epoch: 10 	Train_vae_loss: 13494.0267
# Epoch: 11 	Train_vae_loss: 13490.7874
# Epoch: 12 	Train_vae_loss: 13487.5541
# Epoch: 13 	Train_vae_loss: 13481.1115
# Epoch: 14 	Train_vae_loss: 13478.2771
# Epoch: 15 	Train_vae_loss: 13473.6658
# Epoch: 16 	Train_vae_loss: 13471.5657
# Epoch: 17 	Train_vae_loss: 13467.5142
# Epoch: 18 	Train_vae_loss: 13467.6561
# Epoch: 19 	Train_vae_loss: 13465.4153
# Epoch: 20 	Train_vae_loss: 13464.1719
# Epoch: 21 	Train_vae_loss: 13459.9598
# Epoch: 22 	Train_vae_loss: 13458.1638
# Epoch: 23 	Train_vae_loss: 13456.7814
# Epoch: 24 	Train_vae_loss: 13454.9309
# Epoch: 25 	Train_vae_loss: 13454.2294
# Epoch: 26 	Train_vae_loss: 13454.1160
# Epoch: 27 	Train_vae_loss: 13453.8342
# Epoch: 28 	Train_vae_loss: 13453.4620
# Epoch: 29 	Train_vae_loss: 13450.2905
# Epoch: 30 	Train_vae_loss: 13449.1858
# Epoch: 31 	Train_vae_loss: 13449.8738
# Epoch: 32 	Train_vae_loss: 13446.9464
# Epoch: 33 	Train_vae_loss: 13446.0703
# Epoch: 34 	Train_vae_loss: 13441.6559
# Epoch: 35 	Train_vae_loss: 13443.7621
# Epoch: 36 	Train_vae_loss: 13446.3250
# Epoch: 37 	Train_vae_loss: 13442.1840
# Epoch: 38 	Train_vae_loss: 13440.5574
# Epoch: 39 	Train_vae_loss: 13440.2526
# Epoch: 40 	Train_vae_loss: 13436.8328
# Epoch: 41 	Train_vae_loss: 13436.7623
# Epoch: 42 	Train_vae_loss: 13436.3429
# Epoch: 43 	Train_vae_loss: 13437.5275
# Epoch: 44 	Train_vae_loss: 13434.7891
# Epoch: 45 	Train_vae_loss: 13434.0076
# Epoch: 46 	Train_vae_loss: 13423.6640
# Epoch: 47 	Train_vae_loss: 13407.6581
# Epoch: 48 	Train_vae_loss: 13395.2946
# Epoch: 49 	Train_vae_loss: 13380.9171
# Epoch: 50 	Train_vae_loss: 13373.6051
# Epoch: 51 	Train_vae_loss: 13361.3442
# Epoch: 52 	Train_vae_loss: 13351.1816
# Epoch: 53 	Train_vae_loss: 13338.5577
# Epoch: 54 	Train_vae_loss: 13325.5953
# Epoch: 55 	Train_vae_loss: 13315.4984
# Epoch: 56 	Train_vae_loss: 13300.1093
# Epoch: 57 	Train_vae_loss: 13282.5129
# Epoch: 58 	Train_vae_loss: 13258.5651
# Epoch: 59 	Train_vae_loss: 13243.4176
# Epoch: 60 	Train_vae_loss: 13204.4874
# Epoch: 61 	Train_vae_loss: 13169.3414
# Epoch: 62 	Train_vae_loss: 13127.8402
# Epoch: 63 	Train_vae_loss: 13087.9229
# Epoch: 64 	Train_vae_loss: 13056.4329
# Epoch: 65 	Train_vae_loss: 13035.1786
# Epoch: 66 	Train_vae_loss: 13009.2371
# Epoch: 67 	Train_vae_loss: 12968.2397
# Epoch: 68 	Train_vae_loss: 12903.4497
# Epoch: 69 	Train_vae_loss: 12845.8878
# Epoch: 70 	Train_vae_loss: 12840.0628
# Epoch: 71 	Train_vae_loss: 12787.3960
# Epoch: 72 	Train_vae_loss: 12722.7977
# Epoch: 73 	Train_vae_loss: 12664.4464
# Epoch: 74 	Train_vae_loss: 12590.7788
# Epoch: 75 	Train_vae_loss: 12551.5723
# Epoch: 76 	Train_vae_loss: 12513.9163
# Epoch: 77 	Train_vae_loss: 12480.6805
# Epoch: 78 	Train_vae_loss: 12377.5325
# Epoch: 79 	Train_vae_loss: 12299.5215
# Epoch: 80 	Train_vae_loss: 12256.4147
# Epoch: 81 	Train_vae_loss: 12220.8945
# Epoch: 82 	Train_vae_loss: 12163.1055
# Epoch: 83 	Train_vae_loss: 12093.4920
# Epoch: 84 	Train_vae_loss: 12046.2762
# Epoch: 85 	Train_vae_loss: 12047.6825
# Epoch: 86 	Train_vae_loss: 11954.7120
# Epoch: 87 	Train_vae_loss: 11916.2614
# Epoch: 88 	Train_vae_loss: 11788.8044
# Epoch: 89 	Train_vae_loss: 11678.9960
# Epoch: 90 	Train_vae_loss: 11578.0240
# Epoch: 91 	Train_vae_loss: 11492.4853
# Epoch: 92 	Train_vae_loss: 11521.8161
# Epoch: 93 	Train_vae_loss: 11441.9571
# Epoch: 94 	Train_vae_loss: 11444.0261
# Epoch: 95 	Train_vae_loss: 11479.9178
# Epoch: 96 	Train_vae_loss: 11331.6443
# Epoch: 97 	Train_vae_loss: 11141.9190
# Epoch: 98 	Train_vae_loss: 10977.5092
# Epoch: 99 	Train_vae_loss: 10944.4357
# Epoch: 100 	Train_vae_loss: 10822.4110
# Epoch: 101 	Train_vae_loss: 10762.0479
# Epoch: 102 	Train_vae_loss: 10722.8220
# Epoch: 103 	Train_vae_loss: 10624.8295
# Epoch: 104 	Train_vae_loss: 10502.7111
# Epoch: 105 	Train_vae_loss: 10348.6453
# Epoch: 106 	Train_vae_loss: 10274.0306
# Epoch: 107 	Train_vae_loss: 10258.4305
# Epoch: 108 	Train_vae_loss: 10085.0032
# Epoch: 109 	Train_vae_loss: 9821.9434
# Epoch: 110 	Train_vae_loss: 9616.8577
# Epoch: 111 	Train_vae_loss: 9566.1151
# Epoch: 112 	Train_vae_loss: 9442.9569
# Epoch: 113 	Train_vae_loss: 9417.8923
# Epoch: 114 	Train_vae_loss: 9315.4527
# Epoch: 115 	Train_vae_loss: 9261.1695
# Epoch: 116 	Train_vae_loss: 9246.5010
# Epoch: 117 	Train_vae_loss: 9154.4157
# Epoch: 118 	Train_vae_loss: 8921.0750
# Epoch: 119 	Train_vae_loss: 8742.9165
# Epoch: 120 	Train_vae_loss: 8438.0684
# Epoch: 121 	Train_vae_loss: 8306.0966
# Epoch: 122 	Train_vae_loss: 8170.9890
# Epoch: 123 	Train_vae_loss: 7999.3951
# Epoch: 124 	Train_vae_loss: 7746.5391
# Epoch: 125 	Train_vae_loss: 7611.5092
# Epoch: 126 	Train_vae_loss: 7508.1526
# Epoch: 127 	Train_vae_loss: 7601.9792
# Epoch: 128 	Train_vae_loss: 7654.2145
# Epoch: 129 	Train_vae_loss: 7419.0909
# Epoch: 130 	Train_vae_loss: 7070.9693
# Epoch: 131 	Train_vae_loss: 6796.8001
# Epoch: 132 	Train_vae_loss: 6600.8671
# Epoch: 133 	Train_vae_loss: 6593.6605
# Epoch: 134 	Train_vae_loss: 6379.0856
# Epoch: 135 	Train_vae_loss: 6167.8163
# Epoch: 136 	Train_vae_loss: 5973.9847
# Epoch: 137 	Train_vae_loss: 5890.5511
# Epoch: 138 	Train_vae_loss: 5629.5558
# Epoch: 139 	Train_vae_loss: 5436.0820
# Epoch: 140 	Train_vae_loss: 5474.9720
# Epoch: 141 	Train_vae_loss: 5344.9474
# Epoch: 142 	Train_vae_loss: 5226.1134
# Epoch: 143 	Train_vae_loss: 5199.6049
# Epoch: 144 	Train_vae_loss: 5081.9079
# Epoch: 145 	Train_vae_loss: 4781.0933
# Epoch: 146 	Train_vae_loss: 4510.4333
# Epoch: 147 	Train_vae_loss: 4148.9753
# Epoch: 148 	Train_vae_loss: 3971.7878
# Epoch: 149 	Train_vae_loss: 3737.0205
# Epoch: 150 	Train_vae_loss: 3544.7556
# Epoch: 151 	Train_vae_loss: 3438.8125
# Epoch: 152 	Train_vae_loss: 3400.2007
# Epoch: 153 	Train_vae_loss: 3382.9003
# Epoch: 154 	Train_vae_loss: 3371.1614
# Epoch: 155 	Train_vae_loss: 3485.3454
# Epoch: 156 	Train_vae_loss: 3614.2117
# Epoch: 157 	Train_vae_loss: 3501.1633
# Epoch: 158 	Train_vae_loss: 3189.7480
# Epoch: 159 	Train_vae_loss: 3040.5616
# Epoch: 160 	Train_vae_loss: 2976.3236
# Epoch: 161 	Train_vae_loss: 2867.5144
# Epoch: 162 	Train_vae_loss: 2590.5029
# Epoch: 163 	Train_vae_loss: 2261.4793
# Epoch: 164 	Train_vae_loss: 2121.4938
# Epoch: 165 	Train_vae_loss: 1986.8347
# Epoch: 166 	Train_vae_loss: 1964.4324
# Epoch: 167 	Train_vae_loss: 2047.2556
# Epoch: 168 	Train_vae_loss: 2120.7924
# Epoch: 169 	Train_vae_loss: 2262.0378
# Epoch: 170 	Train_vae_loss: 2753.0840
# Epoch: 171 	Train_vae_loss: 2819.8772
# Epoch: 172 	Train_vae_loss: 2562.7335
# Epoch: 173 	Train_vae_loss: 2323.9439
# Epoch: 174 	Train_vae_loss: 2241.2279
# Epoch: 175 	Train_vae_loss: 2221.6117
# Epoch: 176 	Train_vae_loss: 2129.9567
# Epoch: 177 	Train_vae_loss: 1807.6176
# Epoch: 178 	Train_vae_loss: 1352.2628
# Epoch: 179 	Train_vae_loss: 956.4307
# Epoch: 180 	Train_vae_loss: 707.0103
# Epoch: 181 	Train_vae_loss: 585.4461
# Epoch: 182 	Train_vae_loss: 519.8615
# Epoch: 183 	Train_vae_loss: 507.5089
# Epoch: 184 	Train_vae_loss: 491.2642
# Epoch: 185 	Train_vae_loss: 502.9366
# Epoch: 186 	Train_vae_loss: 654.2723
# Epoch: 187 	Train_vae_loss: 949.3813
# Epoch: 188 	Train_vae_loss: 1273.4840
# Epoch: 189 	Train_vae_loss: 1495.6656
# Epoch: 190 	Train_vae_loss: 1611.4509
# Epoch: 191 	Train_vae_loss: 1486.4714
# Epoch: 192 	Train_vae_loss: 1239.6458
# Epoch: 193 	Train_vae_loss: 1059.0474
# Epoch: 194 	Train_vae_loss: 945.6711
# Epoch: 195 	Train_vae_loss: 737.6647
# Epoch: 196 	Train_vae_loss: 565.6054
# Epoch: 197 	Train_vae_loss: 438.0827
# Epoch: 198 	Train_vae_loss: 370.0477
# Epoch: 199 	Train_vae_loss: 287.8953
# Epoch: 200 	Train_vae_loss: 235.5928

# %%
import torch
import torch.nn as nn

from torch_geometric.nn import GATConv
from torch.optim import Adam, SGD
import torch.nn.functional as F

class GAT(nn.Module):
    def __init__(self, feat_dim, latent_dim, hidden_channels, out_channels, num_heads):
        super(GAT, self).__init__()
        self.linear1 = nn.Linear(latent_dim, 128)
        self.conv1 = GATConv(feat_dim, hidden_channels, heads=num_heads)
        self.conv2 = GATConv(hidden_channels * num_heads+128, out_channels, heads=1)

    def forward(self, feat_i, x_i, edge_index):
        x = self.conv1(feat_i, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=0.2, training=self.training)
        
        latten = F.relu(self.linear1(x_i))
        x =  torch.cat((x, latten), dim=-1)
        
        x = self.conv2(x, edge_index)
        return F.relu(x)

# %%
feat_num = seed_num

forward_model = GAT(feat_num,latent_dim, 512, 1, 4)

optimizer = Adam([{'params': forward_model.parameters()}], 
                 lr=0.001)

adj = adj.to(device)
forward_model = forward_model.to(device)
forward_model.train()
# Out:
# GAT(
#   (linear1): Linear(in_features=64, out_features=128, bias=True)
#   (conv1): GATConv(135, 512, heads=4)
#   (conv2): GATConv(2176, 1, heads=1)
# )

# %%
def normalize_features(tensor):
    # 计算每个特征的最小值和最大值
    min_vals, _ = torch.min(tensor, dim=0)
    max_vals, _ = torch.max(tensor, dim=0)

    # 对每个特征进行归一化
    normalized_tensor = (tensor - min_vals) / (max_vals - min_vals)
    return normalized_tensor

# %%
edge_index = edge_index.to(device)
top_num = 500
encoder = vae_model.Encoder

for epoch in range(2000):

    total_overall = 0
    forward_loss = 0

    mean_train_accuracy = 0
    for batch_idx, x_feature_label in enumerate(train_loader):  
        x =  x_feature_label[0].to(device)     
        features = x_feature_label[1].to(device)
        labels = x_feature_label[2].to(device)
        optimizer.zero_grad()
        
        loss = 0
        train_accuracy = 0
        for i, feat_i in enumerate(features):
            
            # log_sum = torch.sum(torch.log(1 - x_i), dim=1, keepdim=True)
            # feat = 1 - torch.exp(log_sum)
            x_i = x[i]
            x_i = encoder(x_i).detach()
            x_i = normalize_features(x_i)
            x_i = x_i.expand(features.shape[1], -1)
            # final_feat_i =  torch.cat((feat_i, x_i), dim=1)
            
            
            y_i = labels[i]
            y_hat = forward_model(feat_i, x_i, edge_index)
            _, top_indices_true = torch.topk(y_i.clone(), top_num)
            label_2 = torch.zeros(y_i.shape).to(device)
            label_2[top_indices_true] = 1
            
            _, top_indices_predict = torch.topk(y_hat.clone().squeeze(-1), top_num)
            
            # 将张量数组转换为Python列表
            list1 = top_indices_true.tolist()
            list_pre = top_indices_predict.tolist()

            # 使用集合操作找到交集
            intersection = list(set(list1) & set(list_pre))
            accuracy_i = len(intersection) / top_num       
            train_accuracy += accuracy_i 

            forward_loss = 0.5*F.mse_loss(y_hat.squeeze(-1), y_i, reduction='sum') + F.mse_loss(y_hat.squeeze(-1), label_2, reduction='sum')    
            loss += forward_loss    
        
        total_overall += loss.item()    
        train_accuracy /= len(features)
        mean_train_accuracy = train_accuracy
        loss = loss/features.size(0)
        loss.backward()
        optimizer.step()
        # for p in forward_model.parameters():
        #     p.data.clamp_(min=0)
        
        
    print("Epoch: {}".format(epoch+1), 
        "\tTotal: {:.4f}".format(total_overall / train_batch_size),
        "\tMean_train_accuracy: {:.4f}".format(mean_train_accuracy),
        )  
    
    mean_accuracy = 0
    mean_accuracy_sum = 0

    
    for batch_idx, x_feature_label in enumerate(test_loader):  
        x =  x_feature_label[0].to(device)
        features = x_feature_label[1].to(device)
        labels = x_feature_label[2].to(device)
        
        accuracy = 0
        accuracy_sum = 0
        
        for i, feat_i in enumerate(features):
            x_i = x[i]
            x_i = encoder(x_i).detach()
            x_i = normalize_features(x_i)
            x_i = x_i.expand(features.shape[1], -1)
            # final_feat_i =  torch.cat((feat_i, x_i), dim=1)
            y_i = labels[i]
            _, top_indices_true = torch.topk(y_i, top_num)
            
            y_hat = forward_model(feat_i, x_i, edge_index)
            
            _, top_indices_predict = torch.topk(y_hat.squeeze(-1), top_num)
            
            sum_pre = torch.sum(feat_i, dim=1, keepdim=True)
            _, top_indices_sum = torch.topk(sum_pre.squeeze(-1), top_num)
            
            # 将张量数组转换为Python列表
            list1 = top_indices_true.tolist()
            list_pre = top_indices_predict.tolist()
            
            list_sum = top_indices_sum.tolist()

            # 使用集合操作找到交集
            intersection = list(set(list1) & set(list_pre))
            
            intersection_sum = list(set(list1) & set(list_sum))
            
            accuracy_i = len(intersection) / top_num       
            accuracy += accuracy_i 
            accuracy_sum += len(intersection_sum) / top_num  
        accuracy /= test_batch_size
        accuracy_sum/= test_batch_size
        mean_accuracy = accuracy
        mean_accuracy_sum = accuracy_sum
        break
    
    print(
        "\tMean_test_accuracy: {:.4f}".format(mean_accuracy),
        "\tMean_test_accuracy_sum: {:.4f}".format(mean_accuracy_sum)
        )
# Out:
# Epoch: 1 	Total: 10787.1372 	Mean_train_accuracy: 0.4686
# 	Mean_test_accuracy: 0.4750 	Mean_test_accuracy_sum: 0.4980
# Epoch: 2 	Total: 9598.8412 	Mean_train_accuracy: 0.5165
# 	Mean_test_accuracy: 0.5270 	Mean_test_accuracy_sum: 0.4980
# Epoch: 3 	Total: 8978.2754 	Mean_train_accuracy: 0.5793
# 	Mean_test_accuracy: 0.5910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 4 	Total: 8473.8470 	Mean_train_accuracy: 0.6262
# 	Mean_test_accuracy: 0.6380 	Mean_test_accuracy_sum: 0.4980
# Epoch: 5 	Total: 8172.2114 	Mean_train_accuracy: 0.6375
# 	Mean_test_accuracy: 0.6390 	Mean_test_accuracy_sum: 0.4980
# Epoch: 6 	Total: 8011.5687 	Mean_train_accuracy: 0.6427
# 	Mean_test_accuracy: 0.6520 	Mean_test_accuracy_sum: 0.4980
# Epoch: 7 	Total: 7947.2368 	Mean_train_accuracy: 0.6396
# 	Mean_test_accuracy: 0.6550 	Mean_test_accuracy_sum: 0.4980
# Epoch: 8 	Total: 7886.4435 	Mean_train_accuracy: 0.6386
# 	Mean_test_accuracy: 0.6550 	Mean_test_accuracy_sum: 0.4980
# Epoch: 9 	Total: 7830.6162 	Mean_train_accuracy: 0.6484
# 	Mean_test_accuracy: 0.6610 	Mean_test_accuracy_sum: 0.4980
# Epoch: 10 	Total: 7783.8767 	Mean_train_accuracy: 0.6472
# 	Mean_test_accuracy: 0.6550 	Mean_test_accuracy_sum: 0.4980
# Epoch: 11 	Total: 7777.0148 	Mean_train_accuracy: 0.6461
# 	Mean_test_accuracy: 0.6660 	Mean_test_accuracy_sum: 0.4980
# Epoch: 12 	Total: 7724.2692 	Mean_train_accuracy: 0.6475
# 	Mean_test_accuracy: 0.6660 	Mean_test_accuracy_sum: 0.4980
# Epoch: 13 	Total: 7704.6794 	Mean_train_accuracy: 0.6519
# 	Mean_test_accuracy: 0.6690 	Mean_test_accuracy_sum: 0.4980
# Epoch: 14 	Total: 7679.9972 	Mean_train_accuracy: 0.6587
# 	Mean_test_accuracy: 0.6650 	Mean_test_accuracy_sum: 0.4980
# Epoch: 15 	Total: 7652.8704 	Mean_train_accuracy: 0.6588
# 	Mean_test_accuracy: 0.6670 	Mean_test_accuracy_sum: 0.4980
# Epoch: 16 	Total: 7636.9119 	Mean_train_accuracy: 0.6507
# 	Mean_test_accuracy: 0.6730 	Mean_test_accuracy_sum: 0.4980
# Epoch: 17 	Total: 7602.7161 	Mean_train_accuracy: 0.6589
# 	Mean_test_accuracy: 0.6690 	Mean_test_accuracy_sum: 0.4980
# Epoch: 18 	Total: 7564.1875 	Mean_train_accuracy: 0.6671
# 	Mean_test_accuracy: 0.6630 	Mean_test_accuracy_sum: 0.4980
# Epoch: 19 	Total: 7536.2440 	Mean_train_accuracy: 0.6633
# 	Mean_test_accuracy: 0.6720 	Mean_test_accuracy_sum: 0.4980
# Epoch: 20 	Total: 7497.0785 	Mean_train_accuracy: 0.6609
# 	Mean_test_accuracy: 0.6720 	Mean_test_accuracy_sum: 0.4980
# Epoch: 21 	Total: 7494.0402 	Mean_train_accuracy: 0.6620
# 	Mean_test_accuracy: 0.6750 	Mean_test_accuracy_sum: 0.4980
# Epoch: 22 	Total: 7445.9387 	Mean_train_accuracy: 0.6672
# 	Mean_test_accuracy: 0.6710 	Mean_test_accuracy_sum: 0.4980
# Epoch: 23 	Total: 7403.9798 	Mean_train_accuracy: 0.6726
# 	Mean_test_accuracy: 0.6750 	Mean_test_accuracy_sum: 0.4980
# Epoch: 24 	Total: 7385.3957 	Mean_train_accuracy: 0.6729
# 	Mean_test_accuracy: 0.6810 	Mean_test_accuracy_sum: 0.4980
# Epoch: 25 	Total: 7373.7340 	Mean_train_accuracy: 0.6673
# 	Mean_test_accuracy: 0.6740 	Mean_test_accuracy_sum: 0.4980
# Epoch: 26 	Total: 7309.9871 	Mean_train_accuracy: 0.6714
# 	Mean_test_accuracy: 0.6800 	Mean_test_accuracy_sum: 0.4980
# Epoch: 27 	Total: 7309.4209 	Mean_train_accuracy: 0.6651
# 	Mean_test_accuracy: 0.6850 	Mean_test_accuracy_sum: 0.4980
# Epoch: 28 	Total: 7278.7469 	Mean_train_accuracy: 0.6759
# 	Mean_test_accuracy: 0.6840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 29 	Total: 7218.2263 	Mean_train_accuracy: 0.6767
# 	Mean_test_accuracy: 0.6860 	Mean_test_accuracy_sum: 0.4980
# Epoch: 30 	Total: 7182.2242 	Mean_train_accuracy: 0.6852
# 	Mean_test_accuracy: 0.6810 	Mean_test_accuracy_sum: 0.4980
# Epoch: 31 	Total: 7161.5948 	Mean_train_accuracy: 0.6748
# 	Mean_test_accuracy: 0.6790 	Mean_test_accuracy_sum: 0.4980
# Epoch: 32 	Total: 7174.4977 	Mean_train_accuracy: 0.6728
# 	Mean_test_accuracy: 0.6870 	Mean_test_accuracy_sum: 0.4980
# Epoch: 33 	Total: 7098.6733 	Mean_train_accuracy: 0.6748
# 	Mean_test_accuracy: 0.6850 	Mean_test_accuracy_sum: 0.4980
# Epoch: 34 	Total: 7066.6045 	Mean_train_accuracy: 0.6775
# 	Mean_test_accuracy: 0.6860 	Mean_test_accuracy_sum: 0.4980
# Epoch: 35 	Total: 7059.0449 	Mean_train_accuracy: 0.6676
# 	Mean_test_accuracy: 0.6830 	Mean_test_accuracy_sum: 0.4980
# Epoch: 36 	Total: 7055.1043 	Mean_train_accuracy: 0.6763
# 	Mean_test_accuracy: 0.6820 	Mean_test_accuracy_sum: 0.4980
# Epoch: 37 	Total: 7125.1881 	Mean_train_accuracy: 0.6604
# 	Mean_test_accuracy: 0.6780 	Mean_test_accuracy_sum: 0.4980
# Epoch: 38 	Total: 7103.7129 	Mean_train_accuracy: 0.6744
# 	Mean_test_accuracy: 0.6870 	Mean_test_accuracy_sum: 0.4980
# Epoch: 39 	Total: 7006.4616 	Mean_train_accuracy: 0.6714
# 	Mean_test_accuracy: 0.6860 	Mean_test_accuracy_sum: 0.4980
# Epoch: 40 	Total: 6958.2458 	Mean_train_accuracy: 0.6668
# 	Mean_test_accuracy: 0.6830 	Mean_test_accuracy_sum: 0.4980
# Epoch: 41 	Total: 6937.8382 	Mean_train_accuracy: 0.6759
# 	Mean_test_accuracy: 0.6840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 42 	Total: 6922.0528 	Mean_train_accuracy: 0.6762
# 	Mean_test_accuracy: 0.6880 	Mean_test_accuracy_sum: 0.4980
# Epoch: 43 	Total: 6926.5074 	Mean_train_accuracy: 0.6816
# 	Mean_test_accuracy: 0.6870 	Mean_test_accuracy_sum: 0.4980
# Epoch: 44 	Total: 6918.9161 	Mean_train_accuracy: 0.6776
# 	Mean_test_accuracy: 0.6820 	Mean_test_accuracy_sum: 0.4980
# Epoch: 45 	Total: 6882.2038 	Mean_train_accuracy: 0.6788
# 	Mean_test_accuracy: 0.6870 	Mean_test_accuracy_sum: 0.4980
# Epoch: 46 	Total: 6875.3713 	Mean_train_accuracy: 0.6717
# 	Mean_test_accuracy: 0.6920 	Mean_test_accuracy_sum: 0.4980
# Epoch: 47 	Total: 6930.5964 	Mean_train_accuracy: 0.6846
# 	Mean_test_accuracy: 0.6910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 48 	Total: 6878.1562 	Mean_train_accuracy: 0.6782
# 	Mean_test_accuracy: 0.6890 	Mean_test_accuracy_sum: 0.4980
# Epoch: 49 	Total: 6836.9515 	Mean_train_accuracy: 0.6754
# 	Mean_test_accuracy: 0.6910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 50 	Total: 6834.9409 	Mean_train_accuracy: 0.6765
# 	Mean_test_accuracy: 0.6860 	Mean_test_accuracy_sum: 0.4980
# Epoch: 51 	Total: 6813.3659 	Mean_train_accuracy: 0.6820
# 	Mean_test_accuracy: 0.6860 	Mean_test_accuracy_sum: 0.4980
# Epoch: 52 	Total: 6806.0887 	Mean_train_accuracy: 0.6762
# 	Mean_test_accuracy: 0.6880 	Mean_test_accuracy_sum: 0.4980
# Epoch: 53 	Total: 6815.5872 	Mean_train_accuracy: 0.6654
# 	Mean_test_accuracy: 0.6900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 54 	Total: 6817.0178 	Mean_train_accuracy: 0.6747
# 	Mean_test_accuracy: 0.6860 	Mean_test_accuracy_sum: 0.4980
# Epoch: 55 	Total: 6773.3665 	Mean_train_accuracy: 0.6828
# 	Mean_test_accuracy: 0.6900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 56 	Total: 6777.5320 	Mean_train_accuracy: 0.6820
# 	Mean_test_accuracy: 0.6900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 57 	Total: 6786.5835 	Mean_train_accuracy: 0.6713
# 	Mean_test_accuracy: 0.6780 	Mean_test_accuracy_sum: 0.4980
# Epoch: 58 	Total: 6778.6628 	Mean_train_accuracy: 0.6767
# 	Mean_test_accuracy: 0.6880 	Mean_test_accuracy_sum: 0.4980
# Epoch: 59 	Total: 6761.2361 	Mean_train_accuracy: 0.6768
# 	Mean_test_accuracy: 0.6890 	Mean_test_accuracy_sum: 0.4980
# Epoch: 60 	Total: 6747.8693 	Mean_train_accuracy: 0.6871
# 	Mean_test_accuracy: 0.6930 	Mean_test_accuracy_sum: 0.4980
# Epoch: 61 	Total: 6744.8162 	Mean_train_accuracy: 0.6814
# 	Mean_test_accuracy: 0.6970 	Mean_test_accuracy_sum: 0.4980
# Epoch: 62 	Total: 6728.7628 	Mean_train_accuracy: 0.6872
# 	Mean_test_accuracy: 0.6930 	Mean_test_accuracy_sum: 0.4980
# Epoch: 63 	Total: 6734.7363 	Mean_train_accuracy: 0.6752
# 	Mean_test_accuracy: 0.6920 	Mean_test_accuracy_sum: 0.4980
# Epoch: 64 	Total: 6738.2290 	Mean_train_accuracy: 0.6751
# 	Mean_test_accuracy: 0.6840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 65 	Total: 6734.0076 	Mean_train_accuracy: 0.6798
# 	Mean_test_accuracy: 0.6850 	Mean_test_accuracy_sum: 0.4980
# Epoch: 66 	Total: 6737.5604 	Mean_train_accuracy: 0.6794
# 	Mean_test_accuracy: 0.6960 	Mean_test_accuracy_sum: 0.4980
# Epoch: 67 	Total: 6711.4868 	Mean_train_accuracy: 0.6820
# 	Mean_test_accuracy: 0.6940 	Mean_test_accuracy_sum: 0.4980
# Epoch: 68 	Total: 6704.1027 	Mean_train_accuracy: 0.6826
# 	Mean_test_accuracy: 0.6910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 69 	Total: 6693.2002 	Mean_train_accuracy: 0.6837
# 	Mean_test_accuracy: 0.6910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 70 	Total: 6708.5467 	Mean_train_accuracy: 0.6866
# 	Mean_test_accuracy: 0.7000 	Mean_test_accuracy_sum: 0.4980
# Epoch: 71 	Total: 6694.0307 	Mean_train_accuracy: 0.6916
# 	Mean_test_accuracy: 0.6910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 72 	Total: 6690.6857 	Mean_train_accuracy: 0.6852
# 	Mean_test_accuracy: 0.6930 	Mean_test_accuracy_sum: 0.4980
# Epoch: 73 	Total: 6683.7395 	Mean_train_accuracy: 0.6908
# 	Mean_test_accuracy: 0.7000 	Mean_test_accuracy_sum: 0.4980
# Epoch: 74 	Total: 6694.8261 	Mean_train_accuracy: 0.6919
# 	Mean_test_accuracy: 0.6930 	Mean_test_accuracy_sum: 0.4980
# Epoch: 75 	Total: 6680.9752 	Mean_train_accuracy: 0.6844
# 	Mean_test_accuracy: 0.6960 	Mean_test_accuracy_sum: 0.4980
# Epoch: 76 	Total: 6686.3274 	Mean_train_accuracy: 0.6853
# 	Mean_test_accuracy: 0.6870 	Mean_test_accuracy_sum: 0.4980
# Epoch: 77 	Total: 6668.0787 	Mean_train_accuracy: 0.6784
# 	Mean_test_accuracy: 0.6900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 78 	Total: 6653.5973 	Mean_train_accuracy: 0.6788
# 	Mean_test_accuracy: 0.7000 	Mean_test_accuracy_sum: 0.4980
# Epoch: 79 	Total: 6640.5081 	Mean_train_accuracy: 0.6810
# 	Mean_test_accuracy: 0.6970 	Mean_test_accuracy_sum: 0.4980
# Epoch: 80 	Total: 6679.2598 	Mean_train_accuracy: 0.6772
# 	Mean_test_accuracy: 0.6920 	Mean_test_accuracy_sum: 0.4980
# Epoch: 81 	Total: 6659.7309 	Mean_train_accuracy: 0.6854
# 	Mean_test_accuracy: 0.6990 	Mean_test_accuracy_sum: 0.4980
# Epoch: 82 	Total: 6649.7644 	Mean_train_accuracy: 0.6855
# 	Mean_test_accuracy: 0.6940 	Mean_test_accuracy_sum: 0.4980
# Epoch: 83 	Total: 6624.9791 	Mean_train_accuracy: 0.6888
# 	Mean_test_accuracy: 0.6990 	Mean_test_accuracy_sum: 0.4980
# Epoch: 84 	Total: 6617.4774 	Mean_train_accuracy: 0.6908
# 	Mean_test_accuracy: 0.7010 	Mean_test_accuracy_sum: 0.4980
# Epoch: 85 	Total: 6641.5922 	Mean_train_accuracy: 0.6867
# 	Mean_test_accuracy: 0.7010 	Mean_test_accuracy_sum: 0.4980
# Epoch: 86 	Total: 6652.0472 	Mean_train_accuracy: 0.6897
# 	Mean_test_accuracy: 0.7030 	Mean_test_accuracy_sum: 0.4980
# Epoch: 87 	Total: 6581.9930 	Mean_train_accuracy: 0.6886
# 	Mean_test_accuracy: 0.7010 	Mean_test_accuracy_sum: 0.4980
# Epoch: 88 	Total: 6568.7092 	Mean_train_accuracy: 0.6912
# 	Mean_test_accuracy: 0.7070 	Mean_test_accuracy_sum: 0.4980
# Epoch: 89 	Total: 6571.1414 	Mean_train_accuracy: 0.6990
# 	Mean_test_accuracy: 0.7020 	Mean_test_accuracy_sum: 0.4980
# Epoch: 90 	Total: 6626.6898 	Mean_train_accuracy: 0.6898
# 	Mean_test_accuracy: 0.7070 	Mean_test_accuracy_sum: 0.4980
# Epoch: 91 	Total: 6555.6560 	Mean_train_accuracy: 0.6899
# 	Mean_test_accuracy: 0.7060 	Mean_test_accuracy_sum: 0.4980
# Epoch: 92 	Total: 6535.9429 	Mean_train_accuracy: 0.7011
# 	Mean_test_accuracy: 0.7020 	Mean_test_accuracy_sum: 0.4980
# Epoch: 93 	Total: 6569.3286 	Mean_train_accuracy: 0.6976
# 	Mean_test_accuracy: 0.6960 	Mean_test_accuracy_sum: 0.4980
# Epoch: 94 	Total: 6640.0738 	Mean_train_accuracy: 0.6945
# 	Mean_test_accuracy: 0.7070 	Mean_test_accuracy_sum: 0.4980
# Epoch: 95 	Total: 6543.5470 	Mean_train_accuracy: 0.6925
# 	Mean_test_accuracy: 0.7060 	Mean_test_accuracy_sum: 0.4980
# Epoch: 96 	Total: 6527.9447 	Mean_train_accuracy: 0.6964
# 	Mean_test_accuracy: 0.7000 	Mean_test_accuracy_sum: 0.4980
# Epoch: 97 	Total: 6564.6685 	Mean_train_accuracy: 0.6906
# 	Mean_test_accuracy: 0.7050 	Mean_test_accuracy_sum: 0.4980
# Epoch: 98 	Total: 6536.1927 	Mean_train_accuracy: 0.6968
# 	Mean_test_accuracy: 0.7110 	Mean_test_accuracy_sum: 0.4980
# Epoch: 99 	Total: 6567.9222 	Mean_train_accuracy: 0.6953
# 	Mean_test_accuracy: 0.7020 	Mean_test_accuracy_sum: 0.4980
# Epoch: 100 	Total: 6552.1572 	Mean_train_accuracy: 0.6966
# 	Mean_test_accuracy: 0.7120 	Mean_test_accuracy_sum: 0.4980
# Epoch: 101 	Total: 6499.0816 	Mean_train_accuracy: 0.6998
# 	Mean_test_accuracy: 0.7070 	Mean_test_accuracy_sum: 0.4980
# Epoch: 102 	Total: 6491.2540 	Mean_train_accuracy: 0.7037
# 	Mean_test_accuracy: 0.7150 	Mean_test_accuracy_sum: 0.4980
# Epoch: 103 	Total: 6473.1988 	Mean_train_accuracy: 0.6968
# 	Mean_test_accuracy: 0.7060 	Mean_test_accuracy_sum: 0.4980
# Epoch: 104 	Total: 6487.3699 	Mean_train_accuracy: 0.6967
# 	Mean_test_accuracy: 0.7120 	Mean_test_accuracy_sum: 0.4980
# Epoch: 105 	Total: 6475.7046 	Mean_train_accuracy: 0.6969
# 	Mean_test_accuracy: 0.7050 	Mean_test_accuracy_sum: 0.4980
# Epoch: 106 	Total: 6475.9549 	Mean_train_accuracy: 0.7054
# 	Mean_test_accuracy: 0.7140 	Mean_test_accuracy_sum: 0.4980
# Epoch: 107 	Total: 6478.8221 	Mean_train_accuracy: 0.7025
# 	Mean_test_accuracy: 0.7030 	Mean_test_accuracy_sum: 0.4980
# Epoch: 108 	Total: 6578.8747 	Mean_train_accuracy: 0.6922
# 	Mean_test_accuracy: 0.7100 	Mean_test_accuracy_sum: 0.4980
# Epoch: 109 	Total: 6502.5502 	Mean_train_accuracy: 0.6951
# 	Mean_test_accuracy: 0.7100 	Mean_test_accuracy_sum: 0.4980
# Epoch: 110 	Total: 6448.6038 	Mean_train_accuracy: 0.6979
# 	Mean_test_accuracy: 0.7150 	Mean_test_accuracy_sum: 0.4980
# Epoch: 111 	Total: 6434.9006 	Mean_train_accuracy: 0.6975
# 	Mean_test_accuracy: 0.7090 	Mean_test_accuracy_sum: 0.4980
# Epoch: 112 	Total: 6447.7802 	Mean_train_accuracy: 0.6975
# 	Mean_test_accuracy: 0.7180 	Mean_test_accuracy_sum: 0.4980
# Epoch: 113 	Total: 6443.6468 	Mean_train_accuracy: 0.6917
# 	Mean_test_accuracy: 0.7040 	Mean_test_accuracy_sum: 0.4980
# Epoch: 114 	Total: 6437.3336 	Mean_train_accuracy: 0.7041
# 	Mean_test_accuracy: 0.7120 	Mean_test_accuracy_sum: 0.4980
# Epoch: 115 	Total: 6434.2098 	Mean_train_accuracy: 0.6959
# 	Mean_test_accuracy: 0.7150 	Mean_test_accuracy_sum: 0.4980
# Epoch: 116 	Total: 6445.5788 	Mean_train_accuracy: 0.7000
# 	Mean_test_accuracy: 0.7120 	Mean_test_accuracy_sum: 0.4980
# Epoch: 117 	Total: 6421.4619 	Mean_train_accuracy: 0.7077
# 	Mean_test_accuracy: 0.7120 	Mean_test_accuracy_sum: 0.4980
# Epoch: 118 	Total: 6438.7019 	Mean_train_accuracy: 0.6984
# 	Mean_test_accuracy: 0.7210 	Mean_test_accuracy_sum: 0.4980
# Epoch: 119 	Total: 6412.2216 	Mean_train_accuracy: 0.7026
# 	Mean_test_accuracy: 0.7150 	Mean_test_accuracy_sum: 0.4980
# Epoch: 120 	Total: 6416.0303 	Mean_train_accuracy: 0.7032
# 	Mean_test_accuracy: 0.7110 	Mean_test_accuracy_sum: 0.4980
# Epoch: 121 	Total: 6419.4185 	Mean_train_accuracy: 0.6994
# 	Mean_test_accuracy: 0.7050 	Mean_test_accuracy_sum: 0.4980
# Epoch: 122 	Total: 6402.9348 	Mean_train_accuracy: 0.7094
# 	Mean_test_accuracy: 0.7140 	Mean_test_accuracy_sum: 0.4980
# Epoch: 123 	Total: 6379.5919 	Mean_train_accuracy: 0.7088
# 	Mean_test_accuracy: 0.7120 	Mean_test_accuracy_sum: 0.4980
# Epoch: 124 	Total: 6374.5926 	Mean_train_accuracy: 0.7024
# 	Mean_test_accuracy: 0.7140 	Mean_test_accuracy_sum: 0.4980
# Epoch: 125 	Total: 6401.7167 	Mean_train_accuracy: 0.6967
# 	Mean_test_accuracy: 0.7100 	Mean_test_accuracy_sum: 0.4980
# Epoch: 126 	Total: 6375.0573 	Mean_train_accuracy: 0.7066
# 	Mean_test_accuracy: 0.7110 	Mean_test_accuracy_sum: 0.4980
# Epoch: 127 	Total: 6369.7881 	Mean_train_accuracy: 0.7080
# 	Mean_test_accuracy: 0.7080 	Mean_test_accuracy_sum: 0.4980
# Epoch: 128 	Total: 6334.0195 	Mean_train_accuracy: 0.7116
# 	Mean_test_accuracy: 0.7220 	Mean_test_accuracy_sum: 0.4980
# Epoch: 129 	Total: 6320.3056 	Mean_train_accuracy: 0.7156
# 	Mean_test_accuracy: 0.7140 	Mean_test_accuracy_sum: 0.4980
# Epoch: 130 	Total: 6312.1024 	Mean_train_accuracy: 0.7063
# 	Mean_test_accuracy: 0.7150 	Mean_test_accuracy_sum: 0.4980
# Epoch: 131 	Total: 6312.8915 	Mean_train_accuracy: 0.7126
# 	Mean_test_accuracy: 0.7160 	Mean_test_accuracy_sum: 0.4980
# Epoch: 132 	Total: 6286.8611 	Mean_train_accuracy: 0.7167
# 	Mean_test_accuracy: 0.7150 	Mean_test_accuracy_sum: 0.4980
# Epoch: 133 	Total: 6468.7811 	Mean_train_accuracy: 0.7033
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4980
# Epoch: 134 	Total: 6319.3289 	Mean_train_accuracy: 0.7113
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4980
# Epoch: 135 	Total: 6243.0309 	Mean_train_accuracy: 0.7170
# 	Mean_test_accuracy: 0.7140 	Mean_test_accuracy_sum: 0.4980
# Epoch: 136 	Total: 6210.0344 	Mean_train_accuracy: 0.7179
# 	Mean_test_accuracy: 0.7240 	Mean_test_accuracy_sum: 0.4980
# Epoch: 137 	Total: 6199.5874 	Mean_train_accuracy: 0.7204
# 	Mean_test_accuracy: 0.7280 	Mean_test_accuracy_sum: 0.4980
# Epoch: 138 	Total: 6230.1179 	Mean_train_accuracy: 0.7201
# 	Mean_test_accuracy: 0.7190 	Mean_test_accuracy_sum: 0.4980
# Epoch: 139 	Total: 6209.3558 	Mean_train_accuracy: 0.7248
# 	Mean_test_accuracy: 0.7280 	Mean_test_accuracy_sum: 0.4980
# Epoch: 140 	Total: 6180.4215 	Mean_train_accuracy: 0.7211
# 	Mean_test_accuracy: 0.7310 	Mean_test_accuracy_sum: 0.4980
# Epoch: 141 	Total: 6223.3290 	Mean_train_accuracy: 0.7172
# 	Mean_test_accuracy: 0.7290 	Mean_test_accuracy_sum: 0.4980
# Epoch: 142 	Total: 6207.6322 	Mean_train_accuracy: 0.7222
# 	Mean_test_accuracy: 0.7240 	Mean_test_accuracy_sum: 0.4980
# Epoch: 143 	Total: 6152.9289 	Mean_train_accuracy: 0.7309
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4980
# Epoch: 144 	Total: 6084.2623 	Mean_train_accuracy: 0.7276
# 	Mean_test_accuracy: 0.7280 	Mean_test_accuracy_sum: 0.4980
# Epoch: 145 	Total: 6073.6573 	Mean_train_accuracy: 0.7281
# 	Mean_test_accuracy: 0.7420 	Mean_test_accuracy_sum: 0.4980
# Epoch: 146 	Total: 6100.0733 	Mean_train_accuracy: 0.7364
# 	Mean_test_accuracy: 0.7340 	Mean_test_accuracy_sum: 0.4980
# Epoch: 147 	Total: 6058.2416 	Mean_train_accuracy: 0.7296
# 	Mean_test_accuracy: 0.7330 	Mean_test_accuracy_sum: 0.4980
# Epoch: 148 	Total: 6055.7457 	Mean_train_accuracy: 0.7348
# 	Mean_test_accuracy: 0.7260 	Mean_test_accuracy_sum: 0.4980
# Epoch: 149 	Total: 6073.2782 	Mean_train_accuracy: 0.7451
# 	Mean_test_accuracy: 0.7460 	Mean_test_accuracy_sum: 0.4980
# Epoch: 150 	Total: 6010.0232 	Mean_train_accuracy: 0.7388
# 	Mean_test_accuracy: 0.7390 	Mean_test_accuracy_sum: 0.4980
# Epoch: 151 	Total: 5972.9722 	Mean_train_accuracy: 0.7419
# 	Mean_test_accuracy: 0.7460 	Mean_test_accuracy_sum: 0.4980
# Epoch: 152 	Total: 5986.6013 	Mean_train_accuracy: 0.7388
# 	Mean_test_accuracy: 0.7320 	Mean_test_accuracy_sum: 0.4980
# Epoch: 153 	Total: 5934.7536 	Mean_train_accuracy: 0.7410
# 	Mean_test_accuracy: 0.7530 	Mean_test_accuracy_sum: 0.4980
# Epoch: 154 	Total: 5937.8035 	Mean_train_accuracy: 0.7431
# 	Mean_test_accuracy: 0.7340 	Mean_test_accuracy_sum: 0.4980
# Epoch: 155 	Total: 5902.4734 	Mean_train_accuracy: 0.7441
# 	Mean_test_accuracy: 0.7470 	Mean_test_accuracy_sum: 0.4980
# Epoch: 156 	Total: 5890.9627 	Mean_train_accuracy: 0.7463
# 	Mean_test_accuracy: 0.7500 	Mean_test_accuracy_sum: 0.4980
# Epoch: 157 	Total: 5899.0855 	Mean_train_accuracy: 0.7467
# 	Mean_test_accuracy: 0.7560 	Mean_test_accuracy_sum: 0.4980
# Epoch: 158 	Total: 5865.1261 	Mean_train_accuracy: 0.7529
# 	Mean_test_accuracy: 0.7530 	Mean_test_accuracy_sum: 0.4980
# Epoch: 159 	Total: 5837.2801 	Mean_train_accuracy: 0.7512
# 	Mean_test_accuracy: 0.7570 	Mean_test_accuracy_sum: 0.4980
# Epoch: 160 	Total: 5859.3523 	Mean_train_accuracy: 0.7436
# 	Mean_test_accuracy: 0.7620 	Mean_test_accuracy_sum: 0.4980
# Epoch: 161 	Total: 5886.4019 	Mean_train_accuracy: 0.7476
# 	Mean_test_accuracy: 0.7640 	Mean_test_accuracy_sum: 0.4980
# Epoch: 162 	Total: 5819.8914 	Mean_train_accuracy: 0.7509
# 	Mean_test_accuracy: 0.7590 	Mean_test_accuracy_sum: 0.4980
# Epoch: 163 	Total: 5795.6749 	Mean_train_accuracy: 0.7566
# 	Mean_test_accuracy: 0.7600 	Mean_test_accuracy_sum: 0.4980
# Epoch: 164 	Total: 5785.2497 	Mean_train_accuracy: 0.7499
# 	Mean_test_accuracy: 0.7590 	Mean_test_accuracy_sum: 0.4980
# Epoch: 165 	Total: 5818.6940 	Mean_train_accuracy: 0.7565
# 	Mean_test_accuracy: 0.7550 	Mean_test_accuracy_sum: 0.4980
# Epoch: 166 	Total: 5784.9240 	Mean_train_accuracy: 0.7568
# 	Mean_test_accuracy: 0.7550 	Mean_test_accuracy_sum: 0.4980
# Epoch: 167 	Total: 5748.5924 	Mean_train_accuracy: 0.7531
# 	Mean_test_accuracy: 0.7580 	Mean_test_accuracy_sum: 0.4980
# Epoch: 168 	Total: 5731.7408 	Mean_train_accuracy: 0.7603
# 	Mean_test_accuracy: 0.7610 	Mean_test_accuracy_sum: 0.4980
# Epoch: 169 	Total: 5705.8012 	Mean_train_accuracy: 0.7605
# 	Mean_test_accuracy: 0.7640 	Mean_test_accuracy_sum: 0.4980
# Epoch: 170 	Total: 5719.2070 	Mean_train_accuracy: 0.7582
# 	Mean_test_accuracy: 0.7580 	Mean_test_accuracy_sum: 0.4980
# Epoch: 171 	Total: 5712.1212 	Mean_train_accuracy: 0.7577
# 	Mean_test_accuracy: 0.7500 	Mean_test_accuracy_sum: 0.4980
# Epoch: 172 	Total: 5698.4982 	Mean_train_accuracy: 0.7608
# 	Mean_test_accuracy: 0.7680 	Mean_test_accuracy_sum: 0.4980
# Epoch: 173 	Total: 5671.2298 	Mean_train_accuracy: 0.7628
# 	Mean_test_accuracy: 0.7610 	Mean_test_accuracy_sum: 0.4980
# Epoch: 174 	Total: 5657.8945 	Mean_train_accuracy: 0.7665
# 	Mean_test_accuracy: 0.7680 	Mean_test_accuracy_sum: 0.4980
# Epoch: 175 	Total: 5653.2441 	Mean_train_accuracy: 0.7657
# 	Mean_test_accuracy: 0.7600 	Mean_test_accuracy_sum: 0.4980
# Epoch: 176 	Total: 5651.9202 	Mean_train_accuracy: 0.7594
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4980
# Epoch: 177 	Total: 5707.6030 	Mean_train_accuracy: 0.7543
# 	Mean_test_accuracy: 0.7740 	Mean_test_accuracy_sum: 0.4980
# Epoch: 178 	Total: 5631.6785 	Mean_train_accuracy: 0.7706
# 	Mean_test_accuracy: 0.7650 	Mean_test_accuracy_sum: 0.4980
# Epoch: 179 	Total: 5624.9644 	Mean_train_accuracy: 0.7663
# 	Mean_test_accuracy: 0.7670 	Mean_test_accuracy_sum: 0.4980
# Epoch: 180 	Total: 5599.2270 	Mean_train_accuracy: 0.7670
# 	Mean_test_accuracy: 0.7640 	Mean_test_accuracy_sum: 0.4980
# Epoch: 181 	Total: 5601.4808 	Mean_train_accuracy: 0.7689
# 	Mean_test_accuracy: 0.7790 	Mean_test_accuracy_sum: 0.4980
# Epoch: 182 	Total: 5596.2864 	Mean_train_accuracy: 0.7683
# 	Mean_test_accuracy: 0.7720 	Mean_test_accuracy_sum: 0.4980
# Epoch: 183 	Total: 5587.5784 	Mean_train_accuracy: 0.7711
# 	Mean_test_accuracy: 0.7640 	Mean_test_accuracy_sum: 0.4980
# Epoch: 184 	Total: 5594.7999 	Mean_train_accuracy: 0.7688
# 	Mean_test_accuracy: 0.7750 	Mean_test_accuracy_sum: 0.4980
# Epoch: 185 	Total: 5577.0544 	Mean_train_accuracy: 0.7687
# 	Mean_test_accuracy: 0.7730 	Mean_test_accuracy_sum: 0.4980
# Epoch: 186 	Total: 5549.5021 	Mean_train_accuracy: 0.7706
# 	Mean_test_accuracy: 0.7770 	Mean_test_accuracy_sum: 0.4980
# Epoch: 187 	Total: 5559.1860 	Mean_train_accuracy: 0.7687
# 	Mean_test_accuracy: 0.7720 	Mean_test_accuracy_sum: 0.4980
# Epoch: 188 	Total: 5536.9934 	Mean_train_accuracy: 0.7739
# 	Mean_test_accuracy: 0.7710 	Mean_test_accuracy_sum: 0.4980
# Epoch: 189 	Total: 5535.1623 	Mean_train_accuracy: 0.7727
# 	Mean_test_accuracy: 0.7810 	Mean_test_accuracy_sum: 0.4980
# Epoch: 190 	Total: 5534.9290 	Mean_train_accuracy: 0.7748
# 	Mean_test_accuracy: 0.7740 	Mean_test_accuracy_sum: 0.4980
# Epoch: 191 	Total: 5540.4164 	Mean_train_accuracy: 0.7798
# 	Mean_test_accuracy: 0.7730 	Mean_test_accuracy_sum: 0.4980
# Epoch: 192 	Total: 5504.6302 	Mean_train_accuracy: 0.7764
# 	Mean_test_accuracy: 0.7760 	Mean_test_accuracy_sum: 0.4980
# Epoch: 193 	Total: 5526.7915 	Mean_train_accuracy: 0.7682
# 	Mean_test_accuracy: 0.7690 	Mean_test_accuracy_sum: 0.4980
# Epoch: 194 	Total: 5531.8403 	Mean_train_accuracy: 0.7734
# 	Mean_test_accuracy: 0.7700 	Mean_test_accuracy_sum: 0.4980
# Epoch: 195 	Total: 5508.5957 	Mean_train_accuracy: 0.7719
# 	Mean_test_accuracy: 0.7760 	Mean_test_accuracy_sum: 0.4980
# Epoch: 196 	Total: 5512.6109 	Mean_train_accuracy: 0.7779
# 	Mean_test_accuracy: 0.7720 	Mean_test_accuracy_sum: 0.4980
# Epoch: 197 	Total: 5492.0571 	Mean_train_accuracy: 0.7764
# 	Mean_test_accuracy: 0.7860 	Mean_test_accuracy_sum: 0.4980
# Epoch: 198 	Total: 5488.4504 	Mean_train_accuracy: 0.7793
# 	Mean_test_accuracy: 0.7740 	Mean_test_accuracy_sum: 0.4980
# Epoch: 199 	Total: 5552.2610 	Mean_train_accuracy: 0.7824
# 	Mean_test_accuracy: 0.7680 	Mean_test_accuracy_sum: 0.4980
# Epoch: 200 	Total: 5525.7103 	Mean_train_accuracy: 0.7761
# 	Mean_test_accuracy: 0.7730 	Mean_test_accuracy_sum: 0.4980
# Epoch: 201 	Total: 5511.0977 	Mean_train_accuracy: 0.7756
# 	Mean_test_accuracy: 0.7750 	Mean_test_accuracy_sum: 0.4980
# Epoch: 202 	Total: 5463.2294 	Mean_train_accuracy: 0.7758
# 	Mean_test_accuracy: 0.7740 	Mean_test_accuracy_sum: 0.4980
# Epoch: 203 	Total: 5450.9476 	Mean_train_accuracy: 0.7789
# 	Mean_test_accuracy: 0.7780 	Mean_test_accuracy_sum: 0.4980
# Epoch: 204 	Total: 5445.6148 	Mean_train_accuracy: 0.7804
# 	Mean_test_accuracy: 0.7750 	Mean_test_accuracy_sum: 0.4980
# Epoch: 205 	Total: 5437.4868 	Mean_train_accuracy: 0.7799
# 	Mean_test_accuracy: 0.7760 	Mean_test_accuracy_sum: 0.4980
# Epoch: 206 	Total: 5444.2591 	Mean_train_accuracy: 0.7741
# 	Mean_test_accuracy: 0.7730 	Mean_test_accuracy_sum: 0.4980
# Epoch: 207 	Total: 5460.8417 	Mean_train_accuracy: 0.7843
# 	Mean_test_accuracy: 0.7660 	Mean_test_accuracy_sum: 0.4980
# Epoch: 208 	Total: 5480.8255 	Mean_train_accuracy: 0.7795
# 	Mean_test_accuracy: 0.7880 	Mean_test_accuracy_sum: 0.4980
# Epoch: 209 	Total: 5491.1084 	Mean_train_accuracy: 0.7696
# 	Mean_test_accuracy: 0.7780 	Mean_test_accuracy_sum: 0.4980
# Epoch: 210 	Total: 5442.1244 	Mean_train_accuracy: 0.7859
# 	Mean_test_accuracy: 0.7750 	Mean_test_accuracy_sum: 0.4980
# Epoch: 211 	Total: 5428.3455 	Mean_train_accuracy: 0.7759
# 	Mean_test_accuracy: 0.7760 	Mean_test_accuracy_sum: 0.4980
# Epoch: 212 	Total: 5441.2957 	Mean_train_accuracy: 0.7831
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 213 	Total: 5464.6730 	Mean_train_accuracy: 0.7788
# 	Mean_test_accuracy: 0.7720 	Mean_test_accuracy_sum: 0.4980
# Epoch: 214 	Total: 5450.5754 	Mean_train_accuracy: 0.7736
# 	Mean_test_accuracy: 0.7750 	Mean_test_accuracy_sum: 0.4980
# Epoch: 215 	Total: 5450.9470 	Mean_train_accuracy: 0.7789
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.4980
# Epoch: 216 	Total: 5422.1916 	Mean_train_accuracy: 0.7734
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.4980
# Epoch: 217 	Total: 5418.9111 	Mean_train_accuracy: 0.7795
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4980
# Epoch: 218 	Total: 5412.2083 	Mean_train_accuracy: 0.7817
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4980
# Epoch: 219 	Total: 5401.0532 	Mean_train_accuracy: 0.7788
# 	Mean_test_accuracy: 0.7800 	Mean_test_accuracy_sum: 0.4980
# Epoch: 220 	Total: 5437.8801 	Mean_train_accuracy: 0.7808
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4980
# Epoch: 221 	Total: 5398.6558 	Mean_train_accuracy: 0.7807
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4980
# Epoch: 222 	Total: 5387.8426 	Mean_train_accuracy: 0.7771
# 	Mean_test_accuracy: 0.7770 	Mean_test_accuracy_sum: 0.4980
# Epoch: 223 	Total: 5382.5461 	Mean_train_accuracy: 0.7847
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 224 	Total: 5398.8015 	Mean_train_accuracy: 0.7857
# 	Mean_test_accuracy: 0.7800 	Mean_test_accuracy_sum: 0.4980
# Epoch: 225 	Total: 5378.4020 	Mean_train_accuracy: 0.7818
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 226 	Total: 5380.6351 	Mean_train_accuracy: 0.7855
# 	Mean_test_accuracy: 0.7760 	Mean_test_accuracy_sum: 0.4980
# Epoch: 227 	Total: 5372.2739 	Mean_train_accuracy: 0.7833
# 	Mean_test_accuracy: 0.7750 	Mean_test_accuracy_sum: 0.4980
# Epoch: 228 	Total: 5373.2701 	Mean_train_accuracy: 0.7875
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4980
# Epoch: 229 	Total: 5374.1477 	Mean_train_accuracy: 0.7855
# 	Mean_test_accuracy: 0.7790 	Mean_test_accuracy_sum: 0.4980
# Epoch: 230 	Total: 5412.7775 	Mean_train_accuracy: 0.7806
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4980
# Epoch: 231 	Total: 5385.8763 	Mean_train_accuracy: 0.7831
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4980
# Epoch: 232 	Total: 5352.1571 	Mean_train_accuracy: 0.7856
# 	Mean_test_accuracy: 0.7690 	Mean_test_accuracy_sum: 0.4980
# Epoch: 233 	Total: 5351.6283 	Mean_train_accuracy: 0.7875
# 	Mean_test_accuracy: 0.7790 	Mean_test_accuracy_sum: 0.4980
# Epoch: 234 	Total: 5380.2725 	Mean_train_accuracy: 0.7837
# 	Mean_test_accuracy: 0.7760 	Mean_test_accuracy_sum: 0.4980
# Epoch: 235 	Total: 5421.6875 	Mean_train_accuracy: 0.7843
# 	Mean_test_accuracy: 0.7800 	Mean_test_accuracy_sum: 0.4980
# Epoch: 236 	Total: 5366.4397 	Mean_train_accuracy: 0.7874
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4980
# Epoch: 237 	Total: 5352.4087 	Mean_train_accuracy: 0.7869
# 	Mean_test_accuracy: 0.7750 	Mean_test_accuracy_sum: 0.4980
# Epoch: 238 	Total: 5358.6412 	Mean_train_accuracy: 0.7841
# 	Mean_test_accuracy: 0.7740 	Mean_test_accuracy_sum: 0.4980
# Epoch: 239 	Total: 5338.8095 	Mean_train_accuracy: 0.7903
# 	Mean_test_accuracy: 0.7730 	Mean_test_accuracy_sum: 0.4980
# Epoch: 240 	Total: 5336.8099 	Mean_train_accuracy: 0.7833
# 	Mean_test_accuracy: 0.7730 	Mean_test_accuracy_sum: 0.4980
# Epoch: 241 	Total: 5335.4469 	Mean_train_accuracy: 0.7867
# 	Mean_test_accuracy: 0.7760 	Mean_test_accuracy_sum: 0.4980
# Epoch: 242 	Total: 5343.0513 	Mean_train_accuracy: 0.7869
# 	Mean_test_accuracy: 0.7860 	Mean_test_accuracy_sum: 0.4980
# Epoch: 243 	Total: 5323.3560 	Mean_train_accuracy: 0.7888
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 244 	Total: 5344.7989 	Mean_train_accuracy: 0.7826
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.4980
# Epoch: 245 	Total: 5330.5795 	Mean_train_accuracy: 0.7911
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 246 	Total: 5336.9188 	Mean_train_accuracy: 0.7841
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 247 	Total: 5326.9622 	Mean_train_accuracy: 0.7876
# 	Mean_test_accuracy: 0.7870 	Mean_test_accuracy_sum: 0.4980
# Epoch: 248 	Total: 5318.1761 	Mean_train_accuracy: 0.7797
# 	Mean_test_accuracy: 0.7860 	Mean_test_accuracy_sum: 0.4980
# Epoch: 249 	Total: 5343.6142 	Mean_train_accuracy: 0.7884
# 	Mean_test_accuracy: 0.7780 	Mean_test_accuracy_sum: 0.4980
# Epoch: 250 	Total: 5313.7739 	Mean_train_accuracy: 0.7901
# 	Mean_test_accuracy: 0.7750 	Mean_test_accuracy_sum: 0.4980
# Epoch: 251 	Total: 5311.4932 	Mean_train_accuracy: 0.7889
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 252 	Total: 5300.7891 	Mean_train_accuracy: 0.7910
# 	Mean_test_accuracy: 0.7880 	Mean_test_accuracy_sum: 0.4980
# Epoch: 253 	Total: 5324.0482 	Mean_train_accuracy: 0.7881
# 	Mean_test_accuracy: 0.7870 	Mean_test_accuracy_sum: 0.4980
# Epoch: 254 	Total: 5312.7963 	Mean_train_accuracy: 0.7847
# 	Mean_test_accuracy: 0.7790 	Mean_test_accuracy_sum: 0.4980
# Epoch: 255 	Total: 5359.5204 	Mean_train_accuracy: 0.7934
# 	Mean_test_accuracy: 0.7710 	Mean_test_accuracy_sum: 0.4980
# Epoch: 256 	Total: 5384.0947 	Mean_train_accuracy: 0.7872
# 	Mean_test_accuracy: 0.7810 	Mean_test_accuracy_sum: 0.4980
# Epoch: 257 	Total: 5310.3386 	Mean_train_accuracy: 0.7884
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.4980
# Epoch: 258 	Total: 5312.0447 	Mean_train_accuracy: 0.7858
# 	Mean_test_accuracy: 0.7810 	Mean_test_accuracy_sum: 0.4980
# Epoch: 259 	Total: 5295.0742 	Mean_train_accuracy: 0.7863
# 	Mean_test_accuracy: 0.7770 	Mean_test_accuracy_sum: 0.4980
# Epoch: 260 	Total: 5278.6353 	Mean_train_accuracy: 0.7902
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 261 	Total: 5274.0475 	Mean_train_accuracy: 0.7871
# 	Mean_test_accuracy: 0.7880 	Mean_test_accuracy_sum: 0.4980
# Epoch: 262 	Total: 5292.1598 	Mean_train_accuracy: 0.7891
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4980
# Epoch: 263 	Total: 5281.8245 	Mean_train_accuracy: 0.7971
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4980
# Epoch: 264 	Total: 5285.8725 	Mean_train_accuracy: 0.7928
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4980
# Epoch: 265 	Total: 5274.4263 	Mean_train_accuracy: 0.7928
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 266 	Total: 5291.5558 	Mean_train_accuracy: 0.7886
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4980
# Epoch: 267 	Total: 5309.1946 	Mean_train_accuracy: 0.7820
# 	Mean_test_accuracy: 0.7750 	Mean_test_accuracy_sum: 0.4980
# Epoch: 268 	Total: 5336.0408 	Mean_train_accuracy: 0.7886
# 	Mean_test_accuracy: 0.7870 	Mean_test_accuracy_sum: 0.4980
# Epoch: 269 	Total: 5288.3627 	Mean_train_accuracy: 0.7893
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 270 	Total: 5264.8131 	Mean_train_accuracy: 0.7930
# 	Mean_test_accuracy: 0.7770 	Mean_test_accuracy_sum: 0.4980
# Epoch: 271 	Total: 5266.1407 	Mean_train_accuracy: 0.7900
# 	Mean_test_accuracy: 0.7730 	Mean_test_accuracy_sum: 0.4980
# Epoch: 272 	Total: 5310.4898 	Mean_train_accuracy: 0.7876
# 	Mean_test_accuracy: 0.7690 	Mean_test_accuracy_sum: 0.4980
# Epoch: 273 	Total: 5274.9161 	Mean_train_accuracy: 0.7945
# 	Mean_test_accuracy: 0.7800 	Mean_test_accuracy_sum: 0.4980
# Epoch: 274 	Total: 5268.4806 	Mean_train_accuracy: 0.7901
# 	Mean_test_accuracy: 0.7860 	Mean_test_accuracy_sum: 0.4980
# Epoch: 275 	Total: 5264.1086 	Mean_train_accuracy: 0.7961
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4980
# Epoch: 276 	Total: 5246.8337 	Mean_train_accuracy: 0.7914
# 	Mean_test_accuracy: 0.7950 	Mean_test_accuracy_sum: 0.4980
# Epoch: 277 	Total: 5260.2636 	Mean_train_accuracy: 0.7892
# 	Mean_test_accuracy: 0.7780 	Mean_test_accuracy_sum: 0.4980
# Epoch: 278 	Total: 5310.5774 	Mean_train_accuracy: 0.7918
# 	Mean_test_accuracy: 0.7790 	Mean_test_accuracy_sum: 0.4980
# Epoch: 279 	Total: 5301.5816 	Mean_train_accuracy: 0.7843
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4980
# Epoch: 280 	Total: 5267.3905 	Mean_train_accuracy: 0.7954
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.4980
# Epoch: 281 	Total: 5257.4884 	Mean_train_accuracy: 0.7936
# 	Mean_test_accuracy: 0.7860 	Mean_test_accuracy_sum: 0.4980
# Epoch: 282 	Total: 5248.7578 	Mean_train_accuracy: 0.7928
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 283 	Total: 5240.2890 	Mean_train_accuracy: 0.7944
# 	Mean_test_accuracy: 0.7790 	Mean_test_accuracy_sum: 0.4980
# Epoch: 284 	Total: 5269.3465 	Mean_train_accuracy: 0.7994
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.4980
# Epoch: 285 	Total: 5268.6823 	Mean_train_accuracy: 0.7938
# 	Mean_test_accuracy: 0.7760 	Mean_test_accuracy_sum: 0.4980
# Epoch: 286 	Total: 5244.8150 	Mean_train_accuracy: 0.7942
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.4980
# Epoch: 287 	Total: 5239.9444 	Mean_train_accuracy: 0.7931
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.4980
# Epoch: 288 	Total: 5243.5427 	Mean_train_accuracy: 0.7924
# 	Mean_test_accuracy: 0.7760 	Mean_test_accuracy_sum: 0.4980
# Epoch: 289 	Total: 5240.2402 	Mean_train_accuracy: 0.7901
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 290 	Total: 5233.2501 	Mean_train_accuracy: 0.7950
# 	Mean_test_accuracy: 0.7810 	Mean_test_accuracy_sum: 0.4980
# Epoch: 291 	Total: 5229.1640 	Mean_train_accuracy: 0.7945
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4980
# Epoch: 292 	Total: 5259.0867 	Mean_train_accuracy: 0.7899
# 	Mean_test_accuracy: 0.7780 	Mean_test_accuracy_sum: 0.4980
# Epoch: 293 	Total: 5252.8728 	Mean_train_accuracy: 0.7904
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4980
# Epoch: 294 	Total: 5343.9771 	Mean_train_accuracy: 0.7890
# 	Mean_test_accuracy: 0.7680 	Mean_test_accuracy_sum: 0.4980
# Epoch: 295 	Total: 5316.3574 	Mean_train_accuracy: 0.7833
# 	Mean_test_accuracy: 0.7720 	Mean_test_accuracy_sum: 0.4980
# Epoch: 296 	Total: 5245.2801 	Mean_train_accuracy: 0.7924
# 	Mean_test_accuracy: 0.7870 	Mean_test_accuracy_sum: 0.4980
# Epoch: 297 	Total: 5235.1533 	Mean_train_accuracy: 0.7962
# 	Mean_test_accuracy: 0.7780 	Mean_test_accuracy_sum: 0.4980
# Epoch: 298 	Total: 5243.0071 	Mean_train_accuracy: 0.7970
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4980
# Epoch: 299 	Total: 5248.3621 	Mean_train_accuracy: 0.7896
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.4980
# Epoch: 300 	Total: 5288.3315 	Mean_train_accuracy: 0.7951
# 	Mean_test_accuracy: 0.7810 	Mean_test_accuracy_sum: 0.4980
# Epoch: 301 	Total: 5289.7518 	Mean_train_accuracy: 0.7954
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4980
# Epoch: 302 	Total: 5252.4618 	Mean_train_accuracy: 0.7981
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 303 	Total: 5239.4965 	Mean_train_accuracy: 0.7960
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.4980
# Epoch: 304 	Total: 5229.4491 	Mean_train_accuracy: 0.7921
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.4980
# Epoch: 305 	Total: 5223.9338 	Mean_train_accuracy: 0.7941
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 306 	Total: 5220.0151 	Mean_train_accuracy: 0.7997
# 	Mean_test_accuracy: 0.7950 	Mean_test_accuracy_sum: 0.4980
# Epoch: 307 	Total: 5215.8001 	Mean_train_accuracy: 0.7931
# 	Mean_test_accuracy: 0.7800 	Mean_test_accuracy_sum: 0.4980
# Epoch: 308 	Total: 5228.3337 	Mean_train_accuracy: 0.7963
# 	Mean_test_accuracy: 0.7770 	Mean_test_accuracy_sum: 0.4980
# Epoch: 309 	Total: 5276.1586 	Mean_train_accuracy: 0.7895
# 	Mean_test_accuracy: 0.7800 	Mean_test_accuracy_sum: 0.4980
# Epoch: 310 	Total: 5221.9677 	Mean_train_accuracy: 0.7964
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4980
# Epoch: 311 	Total: 5211.2690 	Mean_train_accuracy: 0.7942
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4980
# Epoch: 312 	Total: 5210.1375 	Mean_train_accuracy: 0.8001
# 	Mean_test_accuracy: 0.7780 	Mean_test_accuracy_sum: 0.4980
# Epoch: 313 	Total: 5235.7472 	Mean_train_accuracy: 0.7938
# 	Mean_test_accuracy: 0.7920 	Mean_test_accuracy_sum: 0.4980
# Epoch: 314 	Total: 5216.2845 	Mean_train_accuracy: 0.7952
# 	Mean_test_accuracy: 0.7930 	Mean_test_accuracy_sum: 0.4980
# Epoch: 315 	Total: 5214.2569 	Mean_train_accuracy: 0.7941
# 	Mean_test_accuracy: 0.7750 	Mean_test_accuracy_sum: 0.4980
# Epoch: 316 	Total: 5211.7157 	Mean_train_accuracy: 0.7950
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4980
# Epoch: 317 	Total: 5201.3370 	Mean_train_accuracy: 0.7941
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 318 	Total: 5199.7323 	Mean_train_accuracy: 0.7977
# 	Mean_test_accuracy: 0.7880 	Mean_test_accuracy_sum: 0.4980
# Epoch: 319 	Total: 5251.8598 	Mean_train_accuracy: 0.7907
# 	Mean_test_accuracy: 0.7760 	Mean_test_accuracy_sum: 0.4980
# Epoch: 320 	Total: 5215.8896 	Mean_train_accuracy: 0.7959
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 321 	Total: 5205.2087 	Mean_train_accuracy: 0.7972
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 322 	Total: 5207.1934 	Mean_train_accuracy: 0.7962
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4980
# Epoch: 323 	Total: 5202.9926 	Mean_train_accuracy: 0.7972
# 	Mean_test_accuracy: 0.7870 	Mean_test_accuracy_sum: 0.4980
# Epoch: 324 	Total: 5195.8964 	Mean_train_accuracy: 0.7991
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 325 	Total: 5192.7552 	Mean_train_accuracy: 0.7906
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 326 	Total: 5192.6299 	Mean_train_accuracy: 0.7957
# 	Mean_test_accuracy: 0.7790 	Mean_test_accuracy_sum: 0.4980
# Epoch: 327 	Total: 5194.2975 	Mean_train_accuracy: 0.7936
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 328 	Total: 5192.1403 	Mean_train_accuracy: 0.7958
# 	Mean_test_accuracy: 0.7880 	Mean_test_accuracy_sum: 0.4980
# Epoch: 329 	Total: 5198.1136 	Mean_train_accuracy: 0.7971
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 330 	Total: 5238.0868 	Mean_train_accuracy: 0.7974
# 	Mean_test_accuracy: 0.7740 	Mean_test_accuracy_sum: 0.4980
# Epoch: 331 	Total: 5200.0809 	Mean_train_accuracy: 0.7927
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 332 	Total: 5187.9926 	Mean_train_accuracy: 0.7962
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 333 	Total: 5198.1524 	Mean_train_accuracy: 0.7969
# 	Mean_test_accuracy: 0.7860 	Mean_test_accuracy_sum: 0.4980
# Epoch: 334 	Total: 5188.9250 	Mean_train_accuracy: 0.7967
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4980
# Epoch: 335 	Total: 5177.0559 	Mean_train_accuracy: 0.8008
# 	Mean_test_accuracy: 0.7880 	Mean_test_accuracy_sum: 0.4980
# Epoch: 336 	Total: 5177.4592 	Mean_train_accuracy: 0.7966
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 337 	Total: 5167.8981 	Mean_train_accuracy: 0.7959
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 338 	Total: 5179.9428 	Mean_train_accuracy: 0.8008
# 	Mean_test_accuracy: 0.7870 	Mean_test_accuracy_sum: 0.4980
# Epoch: 339 	Total: 5218.3859 	Mean_train_accuracy: 0.7874
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 340 	Total: 5221.2494 	Mean_train_accuracy: 0.7954
# 	Mean_test_accuracy: 0.8000 	Mean_test_accuracy_sum: 0.4980
# Epoch: 341 	Total: 5184.3456 	Mean_train_accuracy: 0.7989
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.4980
# Epoch: 342 	Total: 5184.2296 	Mean_train_accuracy: 0.8019
# 	Mean_test_accuracy: 0.7870 	Mean_test_accuracy_sum: 0.4980
# Epoch: 343 	Total: 5180.9587 	Mean_train_accuracy: 0.7963
# 	Mean_test_accuracy: 0.7870 	Mean_test_accuracy_sum: 0.4980
# Epoch: 344 	Total: 5243.3890 	Mean_train_accuracy: 0.7948
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.4980
# Epoch: 345 	Total: 5215.9895 	Mean_train_accuracy: 0.7999
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.4980
# Epoch: 346 	Total: 5177.4846 	Mean_train_accuracy: 0.7924
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.4980
# Epoch: 347 	Total: 5164.7526 	Mean_train_accuracy: 0.8056
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.4980
# Epoch: 348 	Total: 5166.2319 	Mean_train_accuracy: 0.7971
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4980
# Epoch: 349 	Total: 5187.9511 	Mean_train_accuracy: 0.7995
# 	Mean_test_accuracy: 0.7880 	Mean_test_accuracy_sum: 0.4980
# Epoch: 350 	Total: 5182.3600 	Mean_train_accuracy: 0.7919
# 	Mean_test_accuracy: 0.7800 	Mean_test_accuracy_sum: 0.4980
# Epoch: 351 	Total: 5195.8892 	Mean_train_accuracy: 0.7954
# 	Mean_test_accuracy: 0.7980 	Mean_test_accuracy_sum: 0.4980
# Epoch: 352 	Total: 5183.1787 	Mean_train_accuracy: 0.7936
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4980
# Epoch: 353 	Total: 5185.0867 	Mean_train_accuracy: 0.7961
# 	Mean_test_accuracy: 0.7870 	Mean_test_accuracy_sum: 0.4980
# Epoch: 354 	Total: 5180.5870 	Mean_train_accuracy: 0.7951
# 	Mean_test_accuracy: 0.7810 	Mean_test_accuracy_sum: 0.4980
# Epoch: 355 	Total: 5167.6288 	Mean_train_accuracy: 0.7988
# 	Mean_test_accuracy: 0.7880 	Mean_test_accuracy_sum: 0.4980
# Epoch: 356 	Total: 5166.1915 	Mean_train_accuracy: 0.7953
# 	Mean_test_accuracy: 0.7880 	Mean_test_accuracy_sum: 0.4980
# Epoch: 357 	Total: 5161.9243 	Mean_train_accuracy: 0.7988
# 	Mean_test_accuracy: 0.7870 	Mean_test_accuracy_sum: 0.4980
# Epoch: 358 	Total: 5151.1563 	Mean_train_accuracy: 0.7956
# 	Mean_test_accuracy: 0.7930 	Mean_test_accuracy_sum: 0.4980
# Epoch: 359 	Total: 5260.6530 	Mean_train_accuracy: 0.7980
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.4980
# Epoch: 360 	Total: 5201.7915 	Mean_train_accuracy: 0.7989
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4980
# Epoch: 361 	Total: 5177.8283 	Mean_train_accuracy: 0.8010
# 	Mean_test_accuracy: 0.7930 	Mean_test_accuracy_sum: 0.4980
# Epoch: 362 	Total: 5181.1659 	Mean_train_accuracy: 0.7988
# 	Mean_test_accuracy: 0.7920 	Mean_test_accuracy_sum: 0.4980
# Epoch: 363 	Total: 5162.6792 	Mean_train_accuracy: 0.8051
# 	Mean_test_accuracy: 0.7860 	Mean_test_accuracy_sum: 0.4980
# Epoch: 364 	Total: 5185.6981 	Mean_train_accuracy: 0.8026
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 365 	Total: 5253.9759 	Mean_train_accuracy: 0.7981
# 	Mean_test_accuracy: 0.7690 	Mean_test_accuracy_sum: 0.4980
# Epoch: 366 	Total: 5169.9309 	Mean_train_accuracy: 0.8004
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 367 	Total: 5176.0540 	Mean_train_accuracy: 0.7981
# 	Mean_test_accuracy: 0.7880 	Mean_test_accuracy_sum: 0.4980
# Epoch: 368 	Total: 5162.7664 	Mean_train_accuracy: 0.8000
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4980
# Epoch: 369 	Total: 5179.7971 	Mean_train_accuracy: 0.7969
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 370 	Total: 5187.4311 	Mean_train_accuracy: 0.7988
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 371 	Total: 5159.9004 	Mean_train_accuracy: 0.8020
# 	Mean_test_accuracy: 0.7810 	Mean_test_accuracy_sum: 0.4980
# Epoch: 372 	Total: 5179.3279 	Mean_train_accuracy: 0.7971
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 373 	Total: 5164.1188 	Mean_train_accuracy: 0.7986
# 	Mean_test_accuracy: 0.7860 	Mean_test_accuracy_sum: 0.4980
# Epoch: 374 	Total: 5149.9526 	Mean_train_accuracy: 0.8001
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 375 	Total: 5152.4897 	Mean_train_accuracy: 0.7966
# 	Mean_test_accuracy: 0.7920 	Mean_test_accuracy_sum: 0.4980
# Epoch: 376 	Total: 5185.9449 	Mean_train_accuracy: 0.8038
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 377 	Total: 5176.3913 	Mean_train_accuracy: 0.8028
# 	Mean_test_accuracy: 0.7740 	Mean_test_accuracy_sum: 0.4980
# Epoch: 378 	Total: 5157.7257 	Mean_train_accuracy: 0.7963
# 	Mean_test_accuracy: 0.7880 	Mean_test_accuracy_sum: 0.4980
# Epoch: 379 	Total: 5161.6510 	Mean_train_accuracy: 0.8016
# 	Mean_test_accuracy: 0.7870 	Mean_test_accuracy_sum: 0.4980
# Epoch: 380 	Total: 5141.8200 	Mean_train_accuracy: 0.8012
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 381 	Total: 5145.0038 	Mean_train_accuracy: 0.8002
# 	Mean_test_accuracy: 0.7880 	Mean_test_accuracy_sum: 0.4980
# Epoch: 382 	Total: 5177.2778 	Mean_train_accuracy: 0.7934
# 	Mean_test_accuracy: 0.7920 	Mean_test_accuracy_sum: 0.4980
# Epoch: 383 	Total: 5159.1975 	Mean_train_accuracy: 0.8014
# 	Mean_test_accuracy: 0.7870 	Mean_test_accuracy_sum: 0.4980
# Epoch: 384 	Total: 5153.6831 	Mean_train_accuracy: 0.8023
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.4980
# Epoch: 385 	Total: 5152.8351 	Mean_train_accuracy: 0.7955
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4980
# Epoch: 386 	Total: 5151.3637 	Mean_train_accuracy: 0.8032
# 	Mean_test_accuracy: 0.7800 	Mean_test_accuracy_sum: 0.4980
# Epoch: 387 	Total: 5142.6067 	Mean_train_accuracy: 0.8011
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 388 	Total: 5139.9195 	Mean_train_accuracy: 0.8034
# 	Mean_test_accuracy: 0.7920 	Mean_test_accuracy_sum: 0.4980
# Epoch: 389 	Total: 5164.3512 	Mean_train_accuracy: 0.8053
# 	Mean_test_accuracy: 0.7790 	Mean_test_accuracy_sum: 0.4980
# Epoch: 390 	Total: 5158.0609 	Mean_train_accuracy: 0.7982
# 	Mean_test_accuracy: 0.7810 	Mean_test_accuracy_sum: 0.4980
# Epoch: 391 	Total: 5134.0695 	Mean_train_accuracy: 0.8039
# 	Mean_test_accuracy: 0.7860 	Mean_test_accuracy_sum: 0.4980
# Epoch: 392 	Total: 5123.2497 	Mean_train_accuracy: 0.7974
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 393 	Total: 5205.1524 	Mean_train_accuracy: 0.8005
# 	Mean_test_accuracy: 0.7710 	Mean_test_accuracy_sum: 0.4980
# Epoch: 394 	Total: 5163.7869 	Mean_train_accuracy: 0.7943
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.4980
# Epoch: 395 	Total: 5163.8007 	Mean_train_accuracy: 0.7983
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 396 	Total: 5136.8799 	Mean_train_accuracy: 0.8026
# 	Mean_test_accuracy: 0.7860 	Mean_test_accuracy_sum: 0.4980
# Epoch: 397 	Total: 5130.2511 	Mean_train_accuracy: 0.8012
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4980
# Epoch: 398 	Total: 5166.8519 	Mean_train_accuracy: 0.8014
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 399 	Total: 5182.0175 	Mean_train_accuracy: 0.7972
# 	Mean_test_accuracy: 0.7880 	Mean_test_accuracy_sum: 0.4980
# Epoch: 400 	Total: 5159.5520 	Mean_train_accuracy: 0.7972
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.4980
# Epoch: 401 	Total: 5137.5094 	Mean_train_accuracy: 0.7973
# 	Mean_test_accuracy: 0.7960 	Mean_test_accuracy_sum: 0.4980
# Epoch: 402 	Total: 5140.2003 	Mean_train_accuracy: 0.8010
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4980
# Epoch: 403 	Total: 5128.7626 	Mean_train_accuracy: 0.8034
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4980
# Epoch: 404 	Total: 5134.6091 	Mean_train_accuracy: 0.8006
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 405 	Total: 5123.7410 	Mean_train_accuracy: 0.8049
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.4980
# Epoch: 406 	Total: 5130.6369 	Mean_train_accuracy: 0.8004
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4980
# Epoch: 407 	Total: 5119.8594 	Mean_train_accuracy: 0.8034
# 	Mean_test_accuracy: 0.7780 	Mean_test_accuracy_sum: 0.4980
# Epoch: 408 	Total: 5127.8311 	Mean_train_accuracy: 0.8012
# ...
# Epoch: 1867 	Total: 4916.6559 	Mean_train_accuracy: 0.8139
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1868 	Total: 4908.9327 	Mean_train_accuracy: 0.8149
# 	Mean_test_accuracy: 0.7990 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1869 	Total: 4918.5802 	Mean_train_accuracy: 0.8116
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1870 	Total: 4903.9700 	Mean_train_accuracy: 0.8163
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1871 	Total: 4900.9446 	Mean_train_accuracy: 0.8127
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1872 	Total: 4903.1737 	Mean_train_accuracy: 0.8143
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1873 	Total: 4938.1063 	Mean_train_accuracy: 0.8143
# 	Mean_test_accuracy: 0.8010 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1874 	Total: 4912.7885 	Mean_train_accuracy: 0.8151
# 	Mean_test_accuracy: 0.8000 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1875 	Total: 4913.2803 	Mean_train_accuracy: 0.8160
# 	Mean_test_accuracy: 0.7930 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1876 	Total: 4913.9336 	Mean_train_accuracy: 0.8164
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1877 	Total: 4903.1492 	Mean_train_accuracy: 0.8161
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1878 	Total: 4902.7672 	Mean_train_accuracy: 0.8197
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1879 	Total: 4895.7400 	Mean_train_accuracy: 0.8174
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1880 	Total: 4904.7652 	Mean_train_accuracy: 0.8164
# 	Mean_test_accuracy: 0.8000 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1881 	Total: 4921.9994 	Mean_train_accuracy: 0.8163
# 	Mean_test_accuracy: 0.8000 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1882 	Total: 4932.3124 	Mean_train_accuracy: 0.8160
# 	Mean_test_accuracy: 0.7930 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1883 	Total: 4928.0448 	Mean_train_accuracy: 0.8220
# 	Mean_test_accuracy: 0.7970 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1884 	Total: 4929.9014 	Mean_train_accuracy: 0.8102
# 	Mean_test_accuracy: 0.7990 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1885 	Total: 4969.4918 	Mean_train_accuracy: 0.8134
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1886 	Total: 4924.8622 	Mean_train_accuracy: 0.8208
# 	Mean_test_accuracy: 0.8010 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1887 	Total: 4904.4800 	Mean_train_accuracy: 0.8155
# 	Mean_test_accuracy: 0.7980 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1888 	Total: 4896.2709 	Mean_train_accuracy: 0.8140
# 	Mean_test_accuracy: 0.8000 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1889 	Total: 4902.6425 	Mean_train_accuracy: 0.8231
# 	Mean_test_accuracy: 0.7960 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1890 	Total: 4920.3058 	Mean_train_accuracy: 0.8194
# 	Mean_test_accuracy: 0.7950 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1891 	Total: 4928.0914 	Mean_train_accuracy: 0.8177
# 	Mean_test_accuracy: 0.7990 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1892 	Total: 4913.9506 	Mean_train_accuracy: 0.8184
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1893 	Total: 4912.3727 	Mean_train_accuracy: 0.8127
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1894 	Total: 4910.4565 	Mean_train_accuracy: 0.8224
# 	Mean_test_accuracy: 0.7950 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1895 	Total: 4904.5176 	Mean_train_accuracy: 0.8155
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1896 	Total: 4895.8466 	Mean_train_accuracy: 0.8151
# 	Mean_test_accuracy: 0.8000 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1897 	Total: 4894.3410 	Mean_train_accuracy: 0.8145
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1898 	Total: 4888.6347 	Mean_train_accuracy: 0.8173
# 	Mean_test_accuracy: 0.7970 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1899 	Total: 4891.6690 	Mean_train_accuracy: 0.8130
# 	Mean_test_accuracy: 0.7990 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1900 	Total: 4914.4755 	Mean_train_accuracy: 0.8140
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1901 	Total: 4927.3530 	Mean_train_accuracy: 0.8170
# 	Mean_test_accuracy: 0.7930 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1902 	Total: 4919.0609 	Mean_train_accuracy: 0.8142
# 	Mean_test_accuracy: 0.7930 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1903 	Total: 4898.7799 	Mean_train_accuracy: 0.8104
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1904 	Total: 4906.9764 	Mean_train_accuracy: 0.8188
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1905 	Total: 4903.9700 	Mean_train_accuracy: 0.8151
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1906 	Total: 4900.5972 	Mean_train_accuracy: 0.8164
# 	Mean_test_accuracy: 0.8010 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1907 	Total: 4894.1160 	Mean_train_accuracy: 0.8179
# 	Mean_test_accuracy: 0.7970 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1908 	Total: 4900.4468 	Mean_train_accuracy: 0.8177
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1909 	Total: 4892.8658 	Mean_train_accuracy: 0.8163
# 	Mean_test_accuracy: 0.8020 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1910 	Total: 4904.5100 	Mean_train_accuracy: 0.8201
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1911 	Total: 4909.9603 	Mean_train_accuracy: 0.8172
# 	Mean_test_accuracy: 0.7920 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1912 	Total: 4909.3198 	Mean_train_accuracy: 0.8187
# 	Mean_test_accuracy: 0.8000 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1913 	Total: 4898.8007 	Mean_train_accuracy: 0.8184
# 	Mean_test_accuracy: 0.7970 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1914 	Total: 4901.3707 	Mean_train_accuracy: 0.8181
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1915 	Total: 4898.3846 	Mean_train_accuracy: 0.8199
# 	Mean_test_accuracy: 0.8020 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1916 	Total: 4901.4388 	Mean_train_accuracy: 0.8189
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1917 	Total: 4916.9428 	Mean_train_accuracy: 0.8121
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1918 	Total: 4939.2984 	Mean_train_accuracy: 0.8167
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1919 	Total: 4940.6900 	Mean_train_accuracy: 0.8151
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1920 	Total: 4915.3019 	Mean_train_accuracy: 0.8178
# 	Mean_test_accuracy: 0.7970 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1921 	Total: 4909.7563 	Mean_train_accuracy: 0.8144
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1922 	Total: 4906.3677 	Mean_train_accuracy: 0.8109
# 	Mean_test_accuracy: 0.7980 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1923 	Total: 4898.5476 	Mean_train_accuracy: 0.8161
# 	Mean_test_accuracy: 0.8010 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1924 	Total: 4921.1880 	Mean_train_accuracy: 0.8151
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1925 	Total: 4918.1418 	Mean_train_accuracy: 0.8167
# 	Mean_test_accuracy: 0.8020 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1926 	Total: 4906.4545 	Mean_train_accuracy: 0.8167
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1927 	Total: 4914.6535 	Mean_train_accuracy: 0.8184
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1928 	Total: 4922.0641 	Mean_train_accuracy: 0.8207
# 	Mean_test_accuracy: 0.8000 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1929 	Total: 4902.3530 	Mean_train_accuracy: 0.8187
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1930 	Total: 4894.5875 	Mean_train_accuracy: 0.8253
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1931 	Total: 4923.7101 	Mean_train_accuracy: 0.8216
# 	Mean_test_accuracy: 0.7980 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1932 	Total: 4916.0650 	Mean_train_accuracy: 0.8209
# 	Mean_test_accuracy: 0.7960 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1933 	Total: 4923.5331 	Mean_train_accuracy: 0.8153
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1934 	Total: 4917.6471 	Mean_train_accuracy: 0.8173
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1935 	Total: 4921.2751 	Mean_train_accuracy: 0.8144
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1936 	Total: 4927.2981 	Mean_train_accuracy: 0.8178
# 	Mean_test_accuracy: 0.7970 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1937 	Total: 4943.1801 	Mean_train_accuracy: 0.8209
# 	Mean_test_accuracy: 0.7950 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1938 	Total: 4926.2160 	Mean_train_accuracy: 0.8181
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1939 	Total: 4920.4216 	Mean_train_accuracy: 0.8178
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1940 	Total: 4921.2292 	Mean_train_accuracy: 0.8174
# 	Mean_test_accuracy: 0.7960 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1941 	Total: 4937.7896 	Mean_train_accuracy: 0.8140
# 	Mean_test_accuracy: 0.8010 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1942 	Total: 4915.2175 	Mean_train_accuracy: 0.8161
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1943 	Total: 4933.1752 	Mean_train_accuracy: 0.8096
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1944 	Total: 4916.9918 	Mean_train_accuracy: 0.8196
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1945 	Total: 4911.6794 	Mean_train_accuracy: 0.8195
# 	Mean_test_accuracy: 0.8020 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1946 	Total: 4901.8639 	Mean_train_accuracy: 0.8192
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1947 	Total: 4896.5913 	Mean_train_accuracy: 0.8159
# 	Mean_test_accuracy: 0.7960 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1948 	Total: 4899.6950 	Mean_train_accuracy: 0.8112
# 	Mean_test_accuracy: 0.8010 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1949 	Total: 4914.7537 	Mean_train_accuracy: 0.8147
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1950 	Total: 4912.4117 	Mean_train_accuracy: 0.8180
# 	Mean_test_accuracy: 0.7960 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1951 	Total: 4945.9713 	Mean_train_accuracy: 0.8167
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1952 	Total: 4919.0621 	Mean_train_accuracy: 0.8158
# 	Mean_test_accuracy: 0.7970 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1953 	Total: 4904.3434 	Mean_train_accuracy: 0.8170
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1954 	Total: 4905.0495 	Mean_train_accuracy: 0.8261
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1955 	Total: 4915.4695 	Mean_train_accuracy: 0.8124
# 	Mean_test_accuracy: 0.7950 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1956 	Total: 4912.1481 	Mean_train_accuracy: 0.8173
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1957 	Total: 4915.4426 	Mean_train_accuracy: 0.8181
# 	Mean_test_accuracy: 0.7960 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1958 	Total: 4909.0128 	Mean_train_accuracy: 0.8187
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1959 	Total: 4919.4902 	Mean_train_accuracy: 0.8198
# 	Mean_test_accuracy: 0.7950 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1960 	Total: 4901.0802 	Mean_train_accuracy: 0.8196
# 	Mean_test_accuracy: 0.7930 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1961 	Total: 4910.9582 	Mean_train_accuracy: 0.8123
# 	Mean_test_accuracy: 0.8020 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1962 	Total: 4920.1647 	Mean_train_accuracy: 0.8201
# 	Mean_test_accuracy: 0.8020 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1963 	Total: 4916.1823 	Mean_train_accuracy: 0.8136
# 	Mean_test_accuracy: 0.8000 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1964 	Total: 4908.7161 	Mean_train_accuracy: 0.8198
# 	Mean_test_accuracy: 0.7950 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1965 	Total: 4923.8240 	Mean_train_accuracy: 0.8223
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1966 	Total: 4910.1585 	Mean_train_accuracy: 0.8217
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1967 	Total: 4902.8826 	Mean_train_accuracy: 0.8218
# 	Mean_test_accuracy: 0.7990 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1968 	Total: 4909.2117 	Mean_train_accuracy: 0.8120
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1969 	Total: 4906.5024 	Mean_train_accuracy: 0.8169
# 	Mean_test_accuracy: 0.7920 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1970 	Total: 4924.7076 	Mean_train_accuracy: 0.8195
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1971 	Total: 4910.8463 	Mean_train_accuracy: 0.8197
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1972 	Total: 4941.5251 	Mean_train_accuracy: 0.8228
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1973 	Total: 4958.2177 	Mean_train_accuracy: 0.8144
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1974 	Total: 4957.3565 	Mean_train_accuracy: 0.8116
# 	Mean_test_accuracy: 0.8010 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1975 	Total: 4921.3677 	Mean_train_accuracy: 0.8167
# 	Mean_test_accuracy: 0.7970 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1976 	Total: 4918.7759 	Mean_train_accuracy: 0.8179
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1977 	Total: 4909.4020 	Mean_train_accuracy: 0.8196
# 	Mean_test_accuracy: 0.8010 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1978 	Total: 4888.0757 	Mean_train_accuracy: 0.8183
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1979 	Total: 4891.8837 	Mean_train_accuracy: 0.8181
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1980 	Total: 4898.8133 	Mean_train_accuracy: 0.8188
# 	Mean_test_accuracy: 0.7990 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1981 	Total: 4900.8444 	Mean_train_accuracy: 0.8154
# 	Mean_test_accuracy: 0.7930 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1982 	Total: 4915.9538 	Mean_train_accuracy: 0.8180
# 	Mean_test_accuracy: 0.8020 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1983 	Total: 4906.4885 	Mean_train_accuracy: 0.8157
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1984 	Total: 4898.8785 	Mean_train_accuracy: 0.8164
# 	Mean_test_accuracy: 0.7860 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1985 	Total: 4886.5256 	Mean_train_accuracy: 0.8164
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1986 	Total: 4893.3344 	Mean_train_accuracy: 0.8164
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1987 	Total: 4888.8741 	Mean_train_accuracy: 0.8163
# 	Mean_test_accuracy: 0.7960 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1988 	Total: 4894.8353 	Mean_train_accuracy: 0.8133
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1989 	Total: 4906.2171 	Mean_train_accuracy: 0.8193
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1990 	Total: 4907.5449 	Mean_train_accuracy: 0.8163
# 	Mean_test_accuracy: 0.7920 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1991 	Total: 4889.0608 	Mean_train_accuracy: 0.8208
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1992 	Total: 4887.3825 	Mean_train_accuracy: 0.8173
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1993 	Total: 4898.9988 	Mean_train_accuracy: 0.8169
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1994 	Total: 4915.2145 	Mean_train_accuracy: 0.8179
# 	Mean_test_accuracy: 0.7950 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1995 	Total: 4924.1085 	Mean_train_accuracy: 0.8126
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1996 	Total: 4940.6420 	Mean_train_accuracy: 0.8084
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1997 	Total: 5014.2582 	Mean_train_accuracy: 0.8083
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1998 	Total: 4966.7296 	Mean_train_accuracy: 0.8119
# 	Mean_test_accuracy: 0.7950 	Mean_test_accuracy_sum: 0.4980
# Epoch: 1999 	Total: 4925.1062 	Mean_train_accuracy: 0.8168
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.4980
# Epoch: 2000 	Total: 4925.2732 	Mean_train_accuracy: 0.8109
# 	Mean_test_accuracy: 0.8020 	Mean_test_accuracy_sum: 0.4980
