# %%
import torch
import sys
sys.path.append('/home/zjy/project/MetaIM')
pwd = '/home/zjy/project/MetaIM/data'
device = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=3)

# %%
from torch_geometric.datasets import Planetoid

cora_dataset = Planetoid(root=pwd+'/cora', name='cora')
data = cora_dataset[0]
edge_index = data.edge_index

# %%
import numpy as np
individual_infection_path = pwd+'/for_meta/cora_individual_infection_sir_200.npy'
seeds_infection_path = pwd+'/for_meta/cora_seed_infection_sir_200_sample_1000.npy'

individual_infection = np.load(individual_infection_path)
seeds_infection = np.load(seeds_infection_path)
individual_infection.shape,seeds_infection.shape
# Out:
# ((2708, 2708), (1000, 2, 2708))

# %%
import torch
from torch_geometric.utils import to_scipy_sparse_matrix
import scipy.sparse as sp

# 转换为 scipy 稀疏矩阵
adj = to_scipy_sparse_matrix(edge_index)


# def normalize_adj(mx):
#     """Row-normalize sparse matrix"""
#     rowsum = np.array(mx.sum(1))
#     r_inv_sqrt = np.power(rowsum, -0.5).flatten()
#     r_inv_sqrt[np.isinf(r_inv_sqrt)] = 0.
#     r_mat_inv_sqrt = sp.diags(r_inv_sqrt)
#     return mx.dot(r_mat_inv_sqrt).transpose().dot(r_mat_inv_sqrt)



# adj = adj + adj.T.multiply(adj.T > adj) - adj.multiply(adj.T > adj)
# adj = normalize_adj(adj + sp.eye(adj.shape[0]))
adj = torch.Tensor(adj.toarray()).to_sparse()
adj
# Out:
# tensor(indices=tensor([[   0,    0,    0,  ..., 2707, 2707, 2707],
#                        [ 633, 1862, 2582,  ...,  598, 1473, 2706]]),
#        values=tensor([1., 1., 1.,  ..., 1., 1., 1.]),
#        size=(2708, 2708), nnz=10556, layout=torch.sparse_coo)

# %%
seed_num = int(seeds_infection[0][0].sum())

# %%
from torch.utils.data import Dataset, DataLoader, random_split


class CustomDataset(Dataset):
    def __init__(self, individual_infection,seeds_infection, seed_num):
        self.individual_infection = individual_infection
        self.seeds_infection = seeds_infection
        self.feat_shape = (len(individual_infection), seed_num)

    def __len__(self):
        return len(self.seeds_infection)

    def __getitem__(self, idx):
        seeds= np.nonzero(self.seeds_infection[idx][0])[0]
        
        feature = torch.zeros(self.feat_shape[0],self.feat_shape[1])
        for i in range(len(seeds)):
            seed_i_infection = torch.tensor(self.individual_infection[seeds[i]])
            feature[:, i] = seed_i_infection
            
        label = self.seeds_infection[idx][1]
        
        return self.seeds_infection[idx][0], feature, label

dataset = CustomDataset(individual_infection, seeds_infection, seed_num)

# %%
# 定义划分比例
train_ratio = 0.8
test_ratio = 0.2

# 划分数据集
train_dataset, test_dataset = random_split(dataset, [int(len(dataset)*train_ratio), int(len(dataset)*test_ratio)])

train_batch_size = 64
test_batch_size = 4

# 创建数据加载器
train_loader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True, drop_last=False)
test_loader = DataLoader(test_dataset, batch_size=test_batch_size, shuffle=False)

# %% [markdown]
# 训练VAE

# %%
# from data import model 
from data.model.model import VAEModel, Encoder, Decoder
from torch.optim import Adam, SGD
import torch.nn.functional as F

# # hidden_dim = 256
# # latent_dim = 64
hidden_dim = 1024
latent_dim = 64

encoder = Encoder(input_dim= len(seeds_infection[0][0]), 
                  hidden_dim=hidden_dim, 
                  latent_dim=latent_dim)

decoder = Decoder(input_dim=latent_dim, 
                  latent_dim=latent_dim, 
                  hidden_dim=hidden_dim, 
                  output_dim=len(seeds_infection[0][0]))

vae_model = VAEModel(Encoder=encoder, Decoder=decoder).to(device)

optimizer_vae = Adam([{'params': vae_model.parameters()}], 
                 lr=1e-3)
vae_model.train()
# Out:
# VAEModel(
#   (Encoder): Encoder(
#     (FC_input): Linear(in_features=2708, out_features=1024, bias=True)
#     (FC_input2): Linear(in_features=1024, out_features=1024, bias=True)
#     (FC_output): Linear(in_features=1024, out_features=64, bias=True)
#     (bn): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Decoder): Decoder(
#     (FC_input): Linear(in_features=64, out_features=64, bias=True)
#     (FC_hidden_1): Linear(in_features=64, out_features=1024, bias=True)
#     (FC_hidden_2): Linear(in_features=1024, out_features=1024, bias=True)
#     (FC_output): Linear(in_features=1024, out_features=2708, bias=True)
#   )
# )

# %%
for epoch in range(200):
    train_vae_loss = 0
    mean_train_accuracy = 0
    for batch_idx, x_feature_label in enumerate(train_loader):        
        x = x_feature_label[0].to(device)
        optimizer_vae.zero_grad()
        loss = 0
        for i, x_i in enumerate(x):
            x_hat = vae_model(x_i)

            reproduction_loss = F.binary_cross_entropy(x_hat, x_i, reduction='sum')   
            loss += reproduction_loss    
        train_vae_loss += loss.item()
        loss = loss/x.size(0)
        loss.backward()
        optimizer_vae.step()
        
    print("Epoch: {}".format(epoch+1), 
        "\tTrain_vae_loss: {:.4f}".format(train_vae_loss / train_batch_size),
        )
    
for param in vae_model.parameters():
    param.requires_grad = False
# Out:
# Epoch: 1 	Train_vae_loss: 13454.0364
# Epoch: 2 	Train_vae_loss: 7524.3380
# Epoch: 3 	Train_vae_loss: 6927.9572
# Epoch: 4 	Train_vae_loss: 6805.7452
# Epoch: 5 	Train_vae_loss: 6759.3025
# Epoch: 6 	Train_vae_loss: 6742.7195
# Epoch: 7 	Train_vae_loss: 6737.9240
# Epoch: 8 	Train_vae_loss: 6733.8755
# Epoch: 9 	Train_vae_loss: 6728.1880
# Epoch: 10 	Train_vae_loss: 6730.5978
# Epoch: 11 	Train_vae_loss: 6729.0635
# Epoch: 12 	Train_vae_loss: 6729.8156
# Epoch: 13 	Train_vae_loss: 6725.5660
# Epoch: 14 	Train_vae_loss: 6726.5098
# Epoch: 15 	Train_vae_loss: 6726.9864
# Epoch: 16 	Train_vae_loss: 6726.1282
# Epoch: 17 	Train_vae_loss: 6724.0960
# Epoch: 18 	Train_vae_loss: 6723.9723
# Epoch: 19 	Train_vae_loss: 6721.9670
# Epoch: 20 	Train_vae_loss: 6723.9022
# Epoch: 21 	Train_vae_loss: 6721.5599
# Epoch: 22 	Train_vae_loss: 6720.1903
# Epoch: 23 	Train_vae_loss: 6720.0276
# Epoch: 24 	Train_vae_loss: 6720.9834
# Epoch: 25 	Train_vae_loss: 6720.5082
# Epoch: 26 	Train_vae_loss: 6719.0047
# Epoch: 27 	Train_vae_loss: 6718.0310
# Epoch: 28 	Train_vae_loss: 6717.3433
# Epoch: 29 	Train_vae_loss: 6717.0962
# Epoch: 30 	Train_vae_loss: 6718.1270
# Epoch: 31 	Train_vae_loss: 6715.7378
# Epoch: 32 	Train_vae_loss: 6716.3805
# Epoch: 33 	Train_vae_loss: 6716.3806
# Epoch: 34 	Train_vae_loss: 6713.8771
# Epoch: 35 	Train_vae_loss: 6715.3076
# Epoch: 36 	Train_vae_loss: 6713.8602
# Epoch: 157 	Train_vae_loss: 3767.0786
# Epoch: 158 	Train_vae_loss: 3641.7689
# Epoch: 159 	Train_vae_loss: 3539.6604
# Epoch: 160 	Train_vae_loss: 3430.0182
# Epoch: 161 	Train_vae_loss: 3343.9322
# Epoch: 162 	Train_vae_loss: 3264.0022
# Epoch: 163 	Train_vae_loss: 3152.2481
# Epoch: 164 	Train_vae_loss: 2960.8202
# Epoch: 165 	Train_vae_loss: 2844.3534
# Epoch: 166 	Train_vae_loss: 2759.1807
# Epoch: 167 	Train_vae_loss: 2707.9792
# Epoch: 168 	Train_vae_loss: 2793.1726
# Epoch: 169 	Train_vae_loss: 2737.4949
# Epoch: 170 	Train_vae_loss: 2523.1225
# Epoch: 171 	Train_vae_loss: 2367.2968
# Epoch: 172 	Train_vae_loss: 2231.8630
# Epoch: 173 	Train_vae_loss: 2109.5386
# Epoch: 174 	Train_vae_loss: 2059.7920
# Epoch: 175 	Train_vae_loss: 1967.1258
# Epoch: 176 	Train_vae_loss: 1905.5946
# Epoch: 177 	Train_vae_loss: 1861.6707
# Epoch: 178 	Train_vae_loss: 1737.0847
# Epoch: 179 	Train_vae_loss: 1629.7558
# Epoch: 180 	Train_vae_loss: 1666.5823
# Epoch: 181 	Train_vae_loss: 1667.0932
# Epoch: 182 	Train_vae_loss: 1613.3751
# Epoch: 183 	Train_vae_loss: 1601.8776
# Epoch: 184 	Train_vae_loss: 1497.3476
# Epoch: 185 	Train_vae_loss: 1365.7102
# Epoch: 186 	Train_vae_loss: 1225.5453
# Epoch: 187 	Train_vae_loss: 1103.1181
# Epoch: 188 	Train_vae_loss: 1196.6208
# Epoch: 189 	Train_vae_loss: 1250.8430
# Epoch: 190 	Train_vae_loss: 1184.4649
# Epoch: 191 	Train_vae_loss: 1050.1453
# Epoch: 192 	Train_vae_loss: 936.6986
# Epoch: 193 	Train_vae_loss: 937.4495
# Epoch: 194 	Train_vae_loss: 885.1948
# Epoch: 195 	Train_vae_loss: 759.1549
# Epoch: 196 	Train_vae_loss: 688.9120
# Epoch: 197 	Train_vae_loss: 578.3316
# Epoch: 198 	Train_vae_loss: 509.9118
# Epoch: 199 	Train_vae_loss: 459.6975
# Epoch: 200 	Train_vae_loss: 395.9933

# %%
import torch
import torch.nn as nn

from torch_geometric.nn import GATConv
from torch.optim import Adam, SGD
import torch.nn.functional as F

class GAT(nn.Module):
    def __init__(self, feat_dim, latent_dim, hidden_channels, out_channels, num_heads):
        super(GAT, self).__init__()
        self.linear1 = nn.Linear(latent_dim, 128)
        self.conv1 = GATConv(feat_dim, hidden_channels, heads=num_heads)
        self.conv2 = GATConv(hidden_channels * num_heads, hidden_channels * num_heads, heads=1)
        self.linear2 = nn.Linear(hidden_channels * num_heads+128, 1)

    def forward(self, feat_i, x_i, edge_index):
        x = self.conv1(feat_i, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv2(x, edge_index)
        
        latten = F.relu(self.linear1(x_i))
        x =  torch.cat((x, latten), dim=-1)
        x = self.linear2(x)
        return F.relu(x)

# %%
feat_num = seed_num

forward_model = GAT(feat_num,latent_dim, 512, 1, 4)

optimizer = Adam([{'params': forward_model.parameters()}], 
                 lr=0.001)

adj = adj.to(device)
forward_model = forward_model.to(device)
forward_model.train()
# Out:
# GAT(
#   (linear1): Linear(in_features=64, out_features=128, bias=True)
#   (conv1): GATConv(135, 512, heads=4)
#   (conv2): GATConv(2048, 2048, heads=1)
#   (linear2): Linear(in_features=2176, out_features=1, bias=True)
# )

# %%
def normalize_features(tensor):
    # 计算每个特征的最小值和最大值
    min_vals, _ = torch.min(tensor, dim=0)
    max_vals, _ = torch.max(tensor, dim=0)

    # 对每个特征进行归一化
    normalized_tensor = (tensor - min_vals) / (max_vals - min_vals)
    return normalized_tensor

# %%
edge_index = edge_index.to(device)
top_num = 500
encoder = vae_model.Encoder

for epoch in range(2000):

    total_overall = 0
    forward_loss = 0

    mean_train_accuracy = 0
    for batch_idx, x_feature_label in enumerate(train_loader):  
        x =  x_feature_label[0].to(device)     
        features = x_feature_label[1].to(device)
        labels = x_feature_label[2].to(device)
        optimizer.zero_grad()
        
        loss = 0
        train_accuracy = 0
        for i, feat_i in enumerate(features):
            
            # log_sum = torch.sum(torch.log(1 - x_i), dim=1, keepdim=True)
            # feat = 1 - torch.exp(log_sum)
            x_i = x[i]
            x_i = encoder(x_i).detach()
            x_i = normalize_features(x_i)
            x_i = x_i.expand(features.shape[1], -1)
            # final_feat_i =  torch.cat((feat_i, x_i), dim=1)
            
            
            y_i = labels[i]
            y_hat = forward_model(feat_i, x_i, edge_index)
            _, top_indices_true = torch.topk(y_i.clone(), top_num)
            label_2 = torch.zeros(y_i.shape).to(device)
            label_2[top_indices_true] = 1
            
            _, top_indices_predict = torch.topk(y_hat.clone().squeeze(-1), top_num)
            
            # 将张量数组转换为Python列表
            list1 = top_indices_true.tolist()
            list_pre = top_indices_predict.tolist()

            # 使用集合操作找到交集
            intersection = list(set(list1) & set(list_pre))
            accuracy_i = len(intersection) / top_num       
            train_accuracy += accuracy_i 

            forward_loss = 0.5*F.mse_loss(y_hat.squeeze(-1), y_i, reduction='sum') + F.mse_loss(y_hat.squeeze(-1), label_2, reduction='sum')    
            loss += forward_loss    
        
        total_overall += loss.item()    
        train_accuracy /= len(features)
        mean_train_accuracy = train_accuracy
        loss = loss/features.size(0)
        loss.backward()
        optimizer.step()
        # for p in forward_model.parameters():
        #     p.data.clamp_(min=0)
        
        
    print("Epoch: {}".format(epoch+1), 
        "\tTotal: {:.4f}".format(total_overall / train_batch_size),
        "\tMean_train_accuracy: {:.4f}".format(mean_train_accuracy),
        )  
    
    mean_accuracy = 0
    mean_accuracy_sum = 0

    
    for batch_idx, x_feature_label in enumerate(test_loader):  
        x =  x_feature_label[0].to(device)
        features = x_feature_label[1].to(device)
        labels = x_feature_label[2].to(device)
        
        accuracy = 0
        accuracy_sum = 0
        
        for i, feat_i in enumerate(features):
            x_i = x[i]
            x_i = encoder(x_i).detach()
            x_i = normalize_features(x_i)
            x_i = x_i.expand(features.shape[1], -1)
            # final_feat_i =  torch.cat((feat_i, x_i), dim=1)
            y_i = labels[i]
            _, top_indices_true = torch.topk(y_i, top_num)
            
            y_hat = forward_model(feat_i, x_i, edge_index)
            
            _, top_indices_predict = torch.topk(y_hat.squeeze(-1), top_num)
            
            sum_pre = torch.sum(feat_i, dim=1, keepdim=True)
            _, top_indices_sum = torch.topk(sum_pre.squeeze(-1), top_num)
            
            # 将张量数组转换为Python列表
            list1 = top_indices_true.tolist()
            list_pre = top_indices_predict.tolist()
            
            list_sum = top_indices_sum.tolist()

            # 使用集合操作找到交集
            intersection = list(set(list1) & set(list_pre))
            
            intersection_sum = list(set(list1) & set(list_sum))
            
            accuracy_i = len(intersection) / top_num       
            accuracy += accuracy_i 
            accuracy_sum += len(intersection_sum) / top_num  
        accuracy /= test_batch_size
        accuracy_sum/= test_batch_size
        mean_accuracy = accuracy
        mean_accuracy_sum = accuracy_sum
        break
    
    print(
        "\tMean_test_accuracy: {:.4f}".format(mean_accuracy),
        "\tMean_test_accuracy_sum: {:.4f}".format(mean_accuracy_sum)
        )
# Out:
# Epoch: 1 	Total: 2226.8548 	Mean_train_accuracy: 0.8427
# 	Mean_test_accuracy: 0.7715 	Mean_test_accuracy_sum: 0.4845
# Epoch: 2 	Total: 2229.5454 	Mean_train_accuracy: 0.8465
# 	Mean_test_accuracy: 0.7780 	Mean_test_accuracy_sum: 0.4845
# Epoch: 3 	Total: 2225.6142 	Mean_train_accuracy: 0.8373
# 	Mean_test_accuracy: 0.7730 	Mean_test_accuracy_sum: 0.4845
# Epoch: 4 	Total: 2228.9141 	Mean_train_accuracy: 0.8414
# 	Mean_test_accuracy: 0.7735 	Mean_test_accuracy_sum: 0.4845
# Epoch: 5 	Total: 2226.7092 	Mean_train_accuracy: 0.8385
# 	Mean_test_accuracy: 0.7805 	Mean_test_accuracy_sum: 0.4845
# Epoch: 6 	Total: 2232.4376 	Mean_train_accuracy: 0.8406
# 	Mean_test_accuracy: 0.7760 	Mean_test_accuracy_sum: 0.4845
# Epoch: 7 	Total: 2231.2436 	Mean_train_accuracy: 0.8417
# 	Mean_test_accuracy: 0.7745 	Mean_test_accuracy_sum: 0.4845
# Epoch: 8 	Total: 2245.2642 	Mean_train_accuracy: 0.8444
# 	Mean_test_accuracy: 0.7720 	Mean_test_accuracy_sum: 0.4845
# Epoch: 9 	Total: 2236.1867 	Mean_train_accuracy: 0.8387
# 	Mean_test_accuracy: 0.7765 	Mean_test_accuracy_sum: 0.4845
# Epoch: 10 	Total: 2230.5323 	Mean_train_accuracy: 0.8389
# 	Mean_test_accuracy: 0.7745 	Mean_test_accuracy_sum: 0.4845
# Epoch: 11 	Total: 2225.8124 	Mean_train_accuracy: 0.8467
# 	Mean_test_accuracy: 0.7700 	Mean_test_accuracy_sum: 0.4845
# Epoch: 12 	Total: 2232.0163 	Mean_train_accuracy: 0.8383
# 	Mean_test_accuracy: 0.7835 	Mean_test_accuracy_sum: 0.4845
# Epoch: 13 	Total: 2235.3859 	Mean_train_accuracy: 0.8371
# 	Mean_test_accuracy: 0.7815 	Mean_test_accuracy_sum: 0.4845
# Epoch: 14 	Total: 2256.9056 	Mean_train_accuracy: 0.8372
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.4845
# Epoch: 15 	Total: 2250.8551 	Mean_train_accuracy: 0.8410
# 	Mean_test_accuracy: 0.7780 	Mean_test_accuracy_sum: 0.4845
# Epoch: 16 	Total: 2242.7130 	Mean_train_accuracy: 0.8436
# 	Mean_test_accuracy: 0.7885 	Mean_test_accuracy_sum: 0.4845
# Epoch: 17 	Total: 2232.1002 	Mean_train_accuracy: 0.8395
# 	Mean_test_accuracy: 0.7780 	Mean_test_accuracy_sum: 0.4845
# Epoch: 18 	Total: 2229.2057 	Mean_train_accuracy: 0.8403
# 	Mean_test_accuracy: 0.7770 	Mean_test_accuracy_sum: 0.4845
# Epoch: 19 	Total: 2226.8574 	Mean_train_accuracy: 0.8429
# 	Mean_test_accuracy: 0.7750 	Mean_test_accuracy_sum: 0.4845
# Epoch: 20 	Total: 2224.7188 	Mean_train_accuracy: 0.8404
# 	Mean_test_accuracy: 0.7845 	Mean_test_accuracy_sum: 0.4845
# Epoch: 21 	Total: 2238.6888 	Mean_train_accuracy: 0.8384
# 	Mean_test_accuracy: 0.7720 	Mean_test_accuracy_sum: 0.4845
# Epoch: 22 	Total: 2233.8388 	Mean_train_accuracy: 0.8424
# 	Mean_test_accuracy: 0.7805 	Mean_test_accuracy_sum: 0.4845
# Epoch: 23 	Total: 2228.9532 	Mean_train_accuracy: 0.8386
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4845
# Epoch: 24 	Total: 2231.0709 	Mean_train_accuracy: 0.8411
# 	Mean_test_accuracy: 0.7780 	Mean_test_accuracy_sum: 0.4845
# Epoch: 25 	Total: 2224.9102 	Mean_train_accuracy: 0.8418
# 	Mean_test_accuracy: 0.7790 	Mean_test_accuracy_sum: 0.4845
# Epoch: 26 	Total: 2226.5661 	Mean_train_accuracy: 0.8449
# 	Mean_test_accuracy: 0.7745 	Mean_test_accuracy_sum: 0.4845
# Epoch: 27 	Total: 2230.0065 	Mean_train_accuracy: 0.8448
# 	Mean_test_accuracy: 0.7770 	Mean_test_accuracy_sum: 0.4845
# Epoch: 28 	Total: 2229.5886 	Mean_train_accuracy: 0.8418
# 	Mean_test_accuracy: 0.7825 	Mean_test_accuracy_sum: 0.4845
# Epoch: 29 	Total: 2232.3652 	Mean_train_accuracy: 0.8439
# 	Mean_test_accuracy: 0.7835 	Mean_test_accuracy_sum: 0.4845
# Epoch: 30 	Total: 2230.8298 	Mean_train_accuracy: 0.8412
# 	Mean_test_accuracy: 0.7805 	Mean_test_accuracy_sum: 0.4845
# Epoch: 31 	Total: 2233.6624 	Mean_train_accuracy: 0.8433
# 	Mean_test_accuracy: 0.7760 	Mean_test_accuracy_sum: 0.4845
# Epoch: 32 	Total: 2233.4067 	Mean_train_accuracy: 0.8405
# 	Mean_test_accuracy: 0.7785 	Mean_test_accuracy_sum: 0.4845
# Epoch: 33 	Total: 2228.1072 	Mean_train_accuracy: 0.8411
# 	Mean_test_accuracy: 0.7930 	Mean_test_accuracy_sum: 0.4845
# Epoch: 34 	Total: 2233.8040 	Mean_train_accuracy: 0.8406
# 	Mean_test_accuracy: 0.7775 	Mean_test_accuracy_sum: 0.4845
# Epoch: 35 	Total: 2236.1210 	Mean_train_accuracy: 0.8401
# 	Mean_test_accuracy: 0.7765 	Mean_test_accuracy_sum: 0.4845
# Epoch: 36 	Total: 2227.4100 	Mean_train_accuracy: 0.8390
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4845
# Epoch: 37 	Total: 2237.5930 	Mean_train_accuracy: 0.8450
# 	Mean_test_accuracy: 0.7785 	Mean_test_accuracy_sum: 0.4845
# Epoch: 38 	Total: 2232.9826 	Mean_train_accuracy: 0.8414
# 	Mean_test_accuracy: 0.7865 	Mean_test_accuracy_sum: 0.4845
# Epoch: 39 	Total: 2228.1273 	Mean_train_accuracy: 0.8451
# 	Mean_test_accuracy: 0.7800 	Mean_test_accuracy_sum: 0.4845
# Epoch: 40 	Total: 2230.2543 	Mean_train_accuracy: 0.8374
# 	Mean_test_accuracy: 0.7785 	Mean_test_accuracy_sum: 0.4845
# Epoch: