# %%
import torch
import sys
sys.path.append('/home/zjy/project/MetaIM')
pwd = '/home/zjy/project/MetaIM/data'
device = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=3)

# %%
from torch_geometric.datasets import Planetoid

cora_dataset = Planetoid(root=pwd+'/cora', name='cora')
data = cora_dataset[0]
edge_index = data.edge_index

# %%
import numpy as np
individual_infection_path = pwd+'/for_meta/cora_individual_infection_sir_200.npy'
seeds_infection_path = pwd+'/for_meta/cora_seed_infection_sir_200_sample_1000.npy'

individual_infection = np.load(individual_infection_path)
seeds_infection = np.load(seeds_infection_path)
individual_infection.shape,seeds_infection.shape
# Out:
# ((2708, 2708), (1000, 2, 2708))

# %%
import torch
from torch_geometric.utils import to_scipy_sparse_matrix
import scipy.sparse as sp

# 转换为 scipy 稀疏矩阵
adj = to_scipy_sparse_matrix(edge_index)

adj = torch.Tensor(adj.toarray()).to_sparse()
adj
# Out:
# tensor(indices=tensor([[   0,    0,    0,  ..., 2707, 2707, 2707],
#                        [ 633, 1862, 2582,  ...,  598, 1473, 2706]]),
#        values=tensor([1., 1., 1.,  ..., 1., 1., 1.]),
#        size=(2708, 2708), nnz=10556, layout=torch.sparse_coo)

# %%
def graph_laplacian_embedding(adjacency_matrix, num_dimensions):
    # 将邻接矩阵转换为PyTorch张量
    adjacency_matrix = torch.tensor(adjacency_matrix, dtype=torch.float32)
    
    # Step 1: 计算度矩阵
    degree_matrix = torch.diag(adjacency_matrix.sum(dim=1))
    
    # Step 2: 计算拉普拉斯矩阵
    laplacian_matrix = degree_matrix - adjacency_matrix
    
    # Step 3: 计算拉普拉斯矩阵的特征向量和特征值
    eigenvalues, eigenvectors = torch.linalg.eigh(laplacian_matrix)
    
    # Step 4: 选择低维表示
    # 取特征值非零的前 num_dimensions 个特征向量作为嵌入结果
    embedding = eigenvectors[:, :num_dimensions]
    
    return embedding

def edge_index_to_adj(edge_index, num_nodes):
    adj = torch.zeros((num_nodes, num_nodes))
    for i in range(edge_index.size(1)):
        start_node = edge_index[0, i]
        end_node = edge_index[1, i]
        adj[start_node, end_node] = 1
        adj[end_node, start_node] = 1  # 如果是有向图，可以不需要这行
    return adj

latent_dim = 128

adj_n = edge_index_to_adj(edge_index, individual_infection.shape[0])

laplace_emb = graph_laplacian_embedding(adj_n, latent_dim)

laplace_emb = laplace_emb.to(device)
# Out:
# /tmp/ipykernel_2526947/4019088435.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   adjacency_matrix = torch.tensor(adjacency_matrix, dtype=torch.float32)

# %%
seed_num = int(seeds_infection[0][0].sum())

# %%
from torch.utils.data import Dataset, DataLoader, random_split


class CustomDataset(Dataset):
    def __init__(self, individual_infection,seeds_infection, seed_num):
        self.individual_infection = individual_infection
        self.seeds_infection = seeds_infection
        self.feat_shape = (len(individual_infection), seed_num)

    def __len__(self):
        return len(self.seeds_infection)

    def __getitem__(self, idx):
        seeds= np.nonzero(self.seeds_infection[idx][0])[0]
        
        feature = torch.zeros(self.feat_shape[0],self.feat_shape[1])
        for i in range(len(seeds)):
            seed_i_infection = torch.tensor(self.individual_infection[seeds[i]])
            feature[:, i] = seed_i_infection
            
        label = self.seeds_infection[idx][1]
        
        return self.seeds_infection[idx][0], feature, label

dataset = CustomDataset(individual_infection, seeds_infection, seed_num)

# %%
# 定义划分比例
train_ratio = 0.8
test_ratio = 0.2

# 划分数据集
train_dataset, test_dataset = random_split(dataset, [int(len(dataset)*train_ratio), int(len(dataset)*test_ratio)])

train_batch_size = 64
test_batch_size = 4

# 创建数据加载器
train_loader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True, drop_last=False)
test_loader = DataLoader(test_dataset, batch_size=test_batch_size, shuffle=False)

# %%
import torch
import torch.nn as nn

from torch_geometric.nn import GATConv
from torch.optim import Adam, SGD
import torch.nn.functional as F

class GAT(nn.Module):
    def __init__(self, feat_dim, latent_dim, hidden_channels, out_channels, num_heads):
        super(GAT, self).__init__()
        # self.linear1 = nn.Linear(latent_dim, 128)
        self.conv1 = GATConv(feat_dim, hidden_channels, heads=num_heads)
        self.conv2 = GATConv(hidden_channels * num_heads, hidden_channels * num_heads, heads=1)
        self.linear2 = nn.Linear(hidden_channels * num_heads+latent_dim, 1)

    def forward(self, feat_i, x_i, edge_index):
        x = self.conv1(feat_i, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv2(x, edge_index)
        
        # latten = F.relu(self.linear1(x_i))
        x =  torch.cat((x, x_i), dim=-1)
        x = self.linear2(x)
        return F.relu(x)

# %%
feat_num = seed_num

forward_model = GAT(feat_num,latent_dim, 512, 1, 4)

optimizer = Adam([{'params': forward_model.parameters()}], 
                 lr=0.001)

adj = adj.to(device)
forward_model = forward_model.to(device)
forward_model.train()
# Out:
# GAT(
#   (conv1): GATConv(135, 512, heads=4)
#   (conv2): GATConv(2048, 2048, heads=1)
#   (linear2): Linear(in_features=2176, out_features=1, bias=True)
# )

# %%
def normalize_features(tensor):
    # 计算每个特征的最小值和最大值
    min_vals, _ = torch.min(tensor, dim=0)
    max_vals, _ = torch.max(tensor, dim=0)

    # 对每个特征进行归一化
    normalized_tensor = (tensor - min_vals) / (max_vals - min_vals)
    return normalized_tensor

# %%
optimizer = Adam([{'params': forward_model.parameters()}], 
                 lr=0.0001)
edge_index = edge_index.to(device)
top_num = 500
# encoder = vae_model.Encoder

for epoch in range(2000):

    total_overall = 0
    forward_loss = 0

    mean_train_accuracy = 0
    for batch_idx, x_feature_label in enumerate(train_loader):  
        x =  x_feature_label[0].to(device)     
        features = x_feature_label[1].to(device)
        labels = x_feature_label[2].to(device)
        optimizer.zero_grad()
        
        loss = 0
        train_accuracy = 0
        for i, feat_i in enumerate(features):
            
            # log_sum = torch.sum(torch.log(1 - x_i), dim=1, keepdim=True)
            # feat = 1 - torch.exp(log_sum)
            x_i = x[i]
            x_i = torch.matmul(x_i, laplace_emb)
            
            
            # x_i = encoder(x_i).detach()
            # x_i = torch.rand(latent_dim).to(device)
            # x_i = normalize_features(x_i)
            x_i = x_i.expand(features.shape[1], -1)
            # final_feat_i =  torch.cat((feat_i, x_i), dim=1)
            
            
            y_i = labels[i]
            y_hat = forward_model(feat_i, x_i, edge_index)
            _, top_indices_true = torch.topk(y_i.clone(), top_num)
            label_2 = torch.zeros(y_i.shape).to(device)
            label_2[top_indices_true] = 1
            
            _, top_indices_predict = torch.topk(y_hat.clone().squeeze(-1), top_num)
            
            # 将张量数组转换为Python列表
            list1 = top_indices_true.tolist()
            list_pre = top_indices_predict.tolist()

            # 使用集合操作找到交集
            intersection = list(set(list1) & set(list_pre))
            accuracy_i = len(intersection) / top_num       
            train_accuracy += accuracy_i 

            forward_loss = 0.5*F.mse_loss(y_hat.squeeze(-1), y_i, reduction='sum') + F.mse_loss(y_hat.squeeze(-1), label_2, reduction='sum')    
            loss += forward_loss    
        
        total_overall += loss.item()    
        train_accuracy /= len(features)
        mean_train_accuracy = train_accuracy
        loss = loss/features.size(0)
        loss.backward()
        optimizer.step()
        # for p in forward_model.parameters():
        #     p.data.clamp_(min=0)
        
        
    print("Epoch: {}".format(epoch+1), 
        "\tTotal: {:.4f}".format(total_overall / train_batch_size),
        "\tMean_train_accuracy: {:.4f}".format(mean_train_accuracy),
        )  
    
    mean_accuracy = 0
    mean_accuracy_sum = 0

    
    for batch_idx, x_feature_label in enumerate(test_loader):  
        x =  x_feature_label[0].to(device)
        features = x_feature_label[1].to(device)
        labels = x_feature_label[2].to(device)
        
        accuracy = 0
        accuracy_sum = 0
        
        for i, feat_i in enumerate(features):
            # x_i = x[i]
            # x_i = encoder(x_i).detach()
            # x_i = normalize_features(x_i)
            x_i = x[i]
            x_i = torch.matmul(x_i, laplace_emb)
            x_i = x_i.expand(features.shape[1], -1)
            # final_feat_i =  torch.cat((feat_i, x_i), dim=1)
            y_i = labels[i]
            _, top_indices_true = torch.topk(y_i, top_num)
            
            y_hat = forward_model(feat_i, x_i, edge_index)
            
            _, top_indices_predict = torch.topk(y_hat.squeeze(-1), top_num)
            
            sum_pre = torch.sum(feat_i, dim=1, keepdim=True)
            _, top_indices_sum = torch.topk(sum_pre.squeeze(-1), top_num)
            
            # 将张量数组转换为Python列表
            list1 = top_indices_true.tolist()
            list_pre = top_indices_predict.tolist()
            
            list_sum = top_indices_sum.tolist()

            # 使用集合操作找到交集
            intersection = list(set(list1) & set(list_pre))
            
            intersection_sum = list(set(list1) & set(list_sum))
            
            accuracy_i = len(intersection) / top_num       
            accuracy += accuracy_i 
            accuracy_sum += len(intersection_sum) / top_num  
        accuracy /= test_batch_size
        accuracy_sum/= test_batch_size
        mean_accuracy = accuracy
        mean_accuracy_sum = accuracy_sum
        break
    
    print(
        "\tMean_test_accuracy: {:.4f}".format(mean_accuracy),
        "\tMean_test_accuracy_sum: {:.4f}".format(mean_accuracy_sum)
        )
# Out:
# Epoch: 1 	Total: 2862.8616 	Mean_train_accuracy: 0.7856
# 	Mean_test_accuracy: 0.7855 	Mean_test_accuracy_sum: 0.4970
# Epoch: 2 	Total: 2820.3450 	Mean_train_accuracy: 0.7828
# 	Mean_test_accuracy: 0.7745 	Mean_test_accuracy_sum: 0.4970
# Epoch: 3 	Total: 2801.7856 	Mean_train_accuracy: 0.7847
# 	Mean_test_accuracy: 0.7775 	Mean_test_accuracy_sum: 0.4970
# Epoch: 4 	Total: 2790.8159 	Mean_train_accuracy: 0.7903
# 	Mean_test_accuracy: 0.7785 	Mean_test_accuracy_sum: 0.4970
# Epoch: 5 	Total: 2787.0345 	Mean_train_accuracy: 0.7844
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4970
# Epoch: 6 	Total: 2783.2499 	Mean_train_accuracy: 0.7913
# 	Mean_test_accuracy: 0.7845 	Mean_test_accuracy_sum: 0.4970
# Epoch: 7 	Total: 2781.4017 	Mean_train_accuracy: 0.7889
# 	Mean_test_accuracy: 0.7825 	Mean_test_accuracy_sum: 0.4970
# Epoch: 8 	Total: 2778.3169 	Mean_train_accuracy: 0.7867
# 	Mean_test_accuracy: 0.7905 	Mean_test_accuracy_sum: 0.4970
# Epoch: 9 	Total: 2776.1798 	Mean_train_accuracy: 0.7869
# 	Mean_test_accuracy: 0.7805 	Mean_test_accuracy_sum: 0.4970
# Epoch: 10 	Total: 2775.3709 	Mean_train_accuracy: 0.7894
# 	Mean_test_accuracy: 0.7875 	Mean_test_accuracy_sum: 0.4970
# Epoch: 11 	Total: 2772.7250 	Mean_train_accuracy: 0.7871
# 	Mean_test_accuracy: 0.7775 	Mean_test_accuracy_sum: 0.4970
# Epoch: 12 	Total: 2771.5254 	Mean_train_accuracy: 0.7886
# 	Mean_test_accuracy: 0.7770 	Mean_test_accuracy_sum: 0.4970
# Epoch: 13 	Total: 2769.4900 	Mean_train_accuracy: 0.7892
# 	Mean_test_accuracy: 0.7855 	Mean_test_accuracy_sum: 0.4970
# Epoch: 14 	Total: 2767.8531 	Mean_train_accuracy: 0.7900
# 	Mean_test_accuracy: 0.7800 	Mean_test_accuracy_sum: 0.4970
# Epoch: 15 	Total: 2766.4783 	Mean_train_accuracy: 0.7855
# 	Mean_test_accuracy: 0.7785 	Mean_test_accuracy_sum: 0.4970
# Epoch: 16 	Total: 2766.9829 	Mean_train_accuracy: 0.7866
# 	Mean_test_accuracy: 0.7775 	Mean_test_accuracy_sum: 0.4970
# Epoch: 17 	Total: 2765.8409 	Mean_train_accuracy: 0.7919
# 	Mean_test_accuracy: 0.7720 	Mean_test_accuracy_sum: 0.4970
# Epoch: 18 	Total: 2765.8691 	Mean_train_accuracy: 0.7891
# 	Mean_test_accuracy: 0.7780 	Mean_test_accuracy_sum: 0.4970
# Epoch: 19 	Total: 2762.4910 	Mean_train_accuracy: 0.7965
# 	Mean_test_accuracy: 0.7855 	Mean_test_accuracy_sum: 0.4970
# Epoch: 20 	Total: 2763.3921 	Mean_train_accuracy: 0.7883
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4970
# Epoch: 21 	Total: 2759.4866 	Mean_train_accuracy: 0.7915
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4970
# Epoch: 22 	Total: 2759.4822 	Mean_train_accuracy: 0.7883
# 	Mean_test_accuracy: 0.7885 	Mean_test_accuracy_sum: 0.4970
# Epoch: 23 	Total: 2759.3505 	Mean_train_accuracy: 0.7856
# 	Mean_test_accuracy: 0.7765 	Mean_test_accuracy_sum: 0.4970
# Epoch: 24 	Total: 2755.0706 	Mean_train_accuracy: 0.7866
# 	Mean_test_accuracy: 0.7860 	Mean_test_accuracy_sum: 0.4970
# Epoch: 25 	Total: 2754.4738 	Mean_train_accuracy: 0.7967
# 	Mean_test_accuracy: 0.7750 	Mean_test_accuracy_sum: 0.4970
# Epoch: 26 	Total: 2753.2285 	Mean_train_accuracy: 0.7877
# 	Mean_test_accuracy: 0.7795 	Mean_test_accuracy_sum: 0.4970
# Epoch: 27 	Total: 2753.0126 	Mean_train_accuracy: 0.7940
# 	Mean_test_accuracy: 0.7760 	Mean_test_accuracy_sum: 0.4970
# Epoch: 28 	Total: 2752.8478 	Mean_train_accuracy: 0.7911
# 	Mean_test_accuracy: 0.7795 	Mean_test_accuracy_sum: 0.4970
# Epoch: 29 	Total: 2750.3777 	Mean_train_accuracy: 0.7867
# 	Mean_test_accuracy: 0.7875 	Mean_test_accuracy_sum: 0.4970
# Epoch: 30 	Total: 2750.1530 	Mean_train_accuracy: 0.7922
# 	Mean_test_accuracy: 0.7865 	Mean_test_accuracy_sum: 0.4970
# Epoch: 31 	Total: 2751.0412 	Mean_train_accuracy: 0.7911
# 	Mean_test_accuracy: 0.7785 	Mean_test_accuracy_sum: 0.4970
# Epoch: 32 	Total: 2750.1451 	Mean_train_accuracy: 0.7920
# 	Mean_test_accuracy: 0.7855 	Mean_test_accuracy_sum: 0.4970
# Epoch: 33 	Total: 2746.0397 	Mean_train_accuracy: 0.7851
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.4970
# Epoch: 34 	Total: 2743.8165 	Mean_train_accuracy: 0.7885
# 	Mean_test_accuracy: 0.7805 	Mean_test_accuracy_sum: 0.4970
# Epoch: 35 	Total: 2745.0704 	Mean_train_accuracy: 0.7902
# 	Mean_test_accuracy: 0.7905 	Mean_test_accuracy_sum: 0.4970
# Epoch: 36 	Total: 2740.3839 	Mean_train_accuracy: 0.7868
# 	Mean_test_accuracy: 0.7800 	Mean_test_accuracy_sum: 0.4970
# Epoch: 37 	Total: 2743.1362 	Mean_train_accuracy: 0.7923
# 	Mean_test_accuracy: 0.7845 	Mean_test_accuracy_sum: 0.4970
# Epoch: 38 	Total: 2743.8798 	Mean_train_accuracy: 0.7905
# 	Mean_test_accuracy: 0.7845 	Mean_test_accuracy_sum: 0.4970
# Epoch: 39 	Total: 2739.9104 	Mean_train_accuracy: 0.7944
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4970
# Epoch: 40 	Total: 2738.7084 	Mean_train_accuracy: 0.7931
# 	Mean_test_accuracy: 0.7855 	Mean_test_accuracy_sum: 0.4970
# Epoch: 41 	Total: 2737.6198 	Mean_train_accuracy: 0.7918
# 	Mean_test_accuracy: 0.7850 	Mean_test_accuracy_sum: 0.4970
# Epoch: 42 	Total: 2736.4259 	Mean_train_accuracy: 0.7916
# 	Mean_test_accuracy: 0.7875 	Mean_test_accuracy_sum: 0.4970
# Epoch: 43 	Total: 2735.3588 	Mean_train_accuracy: 0.7917
# 	Mean_test_accuracy: 0.7855 	Mean_test_accuracy_sum: 0.4970
# Epoch: 44 	Total: 2732.4461 	Mean_train_accuracy: 0.7884
# 	Mean_test_accuracy: 0.7865 	Mean_test_accuracy_sum: 0.4970
# Epoch: 45 	Total: 2732.7660 	Mean_train_accuracy: 0.7973
# 	Mean_test_accuracy: 0.7860 	Mean_test_accuracy_sum: 0.4970
# Epoch: 46 	Total: 2731.0837 	Mean_train_accuracy: 0.7904
# 	Mean_test_accuracy: 0.7895 	Mean_test_accuracy_sum: 0.4970
# Epoch: 47 	Total: 2728.2021 	Mean_train_accuracy: 0.7926
# 	Mean_test_accuracy: 0.7785 	Mean_test_accuracy_sum: 0.4970
# Epoch: 48 	Total: 2726.1578 	Mean_train_accuracy: 0.7884
# 	Mean_test_accuracy: 0.7785 	Mean_test_accuracy_sum: 0.4970
# Epoch: 49 	Total: 2726.8311 	Mean_train_accuracy: 0.7941
# 	Mean_test_accuracy: 0.7865 	Mean_test_accuracy_sum: 0.4970
# Epoch: 50 	Total: 2725.1055 	Mean_train_accuracy: 0.7927
# 	Mean_test_accuracy: 0.7810 	Mean_test_accuracy_sum: 0.4970
# Epoch: 51 	Total: 2724.7229 	Mean_train_accuracy: 0.7947
# 	Mean_test_accuracy: 0.7870 	Mean_test_accuracy_sum: 0.4970
# Epoch: 52 	Total: 2725.4004 	Mean_train_accuracy: 0.7930
# 	Mean_test_accuracy: 0.7785 	Mean_test_accuracy_sum: 0.4970
# Epoch: 53 	Total: 2722.1301 	Mean_train_accuracy: 0.7916
# 	Mean_test_accuracy: 0.7880 	Mean_test_accuracy_sum: 0.4970
# Epoch: 54 	Total: 2720.9998 	Mean_train_accuracy: 0.8000
# 	Mean_test_accuracy: 0.7790 	Mean_test_accuracy_sum: 0.4970
# Epoch: 55 	Total: 2718.6473 	Mean_train_accuracy: 0.7973
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4970
# Epoch: 56 	Total: 2715.8406 	Mean_train_accuracy: 0.7931
# 	Mean_test_accuracy: 0.7835 	Mean_test_accuracy_sum: 0.4970
# Epoch: 57 	Total: 2717.4874 	Mean_train_accuracy: 0.7996
# 	Mean_test_accuracy: 0.7870 	Mean_test_accuracy_sum: 0.4970
# Epoch: 58 	Total: 2716.5193 	Mean_train_accuracy: 0.7917
# 	Mean_test_accuracy: 0.7865 	Mean_test_accuracy_sum: 0.4970
# Epoch: 59 	Total: 2713.3730 	Mean_train_accuracy: 0.7974
# 	Mean_test_accuracy: 0.7905 	Mean_test_accuracy_sum: 0.4970
# Epoch: 60 	Total: 2712.6102 	Mean_train_accuracy: 0.7966
# 	Mean_test_accuracy: 0.7860 	Mean_test_accuracy_sum: 0.4970
# Epoch: 61 	Total: 2709.7889 	Mean_train_accuracy: 0.7913
# 	Mean_test_accuracy: 0.7920 	Mean_test_accuracy_sum: 0.4970
# Epoch: 62 	Total: 2709.2040 	Mean_train_accuracy: 0.7922
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4970
# Epoch: 63 	Total: 2708.0023 	Mean_train_accuracy: 0.7912
# 	Mean_test_accuracy: 0.7770 	Mean_test_accuracy_sum: 0.4970
# Epoch: 64 	Total: 2708.4967 	Mean_train_accuracy: 0.7949
# 	Mean_test_accuracy: 0.7875 	Mean_test_accuracy_sum: 0.4970
# Epoch: 65 	Total: 2707.3835 	Mean_train_accuracy: 0.8000
# 	Mean_test_accuracy: 0.7905 	Mean_test_accuracy_sum: 0.4970
# Epoch: 66 	Total: 2703.0622 	Mean_train_accuracy: 0.7955
# 	Mean_test_accuracy: 0.7905 	Mean_test_accuracy_sum: 0.4970
# Epoch: 67 	Total: 2702.6858 	Mean_train_accuracy: 0.8002
# 	Mean_test_accuracy: 0.7915 	Mean_test_accuracy_sum: 0.4970
# Epoch: 68 	Total: 2698.5819 	Mean_train_accuracy: 0.8005
# 	Mean_test_accuracy: 0.7865 	Mean_test_accuracy_sum: 0.4970
# Epoch: 69 	Total: 2697.1599 	Mean_train_accuracy: 0.8013
# 	Mean_test_accuracy: 0.7845 	Mean_test_accuracy_sum: 0.4970
# Epoch: 70 	Total: 2697.0971 	Mean_train_accuracy: 0.7994
# 	Mean_test_accuracy: 0.7805 	Mean_test_accuracy_sum: 0.4970
# Epoch: 71 	Total: 2695.9775 	Mean_train_accuracy: 0.7965
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4970
# Epoch: 72 	Total: 2694.3532 	Mean_train_accuracy: 0.7933
# 	Mean_test_accuracy: 0.7905 	Mean_test_accuracy_sum: 0.4970
# Epoch: 73 	Total: 2694.8348 	Mean_train_accuracy: 0.7972
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.4970
# Epoch: 74 	Total: 2690.5320 	Mean_train_accuracy: 0.8024
# 	Mean_test_accuracy: 0.7825 	Mean_test_accuracy_sum: 0.4970
# Epoch: 75 	Total: 2692.6472 	Mean_train_accuracy: 0.7934
# 	Mean_test_accuracy: 0.7920 	Mean_test_accuracy_sum: 0.4970
# Epoch: 76 	Total: 2691.0743 	Mean_train_accuracy: 0.7948
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4970
# Epoch: 77 	Total: 2687.4818 	Mean_train_accuracy: 0.7931
# 	Mean_test_accuracy: 0.7865 	Mean_test_accuracy_sum: 0.4970
# Epoch: 78 	Total: 2684.8830 	Mean_train_accuracy: 0.8021
# 	Mean_test_accuracy: 0.7825 	Mean_test_accuracy_sum: 0.4970
# Epoch: 79 	Total: 2684.1085 	Mean_train_accuracy: 0.7949
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4970
# Epoch: 80 	Total: 2681.7104 	Mean_train_accuracy: 0.8004
# 	Mean_test_accuracy: 0.7925 	Mean_test_accuracy_sum: 0.4970
# Epoch: 81 	Total: 2681.8549 	Mean_train_accuracy: 0.8001
# 	Mean_test_accuracy: 0.7815 	Mean_test_accuracy_sum: 0.4970
# Epoch: 82 	Total: 2681.2958 	Mean_train_accuracy: 0.8017
# 	Mean_test_accuracy: 0.7785 	Mean_test_accuracy_sum: 0.4970
# Epoch: 83 	Total: 2676.5573 	Mean_train_accuracy: 0.7961
# 	Mean_test_accuracy: 0.7945 	Mean_test_accuracy_sum: 0.4970
# Epoch: 84 	Total: 2678.1820 	Mean_train_accuracy: 0.7959
# 	Mean_test_accuracy: 0.7885 	Mean_test_accuracy_sum: 0.4970
# Epoch: 85 	Total: 2673.5819 	Mean_train_accuracy: 0.8011
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4970
# Epoch: 86 	Total: 2675.0306 	Mean_train_accuracy: 0.8041
# 	Mean_test_accuracy: 0.7950 	Mean_test_accuracy_sum: 0.4970
# Epoch: 87 	Total: 2670.7173 	Mean_train_accuracy: 0.7986
# 	Mean_test_accuracy: 0.7810 	Mean_test_accuracy_sum: 0.4970
# Epoch: 88 	Total: 2667.9664 	Mean_train_accuracy: 0.7987
# 	Mean_test_accuracy: 0.7840 	Mean_test_accuracy_sum: 0.4970
# Epoch: 89 	Total: 2666.2343 	Mean_train_accuracy: 0.7988
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4970
# Epoch: 90 	Total: 2664.9002 	Mean_train_accuracy: 0.8007
# 	Mean_test_accuracy: 0.7820 	Mean_test_accuracy_sum: 0.4970
# Epoch: 91 	Total: 2663.7394 	Mean_train_accuracy: 0.8004
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.4970
# Epoch: 92 	Total: 2663.8473 	Mean_train_accuracy: 0.8051
# 	Mean_test_accuracy: 0.7925 	Mean_test_accuracy_sum: 0.4970
# Epoch: 93 	Total: 2654.9541 	Mean_train_accuracy: 0.7959
# 	Mean_test_accuracy: 0.7870 	Mean_test_accuracy_sum: 0.4970
# Epoch: 94 	Total: 2656.2770 	Mean_train_accuracy: 0.8022
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4970
# Epoch: 95 	Total: 2652.1413 	Mean_train_accuracy: 0.7976
# 	Mean_test_accuracy: 0.7890 	Mean_test_accuracy_sum: 0.4970
# Epoch: 96 	Total: 2651.4195 	Mean_train_accuracy: 0.8035
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4970
# Epoch: 97 	Total: 2649.3123 	Mean_train_accuracy: 0.8024
# 	Mean_test_accuracy: 0.7830 	Mean_test_accuracy_sum: 0.4970
# Epoch: 98 	Total: 2646.4204 	Mean_train_accuracy: 0.8056
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4970
# Epoch: 99 	Total: 2645.1385 	Mean_train_accuracy: 0.8041
# 	Mean_test_accuracy: 0.7895 	Mean_test_accuracy_sum: 0.4970
# Epoch: 100 	Total: 2643.3737 	Mean_train_accuracy: 0.8003
# 	Mean_test_accuracy: 0.7865 	Mean_test_accuracy_sum: 0.4970
# Epoch: 101 	Total: 2638.1742 	Mean_train_accuracy: 0.8050
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4970
# Epoch: 102 	Total: 2637.9492 	Mean_train_accuracy: 0.8046
# 	Mean_test_accuracy: 0.7935 	Mean_test_accuracy_sum: 0.4970
# Epoch: 103 	Total: 2634.3420 	Mean_train_accuracy: 0.8045
# 	Mean_test_accuracy: 0.7960 	Mean_test_accuracy_sum: 0.4970
# Epoch: 104 	Total: 2631.3854 	Mean_train_accuracy: 0.8020
# 	Mean_test_accuracy: 0.7955 	Mean_test_accuracy_sum: 0.4970
# Epoch: 105 	Total: 2632.2464 	Mean_train_accuracy: 0.8097
# 	Mean_test_accuracy: 0.7925 	Mean_test_accuracy_sum: 0.4970
# Epoch: 106 	Total: 2624.7769 	Mean_train_accuracy: 0.8037
# 	Mean_test_accuracy: 0.7960 	Mean_test_accuracy_sum: 0.4970
# Epoch: 107 	Total: 2626.4033 	Mean_train_accuracy: 0.8040
# 	Mean_test_accuracy: 0.7825 	Mean_test_accuracy_sum: 0.4970
# Epoch: 108 	Total: 2623.9201 	Mean_train_accuracy: 0.8054
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4970
# Epoch: 109 	Total: 2621.1875 	Mean_train_accuracy: 0.8021
# 	Mean_test_accuracy: 0.8045 	Mean_test_accuracy_sum: 0.4970
# Epoch: 110 	Total: 2619.2602 	Mean_train_accuracy: 0.8091
# 	Mean_test_accuracy: 0.7980 	Mean_test_accuracy_sum: 0.4970
# Epoch: 111 	Total: 2615.0929 	Mean_train_accuracy: 0.8053
# 	Mean_test_accuracy: 0.7950 	Mean_test_accuracy_sum: 0.4970
# Epoch: 112 	Total: 2613.9543 	Mean_train_accuracy: 0.8080
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4970
# Epoch: 113 	Total: 2610.8950 	Mean_train_accuracy: 0.8068
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4970
# Epoch: 114 	Total: 2612.6459 	Mean_train_accuracy: 0.8099
# 	Mean_test_accuracy: 0.7930 	Mean_test_accuracy_sum: 0.4970
# Epoch: 115 	Total: 2609.2187 	Mean_train_accuracy: 0.8064
# 	Mean_test_accuracy: 0.7920 	Mean_test_accuracy_sum: 0.4970
# Epoch: 116 	Total: 2606.9015 	Mean_train_accuracy: 0.8054
# 	Mean_test_accuracy: 0.7955 	Mean_test_accuracy_sum: 0.4970
# Epoch: 117 	Total: 2604.9204 	Mean_train_accuracy: 0.8099
# 	Mean_test_accuracy: 0.7950 	Mean_test_accuracy_sum: 0.4970
# Epoch: 118 	Total: 2602.9268 	Mean_train_accuracy: 0.8052
# 	Mean_test_accuracy: 0.7860 	Mean_test_accuracy_sum: 0.4970
# Epoch: 119 	Total: 2597.8661 	Mean_train_accuracy: 0.8051
# 	Mean_test_accuracy: 0.7910 	Mean_test_accuracy_sum: 0.4970
# Epoch: 120 	Total: 2591.1016 	Mean_train_accuracy: 0.8085
# 	Mean_test_accuracy: 0.7905 	Mean_test_accuracy_sum: 0.4970
# Epoch: 121 	Total: 2593.1601 	Mean_train_accuracy: 0.8017
# 	Mean_test_accuracy: 0.7900 	Mean_test_accuracy_sum: 0.4970
# Epoch: 122 	Total: 2592.3986 	Mean_train_accuracy: 0.8083
# 	Mean_test_accuracy: 0.7950 	Mean_test_accuracy_sum: 0.4970
# Epoch: 123 	Total: 2590.9587 	Mean_train_accuracy: 0.8087
# 	Mean_test_accuracy: 0.7975 	Mean_test_accuracy_sum: 0.4970
# Epoch: 124 	Total: 2587.6001 	Mean_train_accuracy: 0.8111
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4970
# Epoch: 125 	Total: 2584.1546 	Mean_train_accuracy: 0.8062
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4970
# Epoch: 126 	Total: 2585.2593 	Mean_train_accuracy: 0.8041
# 	Mean_test_accuracy: 0.7965 	Mean_test_accuracy_sum: 0.4970
# Epoch: 127 	Total: 2579.3464 	Mean_train_accuracy: 0.8086
# 	Mean_test_accuracy: 0.7955 	Mean_test_accuracy_sum: 0.4970
# Epoch: 128 	Total: 2579.4537 	Mean_train_accuracy: 0.8064
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4970
# Epoch: 129 	Total: 2576.8735 	Mean_train_accuracy: 0.8085
# 	Mean_test_accuracy: 0.7970 	Mean_test_accuracy_sum: 0.4970
# Epoch: 130 	Total: 2572.9016 	Mean_train_accuracy: 0.8054
# 	Mean_test_accuracy: 0.7980 	Mean_test_accuracy_sum: 0.4970
# Epoch: 131 	Total: 2569.9546 	Mean_train_accuracy: 0.8085
# 	Mean_test_accuracy: 0.8035 	Mean_test_accuracy_sum: 0.4970
# Epoch: 132 	Total: 2569.2937 	Mean_train_accuracy: 0.8073
# 	Mean_test_accuracy: 0.7965 	Mean_test_accuracy_sum: 0.4970
# Epoch: 133 	Total: 2571.6809 	Mean_train_accuracy: 0.8069
# 	Mean_test_accuracy: 0.7940 	Mean_test_accuracy_sum: 0.4970
# Epoch: 134 	Total: 2566.7146 	Mean_train_accuracy: 0.8056
# 	Mean_test_accuracy: 0.8035 	Mean_test_accuracy_sum: 0.4970
# Epoch: 135 	Total: 2564.3448 	Mean_train_accuracy: 0.8105
# 	Mean_test_accuracy: 0.8020 	Mean_test_accuracy_sum: 0.4970
# Epoch: 136 	Total: 2565.5909 	Mean_train_accuracy: 0.8051
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4970
# Epoch: 137 	Total: 2562.0739 	Mean_train_accuracy: 0.8086
# 	Mean_test_accuracy: 0.7970 	Mean_test_accuracy_sum: 0.4970
# Epoch: 138 	Total: 2559.4380 	Mean_train_accuracy: 0.8113
# 	Mean_test_accuracy: 0.7995 	Mean_test_accuracy_sum: 0.4970
# Epoch: 139 	Total: 2557.1222 	Mean_train_accuracy: 0.8059
# 	Mean_test_accuracy: 0.7975 	Mean_test_accuracy_sum: 0.4970
# Epoch: 140 	Total: 2554.5090 	Mean_train_accuracy: 0.8187
# 	Mean_test_accuracy: 0.7995 	Mean_test_accuracy_sum: 0.4970
# Epoch: 141 	Total: 2552.9737 	Mean_train_accuracy: 0.8096
# 	Mean_test_accuracy: 0.7930 	Mean_test_accuracy_sum: 0.4970
# Epoch: 142 	Total: 2557.6858 	Mean_train_accuracy: 0.8103
# 	Mean_test_accuracy: 0.7990 	Mean_test_accuracy_sum: 0.4970
# Epoch: 143 	Total: 2553.2566 	Mean_train_accuracy: 0.8142
# 	Mean_test_accuracy: 0.7970 	Mean_test_accuracy_sum: 0.4970
# Epoch: 144 	Total: 2550.8907 	Mean_train_accuracy: 0.8121
# 	Mean_test_accuracy: 0.8015 	Mean_test_accuracy_sum: 0.4970
# Epoch: 145 	Total: 2551.1941 	Mean_train_accuracy: 0.8082
# 	Mean_test_accuracy: 0.8005 	Mean_test_accuracy_sum: 0.4970
# Epoch: 146 	Total: 2545.0139 	Mean_train_accuracy: 0.8157
# 	Mean_test_accuracy: 0.7955 	Mean_test_accuracy_sum: 0.4970
# Epoch: 147 	Total: 2544.2068 	Mean_train_accuracy: 0.8115
# 	Mean_test_accuracy: 0.7950 	Mean_test_accuracy_sum: 0.4970
# Epoch: 148 	Total: 2543.5837 	Mean_train_accuracy: 0.8144
# 	Mean_test_accuracy: 0.7895 	Mean_test_accuracy_sum: 0.4970
# Epoch: 149 	Total: 2539.1747 	Mean_train_accuracy: 0.8117
# 	Mean_test_accuracy: 0.7985 	Mean_test_accuracy_sum: 0.4970
# Epoch: 150 	Total: 2540.0364 	Mean_train_accuracy: 0.8124
# 	Mean_test_accuracy: 0.7970 	Mean_test_accuracy_sum: 0.4970
# Epoch: 151 	Total: 2541.8827 	Mean_train_accuracy: 0.8151
# 	Mean_test_accuracy: 0.7980 	Mean_test_accuracy_sum: 0.4970
# Epoch: 152 	Total: 2535.4070 	Mean_train_accuracy: 0.8156
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.4970
# Epoch: 153 	Total: 2532.3523 	Mean_train_accuracy: 0.8181
# 	Mean_test_accuracy: 0.8020 	Mean_test_accuracy_sum: 0.4970
# Epoch: 154 	Total: 2533.6305 	Mean_train_accuracy: 0.8114
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4970
# Epoch: 155 	Total: 2532.6378 	Mean_train_accuracy: 0.8123
# 	Mean_test_accuracy: 0.7970 	Mean_test_accuracy_sum: 0.4970
# Epoch: 156 	Total: 2530.8045 	Mean_train_accuracy: 0.8142
# 	Mean_test_accuracy: 0.7985 	Mean_test_accuracy_sum: 0.4970
# Epoch: 157 	Total: 2530.1768 	Mean_train_accuracy: 0.8197
# 	Mean_test_accuracy: 0.7990 	Mean_test_accuracy_sum: 0.4970
# Epoch: 158 	Total: 2527.5569 	Mean_train_accuracy: 0.8187
# 	Mean_test_accuracy: 0.8000 	Mean_test_accuracy_sum: 0.4970
# Epoch: 159 	Total: 2528.4991 	Mean_train_accuracy: 0.8076
# 	Mean_test_accuracy: 0.8055 	Mean_test_accuracy_sum: 0.4970
# Epoch: 160 	Total: 2527.4567 	Mean_train_accuracy: 0.8131
# 	Mean_test_accuracy: 0.7955 	Mean_test_accuracy_sum: 0.4970
# Epoch: 161 	Total: 2523.1937 	Mean_train_accuracy: 0.8067
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4970
# Epoch: 162 	Total: 2526.3823 	Mean_train_accuracy: 0.8110
# 	Mean_test_accuracy: 0.7980 	Mean_test_accuracy_sum: 0.4970
# Epoch: 163 	Total: 2523.0448 	Mean_train_accuracy: 0.8153
# 	Mean_test_accuracy: 0.7955 	Mean_test_accuracy_sum: 0.4970
# Epoch: 164 	Total: 2528.1896 	Mean_train_accuracy: 0.8120
# 	Mean_test_accuracy: 0.7955 	Mean_test_accuracy_sum: 0.4970
# Epoch: 165 	Total: 2521.8507 	Mean_train_accuracy: 0.8177
# 	Mean_test_accuracy: 0.7985 	Mean_test_accuracy_sum: 0.4970
# Epoch: 166 	Total: 2518.2965 	Mean_train_accuracy: 0.8115
# 	Mean_test_accuracy: 0.8055 	Mean_test_accuracy_sum: 0.4970
# Epoch: 167 	Total: 2514.8615 	Mean_train_accuracy: 0.8184
# 	Mean_test_accuracy: 0.7975 	Mean_test_accuracy_sum: 0.4970
# Epoch: 168 	Total: 2514.4477 	Mean_train_accuracy: 0.8119
# 	Mean_test_accuracy: 0.7980 	Mean_test_accuracy_sum: 0.4970
# Epoch: 169 	Total: 2514.0143 	Mean_train_accuracy: 0.8206
# 	Mean_test_accuracy: 0.8000 	Mean_test_accuracy_sum: 0.4970
# Epoch: 170 	Total: 2512.9378 	Mean_train_accuracy: 0.8162
# 	Mean_test_accuracy: 0.8000 	Mean_test_accuracy_sum: 0.4970
# Epoch: 171 	Total: 2513.0557 	Mean_train_accuracy: 0.8167
# 	Mean_test_accuracy: 0.8095 	Mean_test_accuracy_sum: 0.4970
# Epoch: 172 	Total: 2512.2673 	Mean_train_accuracy: 0.8164
# 	Mean_test_accuracy: 0.8055 	Mean_test_accuracy_sum: 0.4970
# Epoch: 173 	Total: 2513.3671 	Mean_train_accuracy: 0.8154
# 	Mean_test_accuracy: 0.8020 	Mean_test_accuracy_sum: 0.4970
# Epoch: 174 	Total: 2509.1960 	Mean_train_accuracy: 0.8158
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4970
# Epoch: 175 	Total: 2510.5126 	Mean_train_accuracy: 0.8187
# 	Mean_test_accuracy: 0.8025 	Mean_test_accuracy_sum: 0.4970
# Epoch: 176 	Total: 2506.3461 	Mean_train_accuracy: 0.8182
# 	Mean_test_accuracy: 0.8045 	Mean_test_accuracy_sum: 0.4970
# Epoch: 177 	Total: 2506.1333 	Mean_train_accuracy: 0.8165
# 	Mean_test_accuracy: 0.7935 	Mean_test_accuracy_sum: 0.4970
# Epoch: 178 	Total: 2506.6919 	Mean_train_accuracy: 0.8179
# 	Mean_test_accuracy: 0.8025 	Mean_test_accuracy_sum: 0.4970
# Epoch: 179 	Total: 2504.7595 	Mean_train_accuracy: 0.8214
# 	Mean_test_accuracy: 0.7975 	Mean_test_accuracy_sum: 0.4970
# Epoch: 180 	Total: 2501.1436 	Mean_train_accuracy: 0.8193
# 	Mean_test_accuracy: 0.8085 	Mean_test_accuracy_sum: 0.4970
# Epoch: 181 	Total: 2499.9996 	Mean_train_accuracy: 0.8208
# 	Mean_test_accuracy: 0.8065 	Mean_test_accuracy_sum: 0.4970
# Epoch: 182 	Total: 2499.0122 	Mean_train_accuracy: 0.8129
# 	Mean_test_accuracy: 0.8115 	Mean_test_accuracy_sum: 0.4970
# Epoch: 183 	Total: 2500.3500 	Mean_train_accuracy: 0.8165
# 	Mean_test_accuracy: 0.8000 	Mean_test_accuracy_sum: 0.4970
# Epoch: 184 	Total: 2496.4495 	Mean_train_accuracy: 0.8188
# 	Mean_test_accuracy: 0.7965 	Mean_test_accuracy_sum: 0.4970
# Epoch: 185 	Total: 2496.3242 	Mean_train_accuracy: 0.8149
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4970
# Epoch: 186 	Total: 2495.8643 	Mean_train_accuracy: 0.8155
# 	Mean_test_accuracy: 0.8045 	Mean_test_accuracy_sum: 0.4970
# Epoch: 187 	Total: 2497.5969 	Mean_train_accuracy: 0.8182
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4970
# Epoch: 188 	Total: 2492.1303 	Mean_train_accuracy: 0.8203
# 	Mean_test_accuracy: 0.8025 	Mean_test_accuracy_sum: 0.4970
# Epoch: 189 	Total: 2491.2148 	Mean_train_accuracy: 0.8189
# 	Mean_test_accuracy: 0.7955 	Mean_test_accuracy_sum: 0.4970
# Epoch: 190 	Total: 2490.5768 	Mean_train_accuracy: 0.8199
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4970
# Epoch: 191 	Total: 2488.8769 	Mean_train_accuracy: 0.8190
# 	Mean_test_accuracy: 0.8035 	Mean_test_accuracy_sum: 0.4970
# Epoch: 192 	Total: 2490.5250 	Mean_train_accuracy: 0.8191
# 	Mean_test_accuracy: 0.8125 	Mean_test_accuracy_sum: 0.4970
# Epoch: 193 	Total: 2486.1616 	Mean_train_accuracy: 0.8181
# 	Mean_test_accuracy: 0.8020 	Mean_test_accuracy_sum: 0.4970
# Epoch: 194 	Total: 2488.3728 	Mean_train_accuracy: 0.8211
# 	Mean_test_accuracy: 0.8145 	Mean_test_accuracy_sum: 0.4970
# Epoch: 195 	Total: 2486.9712 	Mean_train_accuracy: 0.8180
# 	Mean_test_accuracy: 0.8045 	Mean_test_accuracy_sum: 0.4970
# Epoch: 196 	Total: 2490.6786 	Mean_train_accuracy: 0.8180
# 	Mean_test_accuracy: 0.7990 	Mean_test_accuracy_sum: 0.4970
# Epoch: 197 	Total: 2486.7942 	Mean_train_accuracy: 0.8207
# 	Mean_test_accuracy: 0.8045 	Mean_test_accuracy_sum: 0.4970
# Epoch: 198 	Total: 2488.1632 	Mean_train_accuracy: 0.8216
# 	Mean_test_accuracy: 0.8015 	Mean_test_accuracy_sum: 0.4970
# Epoch: 199 	Total: 2482.9517 	Mean_train_accuracy: 0.8227
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.4970
# Epoch: 200 	Total: 2483.6579 	Mean_train_accuracy: 0.8149
# 	Mean_test_accuracy: 0.8055 	Mean_test_accuracy_sum: 0.4970
# Epoch: 201 	Total: 2487.5337 	Mean_train_accuracy: 0.8174
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.4970
# Epoch: 202 	Total: 2485.2293 	Mean_train_accuracy: 0.8184
# 	Mean_test_accuracy: 0.8055 	Mean_test_accuracy_sum: 0.4970
# Epoch: 203 	Total: 2479.8191 	Mean_train_accuracy: 0.8208
# 	Mean_test_accuracy: 0.8085 	Mean_test_accuracy_sum: 0.4970
# Epoch: 204 	Total: 2478.9910 	Mean_train_accuracy: 0.8246
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.4970
# Epoch: 205 	Total: 2477.8148 	Mean_train_accuracy: 0.8226
# 	Mean_test_accuracy: 0.7965 	Mean_test_accuracy_sum: 0.4970
# Epoch: 206 	Total: 2473.9794 	Mean_train_accuracy: 0.8175
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4970
# Epoch: 207 	Total: 2477.3244 	Mean_train_accuracy: 0.8150
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4970
# Epoch: 208 	Total: 2474.4301 	Mean_train_accuracy: 0.8248
# 	Mean_test_accuracy: 0.8085 	Mean_test_accuracy_sum: 0.4970
# Epoch: 209 	Total: 2480.9618 	Mean_train_accuracy: 0.8210
# 	Mean_test_accuracy: 0.8000 	Mean_test_accuracy_sum: 0.4970
# Epoch: 210 	Total: 2474.1632 	Mean_train_accuracy: 0.8159
# 	Mean_test_accuracy: 0.8075 	Mean_test_accuracy_sum: 0.4970
# Epoch: 211 	Total: 2470.9170 	Mean_train_accuracy: 0.8193
# 	Mean_test_accuracy: 0.8035 	Mean_test_accuracy_sum: 0.4970
# Epoch: 212 	Total: 2470.4610 	Mean_train_accuracy: 0.8207
# 	Mean_test_accuracy: 0.7950 	Mean_test_accuracy_sum: 0.4970
# Epoch: 213 	Total: 2469.9045 	Mean_train_accuracy: 0.8197
# 	Mean_test_accuracy: 0.8025 	Mean_test_accuracy_sum: 0.4970
# Epoch: 214 	Total: 2469.2005 	Mean_train_accuracy: 0.8211
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4970
# Epoch: 215 	Total: 2466.4043 	Mean_train_accuracy: 0.8198
# 	Mean_test_accuracy: 0.7985 	Mean_test_accuracy_sum: 0.4970
# Epoch: 216 	Total: 2471.1320 	Mean_train_accuracy: 0.8188
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4970
# Epoch: 217 	Total: 2468.6959 	Mean_train_accuracy: 0.8200
# 	Mean_test_accuracy: 0.8055 	Mean_test_accuracy_sum: 0.4970
# Epoch: 218 	Total: 2467.5577 	Mean_train_accuracy: 0.8222
# 	Mean_test_accuracy: 0.7980 	Mean_test_accuracy_sum: 0.4970
# Epoch: 219 	Total: 2467.7650 	Mean_train_accuracy: 0.8212
# 	Mean_test_accuracy: 0.8020 	Mean_test_accuracy_sum: 0.4970
# Epoch: 220 	Total: 2467.8231 	Mean_train_accuracy: 0.8211
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4970
# Epoch: 221 	Total: 2466.5748 	Mean_train_accuracy: 0.8213
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.4970
# Epoch: 222 	Total: 2465.5848 	Mean_train_accuracy: 0.8188
# 	Mean_test_accuracy: 0.7955 	Mean_test_accuracy_sum: 0.4970
# Epoch: 223 	Total: 2462.9436 	Mean_train_accuracy: 0.8235
# 	Mean_test_accuracy: 0.7960 	Mean_test_accuracy_sum: 0.4970
# Epoch: 224 	Total: 2461.6243 	Mean_train_accuracy: 0.8206
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4970
# Epoch: 225 	Total: 2463.4992 	Mean_train_accuracy: 0.8196
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4970
# Epoch: 226 	Total: 2461.0380 	Mean_train_accuracy: 0.8172
# 	Mean_test_accuracy: 0.8025 	Mean_test_accuracy_sum: 0.4970
# Epoch: 227 	Total: 2464.9264 	Mean_train_accuracy: 0.8206
# 	Mean_test_accuracy: 0.8065 	Mean_test_accuracy_sum: 0.4970
# Epoch: 228 	Total: 2464.7730 	Mean_train_accuracy: 0.8273
# 	Mean_test_accuracy: 0.8055 	Mean_test_accuracy_sum: 0.4970
# Epoch: 229 	Total: 2462.3475 	Mean_train_accuracy: 0.8199
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4970
# Epoch: 230 	Total: 2458.8204 	Mean_train_accuracy: 0.8239
# 	Mean_test_accuracy: 0.8055 	Mean_test_accuracy_sum: 0.4970
# Epoch: 231 	Total: 2458.9871 	Mean_train_accuracy: 0.8180
# 	Mean_test_accuracy: 0.8020 	Mean_test_accuracy_sum: 0.4970
# Epoch: 232 	Total: 2457.2046 	Mean_train_accuracy: 0.8249
# 	Mean_test_accuracy: 0.8105 	Mean_test_accuracy_sum: 0.4970
# Epoch: 233 	Total: 2455.5896 	Mean_train_accuracy: 0.8214
# 	Mean_test_accuracy: 0.8065 	Mean_test_accuracy_sum: 0.4970
# Epoch: 234 	Total: 2457.6198 	Mean_train_accuracy: 0.8245
# 	Mean_test_accuracy: 0.8010 	Mean_test_accuracy_sum: 0.4970
# Epoch: 235 	Total: 2459.5590 	Mean_train_accuracy: 0.8193
# 	Mean_test_accuracy: 0.8010 	Mean_test_accuracy_sum: 0.4970
# Epoch: 236 	Total: 2457.1833 	Mean_train_accuracy: 0.8266
# 	Mean_test_accuracy: 0.7995 	Mean_test_accuracy_sum: 0.4970
# Epoch: 237 	Total: 2454.8234 	Mean_train_accuracy: 0.8192
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.4970
# Epoch: 238 	Total: 2454.2013 	Mean_train_accuracy: 0.8201
# 	Mean_test_accuracy: 0.8085 	Mean_test_accuracy_sum: 0.4970
# Epoch: 239 	Total: 2455.8712 	Mean_train_accuracy: 0.8244
# 	Mean_test_accuracy: 0.8075 	Mean_test_accuracy_sum: 0.4970
# Epoch: 240 	Total: 2454.6771 	Mean_train_accuracy: 0.8224
# 	Mean_test_accuracy: 0.7975 	Mean_test_accuracy_sum: 0.4970
# Epoch: 241 	Total: 2454.3727 	Mean_train_accuracy: 0.8184
# 	Mean_test_accuracy: 0.8075 	Mean_test_accuracy_sum: 0.4970
# Epoch: 242 	Total: 2452.0412 	Mean_train_accuracy: 0.8208
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.4970
# Epoch: 243 	Total: 2453.6947 	Mean_train_accuracy: 0.8208
# 	Mean_test_accuracy: 0.8055 	Mean_test_accuracy_sum: 0.4970
# Epoch: 244 	Total: 2452.4437 	Mean_train_accuracy: 0.8188
# 	Mean_test_accuracy: 0.8065 	Mean_test_accuracy_sum: 0.4970
# Epoch: 245 	Total: 2450.8288 	Mean_train_accuracy: 0.8242
# 	Mean_test_accuracy: 0.8180 	Mean_test_accuracy_sum: 0.4970
# Epoch: 246 	Total: 2460.9561 	Mean_train_accuracy: 0.8219
# 	Mean_test_accuracy: 0.8005 	Mean_test_accuracy_sum: 0.4970
# Epoch: 247 	Total: 2457.8203 	Mean_train_accuracy: 0.8231
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4970
# Epoch: 248 	Total: 2447.4464 	Mean_train_accuracy: 0.8249
# 	Mean_test_accuracy: 0.8085 	Mean_test_accuracy_sum: 0.4970
# Epoch: 249 	Total: 2447.8360 	Mean_train_accuracy: 0.8242
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4970
# Epoch: 250 	Total: 2446.5565 	Mean_train_accuracy: 0.8222
# 	Mean_test_accuracy: 0.8115 	Mean_test_accuracy_sum: 0.4970
# Epoch: 251 	Total: 2444.9547 	Mean_train_accuracy: 0.8246
# 	Mean_test_accuracy: 0.8135 	Mean_test_accuracy_sum: 0.4970
# Epoch: 252 	Total: 2443.5589 	Mean_train_accuracy: 0.8203
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.4970
# Epoch: 253 	Total: 2446.0863 	Mean_train_accuracy: 0.8236
# 	Mean_test_accuracy: 0.8015 	Mean_test_accuracy_sum: 0.4970
# Epoch: 254 	Total: 2447.1099 	Mean_train_accuracy: 0.8212
# 	Mean_test_accuracy: 0.7985 	Mean_test_accuracy_sum: 0.4970
# Epoch: 255 	Total: 2445.3848 	Mean_train_accuracy: 0.8203
# 	Mean_test_accuracy: 0.8000 	Mean_test_accuracy_sum: 0.4970
# Epoch: 256 	Total: 2448.9374 	Mean_train_accuracy: 0.8267
# 	Mean_test_accuracy: 0.8035 	Mean_test_accuracy_sum: 0.4970
# Epoch: 257 	Total: 2446.3195 	Mean_train_accuracy: 0.8253
# 	Mean_test_accuracy: 0.8155 	Mean_test_accuracy_sum: 0.4970
# Epoch: 258 	Total: 2443.4756 	Mean_train_accuracy: 0.8269
# 	Mean_test_accuracy: 0.7980 	Mean_test_accuracy_sum: 0.4970
# Epoch: 259 	Total: 2443.9355 	Mean_train_accuracy: 0.8232
# 	Mean_test_accuracy: 0.8075 	Mean_test_accuracy_sum: 0.4970
# Epoch: 260 	Total: 2438.1491 	Mean_train_accuracy: 0.8237
# 	Mean_test_accuracy: 0.8045 	Mean_test_accuracy_sum: 0.4970
# Epoch: 261 	Total: 2438.0766 	Mean_train_accuracy: 0.8218
# 	Mean_test_accuracy: 0.8145 	Mean_test_accuracy_sum: 0.4970
# Epoch: 262 	Total: 2440.0502 	Mean_train_accuracy: 0.8234
# 	Mean_test_accuracy: 0.8115 	Mean_test_accuracy_sum: 0.4970
# Epoch: 263 	Total: 2442.5881 	Mean_train_accuracy: 0.8216
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.4970
# Epoch: 264 	Total: 2440.3893 	Mean_train_accuracy: 0.8241
# 	Mean_test_accuracy: 0.8020 	Mean_test_accuracy_sum: 0.4970
# Epoch: 265 	Total: 2437.6913 	Mean_train_accuracy: 0.8282
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4970
# Epoch: 266 	Total: 2437.4115 	Mean_train_accuracy: 0.8241
# 	Mean_test_accuracy: 0.8075 	Mean_test_accuracy_sum: 0.4970
# Epoch: 267 	Total: 2439.2051 	Mean_train_accuracy: 0.8233
# 	Mean_test_accuracy: 0.8035 	Mean_test_accuracy_sum: 0.4970
# Epoch: 268 	Total: 2439.7472 	Mean_train_accuracy: 0.8189
# 	Mean_test_accuracy: 0.8140 	Mean_test_accuracy_sum: 0.4970
# Epoch: 269 	Total: 2437.6788 	Mean_train_accuracy: 0.8334
# 	Mean_test_accuracy: 0.7990 	Mean_test_accuracy_sum: 0.4970
# Epoch: 270 	Total: 2434.0674 	Mean_train_accuracy: 0.8271
# 	Mean_test_accuracy: 0.8125 	Mean_test_accuracy_sum: 0.4970
# Epoch: 271 	Total: 2433.1275 	Mean_train_accuracy: 0.8259
# 	Mean_test_accuracy: 0.8055 	Mean_test_accuracy_sum: 0.4970
# Epoch: 272 	Total: 2433.6936 	Mean_train_accuracy: 0.8269
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4970
# Epoch: 273 	Total: 2432.6020 	Mean_train_accuracy: 0.8265
# 	Mean_test_accuracy: 0.8075 	Mean_test_accuracy_sum: 0.4970
# Epoch: 274 	Total: 2431.1193 	Mean_train_accuracy: 0.8209
# 	Mean_test_accuracy: 0.8055 	Mean_test_accuracy_sum: 0.4970
# Epoch: 275 	Total: 2434.1670 	Mean_train_accuracy: 0.8270
# 	Mean_test_accuracy: 0.8075 	Mean_test_accuracy_sum: 0.4970
# Epoch: 276 	Total: 2434.3421 	Mean_train_accuracy: 0.8272
# 	Mean_test_accuracy: 0.8075 	Mean_test_accuracy_sum: 0.4970
# Epoch: 277 	Total: 2434.5140 	Mean_train_accuracy: 0.8249
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.4970
# Epoch: 278 	Total: 2434.5798 	Mean_train_accuracy: 0.8217
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.4970
# Epoch: 279 	Total: 2432.0418 	Mean_train_accuracy: 0.8268
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.4970
# Epoch: 280 	Total: 2433.1330 	Mean_train_accuracy: 0.8237
# 	Mean_test_accuracy: 0.8055 	Mean_test_accuracy_sum: 0.4970
# Epoch: 281 	Total: 2428.4416 	Mean_train_accuracy: 0.8238
# 	Mean_test_accuracy: 0.8135 	Mean_test_accuracy_sum: 0.4970
# Epoch: 282 	Total: 2434.3734 	Mean_train_accuracy: 0.8230
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.4970
# Epoch: 283 	Total: 2435.8166 	Mean_train_accuracy: 0.8209
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4970
# Epoch: 284 	Total: 2433.3586 	Mean_train_accuracy: 0.8213
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.4970
# Epoch: 285 	Total: 2432.0377 	Mean_train_accuracy: 0.8270
# 	Mean_test_accuracy: 0.8025 	Mean_test_accuracy_sum: 0.4970
# Epoch: 286 	Total: 2426.5180 	Mean_train_accuracy: 0.8240
# 	Mean_test_accuracy: 0.8155 	Mean_test_accuracy_sum: 0.4970
# Epoch: 287 	Total: 2429.5381 	Mean_train_accuracy: 0.8307
# 	Mean_test_accuracy: 0.8105 	Mean_test_accuracy_sum: 0.4970
# Epoch: 288 	Total: 2426.7139 	Mean_train_accuracy: 0.8281
# 	Mean_test_accuracy: 0.8045 	Mean_test_accuracy_sum: 0.4970
# Epoch: 289 	Total: 2425.4984 	Mean_train_accuracy: 0.8281
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.4970
# Epoch: 290 	Total: 2425.4977 	Mean_train_accuracy: 0.8259
# 	Mean_test_accuracy: 0.8035 	Mean_test_accuracy_sum: 0.4970
# Epoch: 291 	Total: 2425.1906 	Mean_train_accuracy: 0.8221
# 	Mean_test_accuracy: 0.8165 	Mean_test_accuracy_sum: 0.4970
# Epoch: 292 	Total: 2424.4434 	Mean_train_accuracy: 0.8253
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.4970
# Epoch: 293 	Total: 2424.7117 	Mean_train_accuracy: 0.8251
# 	Mean_test_accuracy: 0.8115 	Mean_test_accuracy_sum: 0.4970
# Epoch: 294 	Total: 2423.9828 	Mean_train_accuracy: 0.8153
# 	Mean_test_accuracy: 0.8025 	Mean_test_accuracy_sum: 0.4970
# Epoch: 295 	Total: 2422.7783 	Mean_train_accuracy: 0.8283
# 	Mean_test_accuracy: 0.8085 	Mean_test_accuracy_sum: 0.4970
# Epoch: 296 	Total: 2423.6582 	Mean_train_accuracy: 0.8265
# 	Mean_test_accuracy: 0.8075 	Mean_test_accuracy_sum: 0.4970
# Epoch: 297 	Total: 2424.8643 	Mean_train_accuracy: 0.8244
# 	Mean_test_accuracy: 0.8025 	Mean_test_accuracy_sum: 0.4970
# Epoch: 298 	Total: 2421.3983 	Mean_train_accuracy: 0.8254
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4970
# Epoch: 299 	Total: 2420.3374 	Mean_train_accuracy: 0.8277
# 	Mean_test_accuracy: 0.8075 	Mean_test_accuracy_sum: 0.4970
# Epoch: 300 	Total: 2423.3677 	Mean_train_accuracy: 0.8254
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.4970
# Epoch: 301 	Total: 2420.8203 	Mean_train_accuracy: 0.8216
# 	Mean_test_accuracy: 0.7975 	Mean_test_accuracy_sum: 0.4970
# Epoch: 302 	Total: 2422.3339 	Mean_train_accuracy: 0.8272
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.4970
# Epoch: 303 	Total: 2423.4300 	Mean_train_accuracy: 0.8260
# 	Mean_test_accuracy: 0.8075 	Mean_test_accuracy_sum: 0.4970
# Epoch: 304 	Total: 2424.1819 	Mean_train_accuracy: 0.8234
# 	Mean_test_accuracy: 0.8010 	Mean_test_accuracy_sum: 0.4970
# Epoch: 305 	Total: 2420.9914 	Mean_train_accuracy: 0.8216
# 	Mean_test_accuracy: 0.8135 	Mean_test_accuracy_sum: 0.4970
# Epoch: 306 	Total: 2420.4839 	Mean_train_accuracy: 0.8232
# 	Mean_test_accuracy: 0.8095 	Mean_test_accuracy_sum: 0.4970
# Epoch: 307 	Total: 2418.6001 	Mean_train_accuracy: 0.8336
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4970
# Epoch: 308 	Total: 2420.0991 	Mean_train_accuracy: 0.8261
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4970
# Epoch: 309 	Total: 2419.2965 	Mean_train_accuracy: 0.8239
# 	Mean_test_accuracy: 0.8095 	Mean_test_accuracy_sum: 0.4970
# Epoch: 310 	Total: 2416.0197 	Mean_train_accuracy: 0.8264
# 	Mean_test_accuracy: 0.8125 	Mean_test_accuracy_sum: 0.4970
# Epoch: 311 	Total: 2416.6209 	Mean_train_accuracy: 0.8240
# 	Mean_test_accuracy: 0.8025 	Mean_test_accuracy_sum: 0.4970
# Epoch: 312 	Total: 2415.5734 	Mean_train_accuracy: 0.8267
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.4970
# Epoch: 313 	Total: 2418.4126 	Mean_train_accuracy: 0.8284
# 	Mean_test_accuracy: 0.8115 	Mean_test_accuracy_sum: 0.4970
# Epoch: 314 	Total: 2413.9266 	Mean_train_accuracy: 0.8314
# 	Mean_test_accuracy: 0.8165 	Mean_test_accuracy_sum: 0.4970
# Epoch: 315 	Total: 2414.4419 	Mean_train_accuracy: 0.8310
# 	Mean_test_accuracy: 0.8140 	Mean_test_accuracy_sum: 0.4970
# Epoch: 316 	Total: 2415.3239 	Mean_train_accuracy: 0.8261
# 	Mean_test_accuracy: 0.8065 	Mean_test_accuracy_sum: 0.4970
# Epoch: 317 	Total: 2416.5852 	Mean_train_accuracy: 0.8262
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4970
# Epoch: 318 	Total: 2415.1121 	Mean_train_accuracy: 0.8296
# 	Mean_test_accuracy: 0.8105 	Mean_test_accuracy_sum: 0.4970
# Epoch: 319 	Total: 2411.7335 	Mean_train_accuracy: 0.8306
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4970
# Epoch: 320 	Total: 2411.1751 	Mean_train_accuracy: 0.8303
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.4970
# Epoch: 321 	Total: 2412.2980 	Mean_train_accuracy: 0.8270
# 	Mean_test_accuracy: 0.8095 	Mean_test_accuracy_sum: 0.4970
# Epoch: 322 	Total: 2410.2935 	Mean_train_accuracy: 0.8316
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4970
# Epoch: 323 	Total: 2413.1825 	Mean_train_accuracy: 0.8285
# 	Mean_test_accuracy: 0.8125 	Mean_test_accuracy_sum: 0.4970
# Epoch: 324 	Total: 2412.2944 	Mean_train_accuracy: 0.8297
# 	Mean_test_accuracy: 0.8085 	Mean_test_accuracy_sum: 0.4970
# Epoch: 325 	Total: 2410.7554 	Mean_train_accuracy: 0.8301
# 	Mean_test_accuracy: 0.8055 	Mean_test_accuracy_sum: 0.4970
# Epoch: 326 	Total: 2409.1189 	Mean_train_accuracy: 0.8298
# 	Mean_test_accuracy: 0.8075 	Mean_test_accuracy_sum: 0.4970
# Epoch: 327 	Total: 2411.4747 	Mean_train_accuracy: 0.8299
# 	Mean_test_accuracy: 0.8020 	Mean_test_accuracy_sum: 0.4970
# Epoch: 328 	Total: 2409.8943 	Mean_train_accuracy: 0.8293
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.4970
# Epoch: 329 	Total: 2407.4669 	Mean_train_accuracy: 0.8302
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4970
# Epoch: 330 	Total: 2408.2598 	Mean_train_accuracy: 0.8275
# 	Mean_test_accuracy: 0.8045 	Mean_test_accuracy_sum: 0.4970
# Epoch: 331 	Total: 2405.9093 	Mean_train_accuracy: 0.8293
# 	Mean_test_accuracy: 0.8055 	Mean_test_accuracy_sum: 0.4970
# Epoch: 332 	Total: 2410.5059 	Mean_train_accuracy: 0.8254
# 	Mean_test_accuracy: 0.8045 	Mean_test_accuracy_sum: 0.4970
# Epoch: 333 	Total: 2407.2093 	Mean_train_accuracy: 0.8255
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4970
# Epoch: 334 	Total: 2407.7653 	Mean_train_accuracy: 0.8308
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.4970
# Epoch: 335 	Total: 2407.2764 	Mean_train_accuracy: 0.8278
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.4970
# Epoch: 336 	Total: 2411.1702 	Mean_train_accuracy: 0.8275
# 	Mean_test_accuracy: 0.7975 	Mean_test_accuracy_sum: 0.4970
# Epoch: 337 	Total: 2412.2315 	Mean_train_accuracy: 0.8302
# 	Mean_test_accuracy: 0.8025 	Mean_test_accuracy_sum: 0.4970
# Epoch: 338 	Total: 2406.3866 	Mean_train_accuracy: 0.8267
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4970
# Epoch: 339 	Total: 2408.6573 	Mean_train_accuracy: 0.8328
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.4970
# Epoch: 340 	Total: 2409.1676 	Mean_train_accuracy: 0.8234
# 	Mean_test_accuracy: 0.8045 	Mean_test_accuracy_sum: 0.4970
# Epoch: 341 	Total: 2407.9209 	Mean_train_accuracy: 0.8300
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.4970
# Epoch: 342 	Total: 2405.2467 	Mean_train_accuracy: 0.8254
# 	Mean_test_accuracy: 0.8180 	Mean_test_accuracy_sum: 0.4970
# Epoch: 343 	Total: 2402.5420 	Mean_train_accuracy: 0.8290
# 	Mean_test_accuracy: 0.8005 	Mean_test_accuracy_sum: 0.4970
# Epoch: 344 	Total: 2403.3406 	Mean_train_accuracy: 0.8232
# 	Mean_test_accuracy: 0.8060 	Mean_test_accuracy_sum: 0.4970
# Epoch: 345 	Total: 2399.6490 	Mean_train_accuracy: 0.8313
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.4970
# Epoch: 346 	Total: 2403.7870 	Mean_train_accuracy: 0.8284
# 	Mean_test_accuracy: 0.8035 	Mean_test_accuracy_sum: 0.4970
# Epoch: 347 	Total: 2404.3860 	Mean_train_accuracy: 0.8277
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4970
# Epoch: 348 	Total: 2403.2735 	Mean_train_accuracy: 0.8339
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4970
# Epoch: 349 	Total: 2402.3905 	Mean_train_accuracy: 0.8258
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4970
# Epoch: 350 	Total: 2407.1463 	Mean_train_accuracy: 0.8284
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.4970
# Epoch: 351 	Total: 2401.8296 	Mean_train_accuracy: 0.8260
# 	Mean_test_accuracy: 0.8065 	Mean_test_accuracy_sum: 0.4970
# Epoch: 352 	Total: 2404.0976 	Mean_train_accuracy: 0.8237
# 	Mean_test_accuracy: 0.8065 	Mean_test_accuracy_sum: 0.4970
# Epoch: 353 	Total: 2400.4261 	Mean_train_accuracy: 0.8261
# 	Mean_test_accuracy: 0.8180 	Mean_test_accuracy_sum: 0.4970
# Epoch: 354 	Total: 2399.1345 	Mean_train_accuracy: 0.8281
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.4970
# Epoch: 355 	Total: 2399.5677 	Mean_train_accuracy: 0.8307
# 	Mean_test_accuracy: 0.8145 	Mean_test_accuracy_sum: 0.4970
# Epoch: 356 	Total: 2398.2886 	Mean_train_accuracy: 0.8257
# 	Mean_test_accuracy: 0.8055 	Mean_test_accuracy_sum: 0.4970
# Epoch: 357 	Total: 2398.0338 	Mean_train_accuracy: 0.8257
# 	Mean_test_accuracy: 0.8045 	Mean_test_accuracy_sum: 0.4970
# Epoch: 358 	Total: 2401.2636 	Mean_train_accuracy: 0.8308
# 	Mean_test_accuracy: 0.8010 	Mean_test_accuracy_sum: 0.4970
# Epoch: 359 	Total: 2399.6660 	Mean_train_accuracy: 0.8258
# 	Mean_test_accuracy: 0.8185 	Mean_test_accuracy_sum: 0.4970
# Epoch: 360 	Total: 2400.1684 	Mean_train_accuracy: 0.8299
# 	Mean_test_accuracy: 0.8095 	Mean_test_accuracy_sum: 0.4970
# Epoch: 361 	Total: 2403.5650 	Mean_train_accuracy: 0.8331
# 	Mean_test_accuracy: 0.8045 	Mean_test_accuracy_sum: 0.4970
# Epoch: 362 	Total: 2399.9199 	Mean_train_accuracy: 0.8270
# 	Mean_test_accuracy: 0.8180 	Mean_test_accuracy_sum: 0.4970
# Epoch: 363 	Total: 2399.9923 	Mean_train_accuracy: 0.8297
# 	Mean_test_accuracy: 0.8085 	Mean_test_accuracy_sum: 0.4970
# Epoch: 364 	Total: 2396.6077 	Mean_train_accuracy: 0.8324
# 	Mean_test_accuracy: 0.8045 	Mean_test_accuracy_sum: 0.4970
# Epoch: 365 	Total: 2396.4066 	Mean_train_accuracy: 0.8276
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.4970
# Epoch: 366 	Total: 2400.4828 	Mean_train_accuracy: 0.8254
# 	Mean_test_accuracy: 0.8095 	Mean_test_accuracy_sum: 0.4970
# Epoch: 367 	Total: 2399.1558 	Mean_train_accuracy: 0.8276
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.4970
# Epoch: 368 	Total: 2395.5411 	Mean_train_accuracy: 0.8314
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4970
# Epoch: 369 	Total: 2396.9733 	Mean_train_accuracy: 0.8279
# 	Mean_test_accuracy: 0.8135 	Mean_test_accuracy_sum: 0.4970
# Epoch: 370 	Total: 2393.8030 	Mean_train_accuracy: 0.8309
# 	Mean_test_accuracy: 0.8065 	Mean_test_accuracy_sum: 0.4970
# Epoch: 371 	Total: 2396.3009 	Mean_train_accuracy: 0.8305
# 	Mean_test_accuracy: 0.8035 	Mean_test_accuracy_sum: 0.4970
# Epoch: 372 	Total: 2392.2819 	Mean_train_accuracy: 0.8267
# 	Mean_test_accuracy: 0.8115 	Mean_test_accuracy_sum: 0.4970
# Epoch: 373 	Total: 2394.4078 	Mean_train_accuracy: 0.8284
# 	Mean_test_accuracy: 0.8045 	Mean_test_accuracy_sum: 0.4970
# Epoch: 374 	Total: 2395.5357 	Mean_train_accuracy: 0.8289
# 	Mean_test_accuracy: 0.8025 	Mean_test_accuracy_sum: 0.4970
# Epoch: 375 	Total: 2394.7217 	Mean_train_accuracy: 0.8341
# 	Mean_test_accuracy: 0.8135 	Mean_test_accuracy_sum: 0.4970
# Epoch: 376 	Total: 2392.2218 	Mean_train_accuracy: 0.8300
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.4970
# Epoch: 377 	Total: 2391.5282 	Mean_train_accuracy: 0.8293
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.4970
# Epoch: 378 	Total: 2392.9755 	Mean_train_accuracy: 0.8296
# 	Mean_test_accuracy: 0.8075 	Mean_test_accuracy_sum: 0.4970
# Epoch: 379 	Total: 2395.0686 	Mean_train_accuracy: 0.8289
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.4970
# Epoch: 380 	Total: 2391.8111 	Mean_train_accuracy: 0.8257
# 	Mean_test_accuracy: 0.8095 	Mean_test_accuracy_sum: 0.4970
# Epoch: 381 	Total: 2395.6476 	Mean_train_accuracy: 0.8280
# 	Mean_test_accuracy: 0.7995 	Mean_test_accuracy_sum: 0.4970
# Epoch: 382 	Total: 2393.5245 	Mean_train_accuracy: 0.8290
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.4970
# Epoch: 383 	Total: 2391.4363 	Mean_train_accuracy: 0.8264
# 	Mean_test_accuracy: 0.8135 	Mean_test_accuracy_sum: 0.4970
# Epoch: 384 	Total: 2389.7183 	Mean_train_accuracy: 0.8312
# 	Mean_test_accuracy: 0.8065 	Mean_test_accuracy_sum: 0.4970
# Epoch: 385 	Total: 2387.2669 	Mean_train_accuracy: 0.8301
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.4970
# Epoch: 386 	Total: 2388.7935 	Mean_train_accuracy: 0.8254
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.4970
# Epoch: 387 	Total: 2388.9209 	Mean_train_accuracy: 0.8315
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4970
# Epoch: 388 	Total: 2393.4679 	Mean_train_accuracy: 0.8348
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.4970
# Epoch: 389 	Total: 2389.2498 	Mean_train_accuracy: 0.8295
# 	Mean_test_accuracy: 0.8125 	Mean_test_accuracy_sum: 0.4970
# Epoch: 390 	Total: 2389.8372 	Mean_train_accuracy: 0.8318
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.4970
# Epoch: 391 	Total: 2388.4813 	Mean_train_accuracy: 0.8317
# 	Mean_test_accuracy: 0.8065 	Mean_test_accuracy_sum: 0.4970
# Epoch: 392 	Total: 2391.6499 	Mean_train_accuracy: 0.8321
# 	Mean_test_accuracy: 0.8025 	Mean_test_accuracy_sum: 0.4970
# Epoch: 393 	Total: 2386.0812 	Mean_train_accuracy: 0.8272
# 	Mean_test_accuracy: 0.8055 	Mean_test_accuracy_sum: 0.4970
# Epoch: 394 	Total: 2392.7383 	Mean_train_accuracy: 0.8289
# 	Mean_test_accuracy: 0.8135 	Mean_test_accuracy_sum: 0.4970
# Epoch: 395 	Total: 2388.2813 	Mean_train_accuracy: 0.8266
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.4970
# Epoch: 396 	Total: 2390.0180 	Mean_train_accuracy: 0.8344
# 	Mean_test_accuracy: 0.8045 	Mean_test_accuracy_sum: 0.4970
# Epoch: 397 	Total: 2386.4230 	Mean_train_accuracy: 0.8314
# 	Mean_test_accuracy: 0.8015 	Mean_test_accuracy_sum: 0.4970
# Epoch: 398 	Total: 2388.5940 	Mean_train_accuracy: 0.8262
# 	Mean_test_accuracy: 0.8135 	Mean_test_accuracy_sum: 0.4970
# Epoch: 399 	Total: 2390.2417 	Mean_train_accuracy: 0.8309
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4970
# Epoch: 400 	Total: 2386.8548 	Mean_train_accuracy: 0.8338
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.4970
# Epoch: 401 	Total: 2389.3614 	Mean_train_accuracy: 0.8296
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.4970
# Epoch: 402 	Total: 2385.9212 	Mean_train_accuracy: 0.8346
# 	Mean_test_accuracy: 0.8065 	Mean_test_accuracy_sum: 0.4970
# Epoch: 403 	Total: 2384.8301 	Mean_train_accuracy: 0.8275
# 	Mean_test_accuracy: 0.8025 	Mean_test_accuracy_sum: 0.4970
# Epoch: 404 	Total: 2386.7480 	Mean_train_accuracy: 0.8285
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4970
# Epoch: 405 	Total: 2384.8676 	Mean_train_accuracy: 0.8336
# 	Mean_test_accuracy: 0.8125 	Mean_test_accuracy_sum: 0.4970
# Epoch: 406 	Total: 2385.2738 	Mean_train_accuracy: 0.8307
# 	Mean_test_accuracy: 0.8125 	Mean_test_accuracy_sum: 0.4970
# Epoch: 407 	Total: 2384.8589 	Mean_train_accuracy: 0.8283
# 	Mean_test_accuracy: 0.8045 	Mean_test_accuracy_sum: 0.4970
# Epoch: 408 	Total: 2386.2316 	Mean_train_accuracy: 0.8301
# ...
# 	Mean_test_accuracy: 0.8155 	Mean_test_accuracy_sum: 0.4970
# Epoch: 664 	Total: 2330.0676 	Mean_train_accuracy: 0.8393
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.4970
# Epoch: 665 	Total: 2330.7290 	Mean_train_accuracy: 0.8415
# 	Mean_test_accuracy: 0.8095 	Mean_test_accuracy_sum: 0.4970
# Epoch: 666 	Total: 2330.5583 	Mean_train_accuracy: 0.8449
# 	Mean_test_accuracy: 0.8105 	Mean_test_accuracy_sum: 0.4970
# Epoch: 667 	Total: 2330.5142 	Mean_train_accuracy: 0.8348
# 	Mean_test_accuracy: 0.8155 	Mean_test_accuracy_sum: 0.4970
# Epoch: 668 	Total: 2333.1189 	Mean_train_accuracy: 0.8396
# 	Mean_test_accuracy: 0.8175 	Mean_test_accuracy_sum: 0.4970
# Epoch: 669 	Total: 2330.5296 	Mean_train_accuracy: 0.8381
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.4970
# Epoch: 670 	Total: 2334.4580 	Mean_train_accuracy: 0.8385
# 	Mean_test_accuracy: 0.8175 	Mean_test_accuracy_sum: 0.4970
# Epoch: 671 	Total: 2333.9354 	Mean_train_accuracy: 0.8399
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.4970
# Epoch: 672 	Total: 2331.7862 	Mean_train_accuracy: 0.8461
# 	Mean_test_accuracy: 0.8135 	Mean_test_accuracy_sum: 0.4970
# Epoch: 673 	Total: 2335.6877 	Mean_train_accuracy: 0.8411
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.4970
# Epoch: 674 	Total: 2335.7570 	Mean_train_accuracy: 0.8370
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.4970
# Epoch: 675 	Total: 2328.4298 	Mean_train_accuracy: 0.8395
# 	Mean_test_accuracy: 0.8230 	Mean_test_accuracy_sum: 0.4970
# Epoch: 676 	Total: 2328.0468 	Mean_train_accuracy: 0.8434
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.4970
# Epoch: 677 	Total: 2330.8345 	Mean_train_accuracy: 0.8386
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.4970
# Epoch: 678 	Total: 2328.8225 	Mean_train_accuracy: 0.8397
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.4970
# Epoch: 679 	Total: 2332.1567 	Mean_train_accuracy: 0.8372
# 	Mean_test_accuracy: 0.8115 	Mean_test_accuracy_sum: 0.4970
# Epoch: 680 	Total: 2329.6043 	Mean_train_accuracy: 0.8379
# 	Mean_test_accuracy: 0.8190 	Mean_test_accuracy_sum: 0.4970
# Epoch: 681 	Total: 2330.0377 	Mean_train_accuracy: 0.8399
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.4970
# Epoch: 682 	Total: 2330.7757 	Mean_train_accuracy: 0.8427
# 	Mean_test_accuracy: 0.8265 	Mean_test_accuracy_sum: 0.4970
# Epoch: 683 	Total: 2330.6994 	Mean_train_accuracy: 0.8390
# 	Mean_test_accuracy: 0.8105 	Mean_test_accuracy_sum: 0.4970
# Epoch: 684 	Total: 2326.9456 	Mean_train_accuracy: 0.8369
# 	Mean_test_accuracy: 0.8095 	Mean_test_accuracy_sum: 0.4970
# Epoch: 685 	Total: 2325.4293 	Mean_train_accuracy: 0.8387
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4970
# Epoch: 686 	Total: 2327.7569 	Mean_train_accuracy: 0.8396
# 	Mean_test_accuracy: 0.8140 	Mean_test_accuracy_sum: 0.4970
# Epoch: 687 	Total: 2324.6254 	Mean_train_accuracy: 0.8391
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.4970
# Epoch: 688 	Total: 2325.7988 	Mean_train_accuracy: 0.8360
# 	Mean_test_accuracy: 0.8145 	Mean_test_accuracy_sum: 0.4970
# Epoch: 689 	Total: 2328.1456 	Mean_train_accuracy: 0.8366
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.4970
# Epoch: 690 	Total: 2328.5338 	Mean_train_accuracy: 0.8439
# 	Mean_test_accuracy: 0.8055 	Mean_test_accuracy_sum: 0.4970
# Epoch: 691 	Total: 2329.7112 	Mean_train_accuracy: 0.8395
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.4970
# Epoch: 692 	Total: 2328.9021 	Mean_train_accuracy: 0.8376
# 	Mean_test_accuracy: 0.8155 	Mean_test_accuracy_sum: 0.4970
# Epoch: 693 	Total: 2326.9260 	Mean_train_accuracy: 0.8368
# 	Mean_test_accuracy: 0.8155 	Mean_test_accuracy_sum: 0.4970
# Epoch: 694 	Total: 2327.2108 	Mean_train_accuracy: 0.8347
# 	Mean_test_accuracy: 0.8125 	Mean_test_accuracy_sum: 0.4970
# Epoch: 695 	Total: 2327.6653 	Mean_train_accuracy: 0.8406
# 	Mean_test_accuracy: 0.8105 	Mean_test_accuracy_sum: 0.4970
# Epoch: 696 	Total: 2323.8789 	Mean_train_accuracy: 0.8404
# 	Mean_test_accuracy: 0.8125 	Mean_test_accuracy_sum: 0.4970
# Epoch: 697 	Total: 2330.0312 	Mean_train_accuracy: 0.8407
# 	Mean_test_accuracy: 0.8095 	Mean_test_accuracy_sum: 0.4970
# Epoch: 698 	Total: 2331.1318 	Mean_train_accuracy: 0.8365
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.4970
# Epoch: 699 	Total: 2326.5334 	Mean_train_accuracy: 0.8403
# 	Mean_test_accuracy: 0.8185 	Mean_test_accuracy_sum: 0.4970
# Epoch: 700 	Total: 2326.4916 	Mean_train_accuracy: 0.8375
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.4970
# Epoch: 701 	Total: 2324.2671 	Mean_train_accuracy: 0.8367
# 	Mean_test_accuracy: 0.8095 	Mean_test_accuracy_sum: 0.4970
# Epoch: 702 	Total: 2326.8200 	Mean_train_accuracy: 0.8375
# 	Mean_test_accuracy: 0.8115 	Mean_test_accuracy_sum: 0.4970
# Epoch: 703 	Total: 2325.9417 	Mean_train_accuracy: 0.8339
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.4970
# Epoch: 704 	Total: 2324.8517 	Mean_train_accuracy: 0.8370
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.4970
# Epoch: 705 	Total: 2325.2114 	Mean_train_accuracy: 0.8339
# 	Mean_test_accuracy: 0.8095 	Mean_test_accuracy_sum: 0.4970
# Epoch: 706 	Total: 2323.2150 	Mean_train_accuracy: 0.8448
# 	Mean_test_accuracy: 0.8195 	Mean_test_accuracy_sum: 0.4970
# Epoch: 707 	Total: 2328.1918 	Mean_train_accuracy: 0.8421
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.4970
# Epoch: 708 	Total: 2324.7862 	Mean_train_accuracy: 0.8387
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.4970
# Epoch: 709 	Total: 2324.0194 	Mean_train_accuracy: 0.8422
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.4970
# Epoch: 710 	Total: 2324.3883 	Mean_train_accuracy: 0.8387
# 	Mean_test_accuracy: 0.8135 	Mean_test_accuracy_sum: 0.4970
# Epoch: 711 	Total: 2322.7443 	Mean_train_accuracy: 0.8413
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4970
# Epoch: 712 	Total: 2323.0276 	Mean_train_accuracy: 0.8363
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4970
# Epoch: 713 	Total: 2324.9175 	Mean_train_accuracy: 0.8381
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4970
# Epoch: 714 	Total: 2324.7215 	Mean_train_accuracy: 0.8431
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.4970
# Epoch: 715 	Total: 2325.9307 	Mean_train_accuracy: 0.8412
# 	Mean_test_accuracy: 0.8135 	Mean_test_accuracy_sum: 0.4970
# Epoch: 716 	Total: 2323.8849 	Mean_train_accuracy: 0.8353
# 	Mean_test_accuracy: 0.8095 	Mean_test_accuracy_sum: 0.4970
# Epoch: 717 	Total: 2329.8835 	Mean_train_accuracy: 0.8417
# 	Mean_test_accuracy: 0.8135 	Mean_test_accuracy_sum: 0.4970
# Epoch: 718 	Total: 2324.9034 	Mean_train_accuracy: 0.8404
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4970
# Epoch: 719 	Total: 2324.1887 	Mean_train_accuracy: 0.8381
# 	Mean_test_accuracy: 0.8100 	Mean_test_accuracy_sum: 0.4970
# Epoch: 720 	Total: 2323.4855 	Mean_train_accuracy: 0.8411
# 	Mean_test_accuracy: 0.8045 	Mean_test_accuracy_sum: 0.4970
# Epoch: 721 	Total: 2326.3498 	Mean_train_accuracy: 0.8392
# 	Mean_test_accuracy: 0.8180 	Mean_test_accuracy_sum: 0.4970
# Epoch: 722 	Total: 2319.2765 	Mean_train_accuracy: 0.8360
# 	Mean_test_accuracy: 0.8085 	Mean_test_accuracy_sum: 0.4970
# Epoch: 723 	Total: 2320.6632 	Mean_train_accuracy: 0.8424
# 	Mean_test_accuracy: 0.8065 	Mean_test_accuracy_sum: 0.4970
# Epoch: 724 	Total: 2322.5052 	Mean_train_accuracy: 0.8401
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4970
# Epoch: 725 	Total: 2327.4305 	Mean_train_accuracy: 0.8385
# 	Mean_test_accuracy: 0.8160 	Mean_test_accuracy_sum: 0.4970
# Epoch: 726 	Total: 2325.0562 	Mean_train_accuracy: 0.8369
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.4970
# Epoch: 727 	Total: 2321.6439 	Mean_train_accuracy: 0.8410
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.4970
# Epoch: 728 	Total: 2327.7699 	Mean_train_accuracy: 0.8373
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.4970
# Epoch: 729 	Total: 2322.5314 	Mean_train_accuracy: 0.8440
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.4970
# Epoch: 730 	Total: 2320.8820 	Mean_train_accuracy: 0.8419
# 	Mean_test_accuracy: 0.8105 	Mean_test_accuracy_sum: 0.4970
# Epoch: 731 	Total: 2322.1509 	Mean_train_accuracy: 0.8363
# 	Mean_test_accuracy: 0.8105 	Mean_test_accuracy_sum: 0.4970
# Epoch: 732 	Total: 2319.5661 	Mean_train_accuracy: 0.8441
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.4970
# Epoch: 733 	Total: 2321.6118 	Mean_train_accuracy: 0.8367
# 	Mean_test_accuracy: 0.8095 	Mean_test_accuracy_sum: 0.4970
# Epoch: 734 	Total: 2317.4557 	Mean_train_accuracy: 0.8390
# 	Mean_test_accuracy: 0.8175 	Mean_test_accuracy_sum: 0.4970
# Epoch: 735 	Total: 2319.1619 	Mean_train_accuracy: 0.8443
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.4970
# Epoch: 736 	Total: 2319.2971 	Mean_train_accuracy: 0.8411
# 	Mean_test_accuracy: 0.8000 	Mean_test_accuracy_sum: 0.4970
# Epoch: 737 	Total: 2325.2849 	Mean_train_accuracy: 0.8424
# 	Mean_test_accuracy: 0.8105 	Mean_test_accuracy_sum: 0.4970
# Epoch: 738 	Total: 2327.1233 	Mean_train_accuracy: 0.8409
# 	Mean_test_accuracy: 0.8075 	Mean_test_accuracy_sum: 0.4970
# Epoch: 739 	Total: 2323.9520 	Mean_train_accuracy: 0.8418
# 	Mean_test_accuracy: 0.8120 	Mean_test_accuracy_sum: 0.4970
# Epoch: 740 	Total: 2321.5167 	Mean_train_accuracy: 0.8387
# 	Mean_test_accuracy: 0.8145 	Mean_test_accuracy_sum: 0.4970
# Epoch: 741 	Total: 2319.2346 	Mean_train_accuracy: 0.8372
# 	Mean_test_accuracy: 0.8160 	Mean_test_accuracy_sum: 0.4970
# Epoch: 742 	Total: 2318.9530 	Mean_train_accuracy: 0.8361
# 	Mean_test_accuracy: 0.8210 	Mean_test_accuracy_sum: 0.4970
# Epoch: 743 	Total: 2322.4956 	Mean_train_accuracy: 0.8370
# 	Mean_test_accuracy: 0.8115 	Mean_test_accuracy_sum: 0.4970
# Epoch: 744 	Total: 2317.5746 	Mean_train_accuracy: 0.8422
# 	Mean_test_accuracy: 0.8235 	Mean_test_accuracy_sum: 0.4970
# Epoch: 745 	Total: 2319.0467 	Mean_train_accuracy: 0.8363
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.4970
# Epoch: 746 	Total: 2320.0347 	Mean_train_accuracy: 0.8369
# 	Mean_test_accuracy: 0.8095 	Mean_test_accuracy_sum: 0.4970
# Epoch: 747 	Total: 2320.5298 	Mean_train_accuracy: 0.8384
# 	Mean_test_accuracy: 0.8155 	Mean_test_accuracy_sum: 0.4970
# Epoch: 748 	Total: 2321.3609 	Mean_train_accuracy: 0.8367
# 	Mean_test_accuracy: 0.8070 	Mean_test_accuracy_sum: 0.4970
# Epoch: 749 	Total: 2318.3485 	Mean_train_accuracy: 0.8445
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.4970
# Epoch: 750 	Total: 2317.6038 	Mean_train_accuracy: 0.8460
# 	Mean_test_accuracy: 0.8035 	Mean_test_accuracy_sum: 0.4970
# Epoch: 751 	Total: 2315.7298 	Mean_train_accuracy: 0.8402
# 	Mean_test_accuracy: 0.8155 	Mean_test_accuracy_sum: 0.4970
# Epoch: 752 	Total: 2316.4525 	Mean_train_accuracy: 0.8411
# 	Mean_test_accuracy: 0.8040 	Mean_test_accuracy_sum: 0.4970
# Epoch: 753 	Total: 2317.7871 	Mean_train_accuracy: 0.8323
# 	Mean_test_accuracy: 0.8115 	Mean_test_accuracy_sum: 0.4970
# Epoch: 754 	Total: 2317.4934 	Mean_train_accuracy: 0.8386
# 	Mean_test_accuracy: 0.8170 	Mean_test_accuracy_sum: 0.4970
# Epoch: 755 	Total: 2316.1978 	Mean_train_accuracy: 0.8427
# 	Mean_test_accuracy: 0.8085 	Mean_test_accuracy_sum: 0.4970
# Epoch: 756 	Total: 2318.6283 	Mean_train_accuracy: 0.8375
# 	Mean_test_accuracy: 0.8145 	Mean_test_accuracy_sum: 0.4970
# Epoch: 757 	Total: 2315.4161 	Mean_train_accuracy: 0.8410
# 	Mean_test_accuracy: 0.8065 	Mean_test_accuracy_sum: 0.4970
# Epoch: 758 	Total: 2316.2170 	Mean_train_accuracy: 0.8391
# 	Mean_test_accuracy: 0.8085 	Mean_test_accuracy_sum: 0.4970
# Epoch: 759 	Total: 2316.1759 	Mean_train_accuracy: 0.8411
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.4970
# Epoch: 760 	Total: 2316.3624 	Mean_train_accuracy: 0.8417
# 	Mean_test_accuracy: 0.8115 	Mean_test_accuracy_sum: 0.4970
# Epoch: 761 	Total: 2318.9444 	Mean_train_accuracy: 0.8365
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.4970
# Epoch: 762 	Total: 2316.7209 	Mean_train_accuracy: 0.8432
# 	Mean_test_accuracy: 0.8170 	Mean_test_accuracy_sum: 0.4970
# Epoch: 763 	Total: 2317.6056 	Mean_train_accuracy: 0.8366
# 	Mean_test_accuracy: 0.8165 	Mean_test_accuracy_sum: 0.4970
# Epoch: 764 	Total: 2315.9170 	Mean_train_accuracy: 0.8450
# 	Mean_test_accuracy: 0.8125 	Mean_test_accuracy_sum: 0.4970
# Epoch: 765 	Total: 2314.6791 	Mean_train_accuracy: 0.8451
# 	Mean_test_accuracy: 0.8135 	Mean_test_accuracy_sum: 0.4970
# Epoch: 766 	Total: 2318.0921 	Mean_train_accuracy: 0.8416
# 	Mean_test_accuracy: 0.8115 	Mean_test_accuracy_sum: 0.4970
# Epoch: 767 	Total: 2317.4137 	Mean_train_accuracy: 0.8452
# 	Mean_test_accuracy: 0.8135 	Mean_test_accuracy_sum: 0.4970
# Epoch: 768 	Total: 2315.7637 	Mean_train_accuracy: 0.8394
# 	Mean_test_accuracy: 0.8080 	Mean_test_accuracy_sum: 0.4970
# Epoch: 769 	Total: 2316.7724 	Mean_train_accuracy: 0.8367
# 	Mean_test_accuracy: 0.8085 	Mean_test_accuracy_sum: 0.4970
# Epoch: 770 	Total: 2318.5330 	Mean_train_accuracy: 0.8439
# 	Mean_test_accuracy: 0.8200 	Mean_test_accuracy_sum: 0.4970
# Epoch: 771 	Total: 2315.2168 	Mean_train_accuracy: 0.8424
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.4970
# Epoch: 772 	Total: 2315.4334 	Mean_train_accuracy: 0.8377
# 	Mean_test_accuracy: 0.8185 	Mean_test_accuracy_sum: 0.4970
# Epoch: 773 	Total: 2321.4843 	Mean_train_accuracy: 0.8390
# 	Mean_test_accuracy: 0.8035 	Mean_test_accuracy_sum: 0.4970
# Epoch: 774 	Total: 2316.8351 	Mean_train_accuracy: 0.8364
# 	Mean_test_accuracy: 0.8135 	Mean_test_accuracy_sum: 0.4970
# Epoch: 775 	Total: 2315.5728 	Mean_train_accuracy: 0.8376
# 	Mean_test_accuracy: 0.8160 	Mean_test_accuracy_sum: 0.4970
# Epoch: 776 	Total: 2317.6362 	Mean_train_accuracy: 0.8386
# 	Mean_test_accuracy: 0.8050 	Mean_test_accuracy_sum: 0.4970
# Epoch: 777 	Total: 2317.8433 	Mean_train_accuracy: 0.8394
# 	Mean_test_accuracy: 0.8010 	Mean_test_accuracy_sum: 0.4970
# Epoch: 778 	Total: 2316.6174 	Mean_train_accuracy: 0.8439
# 	Mean_test_accuracy: 0.8145 	Mean_test_accuracy_sum: 0.4970
# Epoch: 779 	Total: 2314.2207 	Mean_train_accuracy: 0.8389
# 	Mean_test_accuracy: 0.8025 	Mean_test_accuracy_sum: 0.4970
# Epoch: 780 	Total: 2309.3859 	Mean_train_accuracy: 0.8385
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.4970
# Epoch: 781 	Total: 2313.5350 	Mean_train_accuracy: 0.8406
# 	Mean_test_accuracy: 0.8090 	Mean_test_accuracy_sum: 0.4970
# Epoch: 782 	Total: 2316.0714 	Mean_train_accuracy: 0.8364
# 	Mean_test_accuracy: 0.8125 	Mean_test_accuracy_sum: 0.4970
# Epoch: 783 	Total: 2316.8003 	Mean_train_accuracy: 0.8407
# 	Mean_test_accuracy: 0.8165 	Mean_test_accuracy_sum: 0.4970
# Epoch: 784 	Total: 2321.6032 	Mean_train_accuracy: 0.8381
# 	Mean_test_accuracy: 0.8155 	Mean_test_accuracy_sum: 0.4970
# Epoch: 785 	Total: 2320.3451 	Mean_train_accuracy: 0.8378
# 	Mean_test_accuracy: 0.8085 	Mean_test_accuracy_sum: 0.4970
# Epoch: 786 	Total: 2318.3743 	Mean_train_accuracy: 0.8416
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.4970
# Epoch: 787 	Total: 2316.5240 	Mean_train_accuracy: 0.8443
# 	Mean_test_accuracy: 0.8215 	Mean_test_accuracy_sum: 0.4970
# Epoch: 788 	Total: 2315.6750 	Mean_train_accuracy: 0.8374
# 	Mean_test_accuracy: 0.8115 	Mean_test_accuracy_sum: 0.4970
# Epoch: 789 	Total: 2315.6726 	Mean_train_accuracy: 0.8384
# 	Mean_test_accuracy: 0.8200 	Mean_test_accuracy_sum: 0.4970
# Epoch: 790 	Total: 2312.2224 	Mean_train_accuracy: 0.8405
# 	Mean_test_accuracy: 0.8165 	Mean_test_accuracy_sum: 0.4970
# Epoch: 791 	Total: 2315.3523 	Mean_train_accuracy: 0.8397
# 	Mean_test_accuracy: 0.8110 	Mean_test_accuracy_sum: 0.4970
# Epoch: 792 	Total: 2313.3847 	Mean_train_accuracy: 0.8444
# 	Mean_test_accuracy: 0.8200 	Mean_test_accuracy_sum: 0.4970
# Epoch: 793 	Total: 2316.1621 	Mean_train_accuracy: 0.8389
# 	Mean_test_accuracy: 0.8030 	Mean_test_accuracy_sum: 0.4970
# Epoch: 794 	Total: 2314.6043 	Mean_train_accuracy: 0.8427
# 	Mean_test_accuracy: 0.8150 	Mean_test_accuracy_sum: 0.4970
# Epoch: 795 	Total: 2311.8428 	Mean_train_accuracy: 0.8431
# 	Mean_test_accuracy: 0.8130 	Mean_test_accuracy_sum: 0.4970
# Epoch: 796 	Total: 2314.8873 	Mean_train_accuracy: 0.8352
# 	Mean_test_accuracy: 0.8115 	Mean_test_accuracy_sum: 0.4970
# Epoch: 797 	Total: 2311.4511 	Mean_train_accuracy: 0.8421
# 	Mean_test_accuracy: 0.8155 	Mean_test_accuracy_sum: 0.4970
# Epoch: 798 	Total: 2310.6602 	Mean_train_accuracy: 0.8419
# 	Mean_test_accuracy: 0.8135 	Mean_test_accuracy_sum: 0.4970
