# %%
import torch
pwd = '/home/zjy/project/MetaIM/data'
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %%
from torch_geometric.datasets import Planetoid

cora_dataset = Planetoid(root=pwd+'/cora', name='cora')
data = cora_dataset[0]
edge_index = data.edge_index

# %%
import numpy as np
individual_infection_path = pwd+'/for_meta/cora_individual_infection_sir_200_sample_500.npy'
seeds_infection_path = pwd+'/for_meta/cora_seed_infection_sir_200_sample_500.npy'

individual_infection = np.load(individual_infection_path)
seeds_infection = np.load(seeds_infection_path)
individual_infection.shape,seeds_infection.shape
# Out:
# ((2708, 2708), (1000, 2, 2708))

# %%
import torch
from torch_geometric.utils import to_scipy_sparse_matrix
import scipy.sparse as sp

# 转换为 scipy 稀疏矩阵
adj = to_scipy_sparse_matrix(edge_index)


# def normalize_adj(mx):
#     """Row-normalize sparse matrix"""
#     rowsum = np.array(mx.sum(1))
#     r_inv_sqrt = np.power(rowsum, -0.5).flatten()
#     r_inv_sqrt[np.isinf(r_inv_sqrt)] = 0.
#     r_mat_inv_sqrt = sp.diags(r_inv_sqrt)
#     return mx.dot(r_mat_inv_sqrt).transpose().dot(r_mat_inv_sqrt)



# adj = adj + adj.T.multiply(adj.T > adj) - adj.multiply(adj.T > adj)
# adj = normalize_adj(adj + sp.eye(adj.shape[0]))
adj = torch.Tensor(adj.toarray()).to_sparse()
adj
# Out:
# tensor(indices=tensor([[   0,    0,    0,  ..., 2707, 2707, 2707],
#                        [ 633, 1862, 2582,  ...,  598, 1473, 2706]]),
#        values=tensor([1., 1., 1.,  ..., 1., 1., 1.]),
#        size=(2708, 2708), nnz=10556, layout=torch.sparse_coo)

# %%
feat_num = int(seeds_infection[0][0].sum())

# %%
from torch.utils.data import Dataset, DataLoader, random_split


class CustomDataset(Dataset):
    def __init__(self, individual_infection,seeds_infection, feat_num):
        self.individual_infection = individual_infection
        self.seeds_infection = seeds_infection
        self.feat_shape = (len(individual_infection), feat_num)

    def __len__(self):
        return len(self.seeds_infection)

    def __getitem__(self, idx):
        seeds= np.nonzero(self.seeds_infection[idx][0])[0]
        
        feature = torch.zeros(self.feat_shape[0],self.feat_shape[1])
        for i in range(len(seeds)):
            seed_i_infection = torch.tensor(self.individual_infection[seeds[i]])
            feature[:, i] = seed_i_infection
            
        label = self.seeds_infection[idx][1]
        
        return feature, label

dataset = CustomDataset(individual_infection,seeds_infection,feat_num)

# %%
# 定义划分比例
train_ratio = 0.8
test_ratio = 0.2

# 划分数据集
train_dataset, test_dataset = random_split(dataset, [int(len(dataset)*train_ratio), int(len(dataset)*test_ratio)])

train_batch_size = 32
test_batch_size = 2

# 创建数据加载器
train_loader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True, drop_last=False)
test_loader = DataLoader(test_dataset, batch_size=test_batch_size, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv

class GAT(nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_heads):
        super(GAT, self).__init__()
        self.conv1 = GATConv(in_channels, hidden_channels, heads=num_heads)
        self.conv2 = GATConv(hidden_channels * num_heads, out_channels, heads=1)

    def forward(self, x, edge_index):
        x = F.elu(self.conv1(x, edge_index))
        x = F.dropout(x, p=0.2, training=self.training)
        x = self.conv2(x, edge_index)
        return F.elu(x)

# %%
# from data.model.gat import GAT, SpGAT
from torch.optim import Adam, SGD


# forward_model = SpGAT(nfeat=feat_num, 
#                 nhid=64, 
#                 nclass=1, 
#                 dropout=0.2, 
#                 nheads=1, 
#                 alpha=0.2)
forward_model = GAT(feat_num, 256, 1, 8)

optimizer = Adam([{'params': forward_model.parameters()}], 
                 lr=1e-3)

adj = adj.to(device)
forward_model = forward_model.to(device)
forward_model.train()
# Out:
# GAT(
#   (conv1): GATConv(135, 256, heads=8)
#   (conv2): GATConv(2048, 1, heads=1)
# )

# %%
def weighted_dkl(y_true, y_pred, weights=None):
    y_true = torch.clamp(y_true, 1e-15, 1 - 1e-15)
    y_pred = torch.clamp(y_pred, 1e-15, 1 - 1e-15)
    loss = torch.sum(y_true * (torch.log(y_true) - torch.log(y_pred)), -1)
    return torch.sum(loss)


def weighted_jsd(y_true, y_pred, weights=None):
    m = 0.5 * (y_true + y_pred)
    return weighted_dkl(y_true, m, weights=weights) + weighted_dkl(
        y_pred, m, weights=weights
    )

# %%
edge_index = edge_index.to(device)
top_num = 300

for epoch in range(2000):

    total_overall = 0
    forward_loss = 0

    mean_train_accuracy = 0
    for batch_idx, feature_label in enumerate(train_loader):        
        features = feature_label[0].to(device)
        labels = feature_label[1].to(device)
        optimizer.zero_grad()
        
        loss = 0
        train_accuracy = 0
        for i, x_i in enumerate(features):
            y_i = labels[i]
            y_hat = forward_model(x_i, edge_index)
            _, top_indices_true = torch.topk(y_i.clone(), top_num)
            label_2 = torch.zeros(y_i.shape).to(device)
            label_2[top_indices_true] = 1
            
            _, top_indices_predict = torch.topk(y_hat.clone().squeeze(-1), top_num)
            
            # 将张量数组转换为Python列表
            list1 = top_indices_true.tolist()
            list_pre = top_indices_predict.tolist()

            # 使用集合操作找到交集
            intersection = list(set(list1) & set(list_pre))
            accuracy_i = len(intersection) / top_num
            train_accuracy += accuracy_i

            forward_loss = 0.5*F.mse_loss(y_hat.squeeze(-1), y_i, reduction='sum') + F.mse_loss(y_hat.squeeze(-1), label_2, reduction='sum')      
            loss += forward_loss
        
        total_overall += loss.item()    
        train_accuracy /= len(features)
        mean_train_accuracy = train_accuracy
        loss.backward()
        optimizer.step()
        # for p in forward_model.parameters():
        #     p.data.clamp_(min=0)
        
        
    print("Epoch: {}".format(epoch+1), 
        "\tTotal: {:.4f}".format(total_overall / train_batch_size),
        "\tMean_train_accuracy: {:.4f}".format(mean_train_accuracy),
        )  
    
    mean_accuracy = 0
    mean_accuracy_sum = 0
    
    for batch_idx, feature_label in enumerate(test_loader):   
        features = feature_label[0].to(device)
        labels = feature_label[1].to(device)
        
        accuracy = 0
        accuracy_sum = 0
        
        for i, x_i in enumerate(features):
            y_i = labels[i]
            _, top_indices_true = torch.topk(y_i, top_num)
            
            y_hat = forward_model(x_i, edge_index)
            
            _, top_indices_predict = torch.topk(y_hat.squeeze(-1), top_num)
            
            sum_pre = torch.sum(x_i, dim=1, keepdim=True)
            _, top_indices_sum = torch.topk(sum_pre.squeeze(-1), top_num)
            
            # 将张量数组转换为Python列表
            list1 = top_indices_true.tolist()
            list_pre = top_indices_predict.tolist()
            
            list_sum = top_indices_sum.tolist()

            # 使用集合操作找到交集
            intersection = list(set(list1) & set(list_pre))
            
            intersection_sum = list(set(list1) & set(list_sum))
            
            accuracy_i = len(intersection) / top_num       
            accuracy += accuracy_i 
            accuracy_sum += len(intersection_sum) / top_num  
        accuracy /= test_batch_size
        accuracy_sum/= test_batch_size
        mean_accuracy = accuracy
        mean_accuracy_sum = accuracy_sum
        break
    
    print(
        "\tMean_test_accuracy: {:.4f}".format(mean_accuracy),
        "\tMean_test_accuracy_sum: {:.4f}".format(mean_accuracy_sum)
    )
# Out:
# Epoch: 1 	Total: 3534.7031 	Mean_train_accuracy: 0.7394
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 2 	Total: 3514.4392 	Mean_train_accuracy: 0.7330
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 3 	Total: 3512.7802 	Mean_train_accuracy: 0.7286
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 4 	Total: 3502.5692 	Mean_train_accuracy: 0.7315
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 5 	Total: 3521.7549 	Mean_train_accuracy: 0.7370
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 6 	Total: 3539.8693 	Mean_train_accuracy: 0.7405
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 7 	Total: 3567.1750 	Mean_train_accuracy: 0.7272
# 	Mean_test_accuracy: 0.7417 	Mean_test_accuracy_sum: 0.4000
# Epoch: 8 	Total: 3523.2860 	Mean_train_accuracy: 0.7350
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 9 	Total: 3545.8967 	Mean_train_accuracy: 0.7310
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 10 	Total: 3515.6858 	Mean_train_accuracy: 0.7387
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 11 	Total: 3540.8394 	Mean_train_accuracy: 0.7295
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 12 	Total: 3537.0973 	Mean_train_accuracy: 0.7278
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 13 	Total: 3517.0387 	Mean_train_accuracy: 0.7276
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 14 	Total: 3523.4020 	Mean_train_accuracy: 0.7359
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 15 	Total: 3514.0030 	Mean_train_accuracy: 0.7371
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 16 	Total: 3510.9875 	Mean_train_accuracy: 0.7250
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 17 	Total: 3522.5197 	Mean_train_accuracy: 0.7415
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 18 	Total: 3525.8518 	Mean_train_accuracy: 0.7327
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 19 	Total: 3515.0562 	Mean_train_accuracy: 0.7268
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 20 	Total: 3518.6187 	Mean_train_accuracy: 0.7345
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 21 	Total: 3510.6303 	Mean_train_accuracy: 0.7367
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 22 	Total: 3563.1377 	Mean_train_accuracy: 0.7314
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 23 	Total: 3549.7360 	Mean_train_accuracy: 0.7365
# 	Mean_test_accuracy: 0.7167 	Mean_test_accuracy_sum: 0.4000
# Epoch: 24 	Total: 3531.8793 	Mean_train_accuracy: 0.7428
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4000
# Epoch: 25 	Total: 3579.2491 	Mean_train_accuracy: 0.7347
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 26 	Total: 3514.4769 	Mean_train_accuracy: 0.7293
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 27 	Total: 3539.0862 	Mean_train_accuracy: 0.7340
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 28 	Total: 3604.1896 	Mean_train_accuracy: 0.7289
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 29 	Total: 3540.9787 	Mean_train_accuracy: 0.7296
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 30 	Total: 3513.1138 	Mean_train_accuracy: 0.7284
# 	Mean_test_accuracy: 0.7183 	Mean_test_accuracy_sum: 0.4000
# Epoch: 31 	Total: 3510.2212 	Mean_train_accuracy: 0.7327
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 32 	Total: 3507.3490 	Mean_train_accuracy: 0.7385
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 33 	Total: 3509.8859 	Mean_train_accuracy: 0.7242
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 34 	Total: 3515.3053 	Mean_train_accuracy: 0.7353
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 35 	Total: 3512.4216 	Mean_train_accuracy: 0.7376
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 36 	Total: 3516.3137 	Mean_train_accuracy: 0.7297
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 37 	Total: 3505.3682 	Mean_train_accuracy: 0.7354
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 38 	Total: 3528.0797 	Mean_train_accuracy: 0.7355
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 39 	Total: 3502.1757 	Mean_train_accuracy: 0.7357
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 40 	Total: 3509.5016 	Mean_train_accuracy: 0.7284
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 41 	Total: 3511.0429 	Mean_train_accuracy: 0.7380
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 42 	Total: 3503.7238 	Mean_train_accuracy: 0.7300
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 43 	Total: 3545.3247 	Mean_train_accuracy: 0.7248
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 44 	Total: 3655.5139 	Mean_train_accuracy: 0.7404
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 45 	Total: 3521.9094 	Mean_train_accuracy: 0.7276
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 46 	Total: 3509.0805 	Mean_train_accuracy: 0.7366
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 47 	Total: 3508.7073 	Mean_train_accuracy: 0.7298
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 48 	Total: 3500.5356 	Mean_train_accuracy: 0.7286
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 49 	Total: 3521.3838 	Mean_train_accuracy: 0.7368
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 50 	Total: 3519.7057 	Mean_train_accuracy: 0.7315
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 51 	Total: 3524.3812 	Mean_train_accuracy: 0.7291
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 52 	Total: 3517.5794 	Mean_train_accuracy: 0.7259
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 53 	Total: 3519.7496 	Mean_train_accuracy: 0.7310
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 54 	Total: 3498.2962 	Mean_train_accuracy: 0.7325
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 55 	Total: 3500.3058 	Mean_train_accuracy: 0.7322
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 56 	Total: 3522.7396 	Mean_train_accuracy: 0.7251
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 57 	Total: 3509.8928 	Mean_train_accuracy: 0.7371
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 58 	Total: 3511.9939 	Mean_train_accuracy: 0.7285
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 59 	Total: 3529.1039 	Mean_train_accuracy: 0.7315
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 60 	Total: 3508.2028 	Mean_train_accuracy: 0.7407
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 61 	Total: 3507.8454 	Mean_train_accuracy: 0.7349
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4000
# Epoch: 62 	Total: 3517.1991 	Mean_train_accuracy: 0.7298
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 63 	Total: 3522.3129 	Mean_train_accuracy: 0.7303
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 64 	Total: 3539.7729 	Mean_train_accuracy: 0.7328
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 65 	Total: 3506.6276 	Mean_train_accuracy: 0.7351
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 66 	Total: 3530.9171 	Mean_train_accuracy: 0.7368
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 67 	Total: 3542.3060 	Mean_train_accuracy: 0.7290
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 68 	Total: 3499.7853 	Mean_train_accuracy: 0.7286
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 69 	Total: 3567.6246 	Mean_train_accuracy: 0.7349
# 	Mean_test_accuracy: 0.7400 	Mean_test_accuracy_sum: 0.4000
# Epoch: 70 	Total: 3567.3296 	Mean_train_accuracy: 0.7329
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 71 	Total: 3579.3726 	Mean_train_accuracy: 0.7161
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 72 	Total: 3529.0299 	Mean_train_accuracy: 0.7275
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 73 	Total: 3516.2024 	Mean_train_accuracy: 0.7347
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 74 	Total: 3518.7740 	Mean_train_accuracy: 0.7372
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 75 	Total: 3502.9770 	Mean_train_accuracy: 0.7268
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 76 	Total: 3553.3490 	Mean_train_accuracy: 0.7343
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 77 	Total: 3535.5336 	Mean_train_accuracy: 0.7330
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 78 	Total: 3509.2327 	Mean_train_accuracy: 0.7252
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 79 	Total: 3497.1135 	Mean_train_accuracy: 0.7333
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 80 	Total: 3514.8012 	Mean_train_accuracy: 0.7346
# 	Mean_test_accuracy: 0.7183 	Mean_test_accuracy_sum: 0.4000
# Epoch: 81 	Total: 3507.7224 	Mean_train_accuracy: 0.7214
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 82 	Total: 3557.9279 	Mean_train_accuracy: 0.7398
# 	Mean_test_accuracy: 0.7183 	Mean_test_accuracy_sum: 0.4000
# Epoch: 83 	Total: 3525.0624 	Mean_train_accuracy: 0.7253
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 84 	Total: 3513.4391 	Mean_train_accuracy: 0.7364
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 85 	Total: 3525.0552 	Mean_train_accuracy: 0.7348
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4000
# Epoch: 86 	Total: 3525.9231 	Mean_train_accuracy: 0.7312
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 87 	Total: 3533.4124 	Mean_train_accuracy: 0.7300
# 	Mean_test_accuracy: 0.7167 	Mean_test_accuracy_sum: 0.4000
# Epoch: 88 	Total: 3518.7623 	Mean_train_accuracy: 0.7283
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 89 	Total: 3524.4677 	Mean_train_accuracy: 0.7358
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 90 	Total: 3514.6735 	Mean_train_accuracy: 0.7233
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 91 	Total: 3516.5105 	Mean_train_accuracy: 0.7249
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 92 	Total: 3547.3210 	Mean_train_accuracy: 0.7329
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 93 	Total: 3529.9212 	Mean_train_accuracy: 0.7300
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 94 	Total: 3520.2895 	Mean_train_accuracy: 0.7340
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 95 	Total: 3513.0646 	Mean_train_accuracy: 0.7299
# 	Mean_test_accuracy: 0.7183 	Mean_test_accuracy_sum: 0.4000
# Epoch: 96 	Total: 3501.0978 	Mean_train_accuracy: 0.7325
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 97 	Total: 3524.4266 	Mean_train_accuracy: 0.7251
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 98 	Total: 3536.4910 	Mean_train_accuracy: 0.7356
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 99 	Total: 3537.5809 	Mean_train_accuracy: 0.7315
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 100 	Total: 3515.9871 	Mean_train_accuracy: 0.7260
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 101 	Total: 3493.3976 	Mean_train_accuracy: 0.7287
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 102 	Total: 3503.9748 	Mean_train_accuracy: 0.7390
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 103 	Total: 3515.4640 	Mean_train_accuracy: 0.7290
# 	Mean_test_accuracy: 0.7433 	Mean_test_accuracy_sum: 0.4000
# Epoch: 104 	Total: 3511.3287 	Mean_train_accuracy: 0.7340
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 105 	Total: 3520.0868 	Mean_train_accuracy: 0.7328
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 106 	Total: 3510.2676 	Mean_train_accuracy: 0.7282
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 107 	Total: 3540.0148 	Mean_train_accuracy: 0.7228
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 108 	Total: 3601.0402 	Mean_train_accuracy: 0.7346
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4000
# Epoch: 109 	Total: 3582.0589 	Mean_train_accuracy: 0.7344
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 110 	Total: 3530.5782 	Mean_train_accuracy: 0.7316
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 111 	Total: 3502.6940 	Mean_train_accuracy: 0.7325
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 112 	Total: 3493.4519 	Mean_train_accuracy: 0.7311
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 113 	Total: 3495.4835 	Mean_train_accuracy: 0.7358
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 114 	Total: 3511.9471 	Mean_train_accuracy: 0.7208
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 115 	Total: 3504.2749 	Mean_train_accuracy: 0.7371
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 116 	Total: 3496.4509 	Mean_train_accuracy: 0.7342
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 117 	Total: 3506.2184 	Mean_train_accuracy: 0.7389
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 118 	Total: 3503.3549 	Mean_train_accuracy: 0.7415
# 	Mean_test_accuracy: 0.7183 	Mean_test_accuracy_sum: 0.4000
# Epoch: 119 	Total: 3529.2813 	Mean_train_accuracy: 0.7357
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 120 	Total: 3530.3372 	Mean_train_accuracy: 0.7320
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 121 	Total: 3526.9363 	Mean_train_accuracy: 0.7307
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 122 	Total: 3509.7669 	Mean_train_accuracy: 0.7265
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 123 	Total: 3520.5370 	Mean_train_accuracy: 0.7298
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 124 	Total: 3533.9162 	Mean_train_accuracy: 0.7235
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4000
# Epoch: 125 	Total: 3512.3351 	Mean_train_accuracy: 0.7242
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 126 	Total: 3526.8428 	Mean_train_accuracy: 0.7357
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 127 	Total: 3518.8836 	Mean_train_accuracy: 0.7398
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 128 	Total: 3509.0704 	Mean_train_accuracy: 0.7330
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 129 	Total: 3511.1691 	Mean_train_accuracy: 0.7308
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 130 	Total: 3515.8291 	Mean_train_accuracy: 0.7379
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 131 	Total: 3516.1817 	Mean_train_accuracy: 0.7383
# 	Mean_test_accuracy: 0.7433 	Mean_test_accuracy_sum: 0.4000
# Epoch: 132 	Total: 3509.9608 	Mean_train_accuracy: 0.7279
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 133 	Total: 3503.3932 	Mean_train_accuracy: 0.7330
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 134 	Total: 3502.9970 	Mean_train_accuracy: 0.7365
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 135 	Total: 3542.5501 	Mean_train_accuracy: 0.7391
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 136 	Total: 3524.5687 	Mean_train_accuracy: 0.7394
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 137 	Total: 3536.6753 	Mean_train_accuracy: 0.7282
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 138 	Total: 3506.2949 	Mean_train_accuracy: 0.7343
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 139 	Total: 3506.1552 	Mean_train_accuracy: 0.7283
# 	Mean_test_accuracy: 0.7400 	Mean_test_accuracy_sum: 0.4000
# Epoch: 140 	Total: 3554.5160 	Mean_train_accuracy: 0.7279
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 141 	Total: 3502.3550 	Mean_train_accuracy: 0.7292
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 142 	Total: 3512.5225 	Mean_train_accuracy: 0.7307
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 143 	Total: 3502.6177 	Mean_train_accuracy: 0.7277
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 144 	Total: 3514.4368 	Mean_train_accuracy: 0.7330
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 145 	Total: 3497.7692 	Mean_train_accuracy: 0.7315
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 146 	Total: 3531.7094 	Mean_train_accuracy: 0.7285
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 147 	Total: 3514.2383 	Mean_train_accuracy: 0.7376
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 148 	Total: 3519.2690 	Mean_train_accuracy: 0.7300
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 149 	Total: 3519.8243 	Mean_train_accuracy: 0.7270
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 150 	Total: 3509.3179 	Mean_train_accuracy: 0.7239
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 151 	Total: 3527.4368 	Mean_train_accuracy: 0.7275
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 152 	Total: 3501.2243 	Mean_train_accuracy: 0.7355
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 153 	Total: 3496.6908 	Mean_train_accuracy: 0.7389
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 154 	Total: 3532.6424 	Mean_train_accuracy: 0.7256
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4000
# Epoch: 155 	Total: 3525.2449 	Mean_train_accuracy: 0.7297
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 156 	Total: 3524.5844 	Mean_train_accuracy: 0.7368
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 157 	Total: 3511.2736 	Mean_train_accuracy: 0.7268
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4000
# Epoch: 158 	Total: 3520.8542 	Mean_train_accuracy: 0.7344
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 159 	Total: 3540.7713 	Mean_train_accuracy: 0.7297
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 160 	Total: 3557.8943 	Mean_train_accuracy: 0.7421
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 161 	Total: 3578.1339 	Mean_train_accuracy: 0.7306
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 162 	Total: 3500.8145 	Mean_train_accuracy: 0.7359
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 163 	Total: 3510.2653 	Mean_train_accuracy: 0.7216
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 164 	Total: 3498.6199 	Mean_train_accuracy: 0.7364
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 165 	Total: 3513.3546 	Mean_train_accuracy: 0.7327
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 166 	Total: 3512.9035 	Mean_train_accuracy: 0.7326
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 167 	Total: 3527.3815 	Mean_train_accuracy: 0.7351
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 168 	Total: 3521.5814 	Mean_train_accuracy: 0.7204
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 169 	Total: 3527.9102 	Mean_train_accuracy: 0.7293
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 170 	Total: 3517.9884 	Mean_train_accuracy: 0.7340
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 171 	Total: 3498.4534 	Mean_train_accuracy: 0.7343
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 172 	Total: 3494.4050 	Mean_train_accuracy: 0.7396
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 173 	Total: 3533.3024 	Mean_train_accuracy: 0.7306
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 174 	Total: 3510.9786 	Mean_train_accuracy: 0.7380
# 	Mean_test_accuracy: 0.7183 	Mean_test_accuracy_sum: 0.4000
# Epoch: 175 	Total: 3511.2240 	Mean_train_accuracy: 0.7331
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 176 	Total: 3529.2494 	Mean_train_accuracy: 0.7380
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 177 	Total: 3509.9316 	Mean_train_accuracy: 0.7428
# 	Mean_test_accuracy: 0.7400 	Mean_test_accuracy_sum: 0.4000
# Epoch: 178 	Total: 3496.6376 	Mean_train_accuracy: 0.7345
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 179 	Total: 3541.9501 	Mean_train_accuracy: 0.7305
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 180 	Total: 3519.6678 	Mean_train_accuracy: 0.7381
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 181 	Total: 3498.2863 	Mean_train_accuracy: 0.7324
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 182 	Total: 3555.4946 	Mean_train_accuracy: 0.7382
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 183 	Total: 3520.5952 	Mean_train_accuracy: 0.7328
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 184 	Total: 3511.8134 	Mean_train_accuracy: 0.7305
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 185 	Total: 3519.7782 	Mean_train_accuracy: 0.7297
# 	Mean_test_accuracy: 0.7183 	Mean_test_accuracy_sum: 0.4000
# Epoch: 186 	Total: 3544.7192 	Mean_train_accuracy: 0.7435
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 187 	Total: 3514.7225 	Mean_train_accuracy: 0.7291
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 188 	Total: 3497.2387 	Mean_train_accuracy: 0.7308
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 189 	Total: 3552.9924 	Mean_train_accuracy: 0.7328
# 	Mean_test_accuracy: 0.7117 	Mean_test_accuracy_sum: 0.4000
# Epoch: 190 	Total: 3560.5723 	Mean_train_accuracy: 0.7343
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 191 	Total: 3500.7403 	Mean_train_accuracy: 0.7345
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 192 	Total: 3543.4301 	Mean_train_accuracy: 0.7249
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 193 	Total: 3506.3783 	Mean_train_accuracy: 0.7291
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 194 	Total: 3499.8889 	Mean_train_accuracy: 0.7358
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 195 	Total: 3523.6268 	Mean_train_accuracy: 0.7302
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 196 	Total: 3507.0474 	Mean_train_accuracy: 0.7300
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 197 	Total: 3521.6399 	Mean_train_accuracy: 0.7384
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 198 	Total: 3539.2663 	Mean_train_accuracy: 0.7285
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 199 	Total: 3628.0175 	Mean_train_accuracy: 0.7284
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 200 	Total: 3516.3009 	Mean_train_accuracy: 0.7340
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 201 	Total: 3506.7778 	Mean_train_accuracy: 0.7370
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 202 	Total: 3524.5317 	Mean_train_accuracy: 0.7403
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 203 	Total: 3513.5369 	Mean_train_accuracy: 0.7386
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 204 	Total: 3510.8690 	Mean_train_accuracy: 0.7341
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 205 	Total: 3492.8001 	Mean_train_accuracy: 0.7317
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 206 	Total: 3501.4738 	Mean_train_accuracy: 0.7377
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 207 	Total: 3536.3601 	Mean_train_accuracy: 0.7251
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 208 	Total: 3520.7185 	Mean_train_accuracy: 0.7273
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 209 	Total: 3505.1489 	Mean_train_accuracy: 0.7321
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 210 	Total: 3514.1412 	Mean_train_accuracy: 0.7299
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 211 	Total: 3493.9876 	Mean_train_accuracy: 0.7312
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 212 	Total: 3508.5974 	Mean_train_accuracy: 0.7293
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 213 	Total: 3576.0643 	Mean_train_accuracy: 0.7298
# 	Mean_test_accuracy: 0.7117 	Mean_test_accuracy_sum: 0.4000
# Epoch: 214 	Total: 3597.2832 	Mean_train_accuracy: 0.7317
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 215 	Total: 3508.0359 	Mean_train_accuracy: 0.7311
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 216 	Total: 3507.6257 	Mean_train_accuracy: 0.7296
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 217 	Total: 3495.7251 	Mean_train_accuracy: 0.7314
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 218 	Total: 3503.5992 	Mean_train_accuracy: 0.7268
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 219 	Total: 3522.7847 	Mean_train_accuracy: 0.7202
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 220 	Total: 3515.6547 	Mean_train_accuracy: 0.7346
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 221 	Total: 3503.5399 	Mean_train_accuracy: 0.7391
# 	Mean_test_accuracy: 0.7183 	Mean_test_accuracy_sum: 0.4000
# Epoch: 222 	Total: 3501.8042 	Mean_train_accuracy: 0.7360
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 223 	Total: 3498.9575 	Mean_train_accuracy: 0.7350
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 224 	Total: 3507.4679 	Mean_train_accuracy: 0.7323
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 225 	Total: 3509.3141 	Mean_train_accuracy: 0.7333
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 226 	Total: 3515.4167 	Mean_train_accuracy: 0.7304
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 227 	Total: 3542.0066 	Mean_train_accuracy: 0.7357
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 228 	Total: 3510.3456 	Mean_train_accuracy: 0.7334
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 229 	Total: 3544.0602 	Mean_train_accuracy: 0.7278
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 230 	Total: 3593.9542 	Mean_train_accuracy: 0.7295
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 231 	Total: 3530.0318 	Mean_train_accuracy: 0.7379
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 232 	Total: 3523.8443 	Mean_train_accuracy: 0.7357
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 233 	Total: 3517.2813 	Mean_train_accuracy: 0.7393
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 234 	Total: 3522.6213 	Mean_train_accuracy: 0.7311
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 235 	Total: 3520.4114 	Mean_train_accuracy: 0.7284
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 236 	Total: 3498.3752 	Mean_train_accuracy: 0.7250
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 237 	Total: 3501.3182 	Mean_train_accuracy: 0.7354
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 238 	Total: 3502.0350 	Mean_train_accuracy: 0.7376
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 239 	Total: 3503.8946 	Mean_train_accuracy: 0.7302
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 240 	Total: 3492.5414 	Mean_train_accuracy: 0.7355
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 241 	Total: 3501.7726 	Mean_train_accuracy: 0.7344
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 242 	Total: 3517.6905 	Mean_train_accuracy: 0.7315
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 243 	Total: 3521.6228 	Mean_train_accuracy: 0.7319
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 244 	Total: 3538.6611 	Mean_train_accuracy: 0.7378
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 245 	Total: 3507.0328 	Mean_train_accuracy: 0.7326
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 246 	Total: 3578.0525 	Mean_train_accuracy: 0.7369
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 247 	Total: 3501.8401 	Mean_train_accuracy: 0.7285
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 248 	Total: 3509.6698 	Mean_train_accuracy: 0.7286
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4000
# Epoch: 249 	Total: 3504.4125 	Mean_train_accuracy: 0.7295
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4000
# Epoch: 250 	Total: 3505.7373 	Mean_train_accuracy: 0.7236
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 251 	Total: 3508.4383 	Mean_train_accuracy: 0.7307
# 	Mean_test_accuracy: 0.7400 	Mean_test_accuracy_sum: 0.4000
# Epoch: 252 	Total: 3513.3306 	Mean_train_accuracy: 0.7377
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 253 	Total: 3495.3942 	Mean_train_accuracy: 0.7301
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 254 	Total: 3506.7641 	Mean_train_accuracy: 0.7332
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 255 	Total: 3569.4179 	Mean_train_accuracy: 0.7300
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 256 	Total: 3509.2269 	Mean_train_accuracy: 0.7355
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 257 	Total: 3496.6011 	Mean_train_accuracy: 0.7286
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 258 	Total: 3491.3210 	Mean_train_accuracy: 0.7361
# 	Mean_test_accuracy: 0.7167 	Mean_test_accuracy_sum: 0.4000
# Epoch: 259 	Total: 3492.4709 	Mean_train_accuracy: 0.7350
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 260 	Total: 3499.0006 	Mean_train_accuracy: 0.7283
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 261 	Total: 3519.2243 	Mean_train_accuracy: 0.7378
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 262 	Total: 3510.7670 	Mean_train_accuracy: 0.7366
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 263 	Total: 3509.3197 	Mean_train_accuracy: 0.7348
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 264 	Total: 3508.0936 	Mean_train_accuracy: 0.7371
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 265 	Total: 3525.3144 	Mean_train_accuracy: 0.7350
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 266 	Total: 3521.1576 	Mean_train_accuracy: 0.7317
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 267 	Total: 3556.3594 	Mean_train_accuracy: 0.7225
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 268 	Total: 3604.0684 	Mean_train_accuracy: 0.7336
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 269 	Total: 3511.4462 	Mean_train_accuracy: 0.7355
# 	Mean_test_accuracy: 0.7150 	Mean_test_accuracy_sum: 0.4000
# Epoch: 270 	Total: 3540.7907 	Mean_train_accuracy: 0.7205
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 271 	Total: 3513.3180 	Mean_train_accuracy: 0.7264
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 272 	Total: 3500.7451 	Mean_train_accuracy: 0.7332
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 273 	Total: 3515.2372 	Mean_train_accuracy: 0.7335
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 274 	Total: 3494.6832 	Mean_train_accuracy: 0.7382
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 275 	Total: 3498.1369 	Mean_train_accuracy: 0.7333
# 	Mean_test_accuracy: 0.7400 	Mean_test_accuracy_sum: 0.4000
# Epoch: 276 	Total: 3510.9520 	Mean_train_accuracy: 0.7354
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 277 	Total: 3515.8580 	Mean_train_accuracy: 0.7285
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 278 	Total: 3511.2278 	Mean_train_accuracy: 0.7302
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 279 	Total: 3504.8793 	Mean_train_accuracy: 0.7351
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 280 	Total: 3507.9481 	Mean_train_accuracy: 0.7299
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 281 	Total: 3512.2873 	Mean_train_accuracy: 0.7347
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 282 	Total: 3498.4886 	Mean_train_accuracy: 0.7232
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 283 	Total: 3499.8761 	Mean_train_accuracy: 0.7269
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 284 	Total: 3537.8819 	Mean_train_accuracy: 0.7323
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 285 	Total: 3503.9394 	Mean_train_accuracy: 0.7393
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 286 	Total: 3517.6900 	Mean_train_accuracy: 0.7328
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 287 	Total: 3503.3515 	Mean_train_accuracy: 0.7262
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 288 	Total: 3517.5592 	Mean_train_accuracy: 0.7320
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 289 	Total: 3514.2568 	Mean_train_accuracy: 0.7363
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 290 	Total: 3501.8099 	Mean_train_accuracy: 0.7277
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 291 	Total: 3515.8750 	Mean_train_accuracy: 0.7274
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 292 	Total: 3513.5542 	Mean_train_accuracy: 0.7283
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 293 	Total: 3517.3358 	Mean_train_accuracy: 0.7321
# 	Mean_test_accuracy: 0.7150 	Mean_test_accuracy_sum: 0.4000
# Epoch: 294 	Total: 3536.0122 	Mean_train_accuracy: 0.7331
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 295 	Total: 3531.0322 	Mean_train_accuracy: 0.7344
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 296 	Total: 3517.5960 	Mean_train_accuracy: 0.7242
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 297 	Total: 3509.9687 	Mean_train_accuracy: 0.7426
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 298 	Total: 3494.3896 	Mean_train_accuracy: 0.7345
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 299 	Total: 3498.6873 	Mean_train_accuracy: 0.7308
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 300 	Total: 3528.9724 	Mean_train_accuracy: 0.7277
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 301 	Total: 3511.4386 	Mean_train_accuracy: 0.7333
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 302 	Total: 3498.7279 	Mean_train_accuracy: 0.7245
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 303 	Total: 3511.9186 	Mean_train_accuracy: 0.7385
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 304 	Total: 3540.0742 	Mean_train_accuracy: 0.7351
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 305 	Total: 3519.1778 	Mean_train_accuracy: 0.7344
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 306 	Total: 3510.8291 	Mean_train_accuracy: 0.7249
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 307 	Total: 3519.5562 	Mean_train_accuracy: 0.7390
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 308 	Total: 3509.8323 	Mean_train_accuracy: 0.7366
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 309 	Total: 3543.9888 	Mean_train_accuracy: 0.7340
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 310 	Total: 3542.3831 	Mean_train_accuracy: 0.7390
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 311 	Total: 3501.8703 	Mean_train_accuracy: 0.7333
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 312 	Total: 3508.4551 	Mean_train_accuracy: 0.7275
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 313 	Total: 3500.3152 	Mean_train_accuracy: 0.7331
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 314 	Total: 3499.0919 	Mean_train_accuracy: 0.7308
# 	Mean_test_accuracy: 0.7183 	Mean_test_accuracy_sum: 0.4000
# Epoch: 315 	Total: 3499.9444 	Mean_train_accuracy: 0.7349
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 316 	Total: 3495.5732 	Mean_train_accuracy: 0.7345
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 317 	Total: 3496.9614 	Mean_train_accuracy: 0.7323
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 318 	Total: 3500.2639 	Mean_train_accuracy: 0.7315
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4000
# Epoch: 319 	Total: 3514.7687 	Mean_train_accuracy: 0.7297
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 320 	Total: 3510.6585 	Mean_train_accuracy: 0.7349
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 321 	Total: 3500.6091 	Mean_train_accuracy: 0.7400
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 322 	Total: 3493.4243 	Mean_train_accuracy: 0.7394
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 323 	Total: 3514.8894 	Mean_train_accuracy: 0.7309
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 324 	Total: 3521.8791 	Mean_train_accuracy: 0.7272
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 325 	Total: 3498.4274 	Mean_train_accuracy: 0.7357
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 326 	Total: 3488.9749 	Mean_train_accuracy: 0.7350
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 327 	Total: 3493.7862 	Mean_train_accuracy: 0.7328
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 328 	Total: 3538.6104 	Mean_train_accuracy: 0.7241
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 329 	Total: 3525.4950 	Mean_train_accuracy: 0.7397
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 330 	Total: 3548.0158 	Mean_train_accuracy: 0.7327
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 331 	Total: 3541.6174 	Mean_train_accuracy: 0.7315
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 332 	Total: 3491.1229 	Mean_train_accuracy: 0.7366
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 333 	Total: 3491.3096 	Mean_train_accuracy: 0.7293
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 334 	Total: 3495.7699 	Mean_train_accuracy: 0.7334
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 335 	Total: 3544.2441 	Mean_train_accuracy: 0.7302
# 	Mean_test_accuracy: 0.7417 	Mean_test_accuracy_sum: 0.4000
# Epoch: 336 	Total: 3513.7617 	Mean_train_accuracy: 0.7291
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 337 	Total: 3581.4848 	Mean_train_accuracy: 0.7385
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 338 	Total: 3803.2474 	Mean_train_accuracy: 0.7238
# 	Mean_test_accuracy: 0.7117 	Mean_test_accuracy_sum: 0.4000
# Epoch: 339 	Total: 3546.8833 	Mean_train_accuracy: 0.7273
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 340 	Total: 3525.7220 	Mean_train_accuracy: 0.7298
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 341 	Total: 3495.6889 	Mean_train_accuracy: 0.7331
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 342 	Total: 3491.4577 	Mean_train_accuracy: 0.7268
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 343 	Total: 3499.6454 	Mean_train_accuracy: 0.7379
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 344 	Total: 3489.5010 	Mean_train_accuracy: 0.7334
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 345 	Total: 3506.4833 	Mean_train_accuracy: 0.7366
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 346 	Total: 3506.7480 	Mean_train_accuracy: 0.7250
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 347 	Total: 3521.3929 	Mean_train_accuracy: 0.7376
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 348 	Total: 3571.4752 	Mean_train_accuracy: 0.7325
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 349 	Total: 3533.5880 	Mean_train_accuracy: 0.7351
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 350 	Total: 3495.8528 	Mean_train_accuracy: 0.7302
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 351 	Total: 3507.6402 	Mean_train_accuracy: 0.7364
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 352 	Total: 3507.6785 	Mean_train_accuracy: 0.7383
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 353 	Total: 3493.4277 	Mean_train_accuracy: 0.7334
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 354 	Total: 3491.4972 	Mean_train_accuracy: 0.7312
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 355 	Total: 3498.9373 	Mean_train_accuracy: 0.7295
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 356 	Total: 3491.2756 	Mean_train_accuracy: 0.7353
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 357 	Total: 3495.2751 	Mean_train_accuracy: 0.7308
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 358 	Total: 3502.2701 	Mean_train_accuracy: 0.7290
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 359 	Total: 3513.5356 	Mean_train_accuracy: 0.7303
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 360 	Total: 3504.3672 	Mean_train_accuracy: 0.7330
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 361 	Total: 3497.7883 	Mean_train_accuracy: 0.7339
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 362 	Total: 3493.8578 	Mean_train_accuracy: 0.7420
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 363 	Total: 3591.2828 	Mean_train_accuracy: 0.7335
# 	Mean_test_accuracy: 0.7167 	Mean_test_accuracy_sum: 0.4000
# Epoch: 364 	Total: 3536.2299 	Mean_train_accuracy: 0.7222
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 365 	Total: 3550.5016 	Mean_train_accuracy: 0.7259
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 366 	Total: 3512.5387 	Mean_train_accuracy: 0.7346
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 367 	Total: 3517.9567 	Mean_train_accuracy: 0.7303
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 368 	Total: 3495.7996 	Mean_train_accuracy: 0.7331
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 369 	Total: 3487.4335 	Mean_train_accuracy: 0.7405
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 370 	Total: 3496.6759 	Mean_train_accuracy: 0.7370
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 371 	Total: 3551.8623 	Mean_train_accuracy: 0.7282
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4000
# Epoch: 372 	Total: 3539.6042 	Mean_train_accuracy: 0.7289
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4000
# Epoch: 373 	Total: 3499.4251 	Mean_train_accuracy: 0.7350
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 374 	Total: 3488.3969 	Mean_train_accuracy: 0.7339
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 375 	Total: 3515.4585 	Mean_train_accuracy: 0.7370
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 376 	Total: 3491.7768 	Mean_train_accuracy: 0.7310
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 377 	Total: 3489.8273 	Mean_train_accuracy: 0.7339
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 378 	Total: 3495.3199 	Mean_train_accuracy: 0.7285
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 379 	Total: 3513.1600 	Mean_train_accuracy: 0.7345
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 380 	Total: 3508.4283 	Mean_train_accuracy: 0.7421
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 381 	Total: 3536.4391 	Mean_train_accuracy: 0.7307
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 382 	Total: 3492.7615 	Mean_train_accuracy: 0.7372
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 383 	Total: 3531.2590 	Mean_train_accuracy: 0.7331
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 384 	Total: 3534.2106 	Mean_train_accuracy: 0.7348
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 385 	Total: 3521.7629 	Mean_train_accuracy: 0.7378
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4000
# Epoch: 386 	Total: 3502.1034 	Mean_train_accuracy: 0.7295
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 387 	Total: 3519.2823 	Mean_train_accuracy: 0.7290
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 388 	Total: 3539.0398 	Mean_train_accuracy: 0.7351
# 	Mean_test_accuracy: 0.7167 	Mean_test_accuracy_sum: 0.4000
# Epoch: 389 	Total: 3516.3803 	Mean_train_accuracy: 0.7331
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 390 	Total: 3502.4613 	Mean_train_accuracy: 0.7222
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 391 	Total: 3498.6996 	Mean_train_accuracy: 0.7325
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 392 	Total: 3502.7237 	Mean_train_accuracy: 0.7428
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 393 	Total: 3502.1433 	Mean_train_accuracy: 0.7308
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 394 	Total: 3534.1688 	Mean_train_accuracy: 0.7406
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 395 	Total: 3546.4579 	Mean_train_accuracy: 0.7397
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 396 	Total: 3494.9474 	Mean_train_accuracy: 0.7358
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 397 	Total: 3490.7701 	Mean_train_accuracy: 0.7332
# 	Mean_test_accuracy: 0.7183 	Mean_test_accuracy_sum: 0.4000
# Epoch: 398 	Total: 3517.4119 	Mean_train_accuracy: 0.7271
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 399 	Total: 3539.9384 	Mean_train_accuracy: 0.7356
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 400 	Total: 3515.1885 	Mean_train_accuracy: 0.7326
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 401 	Total: 3525.8243 	Mean_train_accuracy: 0.7364
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 402 	Total: 3499.2644 	Mean_train_accuracy: 0.7407
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 403 	Total: 3499.1560 	Mean_train_accuracy: 0.7329
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 404 	Total: 3493.5412 	Mean_train_accuracy: 0.7396
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 405 	Total: 3506.1774 	Mean_train_accuracy: 0.7360
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 406 	Total: 3510.2718 	Mean_train_accuracy: 0.7389
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 407 	Total: 3532.6782 	Mean_train_accuracy: 0.7321
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 408 	Total: 3528.4221 	Mean_train_accuracy: 0.7272
# ...
# Epoch: 1867 	Total: 3483.0142 	Mean_train_accuracy: 0.7374
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1868 	Total: 3476.8216 	Mean_train_accuracy: 0.7353
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1869 	Total: 3480.0529 	Mean_train_accuracy: 0.7355
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1870 	Total: 3474.2270 	Mean_train_accuracy: 0.7291
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1871 	Total: 3466.8387 	Mean_train_accuracy: 0.7329
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1872 	Total: 3466.0501 	Mean_train_accuracy: 0.7361
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1873 	Total: 3460.3954 	Mean_train_accuracy: 0.7350
# 	Mean_test_accuracy: 0.7450 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1874 	Total: 3483.0170 	Mean_train_accuracy: 0.7473
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1875 	Total: 3476.5611 	Mean_train_accuracy: 0.7312
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1876 	Total: 3471.0081 	Mean_train_accuracy: 0.7409
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1877 	Total: 3472.5084 	Mean_train_accuracy: 0.7335
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1878 	Total: 3474.6976 	Mean_train_accuracy: 0.7304
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1879 	Total: 3475.3393 	Mean_train_accuracy: 0.7396
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1880 	Total: 3478.1880 	Mean_train_accuracy: 0.7358
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1881 	Total: 3488.7373 	Mean_train_accuracy: 0.7423
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1882 	Total: 3549.6753 	Mean_train_accuracy: 0.7414
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1883 	Total: 3520.2011 	Mean_train_accuracy: 0.7264
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1884 	Total: 3487.8371 	Mean_train_accuracy: 0.7356
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1885 	Total: 3486.7468 	Mean_train_accuracy: 0.7291
# 	Mean_test_accuracy: 0.7400 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1886 	Total: 3476.3176 	Mean_train_accuracy: 0.7290
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1887 	Total: 3467.3931 	Mean_train_accuracy: 0.7320
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1888 	Total: 3467.5962 	Mean_train_accuracy: 0.7382
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1889 	Total: 3479.2465 	Mean_train_accuracy: 0.7322
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1890 	Total: 3478.3060 	Mean_train_accuracy: 0.7449
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1891 	Total: 3474.1749 	Mean_train_accuracy: 0.7331
# 	Mean_test_accuracy: 0.7400 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1892 	Total: 3473.7062 	Mean_train_accuracy: 0.7315
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1893 	Total: 3529.1002 	Mean_train_accuracy: 0.7458
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1894 	Total: 3486.7980 	Mean_train_accuracy: 0.7380
# 	Mean_test_accuracy: 0.7167 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1895 	Total: 3467.0257 	Mean_train_accuracy: 0.7372
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1896 	Total: 3463.2097 	Mean_train_accuracy: 0.7336
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1897 	Total: 3460.8376 	Mean_train_accuracy: 0.7348
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1898 	Total: 3467.8912 	Mean_train_accuracy: 0.7380
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1899 	Total: 3464.2101 	Mean_train_accuracy: 0.7353
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1900 	Total: 3464.1538 	Mean_train_accuracy: 0.7416
# 	Mean_test_accuracy: 0.7417 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1901 	Total: 3523.6771 	Mean_train_accuracy: 0.7444
# 	Mean_test_accuracy: 0.7150 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1902 	Total: 3489.8928 	Mean_train_accuracy: 0.7332
# 	Mean_test_accuracy: 0.7400 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1903 	Total: 3484.8615 	Mean_train_accuracy: 0.7467
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1904 	Total: 3470.7295 	Mean_train_accuracy: 0.7350
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1905 	Total: 3479.5013 	Mean_train_accuracy: 0.7299
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1906 	Total: 3522.7933 	Mean_train_accuracy: 0.7368
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1907 	Total: 3467.5324 	Mean_train_accuracy: 0.7360
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1908 	Total: 3478.6983 	Mean_train_accuracy: 0.7427
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1909 	Total: 3495.0067 	Mean_train_accuracy: 0.7319
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1910 	Total: 3479.6442 	Mean_train_accuracy: 0.7339
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1911 	Total: 3472.8911 	Mean_train_accuracy: 0.7354
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1912 	Total: 3480.2207 	Mean_train_accuracy: 0.7383
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1913 	Total: 3463.2737 	Mean_train_accuracy: 0.7435
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1914 	Total: 3469.7588 	Mean_train_accuracy: 0.7397
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1915 	Total: 3498.7733 	Mean_train_accuracy: 0.7431
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1916 	Total: 3504.9587 	Mean_train_accuracy: 0.7342
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1917 	Total: 3519.9043 	Mean_train_accuracy: 0.7235
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1918 	Total: 3496.0009 	Mean_train_accuracy: 0.7391
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1919 	Total: 3473.8765 	Mean_train_accuracy: 0.7374
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1920 	Total: 3490.7830 	Mean_train_accuracy: 0.7346
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1921 	Total: 3534.3671 	Mean_train_accuracy: 0.7359
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1922 	Total: 3485.9360 	Mean_train_accuracy: 0.7421
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1923 	Total: 3477.5482 	Mean_train_accuracy: 0.7473
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1924 	Total: 3473.1686 	Mean_train_accuracy: 0.7363
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1925 	Total: 3468.0898 	Mean_train_accuracy: 0.7348
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1926 	Total: 3462.3185 	Mean_train_accuracy: 0.7342
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1927 	Total: 3483.8847 	Mean_train_accuracy: 0.7247
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1928 	Total: 3472.3588 	Mean_train_accuracy: 0.7430
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1929 	Total: 3456.6391 	Mean_train_accuracy: 0.7398
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1930 	Total: 3456.7338 	Mean_train_accuracy: 0.7355
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1931 	Total: 3467.2446 	Mean_train_accuracy: 0.7360
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1932 	Total: 3523.5148 	Mean_train_accuracy: 0.7292
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1933 	Total: 3522.9334 	Mean_train_accuracy: 0.7306
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1934 	Total: 3474.8765 	Mean_train_accuracy: 0.7379
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1935 	Total: 3477.4193 	Mean_train_accuracy: 0.7341
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1936 	Total: 3493.4116 	Mean_train_accuracy: 0.7352
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1937 	Total: 3491.7077 	Mean_train_accuracy: 0.7390
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1938 	Total: 3474.4726 	Mean_train_accuracy: 0.7353
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1939 	Total: 3504.2840 	Mean_train_accuracy: 0.7382
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1940 	Total: 3470.4198 	Mean_train_accuracy: 0.7454
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1941 	Total: 3461.6261 	Mean_train_accuracy: 0.7405
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1942 	Total: 3474.6434 	Mean_train_accuracy: 0.7288
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1943 	Total: 3482.1691 	Mean_train_accuracy: 0.7396
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1944 	Total: 3488.5370 	Mean_train_accuracy: 0.7310
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1945 	Total: 3493.9423 	Mean_train_accuracy: 0.7365
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1946 	Total: 3488.5841 	Mean_train_accuracy: 0.7439
# 	Mean_test_accuracy: 0.7200 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1947 	Total: 3476.2803 	Mean_train_accuracy: 0.7322
# 	Mean_test_accuracy: 0.7417 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1948 	Total: 3466.7156 	Mean_train_accuracy: 0.7342
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1949 	Total: 3460.1814 	Mean_train_accuracy: 0.7407
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1950 	Total: 3460.7440 	Mean_train_accuracy: 0.7378
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1951 	Total: 3478.9100 	Mean_train_accuracy: 0.7331
# 	Mean_test_accuracy: 0.7417 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1952 	Total: 3518.4371 	Mean_train_accuracy: 0.7430
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1953 	Total: 3497.8486 	Mean_train_accuracy: 0.7311
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1954 	Total: 3480.9277 	Mean_train_accuracy: 0.7320
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1955 	Total: 3472.8307 	Mean_train_accuracy: 0.7326
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1956 	Total: 3466.8088 	Mean_train_accuracy: 0.7377
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1957 	Total: 3511.0094 	Mean_train_accuracy: 0.7323
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1958 	Total: 3487.2848 	Mean_train_accuracy: 0.7403
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1959 	Total: 3465.4827 	Mean_train_accuracy: 0.7372
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1960 	Total: 3466.1418 	Mean_train_accuracy: 0.7332
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1961 	Total: 3488.6644 	Mean_train_accuracy: 0.7343
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1962 	Total: 3542.6154 	Mean_train_accuracy: 0.7328
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1963 	Total: 3493.1597 	Mean_train_accuracy: 0.7417
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1964 	Total: 3469.7780 	Mean_train_accuracy: 0.7374
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1965 	Total: 3462.8049 	Mean_train_accuracy: 0.7377
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1966 	Total: 3485.1105 	Mean_train_accuracy: 0.7446
# 	Mean_test_accuracy: 0.7333 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1967 	Total: 3463.4726 	Mean_train_accuracy: 0.7347
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1968 	Total: 3497.0015 	Mean_train_accuracy: 0.7292
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1969 	Total: 3488.2602 	Mean_train_accuracy: 0.7310
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1970 	Total: 3498.9419 	Mean_train_accuracy: 0.7333
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1971 	Total: 3484.5615 	Mean_train_accuracy: 0.7330
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1972 	Total: 3474.0183 	Mean_train_accuracy: 0.7297
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1973 	Total: 3488.7106 	Mean_train_accuracy: 0.7357
# 	Mean_test_accuracy: 0.7400 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1974 	Total: 3466.4222 	Mean_train_accuracy: 0.7371
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1975 	Total: 3465.8358 	Mean_train_accuracy: 0.7395
# 	Mean_test_accuracy: 0.7250 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1976 	Total: 3477.5813 	Mean_train_accuracy: 0.7352
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1977 	Total: 3460.5992 	Mean_train_accuracy: 0.7319
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1978 	Total: 3479.2937 	Mean_train_accuracy: 0.7415
# 	Mean_test_accuracy: 0.7217 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1979 	Total: 3483.2559 	Mean_train_accuracy: 0.7358
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1980 	Total: 3485.8850 	Mean_train_accuracy: 0.7316
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1981 	Total: 3482.3119 	Mean_train_accuracy: 0.7384
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1982 	Total: 3482.7958 	Mean_train_accuracy: 0.7344
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1983 	Total: 3503.9166 	Mean_train_accuracy: 0.7314
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1984 	Total: 3490.2599 	Mean_train_accuracy: 0.7364
# 	Mean_test_accuracy: 0.7300 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1985 	Total: 3483.2668 	Mean_train_accuracy: 0.7330
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1986 	Total: 3458.4742 	Mean_train_accuracy: 0.7423
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1987 	Total: 3468.6846 	Mean_train_accuracy: 0.7298
# 	Mean_test_accuracy: 0.7383 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1988 	Total: 3483.6588 	Mean_train_accuracy: 0.7376
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1989 	Total: 3475.7147 	Mean_train_accuracy: 0.7311
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1990 	Total: 3487.1202 	Mean_train_accuracy: 0.7332
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1991 	Total: 3501.5830 	Mean_train_accuracy: 0.7339
# 	Mean_test_accuracy: 0.7233 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1992 	Total: 3458.0861 	Mean_train_accuracy: 0.7385
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1993 	Total: 3467.9496 	Mean_train_accuracy: 0.7268
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1994 	Total: 3473.7723 	Mean_train_accuracy: 0.7397
# 	Mean_test_accuracy: 0.7367 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1995 	Total: 3485.1050 	Mean_train_accuracy: 0.7373
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1996 	Total: 3477.6993 	Mean_train_accuracy: 0.7348
# 	Mean_test_accuracy: 0.7317 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1997 	Total: 3473.3156 	Mean_train_accuracy: 0.7389
# 	Mean_test_accuracy: 0.7267 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1998 	Total: 3494.6726 	Mean_train_accuracy: 0.7284
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
# Epoch: 1999 	Total: 3531.4073 	Mean_train_accuracy: 0.7322
# 	Mean_test_accuracy: 0.7350 	Mean_test_accuracy_sum: 0.4000
# Epoch: 2000 	Total: 3512.5636 	Mean_train_accuracy: 0.7351
# 	Mean_test_accuracy: 0.7283 	Mean_test_accuracy_sum: 0.4000
