# %%
import torch
pwd = '/home/zjy/project/MetaIM/data'
device = torch.device('cuda:4' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=4)

# %%
from torch_geometric.datasets import Planetoid

cora_dataset = Planetoid(root=pwd+'/cora', name='cora')
data = cora_dataset[0]
edge_index = data.edge_index

# %%
import numpy as np
individual_infection_path = pwd+'/for_meta/cora_individual_infection_sir_100.npy'
seeds_infection_path = pwd+'/for_meta/cora_seed_infection_sir_100.npy'

individual_infection = np.load(individual_infection_path)
seeds_infection = np.load(seeds_infection_path)
individual_infection.shape,seeds_infection.shape
# Out:
# ((2708, 2708), (500, 2, 2708))

# %%
import torch
from torch_geometric.utils import to_scipy_sparse_matrix
import scipy.sparse as sp

# 转换为 scipy 稀疏矩阵
adj = to_scipy_sparse_matrix(edge_index)


# def normalize_adj(mx):
#     """Row-normalize sparse matrix"""
#     rowsum = np.array(mx.sum(1))
#     r_inv_sqrt = np.power(rowsum, -0.5).flatten()
#     r_inv_sqrt[np.isinf(r_inv_sqrt)] = 0.
#     r_mat_inv_sqrt = sp.diags(r_inv_sqrt)
#     return mx.dot(r_mat_inv_sqrt).transpose().dot(r_mat_inv_sqrt)



# adj = adj + adj.T.multiply(adj.T > adj) - adj.multiply(adj.T > adj)
# adj = normalize_adj(adj + sp.eye(adj.shape[0]))
adj = torch.Tensor(adj.toarray()).to_sparse()
adj
# Out:
# tensor(indices=tensor([[   0,    0,    0,  ..., 2707, 2707, 2707],
#                        [ 633, 1862, 2582,  ...,  598, 1473, 2706]]),
#        values=tensor([1., 1., 1.,  ..., 1., 1., 1.]),
#        size=(2708, 2708), nnz=10556, layout=torch.sparse_coo)

# %%
feat_num = int(seeds_infection[0][0].sum())

# %%
from torch.utils.data import Dataset, DataLoader, random_split


class CustomDataset(Dataset):
    def __init__(self, individual_infection,seeds_infection, feat_num):
        self.individual_infection = individual_infection
        self.seeds_infection = seeds_infection
        self.feat_shape = (len(individual_infection), feat_num)

    def __len__(self):
        return len(self.seeds_infection)

    def __getitem__(self, idx):
        seeds= np.nonzero(self.seeds_infection[idx][0])[0]
        
        feature = torch.zeros(self.feat_shape[0],self.feat_shape[1])
        for i in range(len(seeds)):
            seed_i_infection = torch.tensor(self.individual_infection[seeds[i]])
            feature[:, i] = seed_i_infection
            
        label = self.seeds_infection[idx][1]
        
        return feature, label

dataset = CustomDataset(individual_infection,seeds_infection,feat_num)

# %%
# 定义划分比例
train_ratio = 0.8
test_ratio = 0.2

# 划分数据集
train_dataset, test_dataset = random_split(dataset, [int(len(dataset)*train_ratio), int(len(dataset)*test_ratio)])

train_batch_size = 64
test_batch_size = 4

# 创建数据加载器
train_loader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True, drop_last=False)
test_loader = DataLoader(test_dataset, batch_size=test_batch_size, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv

class GAT(nn.Module):
    def __init__(self, in_channels, hidden_channels, out_channels, num_heads):
        super(GAT, self).__init__()
        self.conv1 = GATConv(in_channels, hidden_channels, heads=num_heads)
        # self.conv2 = GATConv(hidden_channels * num_heads, hidden_channels * num_heads, heads=1)
        self.conv3 = GATConv(hidden_channels * num_heads, out_channels, heads=1)

    def forward(self, x, edge_index):
        x = F.dropout(x, p=0.2, training=self.training)
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, p=0.2, training=self.training)
        # x = F.elu(self.conv2(x, edge_index))
        
        x = self.conv3(x, edge_index)
        return F.relu(x)

# %%
# from data.model.gat import GAT, SpGAT
from torch.optim import Adam, SGD


# forward_model = SpGAT(nfeat=feat_num, 
#                 nhid=64, 
#                 nclass=1, 
#                 dropout=0.2, 
#                 nheads=1, 
#                 alpha=0.2)
forward_model = GAT(feat_num, 256, 1, 1)

optimizer = Adam([{'params': forward_model.parameters()}], 
                 lr=1e-3)

adj = adj.to(device)
forward_model = forward_model.to(device)
forward_model.train()
# Out:
# GAT(
#   (conv1): GATConv(135, 256, heads=1)
#   (conv3): GATConv(256, 1, heads=1)
# )

# %%
edge_index = edge_index.to(device)
top_num = 300

for epoch in range(2000):

    total_overall = 0
    forward_loss = 0

    mean_train_accuracy = 0
    for batch_idx, feature_label in enumerate(train_loader):        
        features = feature_label[0].to(device)
        labels = feature_label[1].to(device)
        optimizer.zero_grad()
        
        loss = 0
        train_accuracy = 0
        for i, x_i in enumerate(features):
            y_i = labels[i]
            y_hat = forward_model(x_i, edge_index)
            _, top_indices_true = torch.topk(y_i.clone(), top_num)
            
            _, top_indices_predict = torch.topk(y_hat.clone().squeeze(-1), top_num)
            
            # 将张量数组转换为Python列表
            list1 = top_indices_true.tolist()
            list_pre = top_indices_predict.tolist()

            # 使用集合操作找到交集
            intersection = list(set(list1) & set(list_pre))
            accuracy_i = len(intersection) / top_num       
            train_accuracy += accuracy_i 

            forward_loss = F.mse_loss(y_hat.squeeze(-1), y_i, reduction='sum')        
            loss += forward_loss    
        
        total_overall += loss.item()    
        train_accuracy /= len(features)
        mean_train_accuracy = train_accuracy
        loss.backward()
        optimizer.step()
        # for p in forward_model.parameters():
        #     p.data.clamp_(min=0)
        
        
    print("Epoch: {}".format(epoch+1), 
        "\tTotal: {:.4f}".format(total_overall / train_batch_size),
        "\tMean_train_accuracy: {:.4f}".format(mean_train_accuracy),
        )  
    
    mean_accuracy = 0
    mean_accuracy_sum = 0

    
    for batch_idx, feature_label in enumerate(test_loader):   
        features = feature_label[0].to(device)
        labels = feature_label[1].to(device)
        
        accuracy = 0
        accuracy_sum = 0
        
        for i, x_i in enumerate(features):
            y_i = labels[i]
            _, top_indices_true = torch.topk(y_i, top_num)
            
            y_hat = forward_model(x_i, edge_index)
            
            _, top_indices_predict = torch.topk(y_hat.squeeze(-1), top_num)
            
            sum_pre = torch.sum(x_i, dim=1, keepdim=True)
            _, top_indices_sum = torch.topk(sum_pre.squeeze(-1), top_num)
            
            # 将张量数组转换为Python列表
            list1 = top_indices_true.tolist()
            list_pre = top_indices_predict.tolist()
            
            list_sum = top_indices_sum.tolist()

            # 使用集合操作找到交集
            intersection = list(set(list1) & set(list_pre))
            
            intersection_sum = list(set(list1) & set(list_sum))
            
            accuracy_i = len(intersection) / top_num       
            accuracy += accuracy_i 
            accuracy_sum += len(intersection_sum) / top_num  
        accuracy /= test_batch_size
        accuracy_sum/= test_batch_size
        mean_accuracy = accuracy
        mean_accuracy_sum = accuracy_sum
        break
    
    print(
        "\tMean_test_accuracy: {:.4f}".format(mean_accuracy),
        "\tMean_test_accuracy_sum: {:.4f}".format(mean_accuracy_sum)
        )
# Out:
# Epoch: 1 	Total: 828.4900 	Mean_train_accuracy: 0.3056
# 	Mean_test_accuracy: 0.2867 	Mean_test_accuracy_sum: 0.3600
# Epoch: 2 	Total: 759.7836 	Mean_train_accuracy: 0.3113
# 	Mean_test_accuracy: 0.2817 	Mean_test_accuracy_sum: 0.3600
# Epoch: 3 	Total: 731.7962 	Mean_train_accuracy: 0.3575
# 	Mean_test_accuracy: 0.3208 	Mean_test_accuracy_sum: 0.3600
# Epoch: 4 	Total: 708.8499 	Mean_train_accuracy: 0.3312
# 	Mean_test_accuracy: 0.3358 	Mean_test_accuracy_sum: 0.3600
# Epoch: 5 	Total: 692.7156 	Mean_train_accuracy: 0.3585
# 	Mean_test_accuracy: 0.3675 	Mean_test_accuracy_sum: 0.3600
# Epoch: 6 	Total: 678.1318 	Mean_train_accuracy: 0.3837
# 	Mean_test_accuracy: 0.3925 	Mean_test_accuracy_sum: 0.3600
# Epoch: 7 	Total: 666.0510 	Mean_train_accuracy: 0.3831
# 	Mean_test_accuracy: 0.3775 	Mean_test_accuracy_sum: 0.3600
# Epoch: 8 	Total: 654.7167 	Mean_train_accuracy: 0.4088
# 	Mean_test_accuracy: 0.4242 	Mean_test_accuracy_sum: 0.3600
# Epoch: 9 	Total: 644.5070 	Mean_train_accuracy: 0.4231
# 	Mean_test_accuracy: 0.4242 	Mean_test_accuracy_sum: 0.3600
# Epoch: 10 	Total: 634.8721 	Mean_train_accuracy: 0.4396
# 	Mean_test_accuracy: 0.4400 	Mean_test_accuracy_sum: 0.3600
# Epoch: 11 	Total: 625.4287 	Mean_train_accuracy: 0.4527
# 	Mean_test_accuracy: 0.4383 	Mean_test_accuracy_sum: 0.3600
# Epoch: 12 	Total: 616.5961 	Mean_train_accuracy: 0.4706
# 	Mean_test_accuracy: 0.4533 	Mean_test_accuracy_sum: 0.3600
# Epoch: 13 	Total: 608.5116 	Mean_train_accuracy: 0.4606
# 	Mean_test_accuracy: 0.4550 	Mean_test_accuracy_sum: 0.3600
# Epoch: 14 	Total: 600.2505 	Mean_train_accuracy: 0.4615
# 	Mean_test_accuracy: 0.4750 	Mean_test_accuracy_sum: 0.3600
# Epoch: 15 	Total: 592.2226 	Mean_train_accuracy: 0.4833
# 	Mean_test_accuracy: 0.4733 	Mean_test_accuracy_sum: 0.3600
# Epoch: 16 	Total: 584.3229 	Mean_train_accuracy: 0.4727
# 	Mean_test_accuracy: 0.4642 	Mean_test_accuracy_sum: 0.3600
# Epoch: 17 	Total: 577.4050 	Mean_train_accuracy: 0.4729
# 	Mean_test_accuracy: 0.4783 	Mean_test_accuracy_sum: 0.3600
# Epoch: 18 	Total: 569.4704 	Mean_train_accuracy: 0.4712
# 	Mean_test_accuracy: 0.4608 	Mean_test_accuracy_sum: 0.3600
# Epoch: 19 	Total: 563.2466 	Mean_train_accuracy: 0.4790
# 	Mean_test_accuracy: 0.4742 	Mean_test_accuracy_sum: 0.3600
# Epoch: 20 	Total: 557.6292 	Mean_train_accuracy: 0.4792
# 	Mean_test_accuracy: 0.4733 	Mean_test_accuracy_sum: 0.3600
# Epoch: 21 	Total: 552.7551 	Mean_train_accuracy: 0.4677
# 	Mean_test_accuracy: 0.4458 	Mean_test_accuracy_sum: 0.3600
# Epoch: 22 	Total: 546.8137 	Mean_train_accuracy: 0.4704
# 	Mean_test_accuracy: 0.4533 	Mean_test_accuracy_sum: 0.3600
# Epoch: 23 	Total: 542.3128 	Mean_train_accuracy: 0.4750
# 	Mean_test_accuracy: 0.4642 	Mean_test_accuracy_sum: 0.3600
# Epoch: 24 	Total: 538.0420 	Mean_train_accuracy: 0.4729
# 	Mean_test_accuracy: 0.4817 	Mean_test_accuracy_sum: 0.3600
# Epoch: 25 	Total: 534.1721 	Mean_train_accuracy: 0.4852
# 	Mean_test_accuracy: 0.4717 	Mean_test_accuracy_sum: 0.3600
# Epoch: 26 	Total: 531.1133 	Mean_train_accuracy: 0.4806
# 	Mean_test_accuracy: 0.4792 	Mean_test_accuracy_sum: 0.3600
# Epoch: 27 	Total: 527.1877 	Mean_train_accuracy: 0.4785
# 	Mean_test_accuracy: 0.4642 	Mean_test_accuracy_sum: 0.3600
# Epoch: 28 	Total: 525.2056 	Mean_train_accuracy: 0.4731
# 	Mean_test_accuracy: 0.4583 	Mean_test_accuracy_sum: 0.3600
# Epoch: 29 	Total: 523.0539 	Mean_train_accuracy: 0.4775
# 	Mean_test_accuracy: 0.4500 	Mean_test_accuracy_sum: 0.3600
# Epoch: 30 	Total: 522.5985 	Mean_train_accuracy: 0.4815
# 	Mean_test_accuracy: 0.4633 	Mean_test_accuracy_sum: 0.3600
# Epoch: 31 	Total: 519.2845 	Mean_train_accuracy: 0.4763
# 	Mean_test_accuracy: 0.4708 	Mean_test_accuracy_sum: 0.3600
# Epoch: 32 	Total: 516.8231 	Mean_train_accuracy: 0.4694
# 	Mean_test_accuracy: 0.4708 	Mean_test_accuracy_sum: 0.3600
# Epoch: 33 	Total: 515.6685 	Mean_train_accuracy: 0.4658
# 	Mean_test_accuracy: 0.4583 	Mean_test_accuracy_sum: 0.3600
# Epoch: 34 	Total: 514.1089 	Mean_train_accuracy: 0.4571
# 	Mean_test_accuracy: 0.4825 	Mean_test_accuracy_sum: 0.3600
# Epoch: 35 	Total: 512.9096 	Mean_train_accuracy: 0.4690
# 	Mean_test_accuracy: 0.4592 	Mean_test_accuracy_sum: 0.3600
# Epoch: 36 	Total: 511.6156 	Mean_train_accuracy: 0.4758
# 	Mean_test_accuracy: 0.4817 	Mean_test_accuracy_sum: 0.3600
# Epoch: 37 	Total: 510.9087 	Mean_train_accuracy: 0.4667
# 	Mean_test_accuracy: 0.4617 	Mean_test_accuracy_sum: 0.3600
# Epoch: 38 	Total: 509.5483 	Mean_train_accuracy: 0.4773
# 	Mean_test_accuracy: 0.4525 	Mean_test_accuracy_sum: 0.3600
# Epoch: 39 	Total: 509.6038 	Mean_train_accuracy: 0.4683
# 	Mean_test_accuracy: 0.4650 	Mean_test_accuracy_sum: 0.3600
# Epoch: 40 	Total: 508.5479 	Mean_train_accuracy: 0.4685
# 	Mean_test_accuracy: 0.4675 	Mean_test_accuracy_sum: 0.3600
# Epoch: 41 	Total: 507.9923 	Mean_train_accuracy: 0.4706
# 	Mean_test_accuracy: 0.4650 	Mean_test_accuracy_sum: 0.3600
# Epoch: 42 	Total: 507.6284 	Mean_train_accuracy: 0.4731
# 	Mean_test_accuracy: 0.4667 	Mean_test_accuracy_sum: 0.3600
# Epoch: 43 	Total: 506.7849 	Mean_train_accuracy: 0.4729
# 	Mean_test_accuracy: 0.4700 	Mean_test_accuracy_sum: 0.3600
# Epoch: 44 	Total: 506.0909 	Mean_train_accuracy: 0.4652
# 	Mean_test_accuracy: 0.4633 	Mean_test_accuracy_sum: 0.3600
# Epoch: 45 	Total: 505.7040 	Mean_train_accuracy: 0.4785
# 	Mean_test_accuracy: 0.4792 	Mean_test_accuracy_sum: 0.3600
# Epoch: 46 	Total: 505.4492 	Mean_train_accuracy: 0.4758
# 	Mean_test_accuracy: 0.4625 	Mean_test_accuracy_sum: 0.3600
# Epoch: 47 	Total: 504.4354 	Mean_train_accuracy: 0.4725
# 	Mean_test_accuracy: 0.4633 	Mean_test_accuracy_sum: 0.3600
# Epoch: 48 	Total: 503.4621 	Mean_train_accuracy: 0.4702
# 	Mean_test_accuracy: 0.4733 	Mean_test_accuracy_sum: 0.3600
# Epoch: 49 	Total: 504.1588 	Mean_train_accuracy: 0.4702
# 	Mean_test_accuracy: 0.4583 	Mean_test_accuracy_sum: 0.3600
# Epoch: 50 	Total: 504.0858 	Mean_train_accuracy: 0.4683
# 	Mean_test_accuracy: 0.4567 	Mean_test_accuracy_sum: 0.3600
# Epoch: 51 	Total: 502.0610 	Mean_train_accuracy: 0.4804
# 	Mean_test_accuracy: 0.4700 	Mean_test_accuracy_sum: 0.3600
# Epoch: 52 	Total: 503.6790 	Mean_train_accuracy: 0.4785
# 	Mean_test_accuracy: 0.4733 	Mean_test_accuracy_sum: 0.3600
# Epoch: 53 	Total: 502.6503 	Mean_train_accuracy: 0.4694
# 	Mean_test_accuracy: 0.4558 	Mean_test_accuracy_sum: 0.3600
# Epoch: 54 	Total: 502.7131 	Mean_train_accuracy: 0.4721
# 	Mean_test_accuracy: 0.4650 	Mean_test_accuracy_sum: 0.3600
# Epoch: 55 	Total: 502.7660 	Mean_train_accuracy: 0.4777
# 	Mean_test_accuracy: 0.4558 	Mean_test_accuracy_sum: 0.3600
# Epoch: 56 	Total: 501.8737 	Mean_train_accuracy: 0.4635
# 	Mean_test_accuracy: 0.4658 	Mean_test_accuracy_sum: 0.3600
# Epoch: 57 	Total: 501.4156 	Mean_train_accuracy: 0.4767
# 	Mean_test_accuracy: 0.4700 	Mean_test_accuracy_sum: 0.3600
# Epoch: 58 	Total: 501.4662 	Mean_train_accuracy: 0.4854
# 	Mean_test_accuracy: 0.4642 	Mean_test_accuracy_sum: 0.3600
# Epoch: 59 	Total: 499.3094 	Mean_train_accuracy: 0.4840
# 	Mean_test_accuracy: 0.4675 	Mean_test_accuracy_sum: 0.3600
# Epoch: 60 	Total: 499.5021 	Mean_train_accuracy: 0.4783
# 	Mean_test_accuracy: 0.4650 	Mean_test_accuracy_sum: 0.3600
# Epoch: 61 	Total: 498.9764 	Mean_train_accuracy: 0.4748
# 	Mean_test_accuracy: 0.4742 	Mean_test_accuracy_sum: 0.3600
# Epoch: 62 	Total: 498.1789 	Mean_train_accuracy: 0.4931
# 	Mean_test_accuracy: 0.4775 	Mean_test_accuracy_sum: 0.3600
# Epoch: 63 	Total: 498.2808 	Mean_train_accuracy: 0.4823
# 	Mean_test_accuracy: 0.4792 	Mean_test_accuracy_sum: 0.3600
# Epoch: 64 	Total: 496.3215 	Mean_train_accuracy: 0.4775
# 	Mean_test_accuracy: 0.4892 	Mean_test_accuracy_sum: 0.3600
# Epoch: 65 	Total: 497.5000 	Mean_train_accuracy: 0.4971
# 	Mean_test_accuracy: 0.4833 	Mean_test_accuracy_sum: 0.3600
# Epoch: 66 	Total: 496.1499 	Mean_train_accuracy: 0.4729
# 	Mean_test_accuracy: 0.4717 	Mean_test_accuracy_sum: 0.3600
# Epoch: 67 	Total: 496.3920 	Mean_train_accuracy: 0.4798
# 	Mean_test_accuracy: 0.4700 	Mean_test_accuracy_sum: 0.3600
# Epoch: 68 	Total: 496.8791 	Mean_train_accuracy: 0.4737
# 	Mean_test_accuracy: 0.4817 	Mean_test_accuracy_sum: 0.3600
# Epoch: 69 	Total: 493.8991 	Mean_train_accuracy: 0.4848
# 	Mean_test_accuracy: 0.4783 	Mean_test_accuracy_sum: 0.3600
# Epoch: 70 	Total: 494.4835 	Mean_train_accuracy: 0.4881
# 	Mean_test_accuracy: 0.4867 	Mean_test_accuracy_sum: 0.3600
# Epoch: 71 	Total: 495.4002 	Mean_train_accuracy: 0.4817
# 	Mean_test_accuracy: 0.4717 	Mean_test_accuracy_sum: 0.3600
# Epoch: 72 	Total: 494.8989 	Mean_train_accuracy: 0.4760
# 	Mean_test_accuracy: 0.4658 	Mean_test_accuracy_sum: 0.3600
# Epoch: 73 	Total: 493.4659 	Mean_train_accuracy: 0.4758
# 	Mean_test_accuracy: 0.4725 	Mean_test_accuracy_sum: 0.3600
# Epoch: 74 	Total: 494.2460 	Mean_train_accuracy: 0.4965
# 	Mean_test_accuracy: 0.4683 	Mean_test_accuracy_sum: 0.3600
# Epoch: 75 	Total: 493.7637 	Mean_train_accuracy: 0.4798
# 	Mean_test_accuracy: 0.4775 	Mean_test_accuracy_sum: 0.3600
# Epoch: 76 	Total: 493.8602 	Mean_train_accuracy: 0.4708
# 	Mean_test_accuracy: 0.4783 	Mean_test_accuracy_sum: 0.3600
# Epoch: 77 	Total: 493.2291 	Mean_train_accuracy: 0.4921
# 	Mean_test_accuracy: 0.4817 	Mean_test_accuracy_sum: 0.3600
# Epoch: 78 	Total: 493.3639 	Mean_train_accuracy: 0.4852
# 	Mean_test_accuracy: 0.4800 	Mean_test_accuracy_sum: 0.3600
# Epoch: 79 	Total: 493.6329 	Mean_train_accuracy: 0.4729
# 	Mean_test_accuracy: 0.4642 	Mean_test_accuracy_sum: 0.3600
# Epoch: 80 	Total: 493.6683 	Mean_train_accuracy: 0.4854
# 	Mean_test_accuracy: 0.4758 	Mean_test_accuracy_sum: 0.3600
# Epoch: 81 	Total: 496.1664 	Mean_train_accuracy: 0.4819
# 	Mean_test_accuracy: 0.4692 	Mean_test_accuracy_sum: 0.3600
# Epoch: 82 	Total: 491.3726 	Mean_train_accuracy: 0.4948
# 	Mean_test_accuracy: 0.4650 	Mean_test_accuracy_sum: 0.3600
# Epoch: 83 	Total: 492.0282 	Mean_train_accuracy: 0.4900
# 	Mean_test_accuracy: 0.4725 	Mean_test_accuracy_sum: 0.3600
# Epoch: 84 	Total: 492.5688 	Mean_train_accuracy: 0.4940
# 	Mean_test_accuracy: 0.4750 	Mean_test_accuracy_sum: 0.3600
# Epoch: 85 	Total: 492.5312 	Mean_train_accuracy: 0.4775
# 	Mean_test_accuracy: 0.4717 	Mean_test_accuracy_sum: 0.3600
# Epoch: 86 	Total: 491.5474 	Mean_train_accuracy: 0.4904
# 	Mean_test_accuracy: 0.4758 	Mean_test_accuracy_sum: 0.3600
# Epoch: 87 	Total: 489.9483 	Mean_train_accuracy: 0.4856
# 	Mean_test_accuracy: 0.4683 	Mean_test_accuracy_sum: 0.3600
